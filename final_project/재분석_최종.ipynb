# %% [markdown]
# # 구글

# %%
import os
import zipfile
import pandas as pd
from transformers import ElectraForSequenceClassification, AutoTokenizer, ElectraConfig
import torch

# 1. 모델 로드 및 초기화
zip_path = 'C:/fintech_service/final_project/saved_model_KcELECTRA-base.zip'
extract_path = 'C:/fintech_service/final_project/saved_model_KcELECTRA-base'

if not os.path.exists(extract_path):  # 이미 압축이 풀려있는지 확인
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

model_path = 'C:/fintech_service/final_project/saved_model_KcELECTRA-base/saved_model'
config = ElectraConfig.from_pretrained(model_path)
model = ElectraForSequenceClassification.from_pretrained(model_path, config=config)
tokenizer = AutoTokenizer.from_pretrained(model_path)
model.eval()  # 평가 모드로 설정

# 2. 감성 분석 함수 정의
def predict_sentiment(text):
    if not isinstance(text, str):
        return "알 수 없음"  # 문자열이 아닌 경우 기본값 반환
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
    outputs = model(**inputs)
    prediction = torch.argmax(outputs.logits, dim=1).item()
    return "긍정적" if prediction == 1 else "부정적"

def reanalyze_if_negative(sentiment, text):
    if sentiment == "부정적":
        # 부정적으로 판별된 경우에만 재분석 수행
        second_prediction = predict_sentiment(text)
        return second_prediction  # "긍정적" 또는 "부정적" 반환
    # 부정적이지 않은 경우 원래 값을 그대로 유지
    return sentiment

# 3. 입력/출력 폴더 설정
input_folder = "C:/fintech_service/final_project/data/리뷰추출/구글분석후"
output_folder = "C:/fintech_service/final_project/data/리뷰추출/구글재분석"

# 출력 폴더가 없으면 생성
os.makedirs(output_folder, exist_ok=True)

# 4. 입력 폴더의 모든 CSV 파일에 대해 재분석 수행
csv_files = [file for file in os.listdir(input_folder) if file.endswith('.csv')]

for csv_file in csv_files:
    input_path = os.path.join(input_folder, csv_file)
    output_path = os.path.join(output_folder, f"{os.path.splitext(csv_file)[0]}_재분석.csv")
    
    try:
        # CSV 파일 읽기
        df = pd.read_csv(input_path)
        
        # 문자열이 아닌 값(NaN 등)을 제거
        df = df.dropna(subset=['Review'])
        
        # 부정적으로 판별된 리뷰에 대해 재분석
        if 'sentiment' in df.columns:
            df['Sentiment2'] = df.apply(lambda row: reanalyze_if_negative(row['sentiment'], row['Review']), axis=1)
        else:
            print(f"'sentiment' 컬럼이 없습니다: {csv_file}")
            continue
        
        # 결과 저장
        df.to_csv(output_path, index=False)
        print(f"파일 저장 완료: {output_path}")
    
    except Exception as e:
        print(f"파일 처리 중 오류 발생 ({csv_file}): {e}")

print("모든 파일 재분석 완료!")
# Out:
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\고가네철판불백_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\고래똥_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\고불초쌈밥_2호점_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\곰바로곰탕_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\곰작골나주곰탕_역삼초교점_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\교토일식_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\궁민김밥_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\깡돈_강남대로_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\낙여삼_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\노브랜드버거_뱅뱅사거리점_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\다돈식당_도곡동_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\다슬음_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\돼지벅스_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\두두돼지불백_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\두메_도곡점_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\또봉이통닭_서울도곡점_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\뚜레쥬르_뱅뱅사거리점_도곡동_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\라망드쉐프_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\리첸_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\만복회해산물_뱅뱅사거리점_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\맥도날드_서초뱅뱅점_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\맥켄치킨_강남대로_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\명동할머니국수_뱅뱅사거리점_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\무화잠_강남점_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\문화시민_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\뱅뱅막국수_역삼본점_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\버드나무집_서초동본점_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\봉평착한메밀_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\봉피양_양재점_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\브라운돈까스_양재_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\사람사는고깃집김일도_뱅뱅점_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\사천루_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\서초남순남순대국_본점_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\소뭉집_본점_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\스노우폭스_뱅뱅점_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\시원한대구탕_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\아티제_강남유니온센터점_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\아티제_뱅뱅사거리점_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\엄마손맛집밥세로방_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\에슬로우커피_뱅뱅사거리점_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\에이림커피_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\영이네추억의떡볶이_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\예당_도곡동_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\오로스트커피_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\원할매이모네닭한마리_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\월참치_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\장수촌풍천장어_도곡동_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\전주피순대_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\조순금닭도리탕_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\중화카츠_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\지우네_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\짜짜루_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\참족_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\카린지린가네스낵바_뱅뱅사거리점_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\칸꼬시_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\큐뮬러스_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\통돼지_두루치기김치찌개_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\파라노이드_강남뱅뱅_카페_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\파리바게뜨_뱅뱅사거리점_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\파스쿠찌_뱅뱅사거리점_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\판문점부대찌개_역삼점_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\한강수_정육식당_reviews_google_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/구글재분석\회춘식당_reviews_google_분석_재분석.csv
# 모든 파일 재분석 완료!

# %% [markdown]
# # 카카오

# %%
import os
import zipfile
import pandas as pd
from transformers import ElectraForSequenceClassification, AutoTokenizer, ElectraConfig
import torch

# 1. 모델 로드 및 초기화
zip_path = 'C:/fintech_service/final_project/saved_model_KcELECTRA-base.zip'
extract_path = 'C:/fintech_service/final_project/saved_model_KcELECTRA-base'

if not os.path.exists(extract_path):  # 이미 압축이 풀려있는지 확인
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

model_path = 'C:/fintech_service/final_project/saved_model_KcELECTRA-base/saved_model'
config = ElectraConfig.from_pretrained(model_path)
model = ElectraForSequenceClassification.from_pretrained(model_path, config=config)
tokenizer = AutoTokenizer.from_pretrained(model_path)
model.eval()  # 평가 모드로 설정

# 2. 감성 분석 함수 정의
def predict_sentiment(text):
    if not isinstance(text, str):
        return "알 수 없음"  # 문자열이 아닌 경우 기본값 반환
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
    outputs = model(**inputs)
    prediction = torch.argmax(outputs.logits, dim=1).item()
    return "긍정적" if prediction == 1 else "부정적"

def reanalyze_if_negative(sentiment, text):
    if sentiment == "부정적":
        # 부정적으로 판별된 경우에만 재분석 수행
        second_prediction = predict_sentiment(text)
        return second_prediction  # "긍정적" 또는 "부정적" 반환
    # 부정적이지 않은 경우 원래 값을 그대로 유지
    return sentiment

# 3. 입력/출력 폴더 설정
input_folder = "C:/fintech_service/final_project/data/리뷰추출/카카오분석후"
output_folder = "C:/fintech_service/final_project/data/리뷰추출/카카오재분석"

# 출력 폴더가 없으면 생성
os.makedirs(output_folder, exist_ok=True)

# 4. 입력 폴더의 모든 CSV 파일에 대해 재분석 수행
csv_files = [file for file in os.listdir(input_folder) if file.endswith('.csv')]

for csv_file in csv_files:
    input_path = os.path.join(input_folder, csv_file)
    output_path = os.path.join(output_folder, f"{os.path.splitext(csv_file)[0]}_재분석.csv")
    
    try:
        # CSV 파일 읽기
        df = pd.read_csv(input_path)
        
        # 문자열이 아닌 값(NaN 등)을 제거
        df = df.dropna(subset=['Review'])
        
        # 부정적으로 판별된 리뷰에 대해 재분석
        if 'sentiment' in df.columns:
            df['Sentiment2'] = df.apply(lambda row: reanalyze_if_negative(row['sentiment'], row['Review']), axis=1)
        else:
            print(f"'sentiment' 컬럼이 없습니다: {csv_file}")
            continue
        
        # 결과 저장
        df.to_csv(output_path, index=False)
        print(f"파일 저장 완료: {output_path}")
    
    except Exception as e:
        print(f"파일 처리 중 오류 발생 ({csv_file}): {e}")

print("모든 파일 재분석 완료!")
# Out:
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\9CAFE_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\고가네철판불백_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\고래똥_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\고불초쌈밥_2호점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\고품격커피공장_뱅뱅사거리점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\곰바로곰탕_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\곰작골나주곰탕_역삼초교점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\교토일식_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\궁민김밥_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\깡돈_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\낙여삼_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\난타5000_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\남강매점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\노브랜드버거_뱅뱅사거리점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\다돈식당_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\다슬음_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\더벤티_뱅뱅사거리점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\더에이치_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\돼지벅스_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\두두돼지불백_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\두메_도곡점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\드시옹_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\또봉이통닭_도곡점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\뚜레쥬르_뱅뱅사거리점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\라망드쉐프_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\리첸_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\만복회해산물_뱅뱅사거리점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\맥도날드_서초뱅뱅점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\맥켄치킨_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\메종보탄_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\멜론_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\명동할머니국수_뱅뱅사거리점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\무화잠_강남점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\문화시민_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\뱅뱅막국수_역삼본점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\버드나무집_서초본점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\봉구스밥버거_역삼삼일점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\봉평착한메밀_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\봉피양_양재점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\북경반점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\브라운돈까스_뱅뱅사거리점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\비채_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\사람사는고깃집김일도_뱅뱅점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\사천루_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\샵5827_에스프레소_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\서초골_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\서초남순남순대국_본점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\세로방_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\소뭉집_본점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\스노우폭스_뱅뱅점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\스타벅스_서초태우빌딩점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\시원한대구탕_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\썸_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\아워948_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\아티제_강남유니온센터점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\아티제_뱅뱅사거리점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\어가람_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\엄마손맛집밥세로방_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\에슬로우커피_뱅뱅사거리점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\에이림커피_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\영이네추억의떡볶이_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\예당_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\오늘은_어떤닭_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\오로스트커피_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\오아시스_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\왕산골_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\우심터_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\원할매이모네닭한마리_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\월참치_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\웰니스_쌀빵_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\유니마카롱_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\이천쌀밥_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\잇풀키토김밥_샌드위치_샐러드_강남점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\장수촌풍천장어_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\전주피순대_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\조순금닭도리탕_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\중화카츠_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\지우네_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\짜짜루_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\참족_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\청담배짱이_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\카린지린가네스낵바_뱅뱅사거리점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\카페S_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\카페블랑131_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\칸꼬시_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\커피박스_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\커피콩스토리_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\쿡쿡쿡_뱅뱅사거리점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\큐뮬러스_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\통돼지_두루치기김치찌개_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\파라노이드_강남뱅뱅_카페_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\파리바게뜨_뱅뱅사거리점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\파스쿠찌_뱅뱅사거리점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\파스타엔포크_강남역삼점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\판문점부대찌개_역삼점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\한강수_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\해머스미스커피_뱅뱅사거리점_reviews_kakao_분석_재분석.csv
# 파일 저장 완료: C:/fintech_service/final_project/data/리뷰추출/카카오재분석\회춘식당_reviews_kakao_분석_재분석.csv
# 모든 파일 재분석 완료!
