# %% [markdown]
# # 1. pandas
# ## pandas의 특징
# ### pandas의 특징
# * Numpy를 내부적으로 활용함(numpy의 특징을 그대로 가짐)
# * 데이터 분석에 특화된 데이터 구조 제공
# * 다양한 데이터 분석 함수 제공
# * 데이터베이스에 쉽게 연결 가능
# * json데이터나 table요소를 데이터프레임으로 손쉽게 변형 가능

# %%
# 설치
# !pip install pandas
# !conda install pandas

# %% [markdown]
# # 2. Pandas에서 다루는 데이터 타입
# ## 1) DataFrame: 2차원의 표형식 데이터  => key : [ value1, value2 ]
# ## 2) Series: 1차원의 벡터형식 데이터  => list, tuple, ndarray

# %%
import pandas as pd

# %%
df = pd.DataFrame(
    {'이름': ['홍길동', '장마철', '소나기', '더워요'],
     'Age' : [23, 55, 24, 16],
     '성별': ['male', 'female', 'female', 'male']}
)
display(df)
print(type(df))
print(df)
print(df.shape)
# Out:
#     이름  Age      성별
# 0  홍길동   23    male
# 1  장마철   55  female
# 2  소나기   24  female
# 3  더워요   16    male
# <class 'pandas.core.frame.DataFrame'>
#     이름  Age      성별
# 0  홍길동   23    male
# 1  장마철   55  female
# 2  소나기   24  female
# 3  더워요   16    male
# (4, 3)

# %%
display(df['이름'])
print(type(df['이름']))
print(df['이름'].shape)
print(df['이름'].ndim)
print()
display(df[['이름']])
print(type(df[['이름']]))
print(df[['이름']].shape)
print(df[['이름']].ndim)
# Out:
# 0    홍길동
# 1    장마철
# 2    소나기
# 3    더워요
# Name: 이름, dtype: object
# <class 'pandas.core.series.Series'>
# (4,)
# 1
#     이름
# 0  홍길동
# 1  장마철
# 2  소나기
# 3  더워요
# <class 'pandas.core.frame.DataFrame'>
# (4, 1)
# 2

# %% [markdown]
# ## 시리즈 만들기 pd.Series([리스트자료], name='컬럼명')
# * 이름을 가지고 있는 벡터

# %%
ages = pd.Series([22, 35, 58], name="Age")
ages
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
ages[1:]
# Out:
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
ages.max()
# Out:
# np.int64(58)

# %%
ages.min()
# Out:
# np.int64(22)

# %%
ages.sum()
# Out:
# np.int64(115)

# %%
ages.mean()
# Out:
# np.float64(38.333333333333336)

# %%
ages.median()
# Out:
# np.float64(35.0)

# %%
ages.describe()
# Out:
# count     3.000000
# mean     38.333333
# std      18.230012
# min      22.000000
# 25%      28.500000
# 50%      35.000000
# 75%      46.500000
# max      58.000000
# Name: Age, dtype: float64

# %%
ages.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3 entries, 0 to 2
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 3 non-null      int64
# dtypes: int64(1)
# memory usage: 152.0 bytes

# %% [markdown]
# # 판다스에서 자료 불러오기, 저장하기
# * csv, tsv, excel, json, html
# * pd.read_확장자

# %%
# !pip install openpyxl

# %%
df1 = pd.read_excel("./data/Online Retail.xlsx")
df1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df2 = pd.read_excel("./data/아파트(매매)_실거래가_20240806113828.xlsx", header=12, index_col=0)
df2.head(13)
# Out:
# C:\Users\5-04\miniforge3\envs\fintech\lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                     시군구      번지    본번   부번                단지명   전용면적(㎡)  \
# NO
# 1      서울특별시 영등포구 당산동5가      42    42    0          당산삼성래미안4차  115.7800
# 2   강원특별자치도 원주시 지정면 가곡리    1512  1512    0  원주롯데캐슬골드파크1차(5단지)   84.9644
# 3     대구광역시 달성군 화원읍 구라리    1650  1650    0             대곡역래미안   84.5958
# 4          광주광역시 남구 진월동   312-7   312    7                 광명   70.6250
# 5          광주광역시 남구 진월동  331-93   331   93                 중흥   84.8400
# 6       경기도 양평군 양평읍 양근리   140-5   140    5               양평현대   59.7000
# 7        서울특별시 동대문구 장안동     587   587    0         동대문더퍼스트데시앙   59.8074
# 8     대구광역시 달성군 화원읍 천내리   690-1   690    1        화원파크뷰우방아이유쉘   69.6413
# 9   충청남도 천안시서북구 성거읍 신월리    2-26     2   26            천안삼환나우빌   84.9132
# ...

# %% [markdown]
# CSV 파일 읽기 pd.read_csv(파일명, 옵션), tsv

# %%
df3 = pd.read_csv("./data/06고객이탈예측.csv", encoding="cp949")
df3
# Out:
#             회원ID      성별  고연령  배우자 피부양자  가입기간 전화서비스             2회선이상  \
# 0     7590-VHVEG  Female    0  Yes   No     1    No  No phone service
# 1     5575-GNVDE    Male    0   No   No    34   Yes                No
# 2     3668-QPYBK    Male    0   No   No     2   Yes                No
# 3     7795-CFOCW    Male    0   No   No    45    No  No phone service
# 4     9237-HQITU  Female    0   No   No     2   Yes                No
# ...          ...     ...  ...  ...  ...   ...   ...               ...
# 7038  6840-RESVB    Male    0  Yes  Yes    24   Yes               Yes
# 7039  2234-XADUH  Female    0  Yes  Yes    72   Yes               Yes
# 7040  4801-JZAZL  Female    0  Yes  Yes    11    No  No phone service
# 7041  8361-LTMKD    Male    1  Yes   No     4   Yes               Yes
# 7042  3186-AJIEK    Male    0   No   No    66   Yes                No
#
#            인터넷서비스 온라인보안  ... 기기보호서비스 기술지원 스트리밍TV 스트리밍Movies            약정옵션  \
# ...

# %% [markdown]
# json 파일 읽기

# %%
df4 = pd.read_json("./data/Chicken_shops", encoding='cp949')
df4
# Out:
# C:\Users\5-04\AppData\Local\Temp\ipykernel_12616\1533141347.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df4 = pd.read_json("./data/Chicken_shops", encoding='cp949')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 df4 = pd.read_json("./data/Chicken_shops", encoding='cp949')
#       2 df4
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\io\json\_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# ...

# %% [markdown]
# html 파일읽기 pd.read_html

# %%
df5 = pd.read_html("./data/corpList.htm")
df5[0]

# %%
import os
import pandas as pd
from sqlalchemy import create_engine
import pymysql
from dotenv import load_dotenv
pymysql.install_as_MySQLdb()
load_dotenv(dotenv_path="../05_data_scraping/.env_db")
# Out:
# True

# %%
# mysql에서 테이블 불러오기
engine = create_engine(f"{os.getenv('db')}+{os.getenv('dbtype')}://{os.getenv('id')}:{os.getenv('pw')}@{os.getenv('host')}/{os.getenv('database')}")
conn = engine.connect()
data_07 = pd.read_sql('2024_07_stock_price_info', con=conn)
data_08 = pd.read_sql('2024_08_stock_price_info', con=conn)
conn.close()

# %%
data_07.head(2)
# Out:
#           수집일          회사명    종목코드    현재가   변동금액    변화율     전일     고가  \
# 0  2024-07-30        산일전기   062040  55500   5300  10.56  50200  61300
# 1  2024-07-30    에이치에스효성    487570  65700  16900 -20.46  82600  75900
#
#         거래량     시가     저가    거래대금
# 0  12682123  55200  50900  718098
# 1    372304  75400  64800   26079

# %%
data_08.head(2)
# Out:
#           수집일          회사명    종목코드    현재가  변동금액   변화율     전일     고가      거래량  \
# 0  2024-08-01        산일전기   062040  52100  1800  3.58  50300  57900  4183944
# 1  2024-08-01    에이치에스효성    487570  60100  3700 -5.80  63800  64200   137655
#
#       시가     저가    거래대금
# 0  54300  52100  231492
# 1  63500  59400    8439

# %%
df6 = pd.read_json("./data/서울특별시_관광지입장정보_2011_2016.json")
df6
# Out:
#     ForNum  NatNum  addrCd gungu      resNm  rnum   sido  yyyymm
# 0    44722   75991    1111   종로구        창덕궁     1  서울특별시  201112
# 1        0   11017    1111   종로구        운현궁     2  서울특별시  201112
# 2   132399  237330    1111   종로구        경복궁     3  서울특별시  201112
# 3     3133   21267    1111   종로구        창경궁     4  서울특별시  201112
# 4    18226   24223    1111   종로구         종묘     5  서울특별시  201112
# ..     ...     ...     ...   ...        ...   ...    ...     ...
# 62    5588   44232    1141  서대문구  서대문형무소역사관     8  서울특별시  201512
# 63       0   22587    1141  서대문구  서대문자연사박물관     9  서울특별시  201512
# 64   29520    8822    1144   마포구    트릭아이미술관    10  서울특별시  201512
# 65       3    1647    1165   서초구      헌릉ㆍ인릉    11  서울특별시  201512
# 66     492   14454    1168   강남구      선릉·정릉    12  서울특별시  201512
#
# [67 rows x 8 columns]

# %%
# mysql에서 테이블 불러오기
engine = create_engine(f"{os.getenv('db')}+{os.getenv('dbtype')}://{os.getenv('id')}:{os.getenv('pw')}@{os.getenv('host')}/{os.getenv('database')}")
conn = engine.connect()
data_07 = pd.read_sql('2024_07_stock_price_info', con=conn)
data_08 = pd.read_sql('2024_08_stock_price_info', con=conn)
conn.close()

# %%
data_07.head(2)
# Out:
#           수집일          회사명    종목코드    현재가   변동금액    변화율     전일     고가  \
# 0  2024-07-30        산일전기   062040  55500   5300  10.56  50200  61300
# 1  2024-07-30    에이치에스효성    487570  65700  16900 -20.46  82600  75900
#
#         거래량     시가     저가    거래대금
# 0  12682123  55200  50900  718098
# 1    372304  75400  64800   26079

# %%
data_08.head(2)
# Out:
#           수집일          회사명    종목코드    현재가  변동금액   변화율     전일     고가      거래량  \
# 0  2024-08-01        산일전기   062040  52100  1800  3.58  50300  57900  4183944
# 1  2024-08-01    에이치에스효성    487570  60100  3700 -5.80  63800  64200   137655
#
#       시가     저가    거래대금
# 0  54300  52100  231492
# 1  63500  59400    8439

# %% [markdown]
# ## mysql titanic DB에서 passenger, surv, ticket 테이블 로드

# %%
# mysql에서 테이블 불러오기
engine = create_engine(f"{os.getenv('db')}+{os.getenv('dbtype')}://{os.getenv('id')}:{os.getenv('pw')}@{os.getenv('host')}/titanic")
conn = engine.connect()
passenger = pd.read_sql('passenger', con=conn)
surv = pd.read_sql('surv', con=conn)
ticket = pd.read_sql('ticket', con=conn)
conn.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # mysql에서 테이블 불러오기
# ----> 2 engine = create_engine(f"{os.getenv('db')}+{os.getenv('dbtype')}://{os.getenv('id')}:{os.getenv('pw')}@{os.getenv('host')}/titanic")
#       3 conn = engine.connect()
#       4 passenger = pd.read_sql('passenger', con=conn)
#
# NameError: name 'create_engine' is not defined

# %%
passenger
# Out:
#      PassengerId                                             Name     Sex  \
# 0            193  Andersen-Jensen, Miss. Carla Christine Nielsine  female
# 1            192                            Carbines, Mr. William    male
# 2            715                            Greenberg, Mr. Samuel    male
# 3            533                             Elias, Mr. Joseph Jr    male
# 4            133   Robins, Mrs. Alexander A (Grace Charity Laury)  female
# ..           ...                                              ...     ...
# 618          580                              Jussila, Mr. Eiriik    male
# 619          503                   O'Sullivan, Miss. Bridget Mary  female
# 620          538                              LeRoy, Miss. Bertha  female
# 621          197                              Mernagh, Mr. Robert    male
# 622          176                           Klasen, Mr. Klas Albin    male
#
#       Age  SibSp  Parch
# 0    19.0      1      0
# 1    19.0      0      0
# ...

# %%
surv
# Out:
#      PassengerId  Survived
# 0            762         0
# 1            665         1
# 2            809         0
# 3            332         0
# 4             21         0
# ..           ...       ...
# 441          698         1
# 442          778         1
# 443          157         1
# 444          350         0
# 445          881         1
#
# [446 rows x 2 columns]

# %%
ticket
# Out:
#      PassengerId         Ticket  Pclass      Fare    Cabin Embarked
# 0            486           4133       3   25.4667     None        S
# 1            119       PC 17558       1  247.5208  B58 B60        C
# 2            836       PC 17756       1   83.1583      E49        C
# 3            528       PC 17483       1  221.7792      C95        S
# 4            396         350052       3    7.7958     None        S
# ..           ...            ...     ...       ...      ...      ...
# 440          692         349256       3   13.4167     None        C
# 441          585           3411       3    8.7125     None        C
# 442          265         382649       3    7.7500     None        Q
# 443          328          28551       2   13.0000        D        S
# 444          136  SC/PARIS 2133       2   15.0458     None        C
#
# [445 rows x 6 columns]

# %% [markdown]
# # 3개의 데이터프레임을 1개로 합치기
# * join()
# * merge()
# * concat()

# %%
test1 = pd.concat([passenger, ticket, surv], axis=1)
test1.head()  # 젤 윗줄 5줄만 보는거임
# Out:
#    PassengerId                                             Name     Sex   Age  \
# 0          193  Andersen-Jensen, Miss. Carla Christine Nielsine  female  19.0
# 1          192                            Carbines, Mr. William    male  19.0
# 2          715                            Greenberg, Mr. Samuel    male  52.0
# 3          533                             Elias, Mr. Joseph Jr    male  17.0
# 4          133   Robins, Mrs. Alexander A (Grace Charity Laury)  female  47.0
#
#    SibSp  Parch  PassengerId    Ticket  Pclass      Fare    Cabin Embarked  \
# 0      1      0        486.0      4133     3.0   25.4667     None        S
# 1      0      0        119.0  PC 17558     1.0  247.5208  B58 B60        C
# 2      0      0        836.0  PC 17756     1.0   83.1583      E49        C
# 3      1      1        528.0  PC 17483     1.0  221.7792      C95        S
# 4      1      0        396.0    350052     3.0    7.7958     None        S
#
#    PassengerId  Survived
# ...

# %%
test2 = pd.merge(passenger, ticket, how='outer', on='PassengerId')
test2.head()
# Out:
#    PassengerId                                               Name     Sex  \
# 0            1                            Braund, Mr. Owen Harris    male
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2            3                             Heikkinen, Miss. Laina  female
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4            5                           Allen, Mr. William Henry    male
#
#     Age  SibSp  Parch            Ticket  Pclass    Fare Cabin Embarked
# 0  22.0    1.0    0.0         A/5 21171     3.0   7.250  None        S
# 1  38.0    1.0    0.0               NaN     NaN     NaN   NaN      NaN
# 2  26.0    0.0    0.0  STON/O2. 3101282     3.0   7.925  None        S
# 3  35.0    1.0    0.0            113803     1.0  53.100  C123        S
# 4  35.0    0.0    0.0            373450     3.0   8.050  None        S

# %%
test2
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 746          885                                                NaN     NaN
# 747          886               Rice, Mrs. William (Margaret Norton)  female
# 748          887                              Montvila, Rev. Juozas    male
# 749          888                       Graham, Miss. Margaret Edith  female
# 750          891                                                NaN     NaN
#
# ...

# %%
test3 = pd.merge(left=test2, right=surv,  how='outer', on='PassengerId')
test3
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889                                                NaN     NaN
# 889          890                                                NaN     NaN
# 890          891                                                NaN     NaN
#
# ...

# %%
passenger
# Out:
#      PassengerId                                             Name     Sex  \
# 0            193  Andersen-Jensen, Miss. Carla Christine Nielsine  female
# 1            192                            Carbines, Mr. William    male
# 2            715                            Greenberg, Mr. Samuel    male
# 3            533                             Elias, Mr. Joseph Jr    male
# 4            133   Robins, Mrs. Alexander A (Grace Charity Laury)  female
# ..           ...                                              ...     ...
# 618          580                              Jussila, Mr. Eiriik    male
# 619          503                   O'Sullivan, Miss. Bridget Mary  female
# 620          538                              LeRoy, Miss. Bertha  female
# 621          197                              Mernagh, Mr. Robert    male
# 622          176                           Klasen, Mr. Klas Albin    male
#
#       Age  SibSp  Parch
# 0    19.0      1      0
# 1    19.0      0      0
# ...

# %%
passenger = passenger.set_index('PassengerId')

# %%
passenger
# Out:
#                                                         Name     Sex   Age  \
# PassengerId
# 193          Andersen-Jensen, Miss. Carla Christine Nielsine  female  19.0
# 192                                    Carbines, Mr. William    male  19.0
# 715                                    Greenberg, Mr. Samuel    male  52.0
# 533                                     Elias, Mr. Joseph Jr    male  17.0
# 133           Robins, Mrs. Alexander A (Grace Charity Laury)  female  47.0
# ...                                                      ...     ...   ...
# 580                                      Jussila, Mr. Eiriik    male  32.0
# 503                           O'Sullivan, Miss. Bridget Mary  female   NaN
# 538                                      LeRoy, Miss. Bertha  female  30.0
# 197                                      Mernagh, Mr. Robert    male   NaN
# 176                                   Klasen, Mr. Klas Albin    male  18.0
#
#              SibSp  Parch
# PassengerId
# ...

# %%
ticket = ticket.set_index("PassengerId")
ticket
# Out:
#                     Ticket  Pclass      Fare    Cabin Embarked
# PassengerId
# 486                   4133       3   25.4667     None        S
# 119               PC 17558       1  247.5208  B58 B60        C
# 836               PC 17756       1   83.1583      E49        C
# 528               PC 17483       1  221.7792      C95        S
# 396                 350052       3    7.7958     None        S
# ...                    ...     ...       ...      ...      ...
# 692                 349256       3   13.4167     None        C
# 585                   3411       3    8.7125     None        C
# 265                 382649       3    7.7500     None        Q
# 328                  28551       2   13.0000        D        S
# 136          SC/PARIS 2133       2   15.0458     None        C
#
# [445 rows x 5 columns]

# %%
passenger.join(ticket)
# Out:
#                                                         Name     Sex   Age  \
# PassengerId
# 193          Andersen-Jensen, Miss. Carla Christine Nielsine  female  19.0
# 192                                    Carbines, Mr. William    male  19.0
# 715                                    Greenberg, Mr. Samuel    male  52.0
# 533                                     Elias, Mr. Joseph Jr    male  17.0
# 133           Robins, Mrs. Alexander A (Grace Charity Laury)  female  47.0
# ...                                                      ...     ...   ...
# 580                                      Jussila, Mr. Eiriik    male  32.0
# 503                           O'Sullivan, Miss. Bridget Mary  female   NaN
# 538                                      LeRoy, Miss. Bertha  female  30.0
# 197                                      Mernagh, Mr. Robert    male   NaN
# 176                                   Klasen, Mr. Klas Albin    male  18.0
#
# ...

# %% [markdown]
# ## 데이터 읽는 부분!

# %%
data = pd.read_csv("https://raw.githubusercontent.com/haram4th/ablearn/main/Taitanic_train.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 데이터프레임을 조회
# * 앞쪽 5개 행을 읽는 head()   head(행갯수)
# * 뒤쪽 5개 행을 읽는 tail()   tail(행갯수)

# %%
# head는 60을 넘어가면 자동 축약 출력
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
data.tail(1)
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 890          891         0       3  Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 890      0  370376  7.75   NaN        Q

# %% [markdown]
# # 데이터의 타입(자료형)을 보고 싶을 때 .dtypes

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # 데이터프레임의 컬럼명, 결측치, 데이터타입을 같이 표시 .info()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # 데이터프레임에서 숫자 데이터의 기초통계를 보는 함수 .describe()

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # 판다스에서 일부 자료만 추출하기

# %% [markdown]
# ## 1) 데이터프레임에서 1개 컬럼만 가져오기

# %%
data.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
display(data['Name'])
print(type(data['Name']))
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object
# <class 'pandas.core.series.Series'>

# %%
display(data.Name)
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# ## 2) 2개 이상의 컬럼 가져오기

# %%
# 2차원이여서 2개로 치는거임
data[['Name', 'Sex']]
# Out:
#                                                   Name     Sex
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
# [891 rows x 2 columns]

# %%
data[['Name', 'Sex', 'Pclass']]
# Out:
#                                                   Name     Sex  Pclass
# 0                              Braund, Mr. Owen Harris    male       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female       1
# 2                               Heikkinen, Miss. Laina  female       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       1
# 4                             Allen, Mr. William Henry    male       3
# ..                                                 ...     ...     ...
# 886                              Montvila, Rev. Juozas    male       2
# 887                       Graham, Miss. Margaret Edith  female       1
# 888           Johnston, Miss. Catherine Helen "Carrie"  female       3
# 889                              Behr, Mr. Karl Howell    male       1
# 890                                Dooley, Mr. Patrick    male       3
#
# [891 rows x 3 columns]

# %% [markdown]
# ## 데이터프레임 컬럼 순서바꾸기

# %%
data = data[['PassengerId','Pclass','Ticket','Name','Sex','Age','SibSp','Parch','Fare','Cabin','Embarked','Survived']]
data

# %%
data = data[['PassengerId','Pclass','Ticket','Name','Sex','Age','SibSp','Parch','Fare','Cabin','Embarked','Survived']]
data
# Out:
#      PassengerId  Pclass            Ticket  \
# 0              1       3         A/5 21171
# 1              2       1          PC 17599
# 2              3       3  STON/O2. 3101282
# 3              4       1            113803
# 4              5       3            373450
# ..           ...     ...               ...
# 886          887       2            211536
# 887          888       1            112053
# 888          889       3        W./C. 6607
# 889          890       1            111369
# 890          891       3            370376
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# ## 데이터프레임에서 일부 컬럼만 가져오기2
# * loc: 인덱스이름과 컬럼명으로 일부를 추출해서 가져옴
# * iloc: 슬라이싱을 이용해서 가져옴

# %%
data.loc[100:130,['Ticket','Name']]
# Out:
#                 Ticket                               Name
# 100             349245            Petranec, Miss. Matilda
# 101             349215   Petroff, Mr. Pastcho ("Pentcho")
# 102              35281          White, Mr. Richard Frasar
# 103               7540         Johansson, Mr. Gustaf Joel
# 104            3101276     Gustafsson, Mr. Anders Vilhelm
# 105             349207              Mionoff, Mr. Stoytcho
# 106             343120   Salkjelsvik, Miss. Anna Kristine
# 107             312991             Moss, Mr. Albert Johan
# 108             349249                    Rekic, Mr. Tido
# 109             371110                Moran, Miss. Bertha
# 110             110465     Porter, Mr. Walter Chamberlain
# 111               2665               Zabour, Miss. Hileni
# 112             324669             Barton, Mr. David John
# 113               4136            Jussila, Miss. Katriina
# 114               2627              Attalah, Miss. Malake
# ...

# %% [markdown]
# 원래는 130까지 쓰면 129까지 출력을 해오는데 loc는 130까지 다 뽑아온다

# %%
# 원래는 130까지 쓰면 129까지 출력을 해오는데 loc는 130까지 다 뽑아온다
data.loc[:130,['Ticket','Name']]
# Out:
#                Ticket                                               Name
# 0           A/5 21171                            Braund, Mr. Owen Harris
# 1            PC 17599  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2    STON/O2. 3101282                             Heikkinen, Miss. Laina
# 3              113803       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              373450                           Allen, Mr. William Henry
# ..                ...                                                ...
# 126            370372                                McMahon, Mr. Martin
# 127           C 17369                          Madsen, Mr. Fridtjof Arne
# 128              2668                                  Peter, Miss. Anna
# 129            347061                                 Ekstrom, Mr. Johan
# 130            349241                               Drazenoic, Mr. Jozef
#
# [131 rows x 2 columns]

# %%
data.loc[500:,['Ticket','Name']]
# Out:
#          Ticket                                      Name
# 500      315086                          Calic, Mr. Petar
# 501      364846                       Canavan, Miss. Mary
# 502      330909            O'Sullivan, Miss. Bridget Mary
# 503        4135            Laitinen, Miss. Kristina Sofia
# 504      110152                     Maioni, Miss. Roberta
# ..          ...                                       ...
# 886      211536                     Montvila, Rev. Juozas
# 887      112053              Graham, Miss. Margaret Edith
# 888  W./C. 6607  Johnston, Miss. Catherine Helen "Carrie"
# 889      111369                     Behr, Mr. Karl Howell
# 890      370376                       Dooley, Mr. Patrick
#
# [391 rows x 2 columns]

# %% [markdown]
# iloc는 20까지 쓰면 19까지 옴

# %%
data.iloc[10:20,4:8]
# Out:
#        Sex   Age  SibSp  Parch
# 10  female   4.0      1      1
# 11  female  58.0      0      0
# 12    male  20.0      0      0
# 13    male  39.0      1      5
# 14  female  14.0      0      0
# 15  female  55.0      0      0
# 16    male   2.0      4      1
# 17    male   NaN      0      0
# 18  female  31.0      1      0
# 19  female   NaN      0      0

# %%
data.iloc[:20,4:]
# Out:
#        Sex   Age  SibSp  Parch     Fare Cabin Embarked  Survived
# 0     male  22.0      1      0   7.2500   NaN        S         0
# 1   female  38.0      1      0  71.2833   C85        C         1
# 2   female  26.0      0      0   7.9250   NaN        S         1
# 3   female  35.0      1      0  53.1000  C123        S         1
# 4     male  35.0      0      0   8.0500   NaN        S         0
# 5     male   NaN      0      0   8.4583   NaN        Q         0
# 6     male  54.0      0      0  51.8625   E46        S         0
# 7     male   2.0      3      1  21.0750   NaN        S         0
# 8   female  27.0      0      2  11.1333   NaN        S         1
# 9   female  14.0      1      0  30.0708   NaN        C         1
# 10  female   4.0      1      1  16.7000    G6        S         1
# 11  female  58.0      0      0  26.5500  C103        S         1
# 12    male  20.0      0      0   8.0500   NaN        S         0
# ...

# %%
data.iloc[:20,:]
# Out:
#     PassengerId  Pclass            Ticket  \
# 0             1       3         A/5 21171
# 1             2       1          PC 17599
# 2             3       3  STON/O2. 3101282
# 3             4       1            113803
# 4             5       3            373450
# 5             6       3            330877
# 6             7       1             17463
# 7             8       3            349909
# 8             9       3            347742
# 9            10       2            237736
# 10           11       3           PP 9549
# 11           12       1            113783
# 12           13       3         A/5. 2151
# 13           14       3            347082
# 14           15       3            350406
# 15           16       2            248706
# 16           17       3            382652
# 17           18       2            244373
# 18           19       3            345763
# 19           20       3              2649
#
# ...

# %%
data.iloc[:20:2,::-1]
# Out:
#     Survived Embarked Cabin     Fare  Parch  SibSp   Age     Sex  \
# 0          0        S   NaN   7.2500      0      1  22.0    male
# 2          1        S   NaN   7.9250      0      0  26.0  female
# 4          0        S   NaN   8.0500      0      0  35.0    male
# 6          0        S   E46  51.8625      0      0  54.0    male
# 8          1        S   NaN  11.1333      2      0  27.0  female
# 10         1        S    G6  16.7000      1      1   4.0  female
# 12         0        S   NaN   8.0500      0      0  20.0    male
# 14         0        S   NaN   7.8542      0      0  14.0  female
# 16         0        Q   NaN  29.1250      1      4   2.0    male
# 18         0        S   NaN  18.0000      0      1  31.0  female
#
#                                                  Name            Ticket  \
# 0                             Braund, Mr. Owen Harris         A/5 21171
# 2                              Heikkinen, Miss. Laina  STON/O2. 3101282
# ...

# %% [markdown]
# # 특정 컬럼에서 유일값 요소 출력하기 .unique()

# %%
data['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
data['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %% [markdown]
# # 특정 컬럼에서 유일값 개수 출력 .nunique()

# %%
data['Name'].nunique()
# Out:
# 891

# %%
data['Embarked'].nunique()
# Out:
# 3

# %% [markdown]
# # 카테고리 컬럼에서 유일값 별 개수를 세는 함수 value_counts()

# %%
data['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
data['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
data['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# # 데이터를 정렬하는 함수 sort_values(by="컬럼명")

# %%
data.sort_values(by="Age", ascending=False)
# Out:
#      PassengerId  Pclass      Ticket  \
# 630          631       1       27042
# 851          852       3      347060
# 493          494       1    PC 17609
# 96            97       1    PC 17754
# 116          117       3      370369
# ..           ...     ...         ...
# 859          860       3        2629
# 863          864       3    CA. 2343
# 868          869       3      345777
# 878          879       3      349217
# 888          889       3  W./C. 6607
#
#                                          Name     Sex   Age  SibSp  Parch  \
# 630      Barkworth, Mr. Algernon Henry Wilson    male  80.0      0      0
# 851                       Svensson, Mr. Johan    male  74.0      0      0
# 493                   Artagaveytia, Mr. Ramon    male  71.0      0      0
# 96                  Goldschmidt, Mr. George B    male  71.0      0      0
# 116                      Connors, Mr. Patrick    male  70.5      0      0
# ...

# %%
data.sort_values(by=["Age", "Name"], ascending=[False, True])
# Out:
#      PassengerId  Pclass    Ticket                                  Name  \
# 630          631       1     27042  Barkworth, Mr. Algernon Henry Wilson
# 851          852       3    347060                   Svensson, Mr. Johan
# 493          494       1  PC 17609               Artagaveytia, Mr. Ramon
# 96            97       1  PC 17754             Goldschmidt, Mr. George B
# 116          117       3    370369                  Connors, Mr. Patrick
# ..           ...     ...       ...                                   ...
# 55            56       1     19947                     Woolner, Mr. Hugh
# 354          355       3      2647                     Yousif, Mr. Wazli
# 495          496       3      2627                 Yousseff, Mr. Gerious
# 240          241       3      2665                 Zabour, Miss. Thamine
# 868          869       3    345777           van Melkebeke, Mr. Philemon
#
#         Sex   Age  SibSp  Parch     Fare Cabin Embarked  Survived
# ...

# %% [markdown]
# # 컬럼을 인덱스로 지정하기 set_index("컬럼명")

# %%
data.set_index("PassengerId")
# Out:
#              Pclass            Ticket  \
# PassengerId
# 1                 3         A/5 21171
# 2                 1          PC 17599
# 3                 3  STON/O2. 3101282
# 4                 1            113803
# 5                 3            373450
# ...             ...               ...
# 887               2            211536
# 888               1            112053
# 889               3        W./C. 6607
# 890               1            111369
# 891               3            370376
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...

# %%
data = data.set_index(["PassengerId","Name"])

# %% [markdown]
# # 인덱스를 숫자로 초기화 reset_index(drop="원래인덱스를 유지? 삭제)

# %%
data.reset_index(drop=True)
# Out:
#      Pclass            Ticket     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0         3         A/5 21171    male  22.0      1      0   7.2500   NaN
# 1         1          PC 17599  female  38.0      1      0  71.2833   C85
# 2         3  STON/O2. 3101282  female  26.0      0      0   7.9250   NaN
# 3         1            113803  female  35.0      1      0  53.1000  C123
# 4         3            373450    male  35.0      0      0   8.0500   NaN
# ..      ...               ...     ...   ...    ...    ...      ...   ...
# 886       2            211536    male  27.0      0      0  13.0000   NaN
# 887       1            112053  female  19.0      0      0  30.0000   B42
# 888       3        W./C. 6607  female   NaN      1      2  23.4500   NaN
# 889       1            111369    male  26.0      0      0  30.0000  C148
# 890       3            370376    male  32.0      0      0   7.7500   NaN
#
#     Embarked  Survived
# 0          S         0
# 1          C         1
# ...

# %%
data = data.reset_index()
data
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %% [markdown]
# # 컬럼이름 출력 .columns

# %%
col = data.columns
col
# Out:
# Index(['PassengerId', 'Pclass', 'Ticket', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Fare', 'Cabin', 'Embarked', 'Survived'],
#       dtype='object')

# %% [markdown]
# # 컬럼 이름 변경하기
# * rename({이름1 : 변경할 이름1})
# * columns = [컬럼이름]

# %%
data = data.rename(columns={"PassengerId" : "승객번호"})
data
# Out:
#      승객번호  Pclass            Ticket  \
# 0       1       3         A/5 21171
# 1       2       1          PC 17599
# 2       3       3  STON/O2. 3101282
# 3       4       1            113803
# 4       5       3            373450
# ..    ...     ...               ...
# 886   887       2            211536
# 887   888       1            112053
# 888   889       3        W./C. 6607
# 889   890       1            111369
# 890   891       3            370376
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
data = data.rename(columns={"Name" : "이름", "Pclass" : "선실등급"})
data
# Out:
#      승객번호  선실등급            Ticket  \
# 0       1     3         A/5 21171
# 1       2     1          PC 17599
# 2       3     3  STON/O2. 3101282
# 3       4     1            113803
# 4       5     3            373450
# ..    ...   ...               ...
# 886   887     2            211536
# 887   888     1            112053
# 888   889     3        W./C. 6607
# 889   890     1            111369
# 890   891     3            370376
#
#                                                     이름     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
col
# Out:
# Index(['PassengerId', 'Pclass', 'Ticket', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Fare', 'Cabin', 'Embarked', 'Survived'],
#       dtype='object')

# %%
data.columns = ['승객번호', '선실등급', '승차권번호','승객이름', '성별', '나이', '형제자매수', '부모자식수', '승차권금액', '좌석번호', '정박지', '생존여부']

# %%
#data.columns = ['승객번호', '승객이름', '선실등급', '승차권번호', '성별', '나이', '형제자매수',
       '부모자식수', '승차권금액', '좌석번호', '정박지', '생존여부']

# %%
data
# Out:
#      승객번호  선실등급             승차권번호  \
# 0       1     3         A/5 21171
# 1       2     1          PC 17599
# 2       3     3  STON/O2. 3101282
# 3       4     1            113803
# 4       5     3            373450
# ..    ...   ...               ...
# 886   887     2            211536
# 887   888     1            112053
# 888   889     3        W./C. 6607
# 889   890     1            111369
# 890   891     3            370376
#
#                                                   승객이름      성별    나이  형제자매수  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.columns
# Out:
# Index(['승객번호', '승객이름', '선실등급', '승차권번호', '성별', '나이', '형제자매수', '부모자식수', '승차권금액',
#        '좌석번호', '정박지', '생존여부'],
#       dtype='object')

# %% [markdown]
# # 컬럼 추가/삭제하기

# %%
data['가족수'] = data['형제자매수']

# %%
data['테스트'] = "테스트"

# %%
data
# Out:
#      승객번호  승객이름              선실등급  \
# 0       1     3         A/5 21171
# 1       2     1          PC 17599
# 2       3     3  STON/O2. 3101282
# 3       4     1            113803
# 4       5     3            373450
# ..    ...   ...               ...
# 886   887     2            211536
# 887   888     1            112053
# 888   889     3        W./C. 6607
# 889   890     1            111369
# 890   891     3            370376
#
#                                                  승차권번호      성별    나이  형제자매수  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## 데이터프레임의 컬럼과 컬럼을 연산해서 새로운 컬럼 만들기

# %%
data.columns
# Out:
# Index(['승객번호', '승객이름', '선실등급', '승차권번호', '성별', '나이', '형제자매수', '부모자식수', '승차권금액',
#        '좌석번호', '정박지', '생존여부', '가족수'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['승객이름', '선실등급', '승차권번호', '성별', '나이', '승차권금액', '좌석번호', '정박지', '생존여부',
#        '승차권'],
#       dtype='object')

# %%
data['가족수'] = data['형제자매수'] + data['부모자식수']
data.head()
# Out:
#    승객번호  승객이름              선실등급  \
# 0     1     3         A/5 21171
# 1     2     1          PC 17599
# 2     3     3  STON/O2. 3101282
# 3     4     1            113803
# 4     5     3            373450
#
#                                                승차권번호      성별    나이  형제자매수  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    부모자식수    승차권금액  좌석번호 정박지  생존여부  가족수
# 0      0   7.2500   NaN   S     0    1
# 1      0  71.2833   C85   C     1    1
# 2      0   7.9250   NaN   S     1    0
# 3      0  53.1000  C123   S     1    1
# 4      0   8.0500   NaN   S     0    0

# %%
data['승차권'] = data['승차권번호'] + data['좌석번호']
data
# Out:
#      승객번호                                               승객이름  선실등급  \
# 0       1                            Braund, Mr. Owen Harris     3
# 1       2  Cumings, Mrs. John Bradley (Florence Briggs Th...     1
# 2       3                             Heikkinen, Miss. Laina     3
# 3       4       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1
# 4       5                           Allen, Mr. William Henry     3
# ..    ...                                                ...   ...
# 886   887                              Montvila, Rev. Juozas     2
# 887   888                       Graham, Miss. Margaret Edith     1
# 888   889           Johnston, Miss. Catherine Helen "Carrie"     3
# 889   890                              Behr, Mr. Karl Howell     1
# 890   891                                Dooley, Mr. Patrick     3
#
#                 승차권번호      성별    나이  형제자매수  부모자식수    승차권금액  좌석번호 정박지  생존여부  \
# 0           A/5 21171    male  22.0      1      0   7.2500   NaN   S     0
# ...

# %% [markdown]
# ## 컬럼 삭제하기
# * del 변수명['컬럼명']
# * 변수명.drop("컬럼명", axis=1)   변수명.drop(["컬럼명1", "컬럼명2"], axis=1)

# %%
del data['테스트']

# %%
data
# Out:
#      승객번호                                               승객이름  선실등급  \
# 0       1                            Braund, Mr. Owen Harris     3
# 1       2  Cumings, Mrs. John Bradley (Florence Briggs Th...     1
# 2       3                             Heikkinen, Miss. Laina     3
# 3       4       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1
# 4       5                           Allen, Mr. William Henry     3
# ..    ...                                                ...   ...
# 886   887                              Montvila, Rev. Juozas     2
# 887   888                       Graham, Miss. Margaret Edith     1
# 888   889           Johnston, Miss. Catherine Helen "Carrie"     3
# 889   890                              Behr, Mr. Karl Howell     1
# 890   891                                Dooley, Mr. Patrick     3
#
#                 승차권번호      성별    나이  형제자매수  부모자식수    승차권금액  좌석번호 정박지  생존여부  \
# 0           A/5 21171    male  22.0      1      0   7.2500   NaN   S     0
# ...

# %%
data.drop('가족수', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[145], line 1
# ----> 1 data.drop('가족수', axis=1, inplace=True)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
data
# Out:
#      승객번호                                               승객이름  선실등급  \
# 0       1                            Braund, Mr. Owen Harris     3
# 1       2  Cumings, Mrs. John Bradley (Florence Briggs Th...     1
# 2       3                             Heikkinen, Miss. Laina     3
# 3       4       Futrelle, Mrs. Jacques Heath (Lily May Peel)     1
# 4       5                           Allen, Mr. William Henry     3
# ..    ...                                                ...   ...
# 886   887                              Montvila, Rev. Juozas     2
# 887   888                       Graham, Miss. Margaret Edith     1
# 888   889           Johnston, Miss. Catherine Helen "Carrie"     3
# 889   890                              Behr, Mr. Karl Howell     1
# 890   891                                Dooley, Mr. Patrick     3
#
#                 승차권번호      성별    나이  형제자매수  부모자식수    승차권금액  좌석번호 정박지  생존여부  \
# 0           A/5 21171    male  22.0      1      0   7.2500   NaN   S     0
# ...

# %%
data = data.drop('승객번호', axis=1)

# %%
data = data.drop(['형제자매수', '부모자식수'], axis=1)
data
# Out:
#      승객번호  승객이름              선실등급  \
# 0       1     3         A/5 21171
# 1       2     1          PC 17599
# 2       3     3  STON/O2. 3101282
# 3       4     1            113803
# 4       5     3            373450
# ..    ...   ...               ...
# 886   887     2            211536
# 887   888     1            112053
# 888   889     3        W./C. 6607
# 889   890     1            111369
# 890   891     3            370376
#
#                                                  승차권번호      성별    나이    승차권금액  \
# 0                              Braund, Mr. Owen Harris    male  22.0   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                               Heikkinen, Miss. Laina  female  26.0   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                             Allen, Mr. William Henry    male  35.0   8.0500
# ..                                                 ...     ...   ...      ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   승객번호    891 non-null    int64
#  1   승객이름    891 non-null    int64
#  2   선실등급    891 non-null    object
#  3   승차권번호   891 non-null    object
#  4   성별      891 non-null    object
#  5   나이      714 non-null    float64
#  6   승차권금액   891 non-null    float64
#  7   좌석번호    204 non-null    object
#  8   정박지     889 non-null    object
#  9   생존여부    891 non-null    int64
#  10  가족수     891 non-null    int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %% [markdown]
# # 데이터 타입 바꾸기

# %%
data['승객번호'] = data['승객번호'].astype('str')
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '승객번호'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 data['승객번호'] = data['승객번호'].astype('str')
#       2 data
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   승객번호    891 non-null    int64
#  1   승객이름    891 non-null    int64
#  2   선실등급    891 non-null    object
#  3   승차권번호   891 non-null    object
#  4   성별      891 non-null    object
#  5   나이      714 non-null    float64
#  6   승차권금액   891 non-null    float64
#  7   좌석번호    204 non-null    object
#  8   정박지     889 non-null    object
#  9   생존여부    891 non-null    int64
#  10  가족수     891 non-null    int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
data['승객번호'] = data['승객번호'].astype('float32')

# %%
data['승객번호'] = data['승객번호'].apply(lambda x: str(x))

# %%
data['승객번호'].dtype

# %%
data.info()

# %%
data['승객번호'] = data['승객번호'].apply(lambda x: float(x))

# %%
data['승객번호'].info()

# %% [markdown]
# # 판다스 데이터 프레임에서 조건에 맞는 행만 가져오기
# * 데이터프레임.[데이터프레임['컬럼명'] 조건식]. => 조건식이 참인 것만 가져옴
# * 조건식 연산자 >, < , ==, !=, >=, <=, &(and), |(or)

# %%
data['나이'] >35
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: 나이, Length: 891, dtype: bool

# %%
data[data['나이'] > 35]
# Out:
#      승객번호  승객이름      선실등급                                              승차권번호  \
# 1       2     1  PC 17599  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6       7     1     17463                            McCarthy, Mr. Timothy J
# 11     12     1    113783                           Bonnell, Miss. Elizabeth
# 13     14     3    347082                        Andersson, Mr. Anders Johan
# 15     16     2    248706                   Hewlett, Mrs. (Mary D Kingcome)
# ..    ...   ...       ...                                                ...
# 865   866     2    236852                           Bystrom, Mrs. (Karolina)
# 871   872     1     11751   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 873   874     3    345765                        Vander Cruyssen, Mr. Victor
# 879   880     1     11767      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 885   886     3    382652               Rice, Mrs. William (Margaret Norton)
#
# ...

# %% [markdown]
# 성별이 여성이면서 나이가 35세 초과인 행 찾기 - 조건이 2개 조건이 and조건

# %%
(data['나이'] > 35) & (data['성별'] == "female")
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
data[(data['나이'] > 35) & (data['성별'] == "female")]
# Out:
#      승객번호  승객이름      선실등급                                              승차권번호  \
# 1       2     1  PC 17599  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 11     12     1    113783                           Bonnell, Miss. Elizabeth
# 15     16     2    248706                   Hewlett, Mrs. (Mary D Kingcome)
# 25     26     3    347077  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 40     41     3      7546     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# ..    ...   ...       ...                                                ...
# 862   863     1     17466  Swift, Mrs. Frederick Joel (Margaret Welles Ba...
# 865   866     2    236852                           Bystrom, Mrs. (Karolina)
# 871   872     1     11751   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 879   880     1     11767      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 885   886     3    382652               Rice, Mrs. William (Margaret Norton)
#
# ...

# %% [markdown]
# 성별이 남성이고, 선실등급이 1, 생존여부가 1인 사람을 찾으세요

# %%
data[((data['성별'] == 'male') & (data['선실등급'] == 1) & (data['생존여부'] == 1))]
# Out:
# Empty DataFrame
# Columns: [승객번호, 승객이름, 선실등급, 승차권번호, 성별, 나이, 승차권금액, 좌석번호, 정박지, 생존여부, 가족수]
# Index: []

# %% [markdown]
# 승차권 금액이 0원인 사람 찾기

# %%
data[data['승차권금액'] == 0]
# Out:
#                                  승객이름  선실등급   승차권번호    성별    나이  승차권금액  좌석번호  \
# 179               Leonard, Mr. Lionel     3    LINE  male  36.0    0.0   NaN
# 263             Harrison, Mr. William     1  112059  male  40.0    0.0   B94
# 271      Tornquist, Mr. William Henry     3    LINE  male  25.0    0.0   NaN
# 277       Parkes, Mr. Francis "Frank"     2  239853  male   NaN    0.0   NaN
# 302   Johnson, Mr. William Cahoone Jr     3    LINE  male  19.0    0.0   NaN
# 413    Cunningham, Mr. Alfred Fleming     2  239853  male   NaN    0.0   NaN
# 466             Campbell, Mr. William     2  239853  male   NaN    0.0   NaN
# 481  Frost, Mr. Anthony Wood "Archie"     2  239854  male   NaN    0.0   NaN
# 597               Johnson, Mr. Alfred     3    LINE  male  49.0    0.0   NaN
# 633     Parr, Mr. William Henry Marsh     1  112052  male   NaN    0.0   NaN
# 674        Watson, Mr. Ennis Hastings     2  239856  male   NaN    0.0   NaN
# ...

# %% [markdown]
# 남자면서 생존한 사람

# %%
data[((data['성별'] == "male")& (data['생존여부'] == 1))]
# Out:
#                                 승객이름  선실등급   승차권번호    성별    나이    승차권금액  좌석번호  \
# 17      Williams, Mr. Charles Eugene     2  244373  male   NaN  13.0000   NaN
# 21             Beesley, Mr. Lawrence     2  248698  male  34.0  13.0000   D56
# 23      Sloper, Mr. William Thompson     1  113788  male  28.0  35.5000    A6
# 36                  Mamee, Mr. Hanna     3    2677  male   NaN   7.2292   NaN
# 55                 Woolner, Mr. Hugh     1   19947  male   NaN  35.5000   C52
# ..                               ...   ...     ...   ...   ...      ...   ...
# 838                  Chip, Mr. Chang     3    1601  male  32.0  56.4958   NaN
# 839             Marechal, Mr. Pierre     1   11774  male   NaN  29.7000   C47
# 857           Daly, Mr. Peter Denis      1  113055  male  51.0  26.5500   E17
# 869  Johnson, Master. Harold Theodor     3  347742  male   4.0  11.1333   NaN
# 889            Behr, Mr. Karl Howell     1  111369  male  26.0  30.0000  C148
#
#     정박지  생존여부  가족수         승차권
# ...

# %%
data[((data['성별'] == "female")& (data['생존여부'] == 1))]
# Out:
#                                                   승객이름  선실등급  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...     1
# 2                               Heikkinen, Miss. Laina     3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)     1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)     3
# 9                  Nasser, Mrs. Nicholas (Adele Achem)     2
# ..                                                 ...   ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)     2
# 875                   Najib, Miss. Adele Kiamie "Jane"     3
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)     1
# 880       Shelley, Mrs. William (Imanita Parrish Hall)     2
# 887                       Graham, Miss. Margaret Edith     1
#
#                 승차권번호      성별    나이    승차권금액  좌석번호 정박지  생존여부  가족수          승차권
# 1            PC 17599  female  38.0  71.2833   C85   C     1    1  PC 17599C85
# ...

# %% [markdown]
# 선실등급이 1이거나 2면서 생존한 여성

# %%
data[(((data['선실등급'] == 1) | (data['선실등급'] == 2))& (data['성별'] == "female") & (data['생존여부'] == 1))]
# Out:
# Empty DataFrame
# Columns: [승객번호, 승객이름, 선실등급, 승차권번호, 성별, 나이, 승차권금액, 좌석번호, 정박지, 생존여부, 가족수]
# Index: []

# %% [markdown]
# 선실등급이 1이거나 2이면서 생존한 여성 중에서 이름 컬럼만 보고 싶을 때
# * loc
# * 데이터프레임.loc[데이터프레임['컬럼명'] 조건, '원하는 컬럼명']
# * 데이터프레임.[데이터프레임['컬럼명'] 조건]['원하는 컬럼명']

# %%
data.loc[(((data['선실등급'] == 1) | (data['선실등급'] == 2))& (data['성별'] == "female") & (data['생존여부'] == 1)), '승객이름']
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# 11                              Bonnell, Miss. Elizabeth
# 15                      Hewlett, Mrs. (Mary D Kingcome)
#                              ...
# 871     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 874                Abelson, Mrs. Samuel (Hannah Wizosky)
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 880         Shelley, Mrs. William (Imanita Parrish Hall)
# 887                         Graham, Miss. Margaret Edith
# Name: 승객이름, Length: 161, dtype: object

# %% [markdown]
# 선실등급이 1인 사람의 승객 이름과 선실등급 같이 출력하기

# %%
data.loc[data['선실등급'] == 1, ['승객이름', '선실등급']]
# Out:
#                                                   승객이름  선실등급
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...     1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)     1
# 6                              McCarthy, Mr. Timothy J     1
# 11                            Bonnell, Miss. Elizabeth     1
# 23                        Sloper, Mr. William Thompson     1
# ..                                                 ...   ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)     1
# 872                           Carlsson, Mr. Frans Olof     1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)     1
# 887                       Graham, Miss. Margaret Edith     1
# 889                              Behr, Mr. Karl Howell     1
#
# [216 rows x 2 columns]

# %%
data_test = data[data['선실등급'] == 1]
data_test[['승객이름','선실등급']]
# Out:
#                                                   승객이름  선실등급
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...     1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)     1
# 6                              McCarthy, Mr. Timothy J     1
# 11                            Bonnell, Miss. Elizabeth     1
# 23                        Sloper, Mr. William Thompson     1
# ..                                                 ...   ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)     1
# 872                           Carlsson, Mr. Frans Olof     1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)     1
# 887                       Graham, Miss. Margaret Edith     1
# 889                              Behr, Mr. Karl Howell     1
#
# [216 rows x 2 columns]

# %% [markdown]
# 위에꺼랑 똑같은 거임
# 밑에가 원래 맞는거

# %%
data[data['선실등급'] == 1][['승객이름','선실등급']]
# Out:
#                                                   승객이름  선실등급
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...     1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)     1
# 6                              McCarthy, Mr. Timothy J     1
# 11                            Bonnell, Miss. Elizabeth     1
# 23                        Sloper, Mr. William Thompson     1
# ..                                                 ...   ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)     1
# 872                           Carlsson, Mr. Frans Olof     1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)     1
# 887                       Graham, Miss. Margaret Edith     1
# 889                              Behr, Mr. Karl Howell     1
#
# [216 rows x 2 columns]

# %%
data.loc[:20, ['승객이름','선실등급']]
# Out:
#                                                  승객이름  선실등급
# 0                             Braund, Mr. Owen Harris     3
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...     1
# 2                              Heikkinen, Miss. Laina     3
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)     1
# 4                            Allen, Mr. William Henry     3
# 5                                    Moran, Mr. James     3
# 6                             McCarthy, Mr. Timothy J     1
# 7                      Palsson, Master. Gosta Leonard     3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)     3
# 9                 Nasser, Mrs. Nicholas (Adele Achem)     2
# 10                    Sandstrom, Miss. Marguerite Rut     3
# 11                           Bonnell, Miss. Elizabeth     1
# 12                     Saundercock, Mr. William Henry     3
# 13                        Andersson, Mr. Anders Johan     3
# 14               Vestrom, Miss. Hulda Amanda Adolfina     3
# ...

# %% [markdown]
# ## isin([조건1, 조건2]) <br>
# * or 조건을 여러 번 써야할 때 .isin을 쓰면 간단

# %%
# data[(data['선실등급'] == 1) | (data['선실등급'] == 2)]
data[data['선실등급'].isin([1,2])]
# Out:
#                                                   승객이름  선실등급  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...     1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)     1
# 6                              McCarthy, Mr. Timothy J     1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)     2
# 11                            Bonnell, Miss. Elizabeth     1
# ..                                                 ...   ...
# 880       Shelley, Mrs. William (Imanita Parrish Hall)     2
# 883                      Banfield, Mr. Frederick James     2
# 886                              Montvila, Rev. Juozas     2
# 887                       Graham, Miss. Margaret Edith     1
# 889                              Behr, Mr. Karl Howell     1
#
#                 승차권번호      성별    나이    승차권금액  좌석번호 정박지  생존여부  가족수          승차권
# 1            PC 17599  female  38.0  71.2833   C85   C     1    1  PC 17599C85
# ...

# %% [markdown]
# # 특정 단어를 포함한 행을 찾기 예 이름 Joseph이 들어간 사람
# * sql에서는 like %단어% -sql
# * .str.contains('찾을 단어')

# %%
data[data['승객이름'].str.contains("Joseph")]
# Out:
#      승객번호  선실등급          승차권번호  \
# 20     21     2         239865
# 34     35     1       PC 17604
# 95     96     3         374910
# 140   141     3           2678
# 145   146     2     C.A. 33112
# 194   195     1       PC 17610
# 375   376     1       PC 17604
# 454   455     3       A/5 2817
# 532   533     3           2690
# 559   560     3         345572
# 578   579     3           2689
# 589   590     3     A./5. 3235
# 608   609     2  SC/Paris 2123
# 685   686     2  SC/Paris 2123
# 752   753     3         345780
# 828   829     3         367228
#
#                                                   승객이름      성별    나이  형제자매수  \
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# 34                             Meyer, Mr. Edgar Joseph    male  28.0      1
# 95                         Shorney, Mr. Charles Joseph    male   NaN      0
# 140                      Boulos, Mrs. Joseph (Sultana)  female   NaN      0
# ...

# %% [markdown]
# 승차권에 PC 가 포함된 승차권 찾기

# %%
data['승차권'].str.contains("PC")
# Out:
# 0        NaN
# 1       True
# 2        NaN
# 3      False
# 4        NaN
#        ...
# 886      NaN
# 887    False
# 888      NaN
# 889    False
# 890      NaN
# Name: 승차권, Length: 891, dtype: object

# %%
del data['승차권']

# %%
data[data['승객이름'].str.contains("Joseph")]
# Out:
#                                                   승객이름  선실등급          승차권번호  \
# 20                                Fynney, Mr. Joseph J     2         239865
# 34                             Meyer, Mr. Edgar Joseph     1       PC 17604
# 95                         Shorney, Mr. Charles Joseph     3         374910
# 140                      Boulos, Mrs. Joseph (Sultana)     3           2678
# 145                       Nicholls, Mr. Joseph Charles     2     C.A. 33112
# 194          Brown, Mrs. James Joseph (Margaret Tobin)     1       PC 17610
# 375              Meyer, Mrs. Edgar Joseph (Leila Saks)     1       PC 17604
# 454                                Peduzzi, Mr. Joseph     3       A/5 2817
# 532                               Elias, Mr. Joseph Jr     3           2690
# 559       de Messemaeker, Mrs. Guillaume Joseph (Emma)     3         345572
# 578                   Caram, Mrs. Joseph (Maria Elias)     3           2689
# ...

# %%
data[data['승차권번호'].str.contains("PC")]
# NaN이 있어서 발생하는 오류
# Out:
# Empty DataFrame
# Columns: [승객번호, 승객이름, 선실등급, 승차권번호, 성별, 나이, 승차권금액, 좌석번호, 정박지, 생존여부, 가족수]
# Index: []

# %%
data[data['승차권'].str.contains("PC", na = False)]
# na=False를 사용하면 NaN 값을 포함한 행들이 False로 처리되어 오류를 피할 수 있다
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '승차권'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[221], line 1
# ----> 1 data[data['승차권'].str.contains("PC", na = False)]
# ...

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %% [markdown]
# ## 승객이름에서 () 없애기
# * 방법1 : 파이썬 반복문 돌려서 제거하기
# * 방법2 : 시리즈.apply(lambda x: x.replace('(','').replace(')',''))
# * 방법3 : .str.replace('(','').str.replace(')','') <br>
# 시리즈 : 값이 여러 개 있는거

# %%
data
# Out:
#      승객번호  승객이름              선실등급  \
# 0       1     3         A/5 21171
# 1       2     1          PC 17599
# 2       3     3  STON/O2. 3101282
# 3       4     1            113803
# 4       5     3            373450
# ..    ...   ...               ...
# 886   887     2            211536
# 887   888     1            112053
# 888   889     3        W./C. 6607
# 889   890     1            111369
# 890   891     3            370376
#
#                                                  승차권번호      성별    나이    승차권금액  \
# 0                              Braund, Mr. Owen Harris    male  22.0   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                               Heikkinen, Miss. Laina  female  26.0   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                             Allen, Mr. William Henry    male  35.0   8.0500
# ..                                                 ...     ...   ...      ...
# ...

# %%
# Series임
# 반복문에 들어가기
data['승객이름']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: 승객이름, Length: 891, dtype: int64

# %%
result = []
for name in data['승객이름']:
    result.append(name.replace('(',"").replace(')',''))

# %%
result
# Out:
# ['Braund, Mr. Owen Harris',
#  'Cumings, Mrs. John Bradley Florence Briggs Thayer',
#  'Heikkinen, Miss. Laina',
#  'Futrelle, Mrs. Jacques Heath Lily May Peel',
#  'Allen, Mr. William Henry',
#  'Moran, Mr. James',
#  'McCarthy, Mr. Timothy J',
#  'Palsson, Master. Gosta Leonard',
#  'Johnson, Mrs. Oscar W Elisabeth Vilhelmina Berg',
#  'Nasser, Mrs. Nicholas Adele Achem',
#  'Sandstrom, Miss. Marguerite Rut',
#  'Bonnell, Miss. Elizabeth',
#  'Saundercock, Mr. William Henry',
#  'Andersson, Mr. Anders Johan',
#  'Vestrom, Miss. Hulda Amanda Adolfina',
#  'Hewlett, Mrs. Mary D Kingcome ',
#  'Rice, Master. Eugene',
#  'Williams, Mr. Charles Eugene',
#  'Vander Planke, Mrs. Julius Emelia Maria Vandemoortele',
#  'Masselmani, Mrs. Fatima',
#  'Fynney, Mr. Joseph J',
#  'Beesley, Mr. Lawrence',
#  'McGowan, Miss. Anna "Annie"',
#  'Sloper, Mr. William Thompson',
#  'Palsson, Miss. Torborg Danira',
#  'Asplund, Mrs. Carl Oscar Selma Augusta Emilia Johansson',
# ...

# %%
name2 = data['승객이름'].copy()

# %%
# data['승객이름'] = result

# %% [markdown]
# * 방법2

# %%
# 반복문을 쓰지 않아도 됨
# 재할당을 마지막에 해줘야됨
data['승객이름'].apply(lambda x : x.replace('(','').replace(')',''))
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley Florence Briggs Thayer
# 2                                 Heikkinen, Miss. Laina
# 3             Futrelle, Mrs. Jacques Heath Lily May Peel
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: 승객이름, Length: 891, dtype: object

# %% [markdown]
# * 방법3

# %%
# 반복문을 쓰지 않아도 됨
# 재할당을 마지막에 해줘야됨
data['승객이름'].str.replace('(','').str.replace(')','')
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley Florence Briggs Thayer
# 2                                 Heikkinen, Miss. Laina
# 3             Futrelle, Mrs. Jacques Heath Lily May Peel
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: 승객이름, Length: 891, dtype: object

# %%
# 문자열이기 때문에 사용가능
# data['승객이름'].str.lower()
data['승객이름'].str.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 3
#       1 # 문자열이기 때문에 사용가능
#       2 # data['승객이름'].str.lower()
# ----> 3 data['승객이름'].str.upper()
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# ...

# %% [markdown]
# 승객이름 컬럼에서 이름만 추출하기
# * .str.split().get()

# %%
data['승객이름'].str.split(', ')
# Out:
# 0                              [Braund, Mr. Owen Harris]
# 1      [Cumings, Mrs. John Bradley (Florence Briggs T...
# 2                               [Heikkinen, Miss. Laina]
# 3         [Futrelle, Mrs. Jacques Heath (Lily May Peel)]
# 4                             [Allen, Mr. William Henry]
#                              ...
# 886                              [Montvila, Rev. Juozas]
# 887                       [Graham, Miss. Margaret Edith]
# 888           [Johnston, Miss. Catherine Helen "Carrie"]
# 889                              [Behr, Mr. Karl Howell]
# 890                                [Dooley, Mr. Patrick]
# Name: 승객이름, Length: 891, dtype: object

# %%
data['승객이름'].str.split(', ').str.get(0)
# Out:
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: 승객이름, Length: 891, dtype: object

# %% [markdown]
# 리스트로 쪼개진 승객이름 다시 "," 을 기준으로 합치기

# %%
data['승객이름'] = data['승객이름'].str.split(', ')
data['승객이름']
# Out:
# 0          [B,r,a,u,n,d,,,M,r,., ,O,w,e,n, ,H,a,r,r,i,s]
# 1      [C,u,m,i,n,g,s,,,M,r,s,., ,J,o,h,n, ,B,r,a,d,l...
# 2            [H,e,i,k,k,i,n,e,n,,,M,i,s,s,., ,L,a,i,n,a]
# 3      [F,u,t,r,e,l,l,e,,,M,r,s,., ,J,a,c,q,u,e,s, ,H...
# 4        [A,l,l,e,n,,,M,r,., ,W,i,l,l,i,a,m, ,H,e,n,r,y]
#                              ...
# 886            [M,o,n,t,v,i,l,a,,,R,e,v,., ,J,u,o,z,a,s]
# 887    [G,r,a,h,a,m,,,M,i,s,s,., ,M,a,r,g,a,r,e,t, ,E...
# 888    [J,o,h,n,s,t,o,n,,,M,i,s,s,., ,C,a,t,h,e,r,i,n...
# 889            [B,e,h,r,,,M,r,., ,K,a,r,l, ,H,o,w,e,l,l]
# 890                [D,o,o,l,e,y,,,M,r,., ,P,a,t,r,i,c,k]
# Name: 승객이름, Length: 891, dtype: object

# %%
data['승객이름'] = data['승객이름'].str.join(',')
data['승객이름']
# Out:
# 0            B,r,a,u,n,d,,,M,r,., ,O,w,e,n, ,H,a,r,r,i,s
# 1      C,u,m,i,n,g,s,,,M,r,s,., ,J,o,h,n, ,B,r,a,d,l,...
# 2              H,e,i,k,k,i,n,e,n,,,M,i,s,s,., ,L,a,i,n,a
# 3      F,u,t,r,e,l,l,e,,,M,r,s,., ,J,a,c,q,u,e,s, ,H,...
# 4          A,l,l,e,n,,,M,r,., ,W,i,l,l,i,a,m, ,H,e,n,r,y
#                              ...
# 886              M,o,n,t,v,i,l,a,,,R,e,v,., ,J,u,o,z,a,s
# 887    G,r,a,h,a,m,,,M,i,s,s,., ,M,a,r,g,a,r,e,t, ,E,...
# 888    J,o,h,n,s,t,o,n,,,M,i,s,s,., ,C,a,t,h,e,r,i,n,...
# 889              B,e,h,r,,,M,r,., ,K,a,r,l, ,H,o,w,e,l,l
# 890                  D,o,o,l,e,y,,,M,r,., ,P,a,t,r,i,c,k
# Name: 승객이름, Length: 891, dtype: object

# %% [markdown]
# # groupby
# * 데이터프레임[['컬럼1', '컬럼2']].groupby('기준컬럼').집합연산함수(mean, max, min, count, value_counts)
# * 데이터프레임.groupby('기준컬럼').집합연산함수(mean, max, min, count, value_counts)

# %%
data[['성별', '나이']].groupby('성별').mean()
# Out:
#                나이
# 성별
# female  27.915709
# male    30.726645

# %%
data[['성별', '나이']].groupby('성별').value_counts()
# Out:
# 성별      나이
# female  24.0    16
#         18.0    13
#         22.0    12
#         30.0    11
#         35.0     8
#                 ..
# male    57.0     1
#         66.0     1
#         70.5     1
#         74.0     1
#         80.0     1
# Name: count, Length: 145, dtype: int64

# %% [markdown]
# 성별별 생존자 수

# %%
data[['성별', '생존여부']].groupby('성별').value_counts()
# Out:
# 성별      생존여부
# female  1       233
#         0        81
# male    0       468
#         1       109
# Name: count, dtype: int64

# %% [markdown]
# 선실등급 별 생존 여부

# %%
data[['선실등급', '생존여부']].groupby('선실등급').value_counts(sort = False)
# Out:
# 선실등급  생존여부
# 1     0        80
#       1       136
# 2     0        97
#       1        87
# 3     0       372
#       1       119
# Name: count, dtype: int64

# %%
data
# Out:
#      승객번호  선실등급             승차권번호  \
# 0       1     3         A/5 21171
# 1       2     1          PC 17599
# 2       3     3  STON/O2. 3101282
# 3       4     1            113803
# 4       5     3            373450
# ..    ...   ...               ...
# 886   887     2            211536
# 887   888     1            112053
# 888   889     3        W./C. 6607
# 889   890     1            111369
# 890   891     3            370376
#
#                                                   승객이름      성별    나이  형제자매수  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 성별별, 선실등급별 생존 여부

# %%
data[['성별', '선실등급', '생존여부']].groupby(['성별', '선실등급']).value_counts(sort=False)
# Out:
# 성별      선실등급  생존여부
# female  1     0         3
#               1        91
#         2     0         6
#               1        70
#         3     0        72
#               1        72
# male    1     0        77
#               1        45
#         2     0        91
#               1        17
#         3     0       300
#               1        47
# Name: count, dtype: int64

# %%
# 여성이면서
