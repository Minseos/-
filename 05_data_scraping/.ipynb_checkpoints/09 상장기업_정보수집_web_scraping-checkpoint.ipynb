# %% [markdown]
# https://kind.krx.co.kr/main.do?method=loadInitPage, scrnmode=1

# %% [markdown]
# url = "https://kind.krx.co.kr/main.do"
# parameter(method) = method=loadInitPage, scrnmode=1

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
import time
from datetime import date

# %%
today = date.today()
print(today)
# Out:
# 2024-07-29

# %%
url = "https://kind.krx.co.kr/corpgeneral/corpList.do"
payload = dict(method = 'loadInitPage')
r = requests.get(url, params = payload)
print(r.status_code)
print(r.text)

soup = bs(r.text, 'lxml')
# Out:
# 200
#
#
#
#
#
#
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta http-equiv="X-UA-Compatible" content="IE=edge" />
# <meta http-equiv="content-type" content="text/html; charset=utf-8" />
# <meta http-equiv="content-language" content="kr" />
# <meta http-equiv="content-style-type" content="text/css" />
# <meta http-equiv="pragma" content="no-cache" />
# <meta http-equiv="cache-control" content="no-cache" />
# <meta http-equiv="imagetoolbar" content="no" />
# <meta name="copyright" content="대한민국 대표 기업공시채널 KIND(c)2014" />
# <meta name="description" content="대한민국 대표 기업공시채널 KIND" />
# <meta name="keywords" content="대한민국 대표 기업공시채널 KIND" />
# <title>대한민국 대표 기업공시채널 KIND</title>
# <link rel="shortcut icon" href="../images/kind.ico" />
# <link rel="stylesheet" type="text/css" href="../js/jquery/themes-base/jquery-ui.min.css" media="all" />
# <link rel="stylesheet" type="text/css" href="../css/default_new.css" media="all" />
# <link rel="stylesheet" type="text/css" href="../css/common.css?version=20240531" media="all" />
# <link rel="stylesheet" type="text/css" href="../css/style.css?version=20240524" media="all" />
# <link rel="stylesheet" type="text/css" href="../esg/notoSans.css?20240524" media="all" />
#
# <!--[if lt IE 9]>
# <script type="text/javascript" src="../js/html5shiv.js"></script>
# <![endif]-->
# <script type="text/javascript" src="../js/dtree.js"></script>
# <script type="text/javascript" src="../js/trans.js"></script>
# <script type="text/javascript" src="../js/jquery/jquery.js" ></script>
# <script type="text/javascript" src="../js/jquery/jquery-ui.min.js"></script>
# <script type="text/javascript" src="../js/jquery/jquery.placeholder.js"></script>
# <script type="text/javascript" src="../js/common.js?version=20201204"></script>
# <script type="text/javascript" src="../js/common-ajax.js"></script>
# <script type="text/javascript" src="../js/JCommon.js?version=2022042906"></script>
# <script type="text/javascript" src="../js/common-sort.js"></script>
# </head>
#
#
#
#
# 		<body>
#
#
# <!-- 화면 확대/축소 안내 START-->
#
#
# <section class="notice popup modal type-00 hide">
# 	<div class="container">
# 		<div class="wrapper">
# 			<hgroup class="handle"><h2>화면 확대/축소 안내</h2></hgroup>
# 			<a href="#" class="btn-pop-close btn_close">닫기</a>
# 			<section class="body">
# 				<ul class="msg type-99 fc01">
# 					<li>※ IE8 이하의 웹브라우저에서는 다음과 같은 방법으로 화면의 확대/축소 기능을 이용하실 수 있습니다.</li>
# 				</ul>
# 				<img src="../images/common/notice.png"  alt="화면확대 화면축소" />
# 			</section>
# 		</div>
# 		<img src="../images/common/pop-type-00-tl.png" class="tl" alt="배경이미지"/>
# 		<img src="../images/common/pop-type-00-bl.png" class="bl" alt="배경이미지"/>
# 		<img src="../images/common/pop-type-00-tr.png" class="tr" alt="배경이미지"/>
# 		<img src="../images/common/pop-type-00-br.png" class="br" alt="배경이미지"/>
# 		<div class="tm"></div>
# 		<div class="lm"></div>
# 		<div class="bm"></div>
# 		<div class="rm"></div>
# 	</div>
# </section>
#
# <!-- HEADER 영역 START -->
# <header class="container">
#
#
#
#
#
#
#
#
# <div class="container_line">
# 	<div class="wrapper-super">
# 		<hgroup>
# 			<h1 class="logo"><a href="/main.do?method=loadInitPage&scrnmode=1" title="대한민국 대표 기업공시채널 KIND"><img src="../images/main/logo.gif" alt="대한민국 대표 기업공시채널 KIND"/></a></h1>
# 		</hgroup>
# 		<ul class="util">
# 			<li class="first"><a href="/common/JLDDST35000.html" onclick="winCommPopOpen('1'); return false;" title="KIND 소개 새창"><img src="../images/common/util_intro.gif" alt="KIND 소개"/></a></li>
# 			<li>
# 				<a href="https://engkind.krx.co.kr/" title="KIND 영문사이트 바로가기" target="_blank"><img src="../images/common/util_eng.gif" alt="ENGLISH KIND"/></a>
# 			</li>
# 			<li class="btn-group">
# 				<img src="../images/common/ttl_screen.gif" class="ttl" alt="화면크기"/>
# 				<a href="#" class="plus zoom_btn-in"><span>확대</span></a>
# 				<a href="#" class="reset zoom_btn-reset"><span>원래대로</span></a>
# 				<a href="#" class="minus zoom_btn-out"><span>축소</span></a>
# 			</li>
# 		</ul>
# 		<div class="clear"></div>
# 		<form id="AKCFrm" name="AKCFrm">
# 		<input type="hidden" name="method"			id="method" 		value="disclosureSimpleSearchMain"/>
# 		<input type="hidden" name="searchCodeType"	id="searchCodeType" value=""/>
# 		<input type="hidden" name="repIsuSrtCd"		id="repIsuSrtCd" 	value=""/>
# 		<input type="hidden" name="isurCd"			id="isurCd" 		value=""/>
# 		<input type="hidden" name="AKCKwdCode"		id="AKCKwdCode" 	value=""/>
# 		<section class="search auto_complete top-akc-sub">
# 			<div class="autoKey">
# 				<input type="text" id="AKCKwdTop" name="searchCorpName" placeholder="회사명 또는 종목코드를 입력해 주세요." class="search-txt dval" onblur="chkValidChar(this); fnMainCorpType();" autocomplete=off />
# 				<div class="tselect">
# 					<img id="AKCArrowTop" class="autoc_open" src="../images/common/icn_autoc_open.gif" alt="자동완성 열기" />
# 					<div id="AKCDivTop" class="AKCDivTop" style="display:none;">
# 						<iframe id="AKCIfrmTop" name="AKCIfrmTop" title="자동완성" src="../common/akc_top.html?version=20220624" frameborder="0" scrolling="no" ></iframe>
# 					</div>
# 				</div>
# 			</div>
# 			<input type="image" src="../images/common/btn_search.gif" alt="검색" class="submit" onclick="fnTopAKCKwdSearch(); return false;"/>
# 			<div class="clear"></div>
# 		</section>
# 		</form>
# 		<a href="#" class="btn sitemap open"><img src="../images/common/btn_sitemap.gif" alt="전체메뉴보기"/></a>
# 	</div>
# </div>
#
# <div class="sitemap-wrapper">
# 	<!-- TOP MENU START -->
#
#
#
#
#
#
# <section class="sitemap">
# 	<article class="mymenu">
# 		<h3><img src="../images/common/ttl_sitemap_my.png" alt="나만의 메뉴"/></h3>
# 		<div class="list">
# 			<ul id="myMenuTop">
# 				<li class="active"><a href="/disclosure/todaydisclosure.do?method=searchTodayDisclosureMain">오늘의공시</a></li>
# 				<li><a href="/disclosure/searchdisclosurebycorp.do?method=searchDisclosureByCorpMain">회사별검색</a></li>
# 				<li><a href="/disclosure/searchtotalinfo.do?method=searchTotalInfoMain">통합검색</a></li>
# 				<li><a href="/disclosure/details.do?method=searchDetailsMain">상세검색</a></li>
# 				<li><a href="/corpdetail/totalinfo.do?method=loadInitPage">종합정보</a></li>
# 			</ul>
# 		</div>
# 		<a href="#" class="btn_sitemap-set"><img src="../images/common/btn_sitemap_set.png" alt="설정"/></a>
# 	</article>
# 	<section class="list-wrapper links">
# 		<article class="list">
# 			<h3>공시</h3>
# 			<ul>
# 				<li><a href="/disclosure/todaydisclosure.do?method=searchTodayDisclosureMain" class="first">오늘의공시</a></li>
# 				<li><a href="/disclosure/searchdisclosurebycorp.do?method=searchDisclosureByCorpMain" class="first">회사별검색</a></li>
# 				<li><a href="/disclosure/details.do?method=searchDetailsMain" class="first">상세검색</a></li>
# 				<li><a href="#" onclick="krxPaPago_open(); return false;" class="first">KRX-Papago번역기</a></li>
# 				<li><a href="/disclosure/searchtotalinfo.do?method=searchTotalInfoMain" class="first">통합검색</a></li>
# 				<li><a href="/disclosure/searchbondcorpdisclosure.do?method=searchBondCorpDisclosureMain" class="first">채권공시</a></li>
# 				<li><a href="#" class="more">ETF/ELW/ETN<span><img src="../images/common/bg_gnb_gmn2.gif" alt="메뉴 더보기"/></span></a></li>
# 						<DIV id="sub" class="gnb1-wrapper">
# 							<nav id="gnb1"><DL>
# 							<DD>
# 							<DIV class="lnb">
# 								<DIV class="wrapper">
# 									<A class="lmn" href="/disclosure/disclosurebystocktype.do?method=searchDisclosureByStockTypeEtf">ETF</A>
# 									<A class="lmn" href="/disclosure/disclosurebystocktype.do?method=searchDisclosureByStockTypeElw">ELW</A>
# 									<A class="lmn" href="/disclosure/disclosurebystocktype.do?method=searchDisclosureByStockTypeEtn">ETN</A>
# 									<IMG class="arrow" src="../images/common/lnb_arrow_sub.png" />
# 									<IMG class="tl" src="../images/common/lnb_tl.png" />
# 									<IMG class="tr" src="../images/common/lnb_tr.png" />
# 									<IMG class="bl" src="../images/common/lnb_bl.png" />
# 									<IMG class="br" src="../images/common/lnb_br.png" />
# 								</DIV>
# 							</DIV>
# 							</DD>
# 							</DL></nav>
# 						</DIV>
# 				<li><a href="#" class="more">펀드공시<span><img src="../images/common/bg_gnb_gmn2.gif" alt="메뉴 더보기"/></span></a></li>
# 						<DIV id="sub" class="gnb1-wrapper">
# 							<nav id="gnb1"><DL>
# 							<DD>
# 							<DIV class="lnb">
# 								<DIV class="wrapper">
# 									<A class="lmn" href="/disclosure/disclosurebystocktype.do?method=searchDisclosureByStockTypeRestinvstcom">부동산투자회사</A>
# 									<A class="lmn" href="/disclosure/disclosurebystocktype.do?method=searchDisclosureByStockTypeShipinvstcom">선박투자회사</A>
# 									<A class="lmn" href="/disclosure/disclosurebystocktype.do?method=searchDisclosureByStockTypeInvstcom">투자회사</A>
# 									<A class="lmn" href="/disclosure/disclosurebystocktype.do?method=searchDisclosureByStockTypeBenfcert">수익증권</A>
# 									<IMG class="arrow" src="../images/common/lnb_arrow_sub.png" />
# 									<IMG class="tl" src="../images/common/lnb_tl.png" />
# 									<IMG class="tr" src="../images/common/lnb_tr.png" />
# 									<IMG class="bl" src="../images/common/lnb_bl.png" />
# 									<IMG class="br" src="../images/common/lnb_br.png" />
# 								</DIV>
# 							</DIV>
# 							</DD>
# 							</DL></nav>
# 						</DIV>
# 				<li><a href="/disclosure/misccorpdiscls.do?method=searchMiscCorpDisclsMain" class="first">기타법인공시</a></li>
# 				<li><a href="#" class="more">의결권행사공시<span><img src="../images/common/bg_gnb_gmn2.gif" alt="메뉴 더보기"/></span></a></li>
# 						<DIV id="sub" class="gnb1-wrapper">
# 							<nav id="gnb1"><DL>
# 							<DD>
# 							<DIV class="lnb">
# 								<DIV class="wrapper">
# 									<A class="lmn" href="/disclosure/disclosurebyvote.do?method=searchDisclosurebyVoteMain">의결권행사공시</A>
# 									<A class="lmn" href="https://dis.kofia.or.kr/websquare/index.jsp?w2xPath=/wq/compann/DISFndVoteRightView.xml&divisionId=MDIS02003010000000&serviceId=SDIS02003010000#!" target="_blank">운용사 펀드의결권행사공시</A>
# 									<A class="lmn" href="https://dis.kofia.or.kr/websquare/index.jsp?w2xPath=/wq/compann/DISFndVoteRightViewDet.xml&divisionId=MDIS02003011000000&serviceId=SDIS02003011000" target="_blank">펀드별 의결권행사공시</A>
# 									<IMG class="arrow" src="../images/common/lnb_arrow_sub.png" />
# 									<IMG class="tl" src="../images/common/lnb_tl.png" />
# 									<IMG class="tr" src="../images/common/lnb_tr.png" />
# 									<IMG class="bl" src="../images/common/lnb_bl.png" />
# 									<IMG class="br" src="../images/common/lnb_br.png" />
# 								</DIV>
# 							</DIV>
# 							</DD>
# 							</DL></nav>
# 						</DIV>
#
#
# 				<li><a href="/corpdetail/chart.do?method=loadInitPage" class="first">공시차트</a></li>
#
# 				<li><a href="/disclosure/searchErrorTradeRelief.do?method=searchErrorTradeReliefMain" class="first">착오매매구제신청</a></li>
#
# 				<!-- 신종증권 메뉴 제외 -->
# 				<!--<li><a href="#" class="more">신종증권<span><img src="../images/common/bg_gnb_gmn2.gif" alt="메뉴 더보기"/></span></a></li>
# 						<DIV id="sub" class="gnb1-wrapper">
# 							<nav id="gnb1">
# 							<DL>
# 							<DD>
# 							<DIV class="lnb">
# 								<DIV class="wrapper">
# 									<A class="lmn" href="/digital/digitalList.do?method=digitalList">비금전신탁수익증권</A>
# 									<A class="lmn" href="/digital/digitalInvstList.do?method=digitalInvstList">투자계약증권</A>
# 									<IMG class="arrow" src="../images/common/lnb_arrow_sub.png" />
# 									<IMG class="tl" src="../images/common/lnb_tl.png" />
# 									<IMG class="tr" src="../images/common/lnb_tr.png" />
# 									<IMG class="bl" src="../images/common/lnb_bl.png" />
# 									<IMG class="br" src="../images/common/lnb_br.png" />
# 								</DIV>
# 							</DIV>
# 							</DD>
# 							</DL>
# 							</nav>
# 						</DIV>
# 						-->
# 			</ul>
# 		</article>
# 		<article class="list">
# 			<h3>상장법인상세정보</h3>
# 			<ul>
#
# 				<li><a href="/corpdetail/totalinfo.do?method=loadInitPage" class="first">종합정보</a></li>
# 				<li><a href="/corpgeneral/listedIssueStatus.do?method=loadInitPage" class="first">상장종목현황</a></li>
#
# 				<li><a href="/corpgeneral/corpList.do?method=loadInitPage" class="first">상장법인목록</a></li>
# 				<li><a href="/corpgeneral/stockissuelist.do?method=loadInitPage" class="first">주식발행내역</a></li>
# 				<li><a href="#" class="more">기업지배구조<span><img src="../images/common/bg_gnb_gmn2.gif" alt="메뉴 더보기"/></span></a></li>
# 						<DIV id="sub" class="gnb1-wrapper">
# 							<nav id="gnb1"><DL>
# 							<DD>
# 							<DIV class="lnb">
# 								<DIV class="wrapper">
# 									<A class="lmn" href="/corpgeneral/companyGovernance.do?method=loadInitPage">기업지배구조 보고서</A>
# 									<A class="lmn" href="http://www.cgs.or.kr/business/esg_tab04.jsp" target="_blank">ESG등급</A>
# 									<IMG class="arrow" src="../images/common/lnb_arrow_sub.png" />
# 									<IMG class="tl" src="../images/common/lnb_tl.png" />
# 									<IMG class="tr" src="../images/common/lnb_tr.png" />
# 									<IMG class="bl" src="../images/common/lnb_bl.png" />
# 									<IMG class="br" src="../images/common/lnb_br.png" />
# 								</DIV>
# 							</DIV>
# 							</DD>
# 							</DL></nav>
# 						</DIV>
# 				<li><a href="/corpgeneral/treasurystk.do?method=loadInitPage" class="first">자사주취득/처분</a></li>
# 				<li><a href="#" class="more">IR일정/IR자료실<span><img src="../images/common/bg_gnb_gmn2.gif" alt="메뉴 더보기"/></span></a></li>
# 						<DIV id="sub" class="gnb1-wrapper">
# 							<nav id="gnb1"><DL>
# 							<DD>
# 							<DIV class="lnb">
# 								<DIV class="wrapper">
# 									<A class="lmn" href="/corpgeneral/irschedule.do?method=searchIRScheduleMain&gubun=iRSchedule">IR일정</A>
# 									<A class="lmn" href="/corpgeneral/irschedule.do?method=searchIRScheduleMain&gubun=iRMaterials">IR자료실</A>
# 									<A class="lmn" href="http://www.kirs.or.kr/media/ceo.html" target="_blank">CEO인터뷰</A>
# 									<A class="lmn" href="/corpgeneral/irschedule.do?method=searchIRScheduleMain&gubun=iRScheduleCalendar">IR일정 달력</A>
# 									<IMG class="arrow" src="../images/common/lnb_arrow_sub.png" />
# 									<IMG class="tl" src="../images/common/lnb_tl.png" />
# 									<IMG class="tr" src="../images/common/lnb_tr.png" />
# 									<IMG class="bl" src="../images/common/lnb_bl.png" />
# 									<IMG class="br" src="../images/common/lnb_br.png" />
# 								</DIV>
# 							</DIV>
# 							</DD>
# 							</DL></nav>
# 						</DIV>
#
# 				<li><a href="#" class="more">기업분석보고서<span><img src="../images/common/bg_gnb_gmn2.gif" alt="메뉴 더보기"/></span></a></li>
# 						<DIV id="sub" class="gnb1-wrapper">
# 							<nav id="gnb1"><DL>
# 							<DD>
# 							<DIV class="lnb">
# 								<DIV class="wrapper">
# 									<A class="lmn" href="/corpgeneral/companyAnalysisReport.do?method=listingForeignCompanyMain&searchGubun=companyAnalysisReport">기업분석리포트</A>
# 									<A class="lmn" href="/corpgeneral/newListingForeignCompany.do?method=listingForeignCompanyMain&searchGubun=newListingForeignCompany">신규상장기업분석보고서</A>
# 									<A class="lmn" href="/corpgeneral/growthReport.do?method=listingForeignCompanyMain&searchGubun=growthReport">사업모델 평가보고서 및 기업 계속성 보고서</A>
#
# 									<IMG class="arrow" src="../images/common/lnb_arrow_sub.png" />
# 									<IMG class="tl" src="../images/common/lnb_tl.png" />
# 									<IMG class="tr" src="../images/common/lnb_tr.png" />
# 									<IMG class="bl" src="../images/common/lnb_bl.png" />
# 									<IMG class="br" src="../images/common/lnb_br.png" />
# 								</DIV>
# 							</DIV>
# 							</DD>
# 							</DL></nav>
# 						</DIV>
#
# 				<li><a href="/corpgeneral/corpGroup.do?method=loadInitPage" class="first">기업집단</a></li>
# 				<li><a href="#" class="more">배당정보<span><img src="../images/common/bg_gnb_gmn2.gif" alt="메뉴 더보기"/></span></a></li>
# 				<DIV id="sub" class="gnb1-wrapper">
# 							<nav id="gnb1"><DL>
# 							<DD>
# 							<DIV class="lnb">
# 								<DIV class="wrapper">
# 									<A class="lmn" href="/disclosureinfo/dividendinfo.do?method=searchDividendInfoMain">배당정보</A>
# 									<A class="lmn" href="http://data.krx.co.kr/contents/MDC/MDI/mdiLoader/index.cmd?menuId=MDC0201010107" target="_blank">업종배당수익율</A>
# 									<IMG class="arrow" src="../images/common/lnb_arrow_sub.png" />
# 									<IMG class="tl" src="../images/common/lnb_tl.png" />
# 									<IMG class="tr" src="../images/common/lnb_tr.png" />
# 									<IMG class="bl" src="../images/common/lnb_bl.png" />
# 									<IMG class="br" src="../images/common/lnb_br.png" />
# 								</DIV>
# 							</DIV>
# 							</DD>
# 							</DL></nav>
# 						</DIV>
# 				<li><a href="/compfinance/financialinfo.do?method=loadInitPage&searchgubun=corporation" class="first">회사재무비교</a></li>
# 				<li><a href="/corpgeneral/excntDisclsCompany.do?method=loadInitPage" class="first">공시우수법인</a></li>
# 				<li><a href="/corpdetail/ventureFundInvest.do?method=corpListMain" class="first">벤처펀드투자기업(코)</a></li>
# 				<!-- 신종증권 메뉴 제외 -->
# 				<!--<li><a href="/digital/digitalCorpList.do?method=digitalCorpList" class="first">상장종목(신종증권)</a></li>-->
# 			</ul>
# 		</article>
# 		<article class="list">
# 			<h3>기업 밸류업 정보</h3>
# 			<ul>
# 				<li><a href="/valueup/intro.do?method=valueupIntroMain" class="first">기업 밸류업 소개</a></li>
# 				<li><a href="/valueup/notice.do?method=valueupNoticeMain" class="first">공지사항</a></li>
# 				<li><a href="/valueup/disclsstat.do?method=valueupDisclsStatMain" class="first">공시현황</a></li>
#
# 				<li><a href="#" class="more">투자지표<span><img src="../images/common/bg_gnb_gmn2.gif" alt="메뉴 더보기"/></span></a></li>
# 						<DIV id="sub" class="gnb1-wrapper">
# 							<nav id="gnb1"><DL>
# 								<DD>
# 								<DIV class="lnb">
# 								<DIV class="wrapper">
# 								<A class="lmn" href="/valueup/invstindicsectors.do?method=valueupInvstIndicRankIndMain">업종별 투자지표 순위</A>
# 								<A class="lmn" href="/valueup/invstindicstocks.do?method=valueupInvstIndicRankIsuMain">종목별 투자지표 추이</A>
# 								<IMG class="arrow" src="../images/common/lnb_arrow_sub.png" />
# 								<IMG class="tl" src="../images/common/lnb_tl.png" />
# 								<IMG class="tr" src="../images/common/lnb_tr.png" />
# 								<IMG class="bl" src="../images/common/lnb_bl.png" />
# 								<IMG class="br" src="../images/common/lnb_br.png" />
# 								</DIV>
# 								</DIV>
# 								</DD>
# 							</DL></nav>
# 						</DIV>
# 				<li><a href="/valueup/idx.do?method=valueupIdxMain" class="first">인덱스</a></li>
#
# 				<li><a href="/valueup/excntcorp.do?method=valueupExcntCorpMain" class="first">기업 밸류업 우수법인</a></li>
# 				<li><a href="/valueup/resoroom.do?method=valueupResoroomMain" class="first">자료실</a></li>
# 			</ul>
# 		</article>
#
# 		<article class="list weight">
# 			<h3>투자유의사항</h3>
# 			<ul>
# 				<li><a href="/investwarn/adminissue.do?method=searchAdminIssueList" class="first">관리종목</a></li>
# 				<li><a href="/investwarn/hwangiissue.do?method=searchHwangiIssueMain" class="first">투자주의환기종목(코)</a></li>
#
# 				<li><a href="/investwarn/tradinghaltissue.do?method=searchTradingHaltIssueMain" class="first">매매거래정지종목</a></li>
#
# 				<li><a href="/investwarn/undisclosure.do?method=searchUnfaithfulDisclosureCorpList" class="first">불성실공시법인</a></li>
#
# 				<li><a href="/investwarn/investattentwarnrisky.do?method=investattentwarnriskyMain" class="first">투자주의/경고/위험종목</a></li>
#
# 				<li><a href="/corpgeneral/delistRealInvstg.do?method=searchDelistRealInvstgMain" class="first">실질심사법인</a></li>
# 				<li><a href="/investwarn/investattentEmbezzlement.do?method=searchInvestAttentEmbezzlementMain" class="first">횡령 등</a></li>
# 				<li><a href="/investwarn/investattentLargeShareChange.do?method=searchInvestAttentLargeShareChangeMain" class="first">최대주주변경2회이상</a></li>
# 				<li><a href="#" class="more">기타사항<span><img src="../images/common/bg_gnb_gmn2.gif" alt="메뉴 더보기"/></span></a></li>
# 						<DIV id="sub" class="gnb1-wrapper">
# 							<nav id="gnb1"><DL>
# 							<DD>
# 							<DIV class="lnb">
# 								<DIV class="wrapper">
# 									<A class="lmn" href="/investwarn/investattentEtcMarket.do?method=searchInvestAttentEtcMarketMain">기타 시장안내</A>
# 									<A class="lmn" href="/investwarn/prtdepoStat.do?method=searchPrtdepoStatMain">의무보유현황(유가)</A>
# 									<A class="lmn" href="/investwarn/penalty.do?method=searchPenaltyImprovementList">벌점및개선계획서 현황</A>
# 									<A class="lmn" href="/investwarn/delcompany.do?method=searchDelCompanyMain">상장폐지현황</A>
# 									<A class="lmn" href="/investwarn/delListDelibRec.do?method=searchDelListDelibRecMain">상장폐지최종심의의사록</A>
# 									<A class="lmn" href="/investwarn/investwarnGuide.do?method=searchInvestGuideMain">투자유의안내</A>
#
# 									<A class="lmn" href="/disclosureinfo/nfaithdisclsdecl.do?method=insertNfaithdisclsDeclMain">불성실공시 신고포상</A>
#
# 									<IMG class="arrow" src="../images/common/lnb_arrow_sub.png" />
# 									<IMG class="tl" src="../images/common/lnb_tl.png" />
# 									<IMG class="tr" src="../images/common/lnb_tr.png" />
# 									<IMG class="bl" src="../images/common/lnb_bl.png" />
# 									<IMG class="br" src="../images/common/lnb_br.png" />
# 								</DIV>
# 							</DIV>
# 							</DD>
# 							</DL></nav>
# 						</DIV>
# 			</ul>
# 		</article>
# 		<article class="list">
# 			<h3>IPO현황</h3>
# 			<ul>
#
# 				<li><a href="/listinvstg/listinvstgcom.do?method=searchListInvstgCorpMain" class="first">예비심사기업</a></li>
# 				<li><a href="/listinvstg/listapplcom.do?method=searchListApplCorpMain" class="first">코넥스 상장신청기업</a></li>
# 				<li><a href="#" class="more">공모기업<span><img src="../images/common/bg_gnb_gmn2.gif" alt="메뉴 더보기"/></span></a></li>
# 						<DIV id="sub" class="gnb1-wrapper">
# 							<nav id="gnb1"><DL>
# 								<DD>
# 								<DIV class="lnb">
# 								<DIV class="wrapper">
# 								<A class="lmn" href="/listinvstg/pubofrprogcom.do?method=searchPubofrProgComMain">공모기업현황</A>
# 								<A class="lmn" href="/listinvstg/pubofrschdl.do?method=searchPubofrScholMain">공모일정</A>
# 								<IMG class="arrow" src="../images/common/lnb_arrow_sub.png" />
# 								<IMG class="tl" src="../images/common/lnb_tl.png" />
# 								<IMG class="tr" src="../images/common/lnb_tr.png" />
# 								<IMG class="bl" src="../images/common/lnb_bl.png" />
# 								<IMG class="br" src="../images/common/lnb_br.png" />
# 								</DIV>
# 								</DIV>
# 								</DD>
# 							</DL></nav>
# 						</DIV>
# 				<li><a href="#" class="more">신규상장기업<span><img src="../images/common/bg_gnb_gmn2.gif" alt="메뉴 더보기"/></span></a></li>
# 						<DIV id="sub" class="gnb1-wrapper">
# 							<nav id="gnb1"><DL>
# 								<DD>
# 								<DIV class="lnb">
# 								<DIV class="wrapper">
# 								<A class="lmn" href="/listinvstg/listingcompany.do?method=searchListingTypeMain">신규상장기업현황</A>
# 								<A class="lmn" href="/listinvstg/mergeListingCompany.do?method=searchMergeListingCompMain">합병상장기업현황</A>
# 								<A class="lmn " href="/listinvstg/genfinance.do?method=searchGenFinanaceMain">재무현황</A>
# 								<A class="lmn " href="/listinvstg/pubprcCmpStkprcByIssue.do?method=pubprcCmpStkprcByIssueMain">공모가대비주가정보</A>
# 								<IMG class="arrow" src="../images/common/lnb_arrow_sub.png" />
# 								<IMG class="tl" src="../images/common/lnb_tl.png" />
# 								<IMG class="tr" src="../images/common/lnb_tr.png" />
# 								<IMG class="bl" src="../images/common/lnb_bl.png" />
# 								<IMG class="br" src="../images/common/lnb_br.png" />
# 								</DIV>
# 								</DIV>
# 								</DD>
# 							</DL></nav>
# 						</DIV>
#
# 				<li><a href="#" class="more">신규상장통계<span><img src="../images/common/bg_gnb_gmn2.gif" alt="메뉴 더보기"/></span></a></li>
# 						<DIV id="sub" class="gnb1-wrapper">
# 							<nav id="gnb1"><DL>
# 								<DD>
# 								<DIV class="lnb">
# 								<DIV class="wrapper">
# 								<A class="lmn" href="/listinvstg/listtypestat.do?method=searchListTypeStatusMain">상장통계</A>
#
# 								<A class="lmn " href="/listinvstg/puboframt.do?method=searchPubofrAmtMain">공모통계</A>
# 								<A class="lmn " href="/listinvstg/ipoprfm.do?method=searchIpoPrfmMain">상장주선인 IPO실적</A>
#
# 								<A class="lmn " href="/listinvstg/advseripoprfm.do?method=searchAdvserIpoPrfmMain">지정자문인 상장실적</A>
# 								<IMG class="arrow" src="../images/common/lnb_arrow_sub.png" />
# 								<IMG class="tl" src="../images/common/lnb_tl.png" />
# 								<IMG class="tr" src="../images/common/lnb_tr.png" />
# 								<IMG class="bl" src="../images/common/lnb_bl.png" />
# 								<IMG class="br" src="../images/common/lnb_br.png" />
# 								</DIV>
# 								</DIV>
# 								</DD>
# 							</DL></nav>
# 						</DIV>
# 				<li><a href="/listinvstg/listinvstginfo.do?method=searchListInvstgInfoMain" class="first">상장심사가이드</a></li>
# 			</ul>
# 			<h3>정보실</h3>
# 			<ul>
# 				<li><a href="/disclosureinfo/notice.do?method=searchNoticeMain" class="first">공지사항</a></li>
# 				<!-- li><a href="/news/searchnews.do?method=searchNewsMain" class="first">증시뉴스</a></li -->
# 				<li><a href="/disclosureinfo/explanationsystem.do?method=searchSysInfo" class="first">제도해설</a></li>
# 				<li><a href="/disclosureinfo/searchmaterials.do?method=searchMaterialsMain" class="first">자료실</a></li>
# 			</ul>
# 		</article>
# 	</section>
# 	<section class="list-wrapper config">
# 		<article class="list">
# 			<h3>공시</h3>
# 			<ul>
# 				<li><input type="checkbox" id="chkEdit01" name="checkboxMenu" value="ULDDST00000" /> <label for="chkEdit01">오늘의공시</label></li>
# 				<li><input type="checkbox" id="chkEdit02" name="checkboxMenu" value="ULDDST00100" /> <label for="chkEdit02">회사별검색</label></li>
# 				<li><input type="checkbox" id="chkEdit03" name="checkboxMenu" value="ULDDST00300" /> <label for="chkEdit03">상세검색</label></li>
# 				<li><input type="checkbox" id="chkEdit04" name="checkboxMenu" value="ULDDST00200" /> <label for="chkEdit04">통합검색</label></li>
# 				<li><input type="checkbox" id="chkEdit05" name="checkboxMenu" value="ULDDST00700" /> <label for="chkEdit05">채권공시</label></li>
# 				<li><input type="checkbox" id="chkEdit06" name="checkboxMenu" value="ULDDST00400" /> <label for="chkEdit06">ETF ELW ETN</label></li>
# 				<li><input type="checkbox" id="chkEdit07" name="checkboxMenu" value="JLDDST00403" /> <label for="chkEdit07">펀드공시</label></li>
# 				<li><input type="checkbox" id="chkEdit08" name="checkboxMenu" value="ULDDST01300" /> <label for="chkEdit08">기타법인공시</label></li>
# 				<li><input type="checkbox" id="chkEdit010" name="checkboxMenu" value="ULDDST01500" /> <label for="chkEdit010">의결권행사공시</label></li>
#
# 				<li><input type="checkbox" id="chkEdit09" name="checkboxMenu" value="ULDDST10400" /> <label for="chkEdit09">공시차트</label></li>
#
# 			<li><input type="checkbox" id="chkEdit40" name="checkboxMenu" value="ULDDST01600" /><label for="chkEdit40">착오매매구제신청</label></li>
# 			<!-- 신종증권 메뉴 제외 -->
# 			<!--<li><input type="checkbox" id="chkEdit50" name="checkboxMenu" value="ULDDST20000" /><label for="chkEdit50">신종증권</label></li>-->
# 			</ul>
# 		</article>
# 		<article class="list">
# 			<h3>상장법인상세정보</h3>
# 			<ul>
#
# 				<li><input type="checkbox" id="chkEdit10" name="checkboxMenu" value="ULDDST10000" /> <label for="chkEdit10">종합정보</label></li>
# 				<li><input type="checkbox" id="chkEdit11" name="checkboxMenu" value="ULDDST05000" /> <label for="chkEdit11">상장종목현황</label></li>
#
# 				<li><input type="checkbox" id="chkEdit12" name="checkboxMenu" value="ULDDST05100" /> <label for="chkEdit12">상장법인목록</label></li>
# 				<li><input type="checkbox" id="chkEdit13" name="checkboxMenu" value="ULDDST06000" /> <label for="chkEdit13">주식발행내역</label></li>
# 				<li><input type="checkbox" id="chkEdit41" name="checkboxMenu" value="ULDDST38150" /> <label for="chkEdit41">기업지배구조</label></li>
# 				<li><input type="checkbox" id="chkEdit14" name="checkboxMenu" value="ULDDST05300" /> <label for="chkEdit14">자사주취득처분</label></li>
# 				<li><input type="checkbox" id="chkEdit15" name="checkboxMenu" value="ULDDST05600" /> <label for="chkEdit15">IR일정IR자료실</label></li>
#
# 				<li><input type="checkbox" id="chkEdit16" name="checkboxMenu" value="ULDDST38010" /> <label for="chkEdit16">기업분석보고서</label></li>
#
# 				<li><input type="checkbox" id="chkEdit17" name="checkboxMenu" value="ULDDST05800" /> <label for="chkEdit17">기업진단</label></li>
#
# 				<li><input type="checkbox" id="chkEdit18" name="checkboxMenu" value="ULDDST36400" /> <label for="chkEdit18">배당정보</label></li>
#
# 				<li><input type="checkbox" id="chkEdit19" name="checkboxMenu" value="ULDDST15400" /> <label for="chkEdit19">회사재무비교</label></li>
# 				<li><input type="checkbox" id="chkEdit39" name="checkboxMenu" value="JLDDST38140" /> <label for="chkEdit39">공시우수법인</label></li>
# 				<li><input type="checkbox" id="chkEdit42" name="checkboxMenu" value="JLDDST11000" /> <label for="chkEdit42">벤처펀드투자대상기업(코)</label></li>
# 				<!-- 신종증권 메뉴 제외 -->
# 				<!--<li><input type="checkbox" id="chkEdit43" name="checkboxMenu" value="JLDDST30200" /> <label for="chkEdit43">상장종목(신종증권)</label></li>-->
# 			</ul>
# 		</article>
# 		<article class="list">
# 			<h3>기업 밸류업 정보</h3>
# 			<ul>
# 				<li><input type="checkbox" id="chkEdit44" name="checkboxMenu" value="ULDDST80100" /> <label for="chkEdit44">기업 밸류업 소개</label></li>
# 				<li><input type="checkbox" id="chkEdit45" name="checkboxMenu" value="ULDDST80200" /> <label for="chkEdit45">공지사항</label></li>
# 				<li><input type="checkbox" id="chkEdit46" name="checkboxMenu" value="ULDDST80300" /> <label for="chkEdit46">공시현황</label></li>
#
# 				<li><input type="checkbox" id="chkEdit47" name="checkboxMenu" value="ULDDST80400" /> <label for="chkEdit47">투자지표</label></li>
#
# 				<li><input type="checkbox" id="chkEdit48" name="checkboxMenu" value="ULDDST80500" /> <label for="chkEdit48">인덱스</label></li>
# 				<li><input type="checkbox" id="chkEdit49" name="checkboxMenu" value="ULDDST80600" /> <label for="chkEdit49">기업 밸류업 우수법인</label></li>
# 				<li><input type="checkbox" id="chkEdit50" name="checkboxMenu" value="ULDDST80700" /> <label for="chkEdit50">자료실</label></li>
# 			</ul>
# 		</article>
# 		<article class="list">
# 			<h3>투자유의사항</h3>
# 			<ul>
# 				<li><input type="checkbox" id="chkEdit25" name="checkboxMenu" value="ULDDST30000" /> <label for="chkEdit25">관리종목</label></li>
# 				<li><input type="checkbox" id="chkEdit26" name="checkboxMenu" value="ULDDST30900" /> <label for="chkEdit26">투자주의환기종목(코)</label></li>
#
# 				<li><input type="checkbox" id="chkEdit27" name="checkboxMenu" value="ULDDST30400" /> <label for="chkEdit27">매매거래정지종목</label></li>
#
# 				<li><input type="checkbox" id="chkEdit28" name="checkboxMenu" value="ULDDST30100" /> <label for="chkEdit28">불성실공시법인</label></li>
#
# 				<li><input type="checkbox" id="chkEdit29" name="checkboxMenu" value="ULDDST30500" /> <label for="chkEdit29">투자주의경고위험</label></li>
#
# 				<li><input type="checkbox" id="chkEdit30" name="checkboxMenu" value="ULDDST05900" /> <label for="chkEdit30">실질심사법인</label></li>
# 				<li><input type="checkbox" id="chkEdit31" name="checkboxMenu" value="ULDDST30301" /> <label for="chkEdit31">횡령 등</label></li>
# 				<li><input type="checkbox" id="chkEdit32" name="checkboxMenu" value="ULDDST30302" /> <label for="chkEdit32">최대주주변경2회이상</label></li>
# 				<li><input type="checkbox" id="chkEdit33" name="checkboxMenu" value="ULDDST30301" /> <label for="chkEdit33">기타사항</label></li>
# 			</ul>
# 		</article>
# 		<article class="list">
# 			<h3>IPO현황</h3>
# 			<ul>
#
# 				<li><input type="checkbox" id="chkEdit20" name="checkboxMenu" value="ULDDST71000" /> <label for="chkEdit20">예비심사기업</label></li>
#
# 				<li><input type="checkbox" id="chkEdit38" name="checkboxMenu" value="ULDDST71100" /> <label for="chkEdit38">코넥스 상장신청기업</label></li>
# 				<li><input type="checkbox" id="chkEdit21" name="checkboxMenu" value="ULDDST72000" /> <label for="chkEdit21">공모기업</label></li>
#
# 				<li><input type="checkbox" id="chkEdit22" name="checkboxMenu" value="ULDDST70000" /> <label for="chkEdit22">신규상장기업</label></li>
#
# 				<li><input type="checkbox" id="chkEdit23" name="checkboxMenu" value="ULDDST73000" /> <label for="chkEdit23">신규상장통계</label></li>
# 				<li><input type="checkbox" id="chkEdit24" name="checkboxMenu" value="ULDDST75000" /> <label for="chkEdit24">상장심사가이드</label></li>
# 			</ul>
# 			<h3>정보실</h3>
# 			<ul>
# 				<li><input type="checkbox" id="chkEdit34" name="checkboxMenu" value="ULDDST35100" /> <label for="chkEdit34">공지사항</label></li>
# 				<!-- li><input type="checkbox" id="chkEdit35" name="checkboxMenu" value="ULDDST25000" /> <label for="chkEdit35">증시뉴스</label></li -->
# 				<li><input type="checkbox" id="chkEdit36" name="checkboxMenu" value="ULDDST35400" /> <label for="chkEdit36">제도해설</label></li>
# 				<li><input type="checkbox" id="chkEdit37" name="checkboxMenu" value="ULDDST35700" /> <label for="chkEdit37">자료실</label></li>
# 			</ul>
# 		</article>
#
# 	</section>
# 	<div class="clear"></div>
# 	<div class="wrapper-close">
# 		<a href="#" class="btn_sitemap-close"><img src="../images/common/btn_sitemap_close.gif" alt="전체메뉴닫기"/></a>
# 	</div>
# </section>
# <script type="text/javascript">
# $(document).ready(function(){
# 	fnInMyMenu();
# 	sitemap_init();
# });
# var cnt=0;
# function sitemap_init()
# {
# 	if($('section.sitemap').length<1) return;
# 	/*$('a.btn.sitemap.open').bind("click",function(e){
# 		e.preventDefault();
# 		$(this).addClass('hide');
# 		setTimeout(function(){
# 			$('section.sitemap').slideToggle(400);
# 		},200);
# 	});*/
#
# 	$('a.btn.sitemap.open').bind("click focus",function(e){
# 		e.preventDefault();
# 		if(cnt==0){
# 			$(this).addClass('hide');
# 			cnt=1;
# 			setTimeout(function(){
# 				$('section.sitemap').slideToggle(400);
# 			},200);
# 		}else if(cnt==1){
# 			setTimeout(function(){
# 				$('section.sitemap').slideToggle(400);
# 			},200);
# 			setTimeout(function(){
# 				$('a.btn.sitemap.open').removeClass('hide');
# 			},400);
#
# 			cnt=0;
# 		}
# 	});
# 	$('a.btn_sitemap-close').bind("click",function(e){
# 		e.preventDefault();
# 		setTimeout(function(){
# 			$('section.sitemap').slideToggle(400,function(){
# 				cnt=0;
# 				$('a.btn.sitemap.open').removeClass('hide');
# 			});
# 		},100);
# 	});
#
# 	$('section.sitemap a.first').bind("mouseover focus",function(){
# 		$('section.sitemap article').removeClass("active");
# 		$(this).parent().addClass("active");
# 		$(this).parent().parent().parent().addClass("active");
# 	});
# 	$('section.sitemap a.first').bind("mouseout focusout",function(){
# 		$(this).parent().removeClass("active");
# 	});
#
# 	$('section.sitemap span , section.sitemap input[type=checkbox]').bind("mouseover focus",function(){
# 		$('section.sitemap article').removeClass("active");
# 		$(this).parent().parent().addClass("active");
# 		$(this).parent().parent().parent().parent().addClass("active");
# 	});
# 	$('section.sitemap span , section.sitemap input[type=checkbox]').bind("mouseout focusout",function(){
# 		$(this).parent().parent().removeClass("active");
# 	});
#
# 	$('section.sitemap article').bind("mouseleave focusout",function(){
# 		$(this).removeClass("active");
# 	});
# 	$('section.sitemap a.btn_sitemap-set').click(function(e){
# 		e.preventDefault();
# 		if(!$('section.sitemap').hasClass("chkon"))
# 		{
# 			$('section.sitemap section.list-wrapper.links').hide();
# 			$('section.sitemap section.list-wrapper.config').show();
# 			$('section.sitemap').addClass("chkon");
# 			$(this).children("img").attr("src",$(this).children("img").attr("src").replace("_set","_active"));
# 			$(this).children("img").attr("alt","확인");
# 		}
# 		else
# 		{
# 			fnSetCookieMyMenu();
# 			$('section.sitemap section.list-wrapper.links').show();
# 			$('section.sitemap section.list-wrapper.config').hide();
# 			$('section.sitemap').removeClass("chkon");
# 			$(this).children("img").attr("src",$(this).children("img").attr("src").replace("_active","_set"));
# 			$(this).children("img").attr("alt","설정");
# 		}
# 	});
#
# 	try
# 	{
# 		if($.browser.msie && $.browser.version == "7.0") {
# 			$('div.gnb1-wrapper').css("top"	, -3);
# 		}
#
# 		var btnMore = $('div.gnb1-wrapper'); //submenu
# 		var imgArrow = $('#sub nav#gnb1 div.lnb div.wrapper img.arrow'); //화살표
# 		$('section.sitemap a.first').bind("mouseover focus",function(){
# 			fnSubClose(btnMore, -1); //모든 submenu 닫기
# 		});
#
# 		$('section.sitemap article li a.more').each(function(i) {
# 			$(this).bind("mouseover focus",function(){
# 				$(this).parent().addClass("active");
# 				$(this).parent().parent().parent().addClass("active");
# 				$(this).children("span").children("img").attr("src","../images/common/bg_gnb_gmn2_active.gif");
#
# 				fnSubClose(btnMore, i) //모든 submenu 닫기
#
# 				var left1	= $(this).parent().offset().left;
# 				var left2	= $(this).children("span").children("img").offset().left;
# 				var leftVal = left2 - left1 - 2;
# 				if(i == 7){
# 					leftVal = leftVal - 6;
# 				}
# 				imgArrow.eq(i).css("left", leftVal);
# 				btnMore.eq(i).show();
# 			});
#
# 			btnMore.eq(i).bind("mouseleave",function(){
# 				btnMore.eq(i).hide();
# 			});
#
# 			$(this).bind("mouseout focusout",function(){
# 				$(this).parent().removeClass("active");
# 				$(this).children("span").children("img").attr("src","../images/common/bg_gnb_gmn2.gif");
# 			});
# 		});
#
# 	}catch(e){console.error(e.message);}
#
# }
#
# function fnInMyMenu(){
# 	var cookies = GetCookie('krxMenu');
# 	var cookieValue = "";
# 	if(cookies == null ){
# 		cookieValue = cookieValue + "ULDDST00000,오늘의공시/";
# 		cookieValue = cookieValue + "ULDDST00100,회사별검색/";
# 		cookieValue = cookieValue + "ULDDST00300,상세검색/";
# 		cookieValue = cookieValue + "ULDDST00200,통합검색/";
# 		cookieValue = cookieValue + "ULDDST71000,예비심사기업/";
# 		SetCookie('krxMenu',cookieValue ,'7');
# 	} else {
#
# 	}
#
# 	fnUpdateInMyMenu();
# }
#
# function fnSetCookieMyMenu(){
# 	var cookieValue = "";
# 	$('input:checkbox[name="checkboxMenu"]:checked').each(function(){
# 		var menuName = $("label[for="+this.id+"]").text().replace("/","");
# 		cookieValue += $(this).val()+","+menuName+"/";
# 	});
# 	SetCookie('krxMenu',cookieValue ,'7');
# 	fnUpdateInMyMenu();
# }
#
# function fnUpdateInMyMenu(){
# 	var cookies = GetCookie('krxMenu');
# 	if(cookies != null ){
# 		$("#myMenuTop").empty();
# 		var items = cookies.split("/");
# 		for(var i in items){
# 			var item = items[i].split(",");
# 			var menuId	 = item[0];
# 			var menuName = item[1];
# 			if(undefined != menuName){
# 				var url = fnGetInMyMenuUrl(menuId);
# 				$("#myMenuTop").append("<li><a href='"+url+"'>"+menuName+"</a></li>");
# 			}
#
# 			$('input:checkbox[name="checkboxMenu"]').each(function(){
# 				if($(this).val() == menuId)
# 					this.checked = true;
# 			});
# 		}
# 	}
# }
#
# function fnGetInMyMenuUrl(menuId){
#
# 	var url = {
# 			"ULDDST00000":"/disclosure/todaydisclosure.do?method=searchTodayDisclosureMain",						/*오늘의공시*/
# 			"ULDDST00100":"/disclosure/searchdisclosurebycorp.do?method=searchDisclosureByCorpMain",				/*회사별검색*/
# 			"ULDDST00300":"/disclosure/details.do?method=searchDetailsMain",										/*상세검색*/
# 			"ULDDST00200":"/disclosure/searchtotalinfo.do?method=searchTotalInfoMain",								/*통합검색*/
# 			"ULDDST00700":"/disclosure/searchbondcorpdisclosure.do?method=searchBondCorpDisclosureMain",			/*채권공시*/
# 			"ULDDST00400":"/disclosure/disclosurebystocktype.do?method=searchDisclosureByStockTypeEtf",				/*ETF/ELW/ETN*/
# 			"JLDDST00403":"/disclosure/disclosurebystocktype.do?method=searchDisclosureByStockTypeRestinvstcom",	/*펀드공시*/
# 			"ULDDST01300":"/disclosure/misccorpdiscls.do?method=searchMiscCorpDisclsMain",							/*기타법인공시*/
# 			"ULDDST01500":"/disclosure/disclosurebyvote.do?method=searchDisclosurebyVoteMain",						/*의결권공시*/
# 			"ULDDST10400":"/corpdetail/chart.do?method=loadInitPage",												/*공시차트*/
# 			"ULDDST01600":"/disclosure/searchErrorTradeRelief.do?method=searchErrorTradeReliefMain",				/*착오매매구제신청*/
# 			"ULDDST10000":"/corpdetail/totalinfo.do?method=loadInitPage",	/*종합정보*/
# 			"ULDDST05000":"/corpgeneral/listedIssueStatus.do?method=loadInitPage",	/*상장종목현황*/
# 			"ULDDST05100":"/corpgeneral/corpList.do?method=loadInitPage",	/*상장법인목록*/
# 			"ULDDST38150":"/corpgeneral/companyGovernance.do?method=loadInitPage", /*기업지배구조*/
# 			//"ULDDST20000":"/digital/digitalList.do?method=digitalList",				/* 신종증권 메뉴 제외  */
# 			"ULDDST06000":"/corpgeneral/stockissuelist.do?method=loadInitPage",	/*주식발행내역*/
# 			"ULDDST05300":"/corpgeneral/treasurystk.do?method=loadInitPage",	/*자사추취득처분*/
# 			"ULDDST05600":"/corpgeneral/irschedule.do?method=searchIRScheduleMain&gubun=iRScheduleCalendar",	/*IR일정IR자료실*/
# 			"ULDDST38010":"/corpgeneral/companyAnalysisReport.do?method=listingForeignCompanyMain&searchGubun=companyAnalysisReport",	/*기업분석보고서*/
# 			"ULDDST05800":"/corpgeneral/corpGroup.do?method=loadInitPage",	/*기업진단*/
# 			"ULDDST36400":"/disclosureinfo/dividendinfo.do?method=searchDividendInfoMain",	/*배당정보*/
# 			"ULDDST15400":"/compfinance/financialinfo.do?method=loadInitPage&searchgubun=corporation",	/*회사재무비교*/
# 			"JLDDST38140":"/corpgeneral/excntDisclsCompany.do?method=loadInitPage",	/*공시우수법인*/
# 			"JLDDST11000":"/corpdetail/ventureFundInvest.do?method=corpListMain",	/*벤처펀드투자기업(코)*/
# 			//"JLDDST30200":"/digital/digitalCorpList.do?method=digitalCorpList",	/*신종증권 상장종목(신종증권) - 신종증권 메뉴 제외*/
#
# 			"ULDDST80100":"/valueup/intro.do?method=valueupIntroMain",	/*기업밸류업소개*/
# 			"ULDDST80200":"/valueup/notice.do?method=valueupNoticeMain",	/*공지사항*/
# 			"ULDDST80300":"/valueup/disclsstat.do?method=valueupDisclsStatMain",	/*공시현황*/
# 			"ULDDST80400":"/valueup/invstindicsectors.do?method=valueupInvstIndicRankIndMain",	/*투자지표*/
# 			"ULDDST80500":"/valueup/idx.do?method=valueupIdxMain",	/*인덱스*/
# 			"ULDDST80600":"/valueup/excntcorp.do?method=valueupExcntCorpMain",	/*기업 밸류업 우수법인*/
# 			"ULDDST80700":"/valueup/resoroom.do?method=valueupResoroomMain",	/*자료실*/
#
# 			"ULDDST30000":"/investwarn/adminissue.do?method=searchAdminIssueList",	/*관리종목*/
# 			"ULDDST30900":"/investwarn/hwangiissue.do?method=searchHwangiIssueMain",	/*투자주의환기종목(코)*/
# 			"ULDDST30400":"/investwarn/tradinghaltissue.do?method=searchTradingHaltIssueMain",	/*매매거래정지종목*/
# 			"ULDDST30100":"/investwarn/undisclosure.do?method=searchUnfaithfulDisclosureCorpList",	/*불성실공시법인*/
# 			"ULDDST30500":"/investwarn/investattentwarnrisky.do?method=investattentwarnriskyMain",	/*투자주의-경고-위험종목*/
# 			"ULDDST05900":"/corpgeneral/delistRealInvstg.do?method=searchDelistRealInvstgMain",	/*실질심사법인*/
# 			"ULDDST30301":"/investwarn/investattentEmbezzlement.do?method=searchInvestAttentEmbezzlementMain",	/*횡령 등*/
# 			"ULDDST30302":"/investwarn/investattentLargeShareChange.do?method=searchInvestAttentLargeShareChangeMain",	/*최대주주변경2회이상*/
# 			"ULDDST30301":"/investwarn/investattentEtcMarket.do?method=searchInvestAttentEtcMarketMain",	/*기타사항*/
#
# 			"ULDDST71000":"/listinvstg/listinvstgcom.do?method=searchListInvstgCorpMain",		/*예비심사기업*/
# 			"ULDDST71100":"/listinvstg/listapplcom.do?method=searchListApplCorpMain",			/*코넥스상장신청기업*/
# 			"ULDDST72000":"/listinvstg/pubofrprogcom.do?method=searchPubofrProgComMain",		/*공모기업*/
# 			"ULDDST70000":"/listinvstg/listingcompany.do?method=searchListingTypeMain",			/*신규상장기업*/
# 			"ULDDST73000":"/listinvstg/listtypestat.do?method=searchListTypeStatusMain",		/*신규상장통계*/
# 			"ULDDST75000":"/listinvstg/listinvstginfo.do?method=searchListInvstgInfoMain",		/*상장심사가이드*/
#
# 			"ULDDST35100":"/disclosureinfo/notice.do?method=searchNoticeMain",	/*공지사항*/
# 			//"ULDDST25000":"/news/searchnews.do?method=searchNewsMain", /*증시뉴스*/
# 			"ULDDST35400":"/disclosureinfo/explanationsystem.do?method=searchSysInfo",	/*제도해설*/
# 			"ULDDST35700":"/disclosureinfo/searchmaterials.do?method=searchMaterialsMain"	/*자료실*/
#
# 	}
#
# 	return url[menuId];
# }
#
# function fnSubClose(array, i)
# {
# 	for(var a=0;a<array.length;a++){
# 		if(a != i){ array.eq(a).hide(); }
# 	}
# }
#
# </script>
# 	<!-- TOP MENU END -->
# </div>
# 	<div class="gnb-wrapper">
# 		<nav id="gnb">
# 			<dl>
# 				<dt><a href="/">홈</a></dt>
#
#
#
# 					<!-- Lv1 -->
#
#
# 						<dd>
# 							<a href="#" class="gmn">상장법인상세정보</a>
# 							<div class="lnb">
# 								<div class="wrapper">
#
#
#
#
# 										<a href="/disclosure/todaydisclosure.do?method=searchTodayDisclosureMain" class="lmn ">공시</a>
#
#
#
#
#
#
# 										<a href="/corpdetail/totalinfo.do?method=loadInitPage" class="lmn active">상장법인상세정보</a>
#
#
#
#
#
#
# 										<a href="/valueup/intro.do?method=valueupIntroMain" class="lmn ">기업 밸류업 정보</a>
#
#
#
#
#
#
# 										<a href="/investwarn/adminissue.do?method=searchAdminIssueList" class="lmn ">투자유의사항</a>
#
#
#
#
#
#
# 										<a href="/listinvstg/listinvstgcom.do?method=searchListInvstgCorpMain" class="lmn ">IPO현황</a>
#
#
#
#
#
#
# 										<a href="/disclosureinfo/notice.do?method=searchNoticeMain" class="lmn ">정보실</a>
#
#
#
# 									<img src="../images/common/lnb_arrow.png" class="arrow" />
# 									<img src="../images/common/lnb_tl.png" class="tl" />
# 									<img src="../images/common/lnb_tr.png" class="tr" />
# 									<img src="../images/common/lnb_bl.png" class="bl" />
# 									<img src="../images/common/lnb_br.png" class="br" />
# 								</div>
# 							</div>
# 						</dd>
#
#
#
# 					<!-- Lv2 -->
#
#
# 						<dd>
# 							<a href="#" class="gmn">상장법인목록</a>
# 							<div class="lnb">
# 								<div class="wrapper">
#
# 									<a href="/corpdetail/totalinfo.do?method=loadInitPage" class="lmn ">종합정보</a>
#
# 									<a href="/corpgeneral/listedIssueStatus.do?method=loadInitPage" class="lmn ">상장종목현황</a>
#
# 									<a href="/corpgeneral/corpList.do?method=loadInitPage" class="lmn active">상장법인목록</a>
#
# 									<a href="/corpgeneral/stockissuelist.do?method=loadInitPage" class="lmn ">주식발행내역</a>
#
# 									<a href="/corpgeneral/companyGovernance.do?method=loadInitPage" class="lmn ">기업지배구조</a>
#
# 									<a href="/corpgeneral/treasurystk.do?method=loadInitPage" class="lmn ">자사주취득/처분</a>
#
# 									<a href="/corpgeneral/irschedule.do?method=searchIRScheduleMain&gubun=iRScheduleCalendar" class="lmn ">IR일정/IR자료실</a>
#
# 									<a href="/corpgeneral/companyAnalysisReport.do?method=listingForeignCompanyMain&searchGubun=companyAnalysisReport" class="lmn ">기업분석보고서</a>
#
# 									<a href="/corpgeneral/corpGroup.do?method=loadInitPage" class="lmn ">기업집단</a>
#
# 									<a href="/disclosureinfo/dividendinfo.do?method=searchDividendInfoMain" class="lmn ">배당정보</a>
#
# 									<a href="/compfinance/financialinfo.do?method=loadInitPage&searchgubun=corporation" class="lmn ">회사재무비교</a>
#
# 									<a href="/corpgeneral/excntDisclsCompany.do?method=loadInitPage" class="lmn ">공시우수법인</a>
#
# 									<a href="/corpdetail/ventureFundInvest.do?method=corpListMain" class="lmn ">벤처펀드투자기업(코)</a>
#
# 									<img src="../images/common/lnb_arrow.png" class="arrow" />
# 									<img src="../images/common/lnb_tl.png" class="tl" />
# 									<img src="../images/common/lnb_tr.png" class="tr" />
# 									<img src="../images/common/lnb_bl.png" class="bl" />
# 									<img src="../images/common/lnb_br.png" class="br" />
# 								</div>
# 							</div>
# 						</dd>
#
#
# 					<!-- Lv3 -->
#
#
#
# 					<!-- Lv4 -->
#
#
#
#
#
#
# 			</dl>
# 		</nav>
# 	</div>
#
#
# <nav class="aside">
# 	<dl>
# 		<dt><a href="#"><span>마이페이지</span></a></dt>
# 		<dd class="mymenu first">
# 			<a href="#" class="bmn"><span>나만의 메뉴</span></a>
# 			<div class="list">
# 				<a href="#" class="btn-prev"><span>이전</span></a>
# 				<div class="inner">
# 					<ul id="myMenu" class="slider">
# 						<li></li>
# 					</ul>
# 				</div>
# 				<a href="#" class="btn-next"><span>다음</span></a>
# 			</div>
# 		</dd>
# 		<dd class="cache_company">
# 			<a href="#" class="bmn"><span>내가 본 회사</span></a>
# 			<div class="list">
# 				<a href="#" class="btn-prev"><span>이전</span></a>
# 				<div class="inner">
# 					<ul id="myMenuCorp" class="slider">
# 						<li></li>
# 					</ul>
# 				</div>
# 				<a href="#" class="btn-next"><span>다음</span></a>
# 			</div>
# 		</dd>
# 		<dd class="cache_disclosure">
# 			<a href="#" class="bmn"><span>내가 본 공시</span></a>
# 			<div class="list">
# 				<a href="#" class="btn-prev"><span>이전</span></a>
# 				<div class="inner">
# 					<ul id="myMenuDisclosure" class="slider">
# 						<li><a href="#"></a></li>
# 					</ul>
# 				</div>
# 				<a href="#" class="btn-next"><span>다음</span></a>
# 			</div>
# 		</dd>
# 		<dd class="link_top">
# 			<a href="#" class="bmn top"><span>위로</span></a>
# 		</dd>
# 	</dl>
# </nav>
# <script type="text/javascript">
# $(document).ready(function(){
# 	fnMyPage();
# 	fnMyCrop();
# 	fnMyDisclosure();
# });
#
# function fnMyPage(){
# 	var cookies = GetCookie('krxMenu');
# 	if(cookies != null ){
# 		$("#myMenu").empty();
# 		var items = cookies.split("/");
# 		for(var i in items){
# 			var item = items[i].split(",");
# 			var menuId	 = item[0];
# 			var menuName = item[1];
# 			if(undefined != menuName){
# 				var url = fnGetInMyMenuUrl(menuId);
# 				$("#myMenu").append("<li><a href='"+url+"' title='"+menuName+"'>"+menuName+"</a></li>");
# 			}
# 		}
# 	}
# }
#
# function fnMyCrop(){
# 	var cookieName	= "krxComp";
# 	var cookies		= GetCookie(cookieName);
# 	if(cookies != null ){
# 		$("#myMenuCorp").empty();
# ...
#
# </article>
#
# <script type="text/JavaScript">
# document.onkeypress = function(e){
# 	var result = "";
# 	if(typeof(e)!='undefined'){
# 		result = e.which;
# 	}else{
# 		result = event.keyCode;
# 	}
# 	keyEvent(result);
# }
#
# function keyEvent(e){
# 	if(document.all){//IE
# 		if(window.event.keyCode==13){
# 			fnSearchWithoutIndex();
# 		}
# 	}else{
# 		if(e==13){
# 			fnSearchWithoutIndex();
# 		}
# 	}
# }
#
#
# $(document).ready(function(){
# 	fnInit();
# });
#
#
# function fnInit(){
# 	fnOrder("3", "D");
# }
# /*
# *
# *법인명, 종목코드, 일자, 적용구분의 order by 조건
# */
# function fnOrder(mode, stat){
# 	$("#searchForm > #orderMode").val(mode);
# 	$("#searchForm > #orderStat").val(stat);
# 	$("#searchForm > #pageIndex").val("1");
#
# 	fnSearch();
# }
#
# function fnSearch1() {
# 	$("#searchForm > #pageIndex").val("1");
# 	$("#searchForm > #currentPageSize").val($(document).find("select[id=currentPageSize]").val());
# 	fnSearch();
# }
#
# function fnSearchWithoutIndex(){
# 	$("#searchForm > #beginIndex").val("");
# 	fnClearBtnType();
# 	fnInit();
# }
#
# function fnClearBtnType(){
# 	$(document).find("a[id=btnType]").each(function(){
# 		if($(this).hasClass("active")) {
# 			$(this).removeClass("active");
# 		}
# 	});
# }
#
# function fnSetCorpName(str){
# 	$("#searchForm > #comAbbrv").val(encodeURI(str));
# }
#
# function fnClearCorpName(){
# 	$("#searchForm > #comAbbrv").val("");
# 	$("#searchForm").find("input:text[name=comAbbrvTmp]").val("");
# }
#
# function fnSearch(){
#     fnSetCorpName($("#searchForm").find("input:text[name=comAbbrvTmp]").val());
#
#     if($(document).find("select[id=currentPageSize]").val() != undefined) {
#     	$("#searchForm > #currentPageSize").val($(document).find("select[id=currentPageSize]").val());
#     }
# 	$("#searchForm > #method").val("searchCorpList");
# 	$("#searchForm").ajaxSubmit({
# 		  ajaxUrl : '/corpgeneral/corpList.do'
# 		, ajaxCallBack: fnSearchCallBack
# 	});
# }
#
# function fnSearchCallBack(data){
# 	$("#main-contents").empty().append(data);
# 	$("tr:odd").addClass("active");
#
# 	fnLegendTooltip();
# }
#
# function fnDownload(){
# 	$("#searchForm").attr('onsubmit', '');
# 	$("#searchForm > #currentPageSize").val("3000");
# 	$("#searchForm > #pageIndex").val("1");
# 	$("#searchForm > #method").val("download");
# 	$("#searchForm").attr('action', '/corpgeneral/corpList.do').submit();
# 	$("#searchForm").attr('onsubmit', 'return false;');
# }
#
# /** 법인명찾기 팝업의 자바스크립트에서 호출하는 Callback 함수 */
# function setCorpInfo(isurCd, kisComCd, repIsuSrtCd, comNm, comAbbrv, isurSymbl, fssUnqNo){
#
#     var  str = "";
#             str += "isurCd : " + isurCd + "\n";
#             str += "kisComCd : " + kisComCd + "\n";
#             str += "repIsuSrtCd : " + repIsuSrtCd + "\n";
#             str += "comNm : " + comNm + "\n";
#             str += "comAbbrv : " + comAbbrv + "\n";
#             str += "isurSymbl : " + isurSymbl + "\n";
#             str += "fssUnqNo : " + fssUnqNo + "\n";
#     //alert(str);
#
#     $("#searchForm").find("input:text[name=comAbbrvTmp]").val(comAbbrv);	//법인명
#     $("#searchForm > #repIsuSrtCd").val("A"+repIsuSrtCd);					//법인코드
#     $("#searchForm > #searchCodeType").val("char");							//법인코드
# }
#
# function fnBtnType(type, idx){
#
# 	fnClearBtnType();
# 	fnClearCorpName();
#
# 	$("#searchForm > #pageIndex").val("1");
# 	$("#searchForm > #isurCd").val("");
# 	$("#searchForm > #repIsuSrtCd").val("");
# 	$("#searchForm > #beginIndex").val(type);
#
# 	$(document).find("a[id=btnType]").each(function(index){
# 		if(idx == index) {
# 			if(!$(this).hasClass("active")) {
# 				$(this).addClass("active");
# 			}
# 		}
# 	});
#
# 	fnInit();
# }
#
# </script>
# 	</section>
# 	<!-- 본문영역 END -->
#
# 	<!-- 오른쪽 메뉴 START -->
# 	<aside class="contents">
#
#
#
#
#
#
# 				<h3><span class="">상장법인상세정보</span></h3>
#
#
# 		<ul>
#
#
#
#
#
#
#
#
#
#
# 					<li><a href="/corpdetail/totalinfo.do?method=loadInitPage" class="">종합정보</a><div class="dash"></div></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
# 					<li><a href="/corpgeneral/listedIssueStatus.do?method=loadInitPage" class="">상장종목현황</a><div class="dash"></div></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
# 					<li><a href="/corpgeneral/corpList.do?method=loadInitPage" class="active">상장법인목록</a><div class="dash"></div></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
# 					<li><a href="/corpgeneral/stockissuelist.do?method=loadInitPage" class="">주식발행내역</a><div class="dash"></div></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
# 					<li><a href="/corpgeneral/companyGovernance.do?method=loadInitPage" class="">기업지배구조</a><div class="dash"></div></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
# 					<li><a href="/corpgeneral/treasurystk.do?method=loadInitPage" class="">자사주취득/처분</a><div class="dash"></div></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
# 					<li><a href="/corpgeneral/irschedule.do?method=searchIRScheduleMain&gubun=iRScheduleCalendar" class="">IR일정/IR자료실</a><div class="dash"></div></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
# 					<li><a href="/corpgeneral/companyAnalysisReport.do?method=listingForeignCompanyMain&searchGubun=companyAnalysisReport" class="">기업분석보고서</a><div class="dash"></div></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
# 					<li><a href="/corpgeneral/corpGroup.do?method=loadInitPage" class="">기업집단</a><div class="dash"></div></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
# 					<li><a href="/disclosureinfo/dividendinfo.do?method=searchDividendInfoMain" class="">배당정보</a><div class="dash"></div></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
# 					<li><a href="/compfinance/financialinfo.do?method=loadInitPage&searchgubun=corporation" class="">회사재무비교</a><div class="dash"></div></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
# 					<li><a href="/corpgeneral/excntDisclsCompany.do?method=loadInitPage" class="">공시우수법인</a><div class="dash"></div></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
# 					<li><a href="/corpdetail/ventureFundInvest.do?method=corpListMain" class="">벤처펀드투자기업(코)</a><div class="dash"></div></li>
#
#
#
#
# 		</ul>
# 		<form name="menuUrlFrm" >
# 			<input type="hidden" name="menuUrl" value="/corpgeneral/corpList.do?method=loadInitPage"/>
# 		</form>
#
#
# 	</aside>
# 	<!-- 오른쪽 메뉴 END -->
# 	<div class="clear"></div>
# </section>
#
# <!-- FOOTER 영역 START -->
# <footer class="container">
#
#
#
#
#
#
# <section class="footer_map">
# 	<div class="wrapper">
# 		<article class="list first">
# 			<h3>공시</h3>
# 			<ul>
# 				<li><a href="/disclosure/todaydisclosure.do?method=searchTodayDisclosureMain">오늘의공시</a></li>
# 				<li><a href="/disclosure/searchdisclosurebycorp.do?method=searchDisclosureByCorpMain">회사별검색</a></li>
# 				<li><a href="/disclosure/details.do?method=searchDetailsMain">상세검색</a></li>
# 				<li><a href="#" onclick="krxPaPago_open(); return false;">KRX-Papago번역기</a></li>
# 				<li><a href="/disclosure/searchtotalinfo.do?method=searchTotalInfoMain">통합검색</a></li>
# 				<li><a href="/disclosure/searchbondcorpdisclosure.do?method=searchBondCorpDisclosureMain">채권공시</a></li>
# 				<li><a href="/disclosure/disclosurebystocktype.do?method=searchDisclosureByStockTypeEtf">ETF / ELW / ETN</a></li>
# 				<li><a href="/disclosure/disclosurebystocktype.do?method=searchDisclosureByStockTypeRestinvstcom">펀드공시</a></li>
# 				<li><a href="/disclosure/misccorpdiscls.do?method=searchMiscCorpDisclsMain">기타법인공시</a></li>
# 				<li><a href="/disclosure/disclosurebyvote.do?method=searchDisclosurebyVoteMain">의결권행사공시</a></li>
#
# 				<li><a href="/corpdetail/chart.do?method=loadInitPage">공시차트</a></li>
#
# 			<li><a href="/disclosure/searchErrorTradeRelief.do?method=searchErrorTradeReliefMain">착오매매구제신청</a></li>
# 			<!-- 신종증권 메뉴 제외 -->
# 			<!--<li><a href="/digital/digitalList.do?method=digitalList">신종증권</a></li>--><!-- 20231201 신종증권 추가 -->
# 			</ul>
# 		</article>
# 		<article class="list">
# 			<h3>상장법인상세정보</h3>
# 			<ul>
#
# 				<li><a href="/corpdetail/totalinfo.do?method=loadInitPage">종합정보</a></li>
# 				<li><a href="/corpgeneral/listedIssueStatus.do?method=loadInitPage">상장종목현황</a></li>
#
# 				<li><a href="/corpgeneral/corpList.do?method=loadInitPage">상장법인목록</a></li>
# 				<li><a href="/corpgeneral/stockissuelist.do?method=loadInitPage">주식발행내역</a></li>
# 				<li><a href="/corpgeneral/companyGovernance.do?method=loadInitPage">기업지배구조</a></li>
# 				<li><a href="/corpgeneral/treasurystk.do?method=loadInitPage">자사주취득/처분</a></li>
# 				<li><a href="/corpgeneral/irschedule.do?method=searchIRScheduleMain&gubun=iRScheduleCalendar">IR일정/IR자료실</a></li>
#
# 				<li><a href="/corpgeneral/companyAnalysisReport.do?method=listingForeignCompanyMain&searchGubun=companyAnalysisReport">기업분석보고서</a></li>
#
# 				<li><a href="/corpgeneral/corpGroup.do?method=loadInitPage">기업집단</a></li>
# 				<li><a href="/disclosureinfo/dividendinfo.do?method=searchDividendInfoMain">배당정보</a></li>
# 				<li><a href="/compfinance/financialinfo.do?method=loadInitPage&searchgubun=corporation">회사재무비교</a></li>
# 				<li><a href="/corpgeneral/excntDisclsCompany.do?method=loadInitPage">공시우수법인</a></li>
# 				<li><a href="/corpdetail/ventureFundInvest.do?method=corpListMain">벤처펀드투자대상기업(코)</a></li>
# 				<!-- 신종증권 메뉴 제외 -->
# 				<!--<li><a href="/digital/digitalCorpList.do?method=digitalCorpList">상장종목(신종증권)</a></li>--><!-- 20231201 신종증권 추가 -->
# 			</ul>
# 		</article>
# 		<article class="list">
# 			<h3>기업 밸류업 정보</h3>
# 			<ul>
# 				<li><a href="/valueup/intro.do?method=valueupIntroMain">기업 밸류업 소개</a></li>
# 				<li><a href="/valueup/notice.do?method=valueupNoticeMain">공지사항</a></li>
# 				<li><a href="/valueup/disclsstat.do?method=valueupDisclsStatMain">공시현황</a></li>
#
# 				<li><a href="/valueup/invstindicsectors.do?method=valueupInvstIndicRankIndMain">투자지표</a></li>
# 				<li><a href="/valueup/idx.do?method=valueupIdxMain">인덱스</a></li>
#
# 				<li><a href="/valueup/excntcorp.do?method=valueupExcntCorpMain">기업 밸류업 우수법인</a></li>
# 				<li><a href="/valueup/resoroom.do?method=valueupResoroomMain">자료실</a></li>
# 			</ul>
# 		</article>
# 		<article class="list">
# 			<h3>투자유의사항</h3>
# 			<ul>
# 				<li><a href="/investwarn/adminissue.do?method=searchAdminIssueList">관리종목</a></li>
# 				<li><a href="/investwarn/hwangiissue.do?method=searchHwangiIssueMain">투자주의환기종목(코)</a></li>
#
# 				<li><a href="/investwarn/tradinghaltissue.do?method=searchTradingHaltIssueMain">매매거래정지종목</a></li>
#
# 				<li><a href="/investwarn/undisclosure.do?method=searchUnfaithfulDisclosureCorpList">불성실공시법인</a></li>
#
# 				<li><a href="/investwarn/investattentwarnrisky.do?method=investattentwarnriskyMain">투자주의/경고/위험종목</a></li>
#
# 				<li><a href="/corpgeneral/delistRealInvstg.do?method=searchDelistRealInvstgMain">실질심사법인</a></li>
# 				<li><a href="/investwarn/investattentEmbezzlement.do?method=searchInvestAttentEmbezzlementMain">횡령 등</a></li>
# 				<li><a href="/investwarn/investattentLargeShareChange.do?method=searchInvestAttentLargeShareChangeMain">최대주주변경2회이상</a></li>
# 				<li><a href="/investwarn/investattentEtcMarket.do?method=searchInvestAttentEtcMarketMain">기타사항</a></li>
# 			</ul>
# 		</article>
# 		<article class="list">
# 			<h3>IPO현황</h3>
# 			<ul>
#
# 				<li><a href="/listinvstg/listinvstgcom.do?method=searchListInvstgCorpMain">예비심사기업</a></li>
# 				<li><a href="/listinvstg/listapplcom.do?method=searchListApplCorpMain">코넥스 상장신청기업</a></li>
# 				<li><a href="/listinvstg/pubofrprogcom.do?method=searchPubofrProgComMain">공모기업</a></li>
# 				<li><a href="/listinvstg/listingcompany.do?method=searchListingTypeMain">신규상장기업</a></li>
#
# 				<li><a href="/listinvstg/listtypestat.do?method=searchListTypeStatusMain">신규상장통계</a></li>
# 				<li><a href="/listinvstg/listinvstginfo.do?method=searchListInvstgInfoMain">상장심사가이드</a></li>
# 			</ul>
# 			<br>
# 			<h3>정보실</h3>
# 			<ul>
# 				<li><a href="/disclosureinfo/notice.do?method=searchNoticeMain">공지사항</a></li>
# 				<!--  li><a href="/news/searchnews.do?method=searchNewsMain">증시뉴스</a></li -->
# 				<li><a href="/disclosureinfo/explanationsystem.do?method=searchSysInfo">제도해설</a></li>
# 				<li><a href="/disclosureinfo/searchmaterials.do?method=searchMaterialsMain">자료실</a></li>
# 			</ul>
# 		</article>
# 		<div class="clear"></div>
# 	</div>
# </section>
#
# <section class="footer">
# 	<div class="wrapper">
# 		<h5 class="logo"><img src="../images/main/logo_bt.gif" alt="대한민국 대표 기업공시채널 KIND"/></h5>
# 		<nav class="util">
# 			<ul>
# 				<li class="first"><a href="#" onclick="winCommPopOpen('2'); return false;">운영기관안내</a></li>
# 				<li><a href="http://info.krx.co.kr/contents/KRX/06/06070600/KRX06070600.jsp" target="_blank" title="이용자유의사항 새창">이용자유의사항</a></li>
# 				<li><a href="http://info.krx.co.kr/contents/KRX/06/06070200/KRX06070200.jsp"  target="_blank" title="법적고지 새창">법적고지</a></li>
# 				<li><a href="http://info.krx.co.kr/contents/KRX/06/06070100/KRX06070100.jsp"   target="_blank" title="개인정보처리방침 새창">개인정보처리방침</a></li>
# 				<li><a href="#" onclick="winCommPopOpen('5'); return false;">뷰어다운로드</a></li>
# 			</ul>
# 			<div class="clear"></div>
# 		</nav>
#
# 		<div class="copyright">
# 		본 사 : (우) 48400 부산광역시 남구 문현금융로 40(문현동)  TEL : 051-662-2000   사업자등록번호 : 602-81-35420 <br/>
# 		서 울 : (우) 07329 서울특별시 영등포구 여의나루로 76(여의도동)  TEL : 1577-0088, 02-3774-9000 / 통신판매업신고 부산동구004호<br/>
# 		Copyright(c) 2014 by KOREA EXCHANGE. All rights reserved.
# 		</div>
# 	</div>
# </section>
#
# </footer>
# <!-- FOOTER 영역 START -->
#
# <!-- 범례 START -->
#
#
# <div style="position:absolute; display:none" id="marketSection">
# 	<section class="icn_tbox" style="width:400px;top:-30px; left:10px">
# 		<ul>
# 			<li>
# 				<img src="../images/common/icn_t_yu.gif" class="vmiddle" alt="유가증권" /> 유가증권
# 			</li>
# 			<li>
# 				<img src="../images/common/icn_t_ko.gif" class="vmiddle" alt="코스닥" /> 코스닥
# 			</li>
# 			<li>
# 				<img src="../images/common/icn_t_konex.gif" class="vmiddle" alt="코넥스" /> 코넥스
# 			</li>
# 			<li>
# 				<img src="../images/common/icn_t_kwan.gif" class="vmiddle" alt="관리종목" /> 관리종목
# 			</li>
# 			<li>
# 				<img src="../images/common/icn_t_hwan.gif" class="vmiddle" alt="투자주의환기종목" /> 투자주의환기종목
# 			</li>
# 			<li>
# 				<img src="../images/common/icn_t_bul.gif" class="vmiddle" alt="불성실공시법인" /> 불성실공시법인
# 			</li>
# 			<li>
# 				<img src="../images/common/icn_t_pe.gif" class="vmiddle" alt="폐지법인" /> 폐지법인
# 			</li>
# 			<li>
# 				<img src="../images/common/icn_t_ktop.gif" class="vmiddle" alt="KTOP30" /> KTOP30
# 			</li>
# 			<li>
# 				<img src="../images/common/icn_t_k200.gif" class="vmiddle" alt="KOSPI200" /> KOSPI200
# 			</li>
# 			<li>
# 				<img src="../images/common/icn_t_q150.gif" class="vmiddle" alt="KOSDAQ150" /> KOSDAQ150
# 			</li>
# 			<li>
# 				<img src="../images/common/icn_t_x300.gif" class="vmiddle" alt="KRX300" /> KRX300
# 			</li>
# 			<li>
# 				<img src="../images/common/icn_t_jung.gif" class="vmiddle" alt="정정있음" /> 정정있음
# 			</li>
# 			<li>
# 				<img src="../images/common/icn_t_joo.gif" class="vmiddle" alt="투자주의" /> 투자주의
# 			</li>
# 			<li>
# 				<img src="../images/common/icn_t_kyung.gif" class="vmiddle" alt="투자경고" /> 투자경고
# 			</li>
# 			<li>
# 				<img src="../images/common/icn_t_wii.gif" class="vmiddle" alt="투자위험" /> 투자위험
# 			</li>
# 		</ul>
# 		<div class="clear"></div>
# 		<img src="../images/common/icn_tbox_tl.png" class="tl" alt="" />
# 		<img src="../images/common/icn_tbox_bl.gif" class="bl" alt="" />
# 		<img src="../images/common/icn_tbox_tr.gif" class="tr" alt="" />
# 		<img src="../images/common/icn_tbox_br.gif" class="br" alt="" />
# 		<div class="tm"></div>
# 		<div class="lm"></div>
# 		<div class="bm"></div>
# 		<div class="rm"></div>
# 	</section>
# </div>
# <!-- 범례 END -->
#
# <div id='dialog-loading' title='자료를 조회 중입니다.' class='loading' style="display: none;">
# 	<span>
# 		<img src='/images/loader/ajax-loader01.gif' />
# 	</span>
# </div>
#
# <div id='dialog-message' style="display: none;"></div>
#
# <div id='dialog-alert' style="display: none;">
# 	<div id="img"></div>
# 	<div id="msg" class="ui-message"></div>
# </div>
#
# <script type="text/javascript">
# 	$(document).ready(function(){
# 		$('input').placeholder();
# 	});
# </script>
# </body>
# </html>

# %%
url = "https://kind.krx.co.kr/corpgeneral/corpList.do"

payload = {
    'method': 'searchCorpList',
    'pageIndex': 1,
    'currentPageSize': 100,
    'comAbbrv': '',
    'beginIndex': '',
    'orderMode': 3,
    'orderStat': 'D',
    'isurCd': '',
    'repIsuSrtCd': '',
    'searchCodeType': '',
    'marketType': '',
    'searchType': 13,
    'industry': '',
    'fiscalYearEnd': 'all',
    'comAbbrvTmp': '',
    'location': 'all'
}

r = requests.get(url, params = payload)
print(r.status_code)
print(r.text)

soup = bs(r.text, 'lxml')
# Out:
# 200
#
#
#
#
#
#
#
#
# <section class="scrarea type-00">
# 	<table class="list type-00 tmt30" summary="회사명, 업종, 주요제품, 상장일, 결산월, 대표자명, 홈페이지, 지역">
# 		<caption>목록</caption>
# 		<colgroup>
# 			<col width="*" />
# 			<col width="15%" />
# 			<col width="20%" />
# 			<col width="11%" />
# 			<col width="8%" />
# 			<col width="10%" />
# 			<col width="8%" />
# 			<col width="12%" />
# 		</colgroup>
# 		<thead>
# 			<tr class="first" id="title-contents">
# 			</tr>
# 		</thead>
# 		<tbody>
#
#
#
# 			<tr
# 					class="first"
# 			>
# 				<td class="first" title="산일전기(주)"><img src='/images/common/icn_t_yu.gif' class='vmiddle legend' alt='유가증권'> <a id="companysum" href="#companysum" onclick="companysummary_open('06204'); return false;" title='산일전기'> 산일전기</a> </td>
# 				<td class="textOverflow" title="전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업">전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업</td>
# 				<td class="textOverflow" title="유입, 몰드, 주상, 건식 변압기 등">유입, 몰드, 주상, 건식 변압기 등</td>
# 				<td class="txc">2024-07-29</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="박동석">박동석</td>
# 				<td class="txc">
#
# 						<a href="http://www.sanil.co.kr" class="btn ico homepage" target="_blank" title="http://www.sanil.co.kr"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경기도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)에이치에스효성"><img src='/images/common/icn_t_yu.gif' class='vmiddle legend' alt='유가증권'> <a id="companysum" href="#companysum" onclick="companysummary_open('48757'); return false;" title='에이치에스효성'> 에이치에스효성</a> </td>
# 				<td class="textOverflow" title="기타 금융업">기타 금융업</td>
# 				<td class="textOverflow" title="지주사업">지주사업</td>
# 				<td class="txc">2024-07-29</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="조현상, 안성훈">조현상..</td>
# 				<td class="txc">
#
# 						<a href="http://www.hshyosung.com" class="btn ico homepage" target="_blank" title="http://www.hshyosung.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="엔에이치기업인수목적31호(주)"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('48189'); return false;" title='엔에이치스팩31호'> 엔에이치스팩31호</a> <img src='/images/common/icn_t_joo.gif' class='vmiddle legend' alt='투자주의종목'/> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="금융지원서비스업">금융지원서비스업</td>
# 				<td class="txc">2024-07-26</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이시형">이시형</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="에스케이증권제13호기업인수목적 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47395'); return false;" title='SK증권제13호스팩'> SK증권제13호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수목적 주식회사">기업인수목적 주식회사</td>
# 				<td class="txc">2024-07-25</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="임율표">임율표</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)엑셀세라퓨틱스"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('37311'); return false;" title='엑셀세라퓨틱스'> 엑셀세라퓨틱스</a> </td>
# 				<td class="textOverflow" title="기초 의약물질 제조업">기초 의약물질 제조업</td>
# 				<td class="textOverflow" title="CellCor SFD/CD(세포배양배지)">CellCor SFD/CD(세포배양배지)</td>
# 				<td class="txc">2024-07-15</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이의일">이의일</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="이베스트기업인수목적6호 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47811'); return false;" title='이베스트스팩6호'> 이베스트스팩6호</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수목적 주식회사">기업인수목적 주식회사</td>
# 				<td class="txc">2024-07-12</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="박용">박용</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)시프트업"><img src='/images/common/icn_t_yu.gif' class='vmiddle legend' alt='유가증권'> <a id="companysum" href="#companysum" onclick="companysummary_open('46287'); return false;" title='시프트업'> 시프트업</a> </td>
# 				<td class="textOverflow" title="소프트웨어 개발 및 공급업">소프트웨어 개발 및 공급업</td>
# 				<td class="textOverflow" title="게임 소프트웨어">게임 소프트웨어</td>
# 				<td class="txc">2024-07-11</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김형태">김형태</td>
# 				<td class="txc">
#
# 						<a href="http://shiftup.co.kr" class="btn ico homepage" target="_blank" title="http://shiftup.co.kr"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)하스"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('45033'); return false;" title='하스'> 하스</a> </td>
# 				<td class="textOverflow" title="의료용품 및 기타 의약 관련제품 제조업">의료용품 및 기타 의약 관련제품 제조업</td>
# 				<td class="textOverflow" title="리튬디실리케이트 수복소재(Amber block, Amber Ingot 등), 지르코니아 유치관">리튬디실리케이트 수복소재(Amber block, Amber Ingot 등), 지르코니아 유치관</td>
# 				<td class="txc">2024-07-03</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김용수">김용수</td>
# 				<td class="txc">
#
# 						<a href="http://www.hassbio.com" class="btn ico homepage" target="_blank" title="http://www.hassbio.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">강원특별자치도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)이노스페이스"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('46235'); return false;" title='이노스페이스'> 이노스페이스</a> </td>
# 				<td class="textOverflow" title="항공기,우주선 및 부품 제조업">항공기,우주선 및 부품 제조업</td>
# 				<td class="textOverflow" title="소형발사체, 로켓추진기관, 과학로켓, 시험평가용역">소형발사체, 로켓추진기관, 과학로켓, 시험평가용역</td>
# 				<td class="txc">2024-07-02</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김수종">김수종</td>
# 				<td class="txc">
#
# 						<a href="http://www.innospc.com/" class="btn ico homepage" target="_blank" title="http://www.innospc.com/"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">세종특별자치시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)신한글로벌액티브위탁관리부동산투자회사"><img src='/images/common/icn_t_yu.gif' class='vmiddle legend' alt='유가증권'> <a id="companysum" href="#companysum" onclick="companysummary_open('48185'); return false;" title='신한글로벌액티브리츠'> 신한글로벌액티브리츠</a> </td>
# 				<td class="textOverflow" title="신탁업 및 집합투자업">신탁업 및 집합투자업</td>
# 				<td class="textOverflow" title="신탁 및 집합투자">신탁 및 집합투자</td>
# 				<td class="txc">2024-07-01</td>
# 				<td class="txc">02월</td>
# 				<td class="txc" title="김선영">김선영</td>
# 				<td class="txc">
#
# 						<a href="http://shglobalreit.com" class="btn ico homepage" target="_blank" title="http://shglobalreit.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)에이치브이엠"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('29531'); return false;" title='에이치브이엠'> 에이치브이엠</a> </td>
# 				<td class="textOverflow" title="1차 비철금속 제조업">1차 비철금속 제조업</td>
# 				<td class="textOverflow" title="Ni계 합금, Fe계 합금, 스퍼터링타겟, Cu계 합금 등">Ni계 합금, Fe계 합금, 스퍼터링타겟, Cu계 합금 등</td>
# 				<td class="txc">2024-06-28</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="문승호">문승호</td>
# 				<td class="txc">
#
# 						<a href="http://hvm.co.kr/" class="btn ico homepage" target="_blank" title="http://hvm.co.kr/"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경기도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)팡스카이"><img src='/images/common/icn_t_konex.gif' class='vmiddle legend' alt='코넥스'> <a id="companysum" href="#companysum" onclick="companysummary_open('26635'); return false;" title='팡스카이'> 팡스카이</a> </td>
# 				<td class="textOverflow" title="소프트웨어 개발 및 공급업">소프트웨어 개발 및 공급업</td>
# 				<td class="textOverflow" title="게임 개발 및 리퍼블리싱">게임 개발 및 리퍼블리싱</td>
# 				<td class="txc">2024-06-28</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="조호현, 이병진">조호현..</td>
# 				<td class="txc">
#
# 						<a href="http://www.panggame.com/" class="btn ico homepage" target="_blank" title="http://www.panggame.com/"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="하이젠알앤엠 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('16019'); return false;" title='하이젠알앤엠'> 하이젠알앤엠</a> </td>
# 				<td class="textOverflow" title="전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업">전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업</td>
# 				<td class="textOverflow" title="전동기 및 발전기 (범용모터, 서보모터)">전동기 및 발전기 (범용모터, 서보모터)</td>
# 				<td class="txc">2024-06-27</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김재학">김재학</td>
# 				<td class="txc">
#
# 						<a href="http://higenrnm.com" class="btn ico homepage" target="_blank" title="http://higenrnm.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경상남도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="한국제15호기업인수목적 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47988'); return false;" title='한국제15호스팩'> 한국제15호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수합병">기업인수합병</td>
# 				<td class="txc">2024-06-26</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="유한">유한</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)에스오에스랩"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('46408'); return false;" title='에스오에스랩'> 에스오에스랩</a> </td>
# 				<td class="textOverflow" title="측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외">측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외</td>
# 				<td class="textOverflow" title="산업용 및 차량용 라이다(LiDAR)">산업용 및 차량용 라이다(LiDAR)</td>
# 				<td class="txc">2024-06-25</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="정지성">정지성</td>
# 				<td class="txc">
#
# 						<a href="http://soslab.co" class="btn ico homepage" target="_blank" title="http://soslab.co"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">광주광역시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="미래에셋비전기업인수목적6호 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47844'); return false;" title='미래에셋비전스팩6호'> 미래에셋비전스팩6호</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수합병">기업인수합병</td>
# 				<td class="txc">2024-06-24</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="정명훈">정명훈</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="에이치엠씨아이비제7호기업인수목적(주)"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47734'); return false;" title='에이치엠씨제7호스팩'> 에이치엠씨제7호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기타금융">기타금융</td>
# 				<td class="txc">2024-06-24</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="강신명">강신명</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)파라다이스"><img src='/images/common/icn_t_yu.gif' class='vmiddle legend' alt='유가증권'> <a id="companysum" href="#companysum" onclick="companysummary_open('03423'); return false;" title='파라다이스'> 파라다이스</a> <img src='/images/common/icn_t_x300.gif' class='vmiddle legend' alt='KRX300'> </td>
# 				<td class="textOverflow" title="유원지 및 기타 오락관련 서비스업">유원지 및 기타 오락관련 서비스업</td>
# 				<td class="textOverflow" title="카지노, 호텔, 복합리조트">카지노, 호텔, 복합리조트</td>
# 				<td class="txc">2024-06-24</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="최종환, 최성욱">최종환..</td>
# 				<td class="txc">
#
# 						<a href="http://www.paradise.co.kr/ko/main" class="btn ico homepage" target="_blank" title="http://www.paradise.co.kr/ko/main"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)한중엔시에스"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('10764'); return false;" title='한중엔시에스'> 한중엔시에스</a> </td>
# 				<td class="textOverflow" title="전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업">전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업</td>
# 				<td class="textOverflow" title="수냉식 냉각시스템 ESS Parts, 공랭식 ESS Module Parts, EV Module 및 내연기관 Parts">수냉식 냉각시스템 ESS Parts, 공랭식 ESS Module Parts, EV Module 및 내연기관 Parts</td>
# 				<td class="txc">2024-06-24</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김환식">김환식</td>
# 				<td class="txc">
#
# 						<a href="http://www.hjncs.com" class="btn ico homepage" target="_blank" title="http://www.hjncs.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경상북도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="케이비제29호기업인수목적(주)"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47839'); return false;" title='KB제29호스팩'> KB제29호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수합병">기업인수합병</td>
# 				<td class="txc">2024-06-21</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="서영화">서영화</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="미래에셋비전기업인수목적5호 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47747'); return false;" title='미래에셋비전스팩5호'> 미래에셋비전스팩5호</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수합병">기업인수합병</td>
# 				<td class="txc">2024-06-19</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김대호">김대호</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)씨어스테크놀로지"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('45887'); return false;" title='씨어스테크놀로지'> 씨어스테크놀로지</a> </td>
# 				<td class="textOverflow" title="의료용 기기 제조업">의료용 기기 제조업</td>
# 				<td class="textOverflow" title="심전도검사솔루션 입원환자모니터링솔루션">심전도검사솔루션 입원환자모니터링솔루션</td>
# 				<td class="txc">2024-06-19</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이영신">이영신</td>
# 				<td class="txc">
#
# 						<a href="http://seerstech.com" class="btn ico homepage" target="_blank" title="http://seerstech.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경기도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="한국제14호기업인수목적 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47753'); return false;" title='한국제14호스팩'> 한국제14호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수합병">기업인수합병</td>
# 				<td class="txc">2024-06-19</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="변성환">변성환</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="디비금융제12호기업인수목적 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47776'); return false;" title='디비금융스팩12호'> 디비금융스팩12호</a> </td>
# 				<td class="textOverflow" title="기타 금융업">기타 금융업</td>
# 				<td class="textOverflow" title="기업인수 및 합병">기업인수 및 합병</td>
# 				<td class="txc">2024-06-18</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김창희">김창희</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)라메디텍"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('46251'); return false;" title='라메디텍'> 라메디텍</a> </td>
# 				<td class="textOverflow" title="의료용 기기 제조업">의료용 기기 제조업</td>
# 				<td class="textOverflow" title="초소형 레이저 의료기기  및 미용기기">초소형 레이저 의료기기  및 미용기기</td>
# 				<td class="txc">2024-06-17</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="최종석">최종석</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)그리드위즈"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('45345'); return false;" title='그리드위즈'> 그리드위즈</a> </td>
# 				<td class="textOverflow" title="그외 기타 전문, 과학 및 기술 서비스업">그외 기타 전문, 과학 및 기술 서비스업</td>
# 				<td class="textOverflow" title="수요관리 서비스, 전기차 충전기 모뎀 등">수요관리 서비스, 전기차 충전기 모뎀 등</td>
# 				<td class="txc">2024-06-14</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김구환">김구환</td>
# 				<td class="txc">
#
# 						<a href="http://www.gridwiz.com" class="btn ico homepage" target="_blank" title="http://www.gridwiz.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경기도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)다원넥스뷰"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('32335'); return false;" title='다원넥스뷰'> 다원넥스뷰</a> </td>
# 				<td class="textOverflow" title="사진장비 및 광학기기 제조업">사진장비 및 광학기기 제조업</td>
# 				<td class="textOverflow" title="LSMB(Laser Micro Bonding System)">LSMB(Laser Micro Bonding System)</td>
# 				<td class="txc">2024-06-11</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="남기중">남기중</td>
# 				<td class="txc">
#
# 						<a href="http://www.nexview.co.kr" class="btn ico homepage" target="_blank" title="http://www.nexview.co.kr"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경기도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="미래에셋비전기업인수목적4호 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47738'); return false;" title='미래에셋비전스팩4호'> 미래에셋비전스팩4호</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수목적회사(기타금융서비스)">기업인수목적회사(기타금융서비스)</td>
# 				<td class="txc">2024-05-29</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김정수">김정수</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)노브랜드"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('14517'); return false;" title='노브랜드'> 노브랜드</a> </td>
# 				<td class="textOverflow" title="편조의복 제조업">편조의복 제조업</td>
# 				<td class="textOverflow" title="Knit, Woven 의류">Knit, Woven 의류</td>
# 				<td class="txc">2024-05-23</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이상규">이상규</td>
# 				<td class="txc">
#
# 						<a href="http://www.nobland.com" class="btn ico homepage" target="_blank" title="http://www.nobland.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="케이비제28호기업인수목적 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47647'); return false;" title='KB제28호스팩'> KB제28호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수합병">기업인수합병</td>
# 				<td class="txc">2024-05-17</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="고광범">고광범</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="아이씨티케이 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('45601'); return false;" title='아이씨티케이'> 아이씨티케이</a> </td>
# 				<td class="textOverflow" title="반도체 제조업">반도체 제조업</td>
# 				<td class="textOverflow" title="PUF반도체,보안솔루션(보안반도체,정보통신모듈기기,정보통신용반도체) 제조,개발">PUF반도체,보안솔루션(보안반도체,정보통신모듈기기,정보통신용반도체) 제조,개발</td>
# 				<td class="txc">2024-05-17</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이정원">이정원</td>
# 				<td class="txc">
#
# 						<a href="http://www.ictk.com" class="btn ico homepage" target="_blank" title="http://www.ictk.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="에이치디현대마린솔루션(주)"><img src='/images/common/icn_t_yu.gif' class='vmiddle legend' alt='유가증권'> <a id="companysum" href="#companysum" onclick="companysummary_open('44306'); return false;" title='HD현대마린솔루션'> HD현대마린솔루션</a> </td>
# 				<td class="textOverflow" title="건축기술, 엔지니어링 및 관련 기술 서비스업">건축기술, 엔지니어링 및 관련 기술 서비스업</td>
# 				<td class="textOverflow" title="AM(After Market) 솔루션, 친환경 Retrofit, 디지털 제어">AM(After Market) 솔루션, 친환경 Retrofit, 디지털 제어</td>
# 				<td class="txc">2024-05-08</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이기동">이기동</td>
# 				<td class="txc">
#
# 						<a href="http://www.hd-marinesolution.com/" class="btn ico homepage" target="_blank" title="http://www.hd-marinesolution.com/"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">부산광역시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="에스케이증권제12호기업인수목적 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47300'); return false;" title='SK증권제12호스팩'> SK증권제12호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수목적 주식회사">기업인수목적 주식회사</td>
# 				<td class="txc">2024-05-07</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이재혁">이재혁</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="코칩(주)"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('12673'); return false;" title='코칩'> 코칩</a> </td>
# 				<td class="textOverflow" title="전자부품 제조업">전자부품 제조업</td>
# 				<td class="textOverflow" title="소형 및 초소형 슈퍼커패시터">소형 및 초소형 슈퍼커패시터</td>
# 				<td class="txc">2024-05-07</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="손진형">손진형</td>
# 				<td class="txc">
#
# 						<a href="http://www.korchip.com" class="btn ico homepage" target="_blank" title="http://www.korchip.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경기도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="주식회사 민테크"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('45220'); return false;" title='민테크'> 민테크</a> </td>
# 				<td class="textOverflow" title="측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외">측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외</td>
# 				<td class="textOverflow" title="배터리 진단시스템, 배터리 시스템, 충방전 검사장비">배터리 진단시스템, 배터리 시스템, 충방전 검사장비</td>
# 				<td class="txc">2024-05-03</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="홍영진">홍영진</td>
# 				<td class="txc">
#
# 						<a href="http://www.g-mintech.co.kr" class="btn ico homepage" target="_blank" title="http://www.g-mintech.co.kr"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">대전광역시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)카티스"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('14043'); return false;" title='카티스'> 카티스</a> </td>
# 				<td class="textOverflow" title="컴퓨터 프로그래밍, 시스템 통합 및 관리업">컴퓨터 프로그래밍, 시스템 통합 및 관리업</td>
# 				<td class="textOverflow" title="산업인프라 보안플랫폼">산업인프라 보안플랫폼</td>
# 				<td class="txc">2024-05-03</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김승수">김승수</td>
# 				<td class="txc">
#
# 						<a href="http://CATIS.CO.KR" class="btn ico homepage" target="_blank" title="http://CATIS.CO.KR"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경기도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)디앤디파마텍"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('34785'); return false;" title='디앤디파마텍'> 디앤디파마텍</a> </td>
# 				<td class="textOverflow" title="자연과학 및 공학 연구개발업">자연과학 및 공학 연구개발업</td>
# 				<td class="textOverflow" title="대사성질환 치료제 등">대사성질환 치료제 등</td>
# 				<td class="txc">2024-05-02</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이슬기">이슬기</td>
# 				<td class="txc">
#
# 						<a href="http://www.ddpharmatech.com" class="btn ico homepage" target="_blank" title="http://www.ddpharmatech.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경기도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="유안타제16호기업인수목적 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47449'); return false;" title='유안타제16호스팩'> 유안타제16호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="금융 지원 서비스(기업인수목적회사)">금융 지원 서비스(기업인수목적회사)</td>
# 				<td class="txc">2024-05-02</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="박병권">박병권</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)제일엠앤에스"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('41254'); return false;" title='제일엠앤에스'> 제일엠앤에스</a> </td>
# 				<td class="textOverflow" title="특수 목적용 기계 제조업">특수 목적용 기계 제조업</td>
# 				<td class="textOverflow" title="2차전지 믹싱시스템">2차전지 믹싱시스템</td>
# 				<td class="txc">2024-04-30</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이영진">이영진</td>
# 				<td class="txc">
#
# 						<a href="http://www.jeilm.co.kr" class="btn ico homepage" target="_blank" title="http://www.jeilm.co.kr"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경기도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)삐아"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('45125'); return false;" title='삐아'> 삐아</a> </td>
# 				<td class="textOverflow" title="기타 화학제품 제조업">기타 화학제품 제조업</td>
# 				<td class="textOverflow" title="색조화장품">색조화장품</td>
# 				<td class="txc">2024-04-25</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="박광춘">박광춘</td>
# 				<td class="txc">
#
# 						<a href="http://www.bbiacosmetic.com/" class="btn ico homepage" target="_blank" title="http://www.bbiacosmetic.com/"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">인천광역시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="하나33호기업인수목적 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47525'); return false;" title='하나33호스팩'> 하나33호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수합병">기업인수합병</td>
# 				<td class="txc">2024-04-24</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="박태한">박태한</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="신한제13호기업인수목적주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47493'); return false;" title='신한제13호스팩'> 신한제13호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기타금융서비스(기업합병)">기타금융서비스(기업합병)</td>
# 				<td class="txc">2024-04-22</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="배성환">배성환</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="신한제12호기업인수목적 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47466'); return false;" title='신한제12호스팩'> 신한제12호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="금융서비스(기업인수목적회사)">금융서비스(기업인수목적회사)</td>
# 				<td class="txc">2024-04-15</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이동호">이동호</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="주식회사 아이엠비디엑스"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('46103'); return false;" title='아이엠비디엑스'> 아이엠비디엑스</a> <img src='/images/common/icn_t_joo.gif' class='vmiddle legend' alt='투자주의종목'/> </td>
# 				<td class="textOverflow" title="자연과학 및 공학 연구개발업">자연과학 및 공학 연구개발업</td>
# 				<td class="textOverflow" title="알파리퀴드ⓡ 100, 알파리퀴드ⓡ HRR, 알파리퀴드ⓡ 디텍트, 알파리퀴드ⓡ 스크리닝">알파리퀴드ⓡ 100, 알파리퀴드ⓡ HRR, 알파리퀴드ⓡ 디텍트, 알파리퀴드ⓡ 스크리닝</td>
# 				<td class="txc">2024-04-03</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김태유">김태유</td>
# 				<td class="txc">
#
# 						<a href="http://www.imbdx.com/" class="btn ico homepage" target="_blank" title="http://www.imbdx.com/"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="SK이터닉스(주)"><img src='/images/common/icn_t_yu.gif' class='vmiddle legend' alt='유가증권'> <a id="companysum" href="#companysum" onclick="companysummary_open('47515'); return false;" title='SK이터닉스'> SK이터닉스</a> </td>
# 				<td class="textOverflow" title="건물 건설업">건물 건설업</td>
# 				<td class="textOverflow" title="부동산 개발">부동산 개발</td>
# 				<td class="txc">2024-03-29</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김해중">김해중</td>
# 				<td class="txc">
#
# 						<a href="http://www.sketernix.com" class="btn ico homepage" target="_blank" title="http://www.sketernix.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경기도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="하나32호기업인수목적 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47524'); return false;" title='하나32호스팩'> 하나32호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수합병">기업인수합병</td>
# 				<td class="txc">2024-03-27</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="박종찬">박종찬</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="주식회사 엔젤로보틱스"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('45590'); return false;" title='엔젤로보틱스'> 엔젤로보틱스</a> </td>
# 				<td class="textOverflow" title="특수 목적용 기계 제조업">특수 목적용 기계 제조업</td>
# 				<td class="textOverflow" title="재활 전문 웨어러블 로봇, 근력 보조 무동력 웨어러블 슈트, 일상생활 보조 웨어러블 로봇 등">재활 전문 웨어러블 로봇, 근력 보조 무동력 웨어러블 슈트, 일상생활 보조 웨어러블 로봇 등</td>
# 				<td class="txc">2024-03-26</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="공경철">공경철</td>
# 				<td class="txc">
#
# 						<a href="http://www.angel-robotics.com/ko/" class="btn ico homepage" target="_blank" title="http://www.angel-robotics.com/ko/"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="주식회사 제이투케이바이오"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('42057'); return false;" title='제이투케이바이오'> 제이투케이바이오</a> </td>
# 				<td class="textOverflow" title="기타 화학제품 제조업">기타 화학제품 제조업</td>
# 				<td class="textOverflow" title="화장품 원료(천연소재 바이오소재 등)">화장품 원료(천연소재 바이오소재 등)</td>
# 				<td class="txc">2024-03-25</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이재섭">이재섭</td>
# 				<td class="txc">
#
# 						<a href="http://www.j2kbio.com" class="btn ico homepage" target="_blank" title="http://www.j2kbio.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">충청북도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)삼현"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('43773'); return false;" title='삼현'> 삼현</a> </td>
# 				<td class="textOverflow" title="자동차 신품 부품 제조업">자동차 신품 부품 제조업</td>
# 				<td class="textOverflow" title="스마트 액추에이터, 스마트 파워유닛">스마트 액추에이터, 스마트 파워유닛</td>
# 				<td class="txc">2024-03-21</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="황성호">황성호</td>
# 				<td class="txc">
#
# 						<a href="http://www.samhyun.co.kr" class="btn ico homepage" target="_blank" title="http://www.samhyun.co.kr"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경상남도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)오상헬스케어"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('03622'); return false;" title='오상헬스케어'> 오상헬스케어</a> </td>
# 				<td class="textOverflow" title="의료용품 및 기타 의약 관련제품 제조업">의료용품 및 기타 의약 관련제품 제조업</td>
# 				<td class="textOverflow" title="생화학 측정기 및 센서, 면역진단기기 및 마커, 분자진단기기 및 시약 등">생화학 측정기 및 센서, 면역진단기기 및 마커, 분자진단기기 및 시약 등</td>
# 				<td class="txc">2024-03-13</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="강철훈">강철훈</td>
# 				<td class="txc">
#
# 						<a href="http://www.osanghc.com" class="btn ico homepage" target="_blank" title="http://www.osanghc.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경기도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)케이엔알시스템"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('19943'); return false;" title='케이엔알시스템'> 케이엔알시스템</a> </td>
# 				<td class="textOverflow" title="측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외">측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외</td>
# 				<td class="textOverflow" title="특수목적 시험장비, 산업용로봇">특수목적 시험장비, 산업용로봇</td>
# 				<td class="txc">2024-03-07</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김명한">김명한</td>
# 				<td class="txc">
#
# 						<a href="http://www.knrsys.com" class="btn ico homepage" target="_blank" title="http://www.knrsys.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경기도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="비엔케이제2호기업인수목적(주)"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47337'); return false;" title='비엔케이제2호스팩'> 비엔케이제2호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="txc">2024-03-05</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="정민중">정민중</td>
# 				<td class="txc">
#
# 						<a href="http://bnkspac2.com" class="btn ico homepage" target="_blank" title="http://bnkspac2.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="하나31호기업인수목적 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('46990'); return false;" title='하나31호스팩'> 하나31호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수합병">기업인수합병</td>
# 				<td class="txc">2024-03-05</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="한규정">한규정</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="에스케이증권제11호기업인수목적 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47223'); return false;" title='SK증권제11호스팩'> SK증권제11호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수목적 주식회사">기업인수목적 주식회사</td>
# 				<td class="txc">2024-03-04</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="최상우">최상우</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="유안타제15호기업인수목적 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47305'); return false;" title='유안타제15호스팩'> 유안타제15호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="금융 지원 서비스">금융 지원 서비스</td>
# 				<td class="txc">2024-02-29</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="구태훈">구태훈</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="유진기업인수목적10호 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('46876'); return false;" title='유진스팩10호'> 유진스팩10호</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수합병">기업인수합병</td>
# 				<td class="txc">2024-02-29</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김동진">김동진</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)에이피알"><img src='/images/common/icn_t_yu.gif' class='vmiddle legend' alt='유가증권'> <a id="companysum" href="#companysum" onclick="companysummary_open('27847'); return false;" title='에이피알'> 에이피알</a> </td>
# 				<td class="textOverflow" title="기타 화학제품 제조업">기타 화학제품 제조업</td>
# 				<td class="textOverflow" title="화장품, 피부미용기기 등">화장품, 피부미용기기 등</td>
# 				<td class="txc">2024-02-27</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김병훈">김병훈</td>
# 				<td class="txc">
#
# 						<a href="http://apr-in.com" class="btn ico homepage" target="_blank" title="http://apr-in.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="이에이트 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('41862'); return false;" title='이에이트'> 이에이트</a> </td>
# 				<td class="textOverflow" title="소프트웨어 개발 및 공급업">소프트웨어 개발 및 공급업</td>
# 				<td class="textOverflow" title="CFD 시뮬레이션 소프트웨어, 디지털트윈 플랫폼">CFD 시뮬레이션 소프트웨어, 디지털트윈 플랫폼</td>
# 				<td class="txc">2024-02-23</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김진현">김진현</td>
# 				<td class="txc">
#
# 						<a href="http://e8ight.co.kr/" class="btn ico homepage" target="_blank" title="http://e8ight.co.kr/"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="주식회사 코셈"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('36035'); return false;" title='코셈'> 코셈</a> </td>
# 				<td class="textOverflow" title="측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외">측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외</td>
# 				<td class="textOverflow" title="주사전자현미경(SEM)">주사전자현미경(SEM)</td>
# 				<td class="txc">2024-02-23</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이준희">이준희</td>
# 				<td class="txc">
#
# 						<a href="http://www.coxem.com" class="btn ico homepage" target="_blank" title="http://www.coxem.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">대전광역시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="케이웨더(주)"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('06810'); return false;" title='케이웨더'> 케이웨더</a> </td>
# 				<td class="textOverflow" title="일반 목적용 기계 제조업">일반 목적용 기계 제조업</td>
# 				<td class="textOverflow" title="공기개선솔루션, 기상데이터, 공기측정솔루션 등">공기개선솔루션, 기상데이터, 공기측정솔루션 등</td>
# 				<td class="txc">2024-02-22</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김동식">김동식</td>
# 				<td class="txc">
#
# 						<a href="http://www.kweather.co.kr" class="btn ico homepage" target="_blank" title="http://www.kweather.co.kr"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)사피엔반도체"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('45243'); return false;" title='사피엔반도체'> 사피엔반도체</a> </td>
# 				<td class="textOverflow" title="반도체 제조업">반도체 제조업</td>
# 				<td class="textOverflow" title="Micro/Mini-LED Display Driver IC">Micro/Mini-LED Display Driver IC</td>
# 				<td class="txc">2024-02-19</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이명희">이명희</td>
# 				<td class="txc">
#
# 						<a href="http://www.sapien-semicon.com" class="btn ico homepage" target="_blank" title="http://www.sapien-semicon.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경기도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="주식회사 에스피소프트"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('44367'); return false;" title='에스피소프트'> 에스피소프트</a> </td>
# 				<td class="textOverflow" title="컴퓨터 프로그래밍, 시스템 통합 및 관리업">컴퓨터 프로그래밍, 시스템 통합 및 관리업</td>
# 				<td class="textOverflow" title="SPLA 라이센스 총판 사업,CLOUD, gDaaS 등">SPLA 라이센스 총판 사업,CLOUD, gDaaS 등</td>
# 				<td class="txc">2024-02-15</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이은재">이은재</td>
# 				<td class="txc">
#
# 						<a href="http://www.spsoft.co.kr" class="btn ico homepage" target="_blank" title="http://www.spsoft.co.kr"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="주식회사 스튜디오삼익"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('41538'); return false;" title='스튜디오삼익'> 스튜디오삼익</a> </td>
# 				<td class="textOverflow" title="기타 생활용품 소매업">기타 생활용품 소매업</td>
# 				<td class="textOverflow" title="침실가구, 거실가구,  옷장/수납, 주방가구 등">침실가구, 거실가구,  옷장/수납, 주방가구 등</td>
# 				<td class="txc">2024-02-06</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="최정석">최정석</td>
# 				<td class="txc">
#
# 						<a href="http://www.studiosamick.com" class="btn ico homepage" target="_blank" title="http://www.studiosamick.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="신영해피투모로우제10호기업인수목적 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47222'); return false;" title='신영스팩10호'> 신영스팩10호</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수합병">기업인수합병</td>
# 				<td class="txc">2024-02-06</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="여지우">여지우</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="폰드그룹(주)"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47285'); return false;" title='폰드그룹'> 폰드그룹</a> </td>
# 				<td class="textOverflow" title="봉제의복 제조업">봉제의복 제조업</td>
# 				<td class="textOverflow" title="의류(언더웨어, 의복, 잡화, 코스메틱 등)">의류(언더웨어, 의복, 잡화, 코스메틱 등)</td>
# 				<td class="txc">2024-02-02</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="임종민 / 김유진">임종민..</td>
# 				<td class="txc">
#
# 						<a href="http://www.pond-group.co.kr" class="btn ico homepage" target="_blank" title="http://www.pond-group.co.kr"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="아이비케이에스제24호기업인수목적 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('46948'); return false;" title='IBKS제24호스팩'> IBKS제24호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="txc">2024-02-01</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김강민">김강민</td>
# 				<td class="txc">
#
# 						<a href="http://www.ibks.com" class="btn ico homepage" target="_blank" title="http://www.ibks.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)레이저옵텍"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('19955'); return false;" title='레이저옵텍'> 레이저옵텍</a> </td>
# 				<td class="textOverflow" title="의료용 기기 제조업">의료용 기기 제조업</td>
# 				<td class="textOverflow" title="레이저 기반 피부미용기기 및 질환치료기기">레이저 기반 피부미용기기 및 질환치료기기</td>
# 				<td class="txc">2024-02-01</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="주홍, 이창진">주홍,..</td>
# 				<td class="txc">
#
# 						<a href="http://www.laseroptek.com" class="btn ico homepage" target="_blank" title="http://www.laseroptek.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경기도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)이닉스"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('45240'); return false;" title='이닉스'> 이닉스</a> </td>
# 				<td class="textOverflow" title="자동차 신품 부품 제조업">자동차 신품 부품 제조업</td>
# 				<td class="textOverflow" title="2차전지용 배터리셀 패드 등">2차전지용 배터리셀 패드 등</td>
# 				<td class="txc">2024-02-01</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="강동호.김정득(각자 대표이사)">강동호..</td>
# 				<td class="txc">
#
# 						<a href="http://www.inics.kr" class="btn ico homepage" target="_blank" title="http://www.inics.kr"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">부산광역시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# ...
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="하나30호기업인수목적 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('46988'); return false;" title='하나30호스팩'> 하나30호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수합병">기업인수합병</td>
# 				<td class="txc">2023-12-22</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="전신웅">전신웅</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="씨싸이트(주)"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('10967'); return false;" title='씨싸이트'> 씨싸이트</a> </td>
# 				<td class="textOverflow" title="봉제의복 제조업">봉제의복 제조업</td>
# 				<td class="textOverflow" title="니트류 OEM">니트류 OEM</td>
# 				<td class="txc">2023-12-21</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김상기">김상기</td>
# 				<td class="txc">
#
# 						<a href="http://www.c-site.co.kr" class="btn ico homepage" target="_blank" title="http://www.c-site.co.kr"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)블루엠텍"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('43958'); return false;" title='블루엠텍'> 블루엠텍</a> </td>
# 				<td class="textOverflow" title="기타 전문 도매업">기타 전문 도매업</td>
# 				<td class="textOverflow" title="의약품 유통업">의약품 유통업</td>
# 				<td class="txc">2023-12-13</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김현수">김현수</td>
# 				<td class="txc">
#
# 						<a href="http://www.bluemtec.com" class="btn ico homepage" target="_blank" title="http://www.bluemtec.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경기도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="엘에스머트리얼즈 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('41720'); return false;" title='LS머트리얼즈'> LS머트리얼즈</a> <img src='/images/common/icn_t_q150.gif' class='vmiddle legend' alt='KOSDAQ150'> </td>
# 				<td class="textOverflow" title="전자부품 제조업">전자부품 제조업</td>
# 				<td class="textOverflow" title="울트라커패시터(셀 및 모듈)">울트라커패시터(셀 및 모듈)</td>
# 				<td class="txc">2023-12-12</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="홍영호">홍영호</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">경기도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)케이엔에스"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('43247'); return false;" title='케이엔에스'> 케이엔에스</a> </td>
# 				<td class="textOverflow" title="특수 목적용 기계 제조업">특수 목적용 기계 제조업</td>
# 				<td class="textOverflow" title="이차전지 자동화 설비">이차전지 자동화 설비</td>
# 				<td class="txc">2023-12-06</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="정봉진">정봉진</td>
# 				<td class="txc">
#
# 						<a href="http://knssystem.com" class="btn ico homepage" target="_blank" title="http://knssystem.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경기도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="교보15호기업인수목적 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('46532'); return false;" title='교보15호스팩'> 교보15호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수합병">기업인수합병</td>
# 				<td class="txc">2023-12-05</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김상도">김상도</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)와이바이오로직스"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('33884'); return false;" title='와이바이오로직스'> 와이바이오로직스</a> </td>
# 				<td class="textOverflow" title="자연과학 및 공학 연구개발업">자연과학 및 공학 연구개발업</td>
# 				<td class="textOverflow" title="항체의약품 및 항체후보물질 연구개발">항체의약품 및 항체후보물질 연구개발</td>
# 				<td class="txc">2023-12-05</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="박영우, 장우익">박영우..</td>
# 				<td class="txc">
#
# 						<a href="http://ybiologics.com" class="btn ico homepage" target="_blank" title="http://ybiologics.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">대전광역시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="삼성기업인수목적9호(주)"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('46851'); return false;" title='삼성스팩9호'> 삼성스팩9호</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수합병">기업인수합병</td>
# 				<td class="txc">2023-12-04</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="오정헌">오정헌</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)에이텀"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('35569'); return false;" title='에이텀'> 에이텀</a> </td>
# 				<td class="textOverflow" title="전자부품 제조업">전자부품 제조업</td>
# 				<td class="textOverflow" title="평판형 트랜스">평판형 트랜스</td>
# 				<td class="txc">2023-12-01</td>
# 				<td class="txc">06월</td>
# 				<td class="txc" title="한택수">한택수</td>
# 				<td class="txc">
#
# 						<a href="http://www.iatum.com/" class="btn ico homepage" target="_blank" title="http://www.iatum.com/"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경기도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="엔에이치기업인수목적30호 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('46691'); return false;" title='엔에이치스팩30호'> 엔에이치스팩30호</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="금융지원서비스업">금융지원서비스업</td>
# 				<td class="txc">2023-12-01</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="조선희">조선희</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)에이에스텍"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('45386'); return false;" title='에이에스텍'> 에이에스텍</a> </td>
# 				<td class="textOverflow" title="기타 화학제품 제조업">기타 화학제품 제조업</td>
# 				<td class="textOverflow" title="자외선 차단제 유기 원료">자외선 차단제 유기 원료</td>
# 				<td class="txc">2023-11-28</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="윤종배,이승재">윤종배..</td>
# 				<td class="txc">
#
# 						<a href="http://www.asteh.co.kr" class="btn ico homepage" target="_blank" title="http://www.asteh.co.kr"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">충청남도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="주식회사 그린리소스"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('40249'); return false;" title='그린리소스'> 그린리소스</a> </td>
# 				<td class="textOverflow" title="반도체 제조업">반도체 제조업</td>
# 				<td class="textOverflow" title="반도체 및 디스플레이 장비 보호코팅 및 소재">반도체 및 디스플레이 장비 보호코팅 및 소재</td>
# 				<td class="txc">2023-11-24</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이종수,이종범(공동대표이사)">이종수..</td>
# 				<td class="txc">
#
# 						<a href="http://www.greenresource.kr" class="btn ico homepage" target="_blank" title="http://www.greenresource.kr"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">인천광역시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)제이엔비"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('45216'); return false;" title='제이엔비'> 제이엔비</a> </td>
# 				<td class="textOverflow" title="특수 목적용 기계 제조업">특수 목적용 기계 제조업</td>
# 				<td class="textOverflow" title="진공 펌프용 유틸리티 장치(Stacker 등), 정밀가공 부품">진공 펌프용 유틸리티 장치(Stacker 등), 정밀가공 부품</td>
# 				<td class="txc">2023-11-24</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이정범">이정범</td>
# 				<td class="txc">
#
# 						<a href="http://www.jnbeng.com/" class="btn ico homepage" target="_blank" title="http://www.jnbeng.com/"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경기도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="한선엔지니어링(주)"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('45228'); return false;" title='한선엔지니어링'> 한선엔지니어링</a> </td>
# 				<td class="textOverflow" title="기타 금속 가공제품 제조업">기타 금속 가공제품 제조업</td>
# 				<td class="textOverflow" title="계장용 피팅 및 밸브, 모듈">계장용 피팅 및 밸브, 모듈</td>
# 				<td class="txc">2023-11-24</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이제훈">이제훈</td>
# 				<td class="txc">
#
# 						<a href="http://www.slok.co.kr" class="btn ico homepage" target="_blank" title="http://www.slok.co.kr"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">부산광역시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)동인기연"><img src='/images/common/icn_t_yu.gif' class='vmiddle legend' alt='유가증권'> <a id="companysum" href="#companysum" onclick="companysummary_open('11138'); return false;" title='동인기연'> 동인기연</a> </td>
# 				<td class="textOverflow" title="가죽, 가방 및 유사제품 제조업">가죽, 가방 및 유사제품 제조업</td>
# 				<td class="textOverflow" title="스포츠용품(등산용가방,골프백),금속압형제품,유아용품 제조,도소매,통신 판매/부동산 임대">스포츠용품(등산용가방,골프백),금속압형제품,유아용품 제조,도소매,통신 판매/부동산 임대</td>
# 				<td class="txc">2023-11-21</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="정인수">정인수</td>
# 				<td class="txc">
#
# 						<a href="http://www.dong-in.com/" class="btn ico homepage" target="_blank" title="http://www.dong-in.com/"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경기도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="주식회사 에코아이"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('44828'); return false;" title='에코아이'> 에코아이</a> </td>
# 				<td class="textOverflow" title="기타 전문 서비스업">기타 전문 서비스업</td>
# 				<td class="textOverflow" title="탄소배출권 및 탄소배출권 관련 컨설팅">탄소배출권 및 탄소배출권 관련 컨설팅</td>
# 				<td class="txc">2023-11-21</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이수복">이수복</td>
# 				<td class="txc">
#
# 						<a href="http://www.ecoeye.com" class="btn ico homepage" target="_blank" title="http://www.ecoeye.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)스톰테크"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('35209'); return false;" title='스톰테크'> 스톰테크</a> </td>
# 				<td class="textOverflow" title="플라스틱제품 제조업">플라스틱제품 제조업</td>
# 				<td class="textOverflow" title="정수기 피팅, 밸브, 파우셋 등 부품">정수기 피팅, 밸브, 파우셋 등 부품</td>
# 				<td class="txc">2023-11-20</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="강기환, 최준수">강기환..</td>
# 				<td class="txc">
#
# 						<a href="http://www.stormtec.co.kr/" class="btn ico homepage" target="_blank" title="http://www.stormtec.co.kr/"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="주식회사 에코프로머티리얼즈"><img src='/images/common/icn_t_yu.gif' class='vmiddle legend' alt='유가증권'> <a id="companysum" href="#companysum" onclick="companysummary_open('45008'); return false;" title='에코프로머티'> 에코프로머티</a> <img src='/images/common/icn_t_k200.gif' class='vmiddle legend' alt='KOSPI200'> <img src='/images/common/icn_t_x300.gif' class='vmiddle legend' alt='KRX300'> </td>
# 				<td class="textOverflow" title="일차전지 및 이차전지 제조업">일차전지 및 이차전지 제조업</td>
# 				<td class="textOverflow" title="배터리 양극재용 핵심소재 하이니켈 전구체">배터리 양극재용 핵심소재 하이니켈 전구체</td>
# 				<td class="txc">2023-11-17</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김병훈">김병훈</td>
# 				<td class="txc">
#
# 						<a href="http://ecopromaterials.com/" class="btn ico homepage" target="_blank" title="http://ecopromaterials.com/"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경상북도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="캡스톤파트너스(주)"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('45230'); return false;" title='캡스톤파트너스'> 캡스톤파트너스</a> </td>
# 				<td class="textOverflow" title="기타 금융업">기타 금융업</td>
# 				<td class="textOverflow" title="벤처투자조합 등 조합 결성 및 운영">벤처투자조합 등 조합 결성 및 운영</td>
# 				<td class="txc">2023-11-15</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="송은강">송은강</td>
# 				<td class="txc">
#
# 						<a href="http://cspartners.co.kr" class="btn ico homepage" target="_blank" title="http://cspartners.co.kr"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)프로젠"><img src='/images/common/icn_t_konex.gif' class='vmiddle legend' alt='코넥스'> <a id="companysum" href="#companysum" onclick="companysummary_open('29616'); return false;" title='프로젠'> 프로젠</a> </td>
# 				<td class="textOverflow" title="자연과학 및 공학 연구개발업">자연과학 및 공학 연구개발업</td>
# 				<td class="textOverflow" title="바이오의약품">바이오의약품</td>
# 				<td class="txc">2023-11-15</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김종균">김종균</td>
# 				<td class="txc">
#
# 						<a href="http://progen.co.kr/" class="btn ico homepage" target="_blank" title="http://progen.co.kr/"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
#
#
#
# 		</tbody>
# 	</table>
# </section>
#
# <!-- 페이징 START -->
# <section class="paging-group">
# 	<div class='paging type-00'><a href='#prevPage10' class='pprev' onclick='return false;'><span>이전10개 페이지</span></a><a href='#prevPage' class='prev' onclick='return false;'><span>이전 페이지</span></a>
# <a href='#page_link_1' class='active' onclick='return false;'>1</a><a href='#page_link_2' onclick="fnPageGo('2');return false;">2</a><a href='#page_link_3' onclick="fnPageGo('3');return false;">3</a><a href='#page_link_4' onclick="fnPageGo('4');return false;">4</a><a href='#page_link_5' onclick="fnPageGo('5');return false;">5</a><a href='#page_link_6' onclick="fnPageGo('6');return false;">6</a><a href='#page_link_7' onclick="fnPageGo('7');return false;">7</a><a href='#page_link_8' onclick="fnPageGo('8');return false;">8</a><a href='#page_link_9' onclick="fnPageGo('9');return false;">9</a><a href='#page_link_10' onclick="fnPageGo('10');return false;">10</a>
# <a href='#nextPage' class='next' onclick="fnPageGo('2');return false;"><span>다음 페이지</span></a><a href='#nextPage10' class='nnext' onclick="fnPageGo('11');return false;"><span>다음10개 페이지</span></a></div><div class="info type-00">
# 전체 <em>2,705</em>건 : <strong>1</strong>/28&nbsp;&nbsp;&nbsp;
# <select id='currentPageSize' name='currentPageSize'>
# <option value='15'  >15건</option>
# <option value='30'  >30건</option>
# <option value='50'  >50건</option>
# <option value='100' selected='selected'>100건</option>
# </select>&nbsp;&nbsp;<a href='#' onclick="fnSearch1();return false;" class='btn-sprite btn-go vmiddle' title='GO'><span>GO</span></a>
# </div>
# </section>
# <!-- 페이징 END -->
#
# <script type="text/JavaScript">
# $(document).ready(function(){
# 	fn_InitTitle("회사명,업종,주요제품,상장일,결산월,대표자명,홈페이지,지역", "true,false,false,true,false,false,false,false");
# });
# </script>

# %%
# 'th' 요소 내에 있는 텍스트를 찾습니다.
for kind in soup.find_all('th'):
    print(kind.text)

# %%
for company in soup.select('a[title]'):
    title = company.get('title')
    print(title)
# Out:
# 산일전기
# http://www.sanil.co.kr
# 에이치에스효성
# http://www.hshyosung.com
# 엔에이치스팩31호
# SK증권제13호스팩
# 엑셀세라퓨틱스
# 이베스트스팩6호
# 시프트업
# http://shiftup.co.kr
# 하스
# http://www.hassbio.com
# 이노스페이스
# http://www.innospc.com/
# 신한글로벌액티브리츠
# http://shglobalreit.com
# 에이치브이엠
# http://hvm.co.kr/
# 팡스카이
# http://www.panggame.com/
# 하이젠알앤엠
# http://higenrnm.com
# 한국제15호스팩
# 에스오에스랩
# http://soslab.co
# 미래에셋비전스팩6호
# 에이치엠씨제7호스팩
# 파라다이스
# http://www.paradise.co.kr/ko/main
# 한중엔시에스
# http://www.hjncs.com
# KB제29호스팩
# 미래에셋비전스팩5호
# 씨어스테크놀로지
# http://seerstech.com
# 한국제14호스팩
# 디비금융스팩12호
# 라메디텍
# 그리드위즈
# http://www.gridwiz.com
# 다원넥스뷰
# http://www.nexview.co.kr
# 미래에셋비전스팩4호
# 노브랜드
# http://www.nobland.com
# KB제28호스팩
# 아이씨티케이
# http://www.ictk.com
# HD현대마린솔루션
# http://www.hd-marinesolution.com/
# SK증권제12호스팩
# 코칩
# http://www.korchip.com
# 민테크
# http://www.g-mintech.co.kr
# 카티스
# http://CATIS.CO.KR
# 디앤디파마텍
# http://www.ddpharmatech.com
# 유안타제16호스팩
# 제일엠앤에스
# http://www.jeilm.co.kr
# 삐아
# http://www.bbiacosmetic.com/
# 하나33호스팩
# 신한제13호스팩
# 신한제12호스팩
# 아이엠비디엑스
# http://www.imbdx.com/
# SK이터닉스
# http://www.sketernix.com
# 하나32호스팩
# 엔젤로보틱스
# http://www.angel-robotics.com/ko/
# 제이투케이바이오
# http://www.j2kbio.com
# 삼현
# http://www.samhyun.co.kr
# 오상헬스케어
# http://www.osanghc.com
# 케이엔알시스템
# http://www.knrsys.com
# 비엔케이제2호스팩
# http://bnkspac2.com
# 하나31호스팩
# SK증권제11호스팩
# 유안타제15호스팩
# 유진스팩10호
# 에이피알
# http://apr-in.com
# 이에이트
# http://e8ight.co.kr/
# 코셈
# http://www.coxem.com
# 케이웨더
# http://www.kweather.co.kr
# 사피엔반도체
# http://www.sapien-semicon.com
# 에스피소프트
# http://www.spsoft.co.kr
# 스튜디오삼익
# http://www.studiosamick.com
# 신영스팩10호
# 폰드그룹
# http://www.pond-group.co.kr
# IBKS제24호스팩
# http://www.ibks.com
# 레이저옵텍
# http://www.laseroptek.com
# 이닉스
# http://www.inics.kr
# 엘앤에프
# http://www.landf.co.kr/
# 포스뱅크
# http://www.posbank.com/
# 현대힘스
# http://www.hyms.kr
# HB인베스트먼트
# http://www.hbvc.co.kr
# 드림인사이트
# http://bydream.co.kr/
# 대신밸런스제17호스팩
# 우진엔텍
# http://www.woojinntec.com/
# 세븐브로이맥주
# http://sevenbrau.com
# 한빛레이저
# http://www.hblaser.co.kr
# 포스코DX
# http://www.poscodx.com/kor/
# DS단석
# http://dsdansuk.com
# IBKS제23호스팩
# http://www.ibks.com
# 하나30호스팩
# 씨싸이트
# http://www.c-site.co.kr
# 블루엠텍
# http://www.bluemtec.com
# LS머트리얼즈
# 케이엔에스
# http://knssystem.com
# 교보15호스팩
# 와이바이오로직스
# http://ybiologics.com
# 삼성스팩9호
# 에이텀
# http://www.iatum.com/
# 엔에이치스팩30호
# 에이에스텍
# http://www.asteh.co.kr
# 그린리소스
# http://www.greenresource.kr
# 제이엔비
# http://www.jnbeng.com/
# 한선엔지니어링
# http://www.slok.co.kr
# 동인기연
# http://www.dong-in.com/
# 에코아이
# http://www.ecoeye.com
# 스톰테크
# http://www.stormtec.co.kr/
# 에코프로머티
# http://ecopromaterials.com/
# 캡스톤파트너스
# http://cspartners.co.kr
# 프로젠
# http://progen.co.kr/
# GO

# %%
for company in soup.select('tr.first a'):
    title = company.get('title')
    print(title)
# Out:
# 산일전기
# http://www.sanil.co.kr

# %%
for company in soup.select('a#companysum'):   # td.first a 이거 써도됨
    title = company.get('title')
    print(title)
# Out:
# 산일전기
# 에이치에스효성
# 엔에이치스팩31호
# SK증권제13호스팩
# 엑셀세라퓨틱스
# 이베스트스팩6호
# 시프트업
# 하스
# 이노스페이스
# 신한글로벌액티브리츠
# 에이치브이엠
# 팡스카이
# 하이젠알앤엠
# 한국제15호스팩
# 에스오에스랩
# 미래에셋비전스팩6호
# 에이치엠씨제7호스팩
# 파라다이스
# 한중엔시에스
# KB제29호스팩
# 미래에셋비전스팩5호
# 씨어스테크놀로지
# 한국제14호스팩
# 디비금융스팩12호
# 라메디텍
# 그리드위즈
# 다원넥스뷰
# 미래에셋비전스팩4호
# 노브랜드
# KB제28호스팩
# 아이씨티케이
# HD현대마린솔루션
# SK증권제12호스팩
# 코칩
# 민테크
# 카티스
# 디앤디파마텍
# 유안타제16호스팩
# 제일엠앤에스
# 삐아
# 하나33호스팩
# 신한제13호스팩
# 신한제12호스팩
# 아이엠비디엑스
# SK이터닉스
# 하나32호스팩
# 엔젤로보틱스
# 제이투케이바이오
# 삼현
# 오상헬스케어
# 케이엔알시스템
# 비엔케이제2호스팩
# 하나31호스팩
# SK증권제11호스팩
# 유안타제15호스팩
# 유진스팩10호
# 에이피알
# 이에이트
# 코셈
# 케이웨더
# 사피엔반도체
# 에스피소프트
# 스튜디오삼익
# 신영스팩10호
# 폰드그룹
# IBKS제24호스팩
# 레이저옵텍
# 이닉스
# 엘앤에프
# 포스뱅크
# 현대힘스
# HB인베스트먼트
# 드림인사이트
# 대신밸런스제17호스팩
# 우진엔텍
# 세븐브로이맥주
# 한빛레이저
# 포스코DX
# DS단석
# IBKS제23호스팩
# 하나30호스팩
# 씨싸이트
# 블루엠텍
# LS머트리얼즈
# 케이엔에스
# 교보15호스팩
# 와이바이오로직스
# 삼성스팩9호
# 에이텀
# 엔에이치스팩30호
# 에이에스텍
# 그린리소스
# 제이엔비
# 한선엔지니어링
# 동인기연
# 에코아이
# 스톰테크
# 에코프로머티
# 캡스톤파트너스
# 프로젠

# %%
for service in soup.select('td.textOverflow'):
    ser = service.get_text('title')
    print(ser)
# Out:
# 금융 지원 서비스업
# 금융지원서비스업
# 금융 지원 서비스업
# 기업인수목적 주식회사
# 기초 의약물질 제조업
# CellCor SFD/CD(세포배양배지)
# 금융 지원 서비스업
# 기업인수목적 주식회사
# 소프트웨어 개발 및 공급업
# 게임 소프트웨어
# 의료용품 및 기타 의약 관련제품 제조업
# 리튬디실리케이트 수복소재(Amber block, Amber Ingot 등), 지르코니아 유치관
# 항공기,우주선 및 부품 제조업
# 소형발사체, 로켓추진기관, 과학로켓, 시험평가용역
# 신탁업 및 집합투자업
# 신탁 및 집합투자
# 1차 비철금속 제조업
# Ni계 합금, Fe계 합금, 스퍼터링타겟, Cu계 합금 등
# 소프트웨어 개발 및 공급업
# 게임 개발 및 리퍼블리싱
# 전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 전동기 및 발전기 (범용모터, 서보모터)
# 금융 지원 서비스업
# 기업인수합병
# 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 산업용 및 차량용 라이다(LiDAR)
# 금융 지원 서비스업
# 기업인수합병
# 금융 지원 서비스업
# 기타금융
# 유원지 및 기타 오락관련 서비스업
# 카지노, 호텔, 복합리조트
# 전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 수냉식 냉각시스템 ESS Parts, 공랭식 ESS Module Parts, EV Module 및 내연기관 Parts
# 금융 지원 서비스업
# 기업인수합병
# 금융 지원 서비스업
# 기업인수합병
# 의료용 기기 제조업
# 심전도검사솔루션 입원환자모니터링솔루션
# 금융 지원 서비스업
# 기업인수합병
# 기타 금융업
# 기업인수 및 합병
# 의료용 기기 제조업
# 초소형 레이저 의료기기  및 미용기기
# 그외 기타 전문, 과학 및 기술 서비스업
# 수요관리 서비스, 전기차 충전기 모뎀 등
# 사진장비 및 광학기기 제조업
# LSMB(Laser Micro Bonding System)
# 금융 지원 서비스업
# 기업인수목적회사(기타금융서비스)
# 편조의복 제조업
# Knit, Woven 의류
# 금융 지원 서비스업
# 기업인수합병
# 반도체 제조업
# PUF반도체,보안솔루션(보안반도체,정보통신모듈기기,정보통신용반도체) 제조,개발
# 건축기술, 엔지니어링 및 관련 기술 서비스업
# AM(After Market) 솔루션, 친환경 Retrofit, 디지털 제어
# 금융 지원 서비스업
# 기업인수목적 주식회사
# 전자부품 제조업
# 소형 및 초소형 슈퍼커패시터
# 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 배터리 진단시스템, 배터리 시스템, 충방전 검사장비
# 컴퓨터 프로그래밍, 시스템 통합 및 관리업
# 산업인프라 보안플랫폼
# 자연과학 및 공학 연구개발업
# 대사성질환 치료제 등
# 금융 지원 서비스업
# 금융 지원 서비스(기업인수목적회사)
# 특수 목적용 기계 제조업
# 2차전지 믹싱시스템
# 기타 화학제품 제조업
# 색조화장품
# 금융 지원 서비스업
# 기업인수합병
# 금융 지원 서비스업
# 기타금융서비스(기업합병)
# 금융 지원 서비스업
# 금융서비스(기업인수목적회사)
# 자연과학 및 공학 연구개발업
# 알파리퀴드ⓡ 100, 알파리퀴드ⓡ HRR, 알파리퀴드ⓡ 디텍트, 알파리퀴드ⓡ 스크리닝
# 건물 건설업
# 부동산 개발
# 금융 지원 서비스업
# 기업인수합병
# 특수 목적용 기계 제조업
# 재활 전문 웨어러블 로봇, 근력 보조 무동력 웨어러블 슈트, 일상생활 보조 웨어러블 로봇 등
# 기타 화학제품 제조업
# 화장품 원료(천연소재 바이오소재 등)
# 자동차 신품 부품 제조업
# 스마트 액추에이터, 스마트 파워유닛
# 의료용품 및 기타 의약 관련제품 제조업
# 생화학 측정기 및 센서, 면역진단기기 및 마커, 분자진단기기 및 시약 등
# 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 특수목적 시험장비, 산업용로봇
# 금융 지원 서비스업
# 금융 지원 서비스업
# 금융 지원 서비스업
# 기업인수합병
# 금융 지원 서비스업
# 기업인수목적 주식회사
# 금융 지원 서비스업
# 금융 지원 서비스
# 금융 지원 서비스업
# 기업인수합병
# 기타 화학제품 제조업
# 화장품, 피부미용기기 등
# 소프트웨어 개발 및 공급업
# CFD 시뮬레이션 소프트웨어, 디지털트윈 플랫폼
# 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 주사전자현미경(SEM)
# 일반 목적용 기계 제조업
# 공기개선솔루션, 기상데이터, 공기측정솔루션 등
# 반도체 제조업
# Micro/Mini-LED Display Driver IC
# 컴퓨터 프로그래밍, 시스템 통합 및 관리업
# SPLA 라이센스 총판 사업,CLOUD, gDaaS 등
# 기타 생활용품 소매업
# 침실가구, 거실가구,  옷장/수납, 주방가구 등
# 금융 지원 서비스업
# 기업인수합병
# 봉제의복 제조업
# 의류(언더웨어, 의복, 잡화, 코스메틱 등)
# 금융 지원 서비스업
# 금융 지원 서비스업
# 의료용 기기 제조업
# 레이저 기반 피부미용기기 및 질환치료기기
# 자동차 신품 부품 제조업
# 2차전지용 배터리셀 패드 등
# 일차전지 및 이차전지 제조업
# 이차전지 양극활물질
# 일반 목적용 기계 제조업
# POS 단말기, KIOSK 단말기
# 선박 및 보트 건조업
# 선박기자재 (선박 블록, 보강재, 도장 등)
# 기타 금융업
# 벤처투자조합 등 조합 결성 및 운영
# 광고업
# 광고대행
# 금융 지원 서비스업
# 금융 지원 서비스업
# 그외 기타 전문, 과학 및 기술 서비스업
# 발전소 계측제어설비 정비 서비스
# 알코올음료 제조업
# 맥주 등 주류 및 음료
# 특수 목적용 기계 제조업
# 산업용 레이저 가공장비
# 건축기술, 엔지니어링 및 관련 기술 서비스업
# EIC 자동화 엔지니어링 및 IT서비스
# 기타 화학제품 제조업
# 바이오에너지
# 금융 지원 서비스업
# 기업인수 및 합병
# 금융 지원 서비스업
# 기업인수합병
# 봉제의복 제조업
# 니트류 OEM
# 기타 전문 도매업
# 의약품 유통업
# 전자부품 제조업
# 울트라커패시터(셀 및 모듈)
# 특수 목적용 기계 제조업
# 이차전지 자동화 설비
# 금융 지원 서비스업
# 기업인수합병
# 자연과학 및 공학 연구개발업
# 항체의약품 및 항체후보물질 연구개발
# 금융 지원 서비스업
# 기업인수합병
# 전자부품 제조업
# 평판형 트랜스
# 금융 지원 서비스업
# 금융지원서비스업
# 기타 화학제품 제조업
# 자외선 차단제 유기 원료
# 반도체 제조업
# 반도체 및 디스플레이 장비 보호코팅 및 소재
# 특수 목적용 기계 제조업
# 진공 펌프용 유틸리티 장치(Stacker 등), 정밀가공 부품
# 기타 금속 가공제품 제조업
# 계장용 피팅 및 밸브, 모듈
# 가죽, 가방 및 유사제품 제조업
# 스포츠용품(등산용가방,골프백),금속압형제품,유아용품 제조,도소매,통신 판매/부동산 임대
# 기타 전문 서비스업
# 탄소배출권 및 탄소배출권 관련 컨설팅
# 플라스틱제품 제조업
# 정수기 피팅, 밸브, 파우셋 등 부품
# 일차전지 및 이차전지 제조업
# 배터리 양극재용 핵심소재 하이니켈 전구체
# 기타 금융업
# 벤처투자조합 등 조합 결성 및 운영
# 자연과학 및 공학 연구개발업
# 바이오의약품
# 구조용 금속제품, 탱크 및 증기발생기 제조업
# 데크플레이트
# 반도체 제조업
# 비메모리 반도체 설계및 제조, 전자회로 연구, 설계, 레이아웃 등

# %%
for service in soup.select(""td", class_="textOverflow"):
    ser = service.get_text('title')
    print(ser)
# Out:
#   Cell In[83], line 1
#     for service in soup.select(""td", class_="textOverflow"):
#                                                           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
for date in soup.select('td:nth-child(1)'):
    date2 = date.get_text()
    print(date2)
# Out:
#   엔에이치스팩31호
#   SK증권제13호스팩
#   엑셀세라퓨틱스
#   이베스트스팩6호
#   시프트업
#   하스
#   이노스페이스
#   신한글로벌액티브리츠
#   에이치브이엠
#   팡스카이
#   하이젠알앤엠
#   한국제15호스팩
#   에스오에스랩
#   미래에셋비전스팩6호
#   에이치엠씨제7호스팩
#   파라다이스
#   한중엔시에스
#   KB제29호스팩
#   미래에셋비전스팩5호
#   씨어스테크놀로지
#   한국제14호스팩
#   디비금융스팩12호
#   라메디텍
#   그리드위즈
#   다원넥스뷰
#   미래에셋비전스팩4호
#   노브랜드
#   KB제28호스팩
#   아이씨티케이
#   HD현대마린솔루션
#   SK증권제12호스팩
#   코칩
#   민테크
#   카티스
#   디앤디파마텍
#   유안타제16호스팩
#   제일엠앤에스
#   삐아
#   하나33호스팩
#   신한제13호스팩
#   신한제12호스팩
#   아이엠비디엑스
#   SK이터닉스
#   하나32호스팩
#   엔젤로보틱스
#   제이투케이바이오
#   삼현
#   오상헬스케어
#   케이엔알시스템
#   비엔케이제2호스팩
#   하나31호스팩
#   SK증권제11호스팩
#   유안타제15호스팩
#   유진스팩10호
#   에이피알
#   이에이트
#   코셈
#   케이웨더
#   사피엔반도체
#   에스피소프트
#   스튜디오삼익
#   신영스팩10호
#   폰드그룹
#   IBKS제24호스팩
#   레이저옵텍
#   이닉스
#   엘앤에프
#   포스뱅크
#   현대힘스
#   HB인베스트먼트
#   드림인사이트
#   대신밸런스제17호스팩
#   우진엔텍
#   세븐브로이맥주
#   한빛레이저
#   포스코DX
#   DS단석
#   IBKS제23호스팩
#   하나30호스팩
#   씨싸이트
#   블루엠텍
#   LS머트리얼즈
#   케이엔에스
#   교보15호스팩
#   와이바이오로직스
#   삼성스팩9호
#   에이텀
#   엔에이치스팩30호
#   에이에스텍
#   그린리소스
#   제이엔비
#   한선엔지니어링
#   동인기연
#   에코아이
#   스톰테크
#   에코프로머티
#   캡스톤파트너스
#   프로젠
#   에스와이스틸텍
#   에이직랜드

# %%
for title in soup.select('td:nth-child(1)'):
    title2 = title.get_text()
    print(title2)
# Out:
#   엔에이치스팩31호
#   SK증권제13호스팩
#   엑셀세라퓨틱스
#   이베스트스팩6호
#   시프트업
#   하스
#   이노스페이스
#   신한글로벌액티브리츠
#   에이치브이엠
#   팡스카이
#   하이젠알앤엠
#   한국제15호스팩
#   에스오에스랩
#   미래에셋비전스팩6호
#   에이치엠씨제7호스팩
#   파라다이스
#   한중엔시에스
#   KB제29호스팩
#   미래에셋비전스팩5호
#   씨어스테크놀로지
#   한국제14호스팩
#   디비금융스팩12호
#   라메디텍
#   그리드위즈
#   다원넥스뷰
#   미래에셋비전스팩4호
#   노브랜드
#   KB제28호스팩
#   아이씨티케이
#   HD현대마린솔루션
#   SK증권제12호스팩
#   코칩
#   민테크
#   카티스
#   디앤디파마텍
#   유안타제16호스팩
#   제일엠앤에스
#   삐아
#   하나33호스팩
#   신한제13호스팩
#   신한제12호스팩
#   아이엠비디엑스
#   SK이터닉스
#   하나32호스팩
#   엔젤로보틱스
#   제이투케이바이오
#   삼현
#   오상헬스케어
#   케이엔알시스템
#   비엔케이제2호스팩
#   하나31호스팩
#   SK증권제11호스팩
#   유안타제15호스팩
#   유진스팩10호
#   에이피알
#   이에이트
#   코셈
#   케이웨더
#   사피엔반도체
#   에스피소프트
#   스튜디오삼익
#   신영스팩10호
#   폰드그룹
#   IBKS제24호스팩
#   레이저옵텍
#   이닉스
#   엘앤에프
#   포스뱅크
#   현대힘스
#   HB인베스트먼트
#   드림인사이트
#   대신밸런스제17호스팩
#   우진엔텍
#   세븐브로이맥주
#   한빛레이저
#   포스코DX
#   DS단석
#   IBKS제23호스팩
#   하나30호스팩
#   씨싸이트
#   블루엠텍
#   LS머트리얼즈
#   케이엔에스
#   교보15호스팩
#   와이바이오로직스
#   삼성스팩9호
#   에이텀
#   엔에이치스팩30호
#   에이에스텍
#   그린리소스
#   제이엔비
#   한선엔지니어링
#   동인기연
#   에코아이
#   스톰테크
#   에코프로머티
#   캡스톤파트너스
#   프로젠
#   에스와이스틸텍
#   에이직랜드

# %%
for service in soup.select('td:nth-child(2)'):
    service2 = service.get_text()
    print(service2)
# Out:
# 금융 지원 서비스업
# 금융 지원 서비스업
# 기초 의약물질 제조업
# 금융 지원 서비스업
# 소프트웨어 개발 및 공급업
# 의료용품 및 기타 의약 관련제품 제조업
# 항공기,우주선 및 부품 제조업
# 신탁업 및 집합투자업
# 1차 비철금속 제조업
# 소프트웨어 개발 및 공급업
# 전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 금융 지원 서비스업
# 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 금융 지원 서비스업
# 금융 지원 서비스업
# 유원지 및 기타 오락관련 서비스업
# 전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 금융 지원 서비스업
# 금융 지원 서비스업
# 의료용 기기 제조업
# 금융 지원 서비스업
# 기타 금융업
# 의료용 기기 제조업
# 그외 기타 전문, 과학 및 기술 서비스업
# 사진장비 및 광학기기 제조업
# 금융 지원 서비스업
# 편조의복 제조업
# 금융 지원 서비스업
# 반도체 제조업
# 건축기술, 엔지니어링 및 관련 기술 서비스업
# 금융 지원 서비스업
# 전자부품 제조업
# 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 컴퓨터 프로그래밍, 시스템 통합 및 관리업
# 자연과학 및 공학 연구개발업
# 금융 지원 서비스업
# 특수 목적용 기계 제조업
# 기타 화학제품 제조업
# 금융 지원 서비스업
# 금융 지원 서비스업
# 금융 지원 서비스업
# 자연과학 및 공학 연구개발업
# 건물 건설업
# 금융 지원 서비스업
# 특수 목적용 기계 제조업
# 기타 화학제품 제조업
# 자동차 신품 부품 제조업
# 의료용품 및 기타 의약 관련제품 제조업
# 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 금융 지원 서비스업
# 금융 지원 서비스업
# 금융 지원 서비스업
# 금융 지원 서비스업
# 금융 지원 서비스업
# 기타 화학제품 제조업
# 소프트웨어 개발 및 공급업
# 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 일반 목적용 기계 제조업
# 반도체 제조업
# 컴퓨터 프로그래밍, 시스템 통합 및 관리업
# 기타 생활용품 소매업
# 금융 지원 서비스업
# 봉제의복 제조업
# 금융 지원 서비스업
# 의료용 기기 제조업
# 자동차 신품 부품 제조업
# 일차전지 및 이차전지 제조업
# 일반 목적용 기계 제조업
# 선박 및 보트 건조업
# 기타 금융업
# 광고업
# 금융 지원 서비스업
# 그외 기타 전문, 과학 및 기술 서비스업
# 알코올음료 제조업
# 특수 목적용 기계 제조업
# 건축기술, 엔지니어링 및 관련 기술 서비스업
# 기타 화학제품 제조업
# 금융 지원 서비스업
# 금융 지원 서비스업
# 봉제의복 제조업
# 기타 전문 도매업
# 전자부품 제조업
# 특수 목적용 기계 제조업
# 금융 지원 서비스업
# 자연과학 및 공학 연구개발업
# 금융 지원 서비스업
# 전자부품 제조업
# 금융 지원 서비스업
# 기타 화학제품 제조업
# 반도체 제조업
# 특수 목적용 기계 제조업
# 기타 금속 가공제품 제조업
# 가죽, 가방 및 유사제품 제조업
# 기타 전문 서비스업
# 플라스틱제품 제조업
# 일차전지 및 이차전지 제조업
# 기타 금융업
# 자연과학 및 공학 연구개발업
# 구조용 금속제품, 탱크 및 증기발생기 제조업
# 반도체 제조업

# %%
for services in soup.select('td:nth-child(3)'):
    services2 = services.get_text()
    print(services2)
# Out:
# 금융지원서비스업
# 기업인수목적 주식회사
# CellCor SFD/CD(세포배양배지)
# 기업인수목적 주식회사
# 게임 소프트웨어
# 리튬디실리케이트 수복소재(Amber block, Amber Ingot 등), 지르코니아 유치관
# 소형발사체, 로켓추진기관, 과학로켓, 시험평가용역
# 신탁 및 집합투자
# Ni계 합금, Fe계 합금, 스퍼터링타겟, Cu계 합금 등
# 게임 개발 및 리퍼블리싱
# 전동기 및 발전기 (범용모터, 서보모터)
# 기업인수합병
# 산업용 및 차량용 라이다(LiDAR)
# 기업인수합병
# 기타금융
# 카지노, 호텔, 복합리조트
# 수냉식 냉각시스템 ESS Parts, 공랭식 ESS Module Parts, EV Module 및 내연기관 Parts
# 기업인수합병
# 기업인수합병
# 심전도검사솔루션 입원환자모니터링솔루션
# 기업인수합병
# 기업인수 및 합병
# 초소형 레이저 의료기기  및 미용기기
# 수요관리 서비스, 전기차 충전기 모뎀 등
# LSMB(Laser Micro Bonding System)
# 기업인수목적회사(기타금융서비스)
# Knit, Woven 의류
# 기업인수합병
# PUF반도체,보안솔루션(보안반도체,정보통신모듈기기,정보통신용반도체) 제조,개발
# AM(After Market) 솔루션, 친환경 Retrofit, 디지털 제어
# 기업인수목적 주식회사
# 소형 및 초소형 슈퍼커패시터
# 배터리 진단시스템, 배터리 시스템, 충방전 검사장비
# 산업인프라 보안플랫폼
# 대사성질환 치료제 등
# 금융 지원 서비스(기업인수목적회사)
# 2차전지 믹싱시스템
# 색조화장품
# 기업인수합병
# 기타금융서비스(기업합병)
# 금융서비스(기업인수목적회사)
# 알파리퀴드ⓡ 100, 알파리퀴드ⓡ HRR, 알파리퀴드ⓡ 디텍트, 알파리퀴드ⓡ 스크리닝
# 부동산 개발
# 기업인수합병
# 재활 전문 웨어러블 로봇, 근력 보조 무동력 웨어러블 슈트, 일상생활 보조 웨어러블 로봇 등
# 화장품 원료(천연소재 바이오소재 등)
# 스마트 액추에이터, 스마트 파워유닛
# 생화학 측정기 및 센서, 면역진단기기 및 마커, 분자진단기기 및 시약 등
# 특수목적 시험장비, 산업용로봇
# 금융 지원 서비스업
# 기업인수합병
# 기업인수목적 주식회사
# 금융 지원 서비스
# 기업인수합병
# 화장품, 피부미용기기 등
# CFD 시뮬레이션 소프트웨어, 디지털트윈 플랫폼
# 주사전자현미경(SEM)
# 공기개선솔루션, 기상데이터, 공기측정솔루션 등
# Micro/Mini-LED Display Driver IC
# SPLA 라이센스 총판 사업,CLOUD, gDaaS 등
# 침실가구, 거실가구,  옷장/수납, 주방가구 등
# 기업인수합병
# 의류(언더웨어, 의복, 잡화, 코스메틱 등)
# 금융 지원 서비스업
# 레이저 기반 피부미용기기 및 질환치료기기
# 2차전지용 배터리셀 패드 등
# 이차전지 양극활물질
# POS 단말기, KIOSK 단말기
# 선박기자재 (선박 블록, 보강재, 도장 등)
# 벤처투자조합 등 조합 결성 및 운영
# 광고대행
# 금융 지원 서비스업
# 발전소 계측제어설비 정비 서비스
# 맥주 등 주류 및 음료
# 산업용 레이저 가공장비
# EIC 자동화 엔지니어링 및 IT서비스
# 바이오에너지
# 기업인수 및 합병
# 기업인수합병
# 니트류 OEM
# 의약품 유통업
# 울트라커패시터(셀 및 모듈)
# 이차전지 자동화 설비
# 기업인수합병
# 항체의약품 및 항체후보물질 연구개발
# 기업인수합병
# 평판형 트랜스
# 금융지원서비스업
# 자외선 차단제 유기 원료
# 반도체 및 디스플레이 장비 보호코팅 및 소재
# 진공 펌프용 유틸리티 장치(Stacker 등), 정밀가공 부품
# 계장용 피팅 및 밸브, 모듈
# 스포츠용품(등산용가방,골프백),금속압형제품,유아용품 제조,도소매,통신 판매/부동산 임대
# 탄소배출권 및 탄소배출권 관련 컨설팅
# 정수기 피팅, 밸브, 파우셋 등 부품
# 배터리 양극재용 핵심소재 하이니켈 전구체
# 벤처투자조합 등 조합 결성 및 운영
# 바이오의약품
# 데크플레이트
# 비메모리 반도체 설계및 제조, 전자회로 연구, 설계, 레이아웃 등

# %%
for date in soup.select('td:nth-child(4)'):
    date2 = date.get_text()
    print(date2)
# Out:
# 2024-07-26
# 2024-07-25
# 2024-07-15
# 2024-07-12
# 2024-07-11
# 2024-07-03
# 2024-07-02
# 2024-07-01
# 2024-06-28
# 2024-06-28
# 2024-06-27
# 2024-06-26
# 2024-06-25
# 2024-06-24
# 2024-06-24
# 2024-06-24
# 2024-06-24
# 2024-06-21
# 2024-06-19
# 2024-06-19
# 2024-06-19
# 2024-06-18
# 2024-06-17
# 2024-06-14
# 2024-06-11
# 2024-05-29
# 2024-05-23
# 2024-05-17
# 2024-05-17
# 2024-05-08
# 2024-05-07
# 2024-05-07
# 2024-05-03
# 2024-05-03
# 2024-05-02
# 2024-05-02
# 2024-04-30
# 2024-04-25
# 2024-04-24
# 2024-04-22
# 2024-04-15
# 2024-04-03
# 2024-03-29
# 2024-03-27
# 2024-03-26
# 2024-03-25
# 2024-03-21
# 2024-03-13
# 2024-03-07
# 2024-03-05
# 2024-03-05
# 2024-03-04
# 2024-02-29
# 2024-02-29
# 2024-02-27
# 2024-02-23
# 2024-02-23
# 2024-02-22
# 2024-02-19
# 2024-02-15
# 2024-02-06
# 2024-02-06
# 2024-02-02
# 2024-02-01
# 2024-02-01
# 2024-02-01
# 2024-01-29
# 2024-01-29
# 2024-01-26
# 2024-01-25
# 2024-01-25
# 2024-01-24
# 2024-01-24
# 2024-01-17
# 2024-01-04
# 2024-01-02
# 2023-12-22
# 2023-12-22
# 2023-12-22
# 2023-12-21
# 2023-12-13
# 2023-12-12
# 2023-12-06
# 2023-12-05
# 2023-12-05
# 2023-12-04
# 2023-12-01
# 2023-12-01
# 2023-11-28
# 2023-11-24
# 2023-11-24
# 2023-11-24
# 2023-11-21
# 2023-11-21
# 2023-11-20
# 2023-11-17
# 2023-11-15
# 2023-11-15
# 2023-11-13
# 2023-11-13

# %%
for month in soup.select('td:nth-child(5)'):
    month2 = month.get_text()
    print(month2)
# Out:
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 02월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 06월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월
# 12월

# %%
for name in soup.select('td:nth-child(6)'):
    name2 = name.text
    print(name)
# Out:
# <td class="txc" title="이시형">이시형</td>
# <td class="txc" title="임율표">임율표</td>
# <td class="txc" title="이의일">이의일</td>
# <td class="txc" title="박용">박용</td>
# <td class="txc" title="김형태">김형태</td>
# <td class="txc" title="김용수">김용수</td>
# <td class="txc" title="김수종">김수종</td>
# <td class="txc" title="김선영">김선영</td>
# <td class="txc" title="문승호">문승호</td>
# <td class="txc" title="조호현, 이병진">조호현..</td>
# <td class="txc" title="김재학">김재학</td>
# <td class="txc" title="유한">유한</td>
# <td class="txc" title="정지성">정지성</td>
# <td class="txc" title="정명훈">정명훈</td>
# <td class="txc" title="강신명">강신명</td>
# <td class="txc" title="최종환, 최성욱">최종환..</td>
# <td class="txc" title="김환식">김환식</td>
# <td class="txc" title="서영화">서영화</td>
# <td class="txc" title="김대호">김대호</td>
# <td class="txc" title="이영신">이영신</td>
# <td class="txc" title="변성환">변성환</td>
# <td class="txc" title="김창희">김창희</td>
# <td class="txc" title="최종석">최종석</td>
# <td class="txc" title="김구환">김구환</td>
# <td class="txc" title="남기중">남기중</td>
# <td class="txc" title="김정수">김정수</td>
# <td class="txc" title="이상규">이상규</td>
# <td class="txc" title="고광범">고광범</td>
# <td class="txc" title="이정원">이정원</td>
# <td class="txc" title="이기동">이기동</td>
# <td class="txc" title="이재혁">이재혁</td>
# <td class="txc" title="손진형">손진형</td>
# <td class="txc" title="홍영진">홍영진</td>
# <td class="txc" title="김승수">김승수</td>
# <td class="txc" title="이슬기">이슬기</td>
# <td class="txc" title="박병권">박병권</td>
# <td class="txc" title="이영진">이영진</td>
# <td class="txc" title="박광춘">박광춘</td>
# <td class="txc" title="박태한">박태한</td>
# <td class="txc" title="배성환">배성환</td>
# <td class="txc" title="이동호">이동호</td>
# <td class="txc" title="김태유">김태유</td>
# <td class="txc" title="김해중">김해중</td>
# <td class="txc" title="박종찬">박종찬</td>
# <td class="txc" title="공경철">공경철</td>
# <td class="txc" title="이재섭">이재섭</td>
# <td class="txc" title="황성호">황성호</td>
# <td class="txc" title="강철훈">강철훈</td>
# <td class="txc" title="김명한">김명한</td>
# <td class="txc" title="정민중">정민중</td>
# <td class="txc" title="한규정">한규정</td>
# <td class="txc" title="최상우">최상우</td>
# <td class="txc" title="구태훈">구태훈</td>
# <td class="txc" title="김동진">김동진</td>
# <td class="txc" title="김병훈">김병훈</td>
# <td class="txc" title="김진현">김진현</td>
# <td class="txc" title="이준희">이준희</td>
# <td class="txc" title="김동식">김동식</td>
# <td class="txc" title="이명희">이명희</td>
# <td class="txc" title="이은재">이은재</td>
# <td class="txc" title="최정석">최정석</td>
# <td class="txc" title="여지우">여지우</td>
# <td class="txc" title="임종민 / 김유진">임종민..</td>
# <td class="txc" title="김강민">김강민</td>
# <td class="txc" title="주홍, 이창진">주홍,..</td>
# <td class="txc" title="강동호.김정득(각자 대표이사)">강동호..</td>
# <td class="txc" title="최수안">최수안</td>
# <td class="txc" title="은동욱">은동욱</td>
# <td class="txc" title="최지용">최지용</td>
# <td class="txc" title="황유선">황유선</td>
# <td class="txc" title="김기철">김기철</td>
# <td class="txc" title="이문수">이문수</td>
# <td class="txc" title="신상연">신상연</td>
# <td class="txc" title="김강삼">김강삼</td>
# <td class="txc" title="김정묵">김정묵</td>
# <td class="txc" title="정덕균">정덕균</td>
# <td class="txc" title="한승욱">한승욱</td>
# <td class="txc" title="오창수">오창수</td>
# <td class="txc" title="전신웅">전신웅</td>
# <td class="txc" title="김상기">김상기</td>
# <td class="txc" title="김현수">김현수</td>
# <td class="txc" title="홍영호">홍영호</td>
# <td class="txc" title="정봉진">정봉진</td>
# <td class="txc" title="김상도">김상도</td>
# <td class="txc" title="박영우, 장우익">박영우..</td>
# <td class="txc" title="오정헌">오정헌</td>
# <td class="txc" title="한택수">한택수</td>
# <td class="txc" title="조선희">조선희</td>
# <td class="txc" title="윤종배,이승재">윤종배..</td>
# <td class="txc" title="이종수,이종범(공동대표이사)">이종수..</td>
# <td class="txc" title="이정범">이정범</td>
# <td class="txc" title="이제훈">이제훈</td>
# <td class="txc" title="정인수">정인수</td>
# <td class="txc" title="이수복">이수복</td>
# <td class="txc" title="강기환, 최준수">강기환..</td>
# <td class="txc" title="김병훈">김병훈</td>
# <td class="txc" title="송은강">송은강</td>
# <td class="txc" title="김종균">김종균</td>
# <td class="txc" title="홍성균">홍성균</td>
# <td class="txc" title="이종민">이종민</td>

# %%
for home in soup.select('td:nth-child(7)'):
    home2 = home.get_text()
    print(home)
# Out:
# <td class="txc">
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://shiftup.co.kr" target="_blank" title="http://shiftup.co.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.hassbio.com" target="_blank" title="http://www.hassbio.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.innospc.com/" target="_blank" title="http://www.innospc.com/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://shglobalreit.com" target="_blank" title="http://shglobalreit.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://hvm.co.kr/" target="_blank" title="http://hvm.co.kr/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.panggame.com/" target="_blank" title="http://www.panggame.com/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://higenrnm.com" target="_blank" title="http://higenrnm.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://soslab.co" target="_blank" title="http://soslab.co"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.paradise.co.kr/ko/main" target="_blank" title="http://www.paradise.co.kr/ko/main"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.hjncs.com" target="_blank" title="http://www.hjncs.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://seerstech.com" target="_blank" title="http://seerstech.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.gridwiz.com" target="_blank" title="http://www.gridwiz.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.nexview.co.kr" target="_blank" title="http://www.nexview.co.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.nobland.com" target="_blank" title="http://www.nobland.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.ictk.com" target="_blank" title="http://www.ictk.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.hd-marinesolution.com/" target="_blank" title="http://www.hd-marinesolution.com/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.korchip.com" target="_blank" title="http://www.korchip.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.g-mintech.co.kr" target="_blank" title="http://www.g-mintech.co.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://CATIS.CO.KR" target="_blank" title="http://CATIS.CO.KR"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.ddpharmatech.com" target="_blank" title="http://www.ddpharmatech.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.jeilm.co.kr" target="_blank" title="http://www.jeilm.co.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.bbiacosmetic.com/" target="_blank" title="http://www.bbiacosmetic.com/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.imbdx.com/" target="_blank" title="http://www.imbdx.com/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.sketernix.com" target="_blank" title="http://www.sketernix.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.angel-robotics.com/ko/" target="_blank" title="http://www.angel-robotics.com/ko/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.j2kbio.com" target="_blank" title="http://www.j2kbio.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.samhyun.co.kr" target="_blank" title="http://www.samhyun.co.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.osanghc.com" target="_blank" title="http://www.osanghc.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.knrsys.com" target="_blank" title="http://www.knrsys.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://bnkspac2.com" target="_blank" title="http://bnkspac2.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://apr-in.com" target="_blank" title="http://apr-in.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://e8ight.co.kr/" target="_blank" title="http://e8ight.co.kr/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.coxem.com" target="_blank" title="http://www.coxem.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.kweather.co.kr" target="_blank" title="http://www.kweather.co.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.sapien-semicon.com" target="_blank" title="http://www.sapien-semicon.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.spsoft.co.kr" target="_blank" title="http://www.spsoft.co.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.studiosamick.com" target="_blank" title="http://www.studiosamick.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.pond-group.co.kr" target="_blank" title="http://www.pond-group.co.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.ibks.com" target="_blank" title="http://www.ibks.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.laseroptek.com" target="_blank" title="http://www.laseroptek.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.inics.kr" target="_blank" title="http://www.inics.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.landf.co.kr/" target="_blank" title="http://www.landf.co.kr/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.posbank.com/" target="_blank" title="http://www.posbank.com/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.hyms.kr" target="_blank" title="http://www.hyms.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.hbvc.co.kr" target="_blank" title="http://www.hbvc.co.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://bydream.co.kr/" target="_blank" title="http://bydream.co.kr/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.woojinntec.com/" target="_blank" title="http://www.woojinntec.com/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://sevenbrau.com" target="_blank" title="http://sevenbrau.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.hblaser.co.kr" target="_blank" title="http://www.hblaser.co.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.poscodx.com/kor/" target="_blank" title="http://www.poscodx.com/kor/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://dsdansuk.com" target="_blank" title="http://dsdansuk.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.ibks.com" target="_blank" title="http://www.ibks.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.c-site.co.kr" target="_blank" title="http://www.c-site.co.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.bluemtec.com" target="_blank" title="http://www.bluemtec.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://knssystem.com" target="_blank" title="http://knssystem.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://ybiologics.com" target="_blank" title="http://ybiologics.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.iatum.com/" target="_blank" title="http://www.iatum.com/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.asteh.co.kr" target="_blank" title="http://www.asteh.co.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.greenresource.kr" target="_blank" title="http://www.greenresource.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.jnbeng.com/" target="_blank" title="http://www.jnbeng.com/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.slok.co.kr" target="_blank" title="http://www.slok.co.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.dong-in.com/" target="_blank" title="http://www.dong-in.com/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.ecoeye.com" target="_blank" title="http://www.ecoeye.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.stormtec.co.kr/" target="_blank" title="http://www.stormtec.co.kr/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://ecopromaterials.com/" target="_blank" title="http://ecopromaterials.com/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://cspartners.co.kr" target="_blank" title="http://cspartners.co.kr"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://progen.co.kr/" target="_blank" title="http://progen.co.kr/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://systeeltech.com/" target="_blank" title="http://systeeltech.com/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.asicland.com" target="_blank" title="http://www.asicland.com"><span>홈페이지 보기</span></a>
# </td>

# %%
for city in soup.select('td:nth-child(8)'):
    city2 = city.get_text()
    print(city)
# Out:
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">강원특별자치도</td>
# <td class="txc">세종특별자치시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">경기도</td>
# <td class="txc">서울특별시</td>
# <td class="txc">경상남도</td>
# <td class="txc">서울특별시</td>
# <td class="txc">광주광역시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">경상북도</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">경기도</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">경기도</td>
# <td class="txc">경기도</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">부산광역시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">경기도</td>
# <td class="txc">대전광역시</td>
# <td class="txc">경기도</td>
# <td class="txc">경기도</td>
# <td class="txc">서울특별시</td>
# <td class="txc">경기도</td>
# <td class="txc">인천광역시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">경기도</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">충청북도</td>
# <td class="txc">경상남도</td>
# <td class="txc">경기도</td>
# <td class="txc">경기도</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">대전광역시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">경기도</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">경기도</td>
# <td class="txc">부산광역시</td>
# <td class="txc">대구광역시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">울산광역시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">경기도</td>
# <td class="txc">강원특별자치도</td>
# <td class="txc">대전광역시</td>
# <td class="txc">경상북도</td>
# <td class="txc">경기도</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">경기도</td>
# <td class="txc">경기도</td>
# <td class="txc">경기도</td>
# <td class="txc">서울특별시</td>
# <td class="txc">대전광역시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">경기도</td>
# <td class="txc">서울특별시</td>
# <td class="txc">충청남도</td>
# <td class="txc">인천광역시</td>
# <td class="txc">경기도</td>
# <td class="txc">부산광역시</td>
# <td class="txc">경기도</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">경상북도</td>
# <td class="txc">서울특별시</td>
# <td class="txc">서울특별시</td>
# <td class="txc">충청북도</td>
# <td class="txc">경기도</td>

# %% [markdown]
# ## 내가 한거

# %%
page = 1
all_data =[]
while True:
    url = "https://kind.krx.co.kr/corpgeneral/corpList.do"
    payload = {
        'method': 'searchCorpList',
        'pageIndex': page,
        'currentPageSize': 100,
        'comAbbrv': '',
        'beginIndex': '',
        'orderMode': 3,
        'orderStat': 'D',
        'isurCd': '',
        'repIsuSrtCd': '',
        'searchCodeType': '',
        'marketType': '',
        'searchType': 13,
        'industry': '',
        'fiscalYearEnd': 'all',
        'comAbbrvTmp': '',
        'location': 'all'
    }
    
    r = requests.get(url, params = payload)
   # print(r.status_code)
    #print(r.text)
    
    soup = bs(r.text, 'lxml')
    
    
    titles = [title.get_text() for title in soup.select('td:nth-child(1)')]
    services = [service.get_text() for service in soup.select('td:nth-child(2)')]
    services2 = [services.get_text() for services in soup.select('td:nth-child(3)')]
    dates = [date.get_text() for date in soup.select('td:nth-child(4)')]
    months = [month.get_text() for month in soup.select('td:nth-child(5)')]
    names = [name.get_text() for name in soup.select('td:nth-child(6)')]
    homes = [home.get_text() for home in soup.select('td:nth-child(7)')]
    cities = [city.get_text() for city in soup.select('td:nth-child(8)')]
    
    page_data = list(zip(titles, services, services2, dates, months, names, homes, cities))
    
    if not titles: #page_data
        break
    
    for data in page_data:
        all_data.append(data)
    
    page += 1

columns = ['Title', 'Service', 'Services', 'Date', 'Month', 'Name', 'Home', 'City']

df = pd.DataFrame(all_data, columns = columns)

df.to_csv('company_data.csv', encoding = 'cp949', index = False)
df

# %%
for alls in soup.select('table > tbody'):
    all_text = alls.get_text()
    print(all_text)
# Out:
#   엔에이치스팩31호
# 금융 지원 서비스업
# 금융지원서비스업
# 2024-07-26
# 12월
# 이시형
#
#
# 서울특별시
#
#
#   SK증권제13호스팩
# 금융 지원 서비스업
# 기업인수목적 주식회사
# 2024-07-25
# 12월
# 임율표
#
#
# 서울특별시
#
#
#   엑셀세라퓨틱스
# 기초 의약물질 제조업
# CellCor SFD/CD(세포배양배지)
# 2024-07-15
# 12월
# 이의일
#
#
# 서울특별시
#
#
#   이베스트스팩6호
# 금융 지원 서비스업
# 기업인수목적 주식회사
# 2024-07-12
# 12월
# 박용
#
#
# 서울특별시
#
#
#   시프트업
# 소프트웨어 개발 및 공급업
# 게임 소프트웨어
# 2024-07-11
# 12월
# 김형태
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   하스
# 의료용품 및 기타 의약 관련제품 제조업
# 리튬디실리케이트 수복소재(Amber block, Amber Ingot 등), 지르코니아 유치관
# 2024-07-03
# 12월
# 김용수
#
# 홈페이지 보기
#
# 강원특별자치도
#
#
#   이노스페이스
# 항공기,우주선 및 부품 제조업
# 소형발사체, 로켓추진기관, 과학로켓, 시험평가용역
# 2024-07-02
# 12월
# 김수종
#
# 홈페이지 보기
#
# 세종특별자치시
#
#
#   신한글로벌액티브리츠
# 신탁업 및 집합투자업
# 신탁 및 집합투자
# 2024-07-01
# 02월
# 김선영
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   에이치브이엠
# 1차 비철금속 제조업
# Ni계 합금, Fe계 합금, 스퍼터링타겟, Cu계 합금 등
# 2024-06-28
# 12월
# 문승호
#
# 홈페이지 보기
#
# 경기도
#
#
#   팡스카이
# 소프트웨어 개발 및 공급업
# 게임 개발 및 리퍼블리싱
# 2024-06-28
# 12월
# 조호현..
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   하이젠알앤엠
# 전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 전동기 및 발전기 (범용모터, 서보모터)
# 2024-06-27
# 12월
# 김재학
#
# 홈페이지 보기
#
# 경상남도
#
#
#   한국제15호스팩
# 금융 지원 서비스업
# 기업인수합병
# 2024-06-26
# 12월
# 유한
#
#
# 서울특별시
#
#
#   에스오에스랩
# 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 산업용 및 차량용 라이다(LiDAR)
# 2024-06-25
# 12월
# 정지성
#
# 홈페이지 보기
#
# 광주광역시
#
#
#   미래에셋비전스팩6호
# 금융 지원 서비스업
# 기업인수합병
# 2024-06-24
# 12월
# 정명훈
#
#
# 서울특별시
#
#
#   에이치엠씨제7호스팩
# 금융 지원 서비스업
# 기타금융
# 2024-06-24
# 12월
# 강신명
#
#
# 서울특별시
#
#
#   파라다이스
# 유원지 및 기타 오락관련 서비스업
# 카지노, 호텔, 복합리조트
# 2024-06-24
# 12월
# 최종환..
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   한중엔시에스
# 전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 수냉식 냉각시스템 ESS Parts, 공랭식 ESS Module Parts, EV Module 및 내연기관 Parts
# 2024-06-24
# 12월
# 김환식
#
# 홈페이지 보기
#
# 경상북도
#
#
#   KB제29호스팩
# 금융 지원 서비스업
# 기업인수합병
# 2024-06-21
# 12월
# 서영화
#
#
# 서울특별시
#
#
#   미래에셋비전스팩5호
# 금융 지원 서비스업
# 기업인수합병
# 2024-06-19
# 12월
# 김대호
#
#
# 서울특별시
#
#
#   씨어스테크놀로지
# 의료용 기기 제조업
# 심전도검사솔루션 입원환자모니터링솔루션
# 2024-06-19
# 12월
# 이영신
#
# 홈페이지 보기
#
# 경기도
#
#
#   한국제14호스팩
# 금융 지원 서비스업
# 기업인수합병
# 2024-06-19
# 12월
# 변성환
#
#
# 서울특별시
#
#
#   디비금융스팩12호
# 기타 금융업
# 기업인수 및 합병
# 2024-06-18
# 12월
# 김창희
#
#
# 서울특별시
#
#
#   라메디텍
# 의료용 기기 제조업
# 초소형 레이저 의료기기  및 미용기기
# 2024-06-17
# 12월
# 최종석
#
#
# 서울특별시
#
#
#   그리드위즈
# 그외 기타 전문, 과학 및 기술 서비스업
# 수요관리 서비스, 전기차 충전기 모뎀 등
# 2024-06-14
# 12월
# 김구환
#
# 홈페이지 보기
#
# 경기도
#
#
#   다원넥스뷰
# 사진장비 및 광학기기 제조업
# LSMB(Laser Micro Bonding System)
# 2024-06-11
# 12월
# 남기중
#
# 홈페이지 보기
#
# 경기도
#
#
#   미래에셋비전스팩4호
# 금융 지원 서비스업
# 기업인수목적회사(기타금융서비스)
# 2024-05-29
# 12월
# 김정수
#
#
# 서울특별시
#
#
#   노브랜드
# 편조의복 제조업
# Knit, Woven 의류
# 2024-05-23
# 12월
# 이상규
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   KB제28호스팩
# 금융 지원 서비스업
# 기업인수합병
# 2024-05-17
# 12월
# 고광범
#
#
# 서울특별시
#
#
#   아이씨티케이
# 반도체 제조업
# PUF반도체,보안솔루션(보안반도체,정보통신모듈기기,정보통신용반도체) 제조,개발
# 2024-05-17
# 12월
# 이정원
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   HD현대마린솔루션
# 건축기술, 엔지니어링 및 관련 기술 서비스업
# AM(After Market) 솔루션, 친환경 Retrofit, 디지털 제어
# 2024-05-08
# 12월
# 이기동
#
# 홈페이지 보기
#
# 부산광역시
#
#
#   SK증권제12호스팩
# 금융 지원 서비스업
# 기업인수목적 주식회사
# 2024-05-07
# 12월
# 이재혁
#
#
# 서울특별시
#
#
#   코칩
# 전자부품 제조업
# 소형 및 초소형 슈퍼커패시터
# 2024-05-07
# 12월
# 손진형
#
# 홈페이지 보기
#
# 경기도
#
#
#   민테크
# 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 배터리 진단시스템, 배터리 시스템, 충방전 검사장비
# 2024-05-03
# 12월
# 홍영진
#
# 홈페이지 보기
#
# 대전광역시
#
#
#   카티스
# 컴퓨터 프로그래밍, 시스템 통합 및 관리업
# 산업인프라 보안플랫폼
# 2024-05-03
# 12월
# 김승수
#
# 홈페이지 보기
#
# 경기도
#
#
#   디앤디파마텍
# 자연과학 및 공학 연구개발업
# 대사성질환 치료제 등
# 2024-05-02
# 12월
# 이슬기
#
# 홈페이지 보기
#
# 경기도
#
#
#   유안타제16호스팩
# 금융 지원 서비스업
# 금융 지원 서비스(기업인수목적회사)
# 2024-05-02
# 12월
# 박병권
#
#
# 서울특별시
#
#
#   제일엠앤에스
# 특수 목적용 기계 제조업
# 2차전지 믹싱시스템
# 2024-04-30
# 12월
# 이영진
#
# 홈페이지 보기
#
# 경기도
#
#
#   삐아
# 기타 화학제품 제조업
# 색조화장품
# 2024-04-25
# 12월
# 박광춘
#
# 홈페이지 보기
#
# 인천광역시
#
#
#   하나33호스팩
# 금융 지원 서비스업
# 기업인수합병
# 2024-04-24
# 12월
# 박태한
#
#
# 서울특별시
#
#
#   신한제13호스팩
# 금융 지원 서비스업
# 기타금융서비스(기업합병)
# 2024-04-22
# 12월
# 배성환
#
#
# 서울특별시
#
#
#   신한제12호스팩
# 금융 지원 서비스업
# 금융서비스(기업인수목적회사)
# 2024-04-15
# 12월
# 이동호
#
#
# 서울특별시
#
#
#   아이엠비디엑스
# 자연과학 및 공학 연구개발업
# 알파리퀴드ⓡ 100, 알파리퀴드ⓡ HRR, 알파리퀴드ⓡ 디텍트, 알파리퀴드ⓡ 스크리닝
# 2024-04-03
# 12월
# 김태유
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   SK이터닉스
# 건물 건설업
# 부동산 개발
# 2024-03-29
# 12월
# 김해중
#
# 홈페이지 보기
#
# 경기도
#
#
#   하나32호스팩
# 금융 지원 서비스업
# 기업인수합병
# 2024-03-27
# 12월
# 박종찬
#
#
# 서울특별시
#
#
#   엔젤로보틱스
# 특수 목적용 기계 제조업
# 재활 전문 웨어러블 로봇, 근력 보조 무동력 웨어러블 슈트, 일상생활 보조 웨어러블 로봇 등
# 2024-03-26
# 12월
# 공경철
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   제이투케이바이오
# 기타 화학제품 제조업
# 화장품 원료(천연소재 바이오소재 등)
# 2024-03-25
# 12월
# 이재섭
#
# 홈페이지 보기
#
# 충청북도
#
#
#   삼현
# 자동차 신품 부품 제조업
# 스마트 액추에이터, 스마트 파워유닛
# 2024-03-21
# 12월
# 황성호
#
# 홈페이지 보기
#
# 경상남도
#
#
#   오상헬스케어
# 의료용품 및 기타 의약 관련제품 제조업
# 생화학 측정기 및 센서, 면역진단기기 및 마커, 분자진단기기 및 시약 등
# 2024-03-13
# 12월
# 강철훈
#
# 홈페이지 보기
#
# 경기도
#
#
#   케이엔알시스템
# 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 특수목적 시험장비, 산업용로봇
# 2024-03-07
# 12월
# 김명한
#
# 홈페이지 보기
#
# 경기도
#
#
#   비엔케이제2호스팩
# 금융 지원 서비스업
# 금융 지원 서비스업
# 2024-03-05
# 12월
# 정민중
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   하나31호스팩
# 금융 지원 서비스업
# 기업인수합병
# 2024-03-05
# 12월
# 한규정
#
#
# 서울특별시
#
#
#   SK증권제11호스팩
# 금융 지원 서비스업
# 기업인수목적 주식회사
# 2024-03-04
# 12월
# 최상우
#
#
# 서울특별시
#
#
#   유안타제15호스팩
# 금융 지원 서비스업
# 금융 지원 서비스
# 2024-02-29
# 12월
# 구태훈
#
#
# 서울특별시
#
#
#   유진스팩10호
# 금융 지원 서비스업
# 기업인수합병
# 2024-02-29
# 12월
# 김동진
#
#
# 서울특별시
#
#
#   에이피알
# 기타 화학제품 제조업
# 화장품, 피부미용기기 등
# 2024-02-27
# 12월
# 김병훈
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   이에이트
# 소프트웨어 개발 및 공급업
# CFD 시뮬레이션 소프트웨어, 디지털트윈 플랫폼
# 2024-02-23
# 12월
# 김진현
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   코셈
# 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 주사전자현미경(SEM)
# 2024-02-23
# 12월
# 이준희
#
# 홈페이지 보기
#
# 대전광역시
#
#
#   케이웨더
# 일반 목적용 기계 제조업
# 공기개선솔루션, 기상데이터, 공기측정솔루션 등
# 2024-02-22
# 12월
# 김동식
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   사피엔반도체
# 반도체 제조업
# Micro/Mini-LED Display Driver IC
# 2024-02-19
# 12월
# 이명희
#
# 홈페이지 보기
#
# 경기도
#
#
#   에스피소프트
# 컴퓨터 프로그래밍, 시스템 통합 및 관리업
# SPLA 라이센스 총판 사업,CLOUD, gDaaS 등
# 2024-02-15
# 12월
# 이은재
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   스튜디오삼익
# 기타 생활용품 소매업
# 침실가구, 거실가구,  옷장/수납, 주방가구 등
# 2024-02-06
# 12월
# 최정석
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   신영스팩10호
# 금융 지원 서비스업
# 기업인수합병
# 2024-02-06
# 12월
# 여지우
#
#
# 서울특별시
#
#
#   폰드그룹
# 봉제의복 제조업
# 의류(언더웨어, 의복, 잡화, 코스메틱 등)
# 2024-02-02
# 12월
# 임종민..
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   IBKS제24호스팩
# 금융 지원 서비스업
# 금융 지원 서비스업
# 2024-02-01
# 12월
# 김강민
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   레이저옵텍
# 의료용 기기 제조업
# 레이저 기반 피부미용기기 및 질환치료기기
# 2024-02-01
# 12월
# 주홍,..
#
# 홈페이지 보기
#
# 경기도
#
#
#   이닉스
# 자동차 신품 부품 제조업
# 2차전지용 배터리셀 패드 등
# 2024-02-01
# 12월
# 강동호..
#
# 홈페이지 보기
#
# 부산광역시
#
#
#   엘앤에프
# 일차전지 및 이차전지 제조업
# 이차전지 양극활물질
# 2024-01-29
# 12월
# 최수안
#
# 홈페이지 보기
#
# 대구광역시
#
#
#   포스뱅크
# 일반 목적용 기계 제조업
# POS 단말기, KIOSK 단말기
# 2024-01-29
# 12월
# 은동욱
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   현대힘스
# 선박 및 보트 건조업
# 선박기자재 (선박 블록, 보강재, 도장 등)
# 2024-01-26
# 12월
# 최지용
#
# 홈페이지 보기
#
# 울산광역시
#
#
#   HB인베스트먼트
# 기타 금융업
# 벤처투자조합 등 조합 결성 및 운영
# 2024-01-25
# 12월
# 황유선
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   드림인사이트
# 광고업
# 광고대행
# 2024-01-25
# 12월
# 김기철
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   대신밸런스제17호스팩
# 금융 지원 서비스업
# 금융 지원 서비스업
# 2024-01-24
# 12월
# 이문수
#
#
# 서울특별시
#
#
#   우진엔텍
# 그외 기타 전문, 과학 및 기술 서비스업
# 발전소 계측제어설비 정비 서비스
# 2024-01-24
# 12월
# 신상연
#
# 홈페이지 보기
#
# 경기도
#
#
#   세븐브로이맥주
# 알코올음료 제조업
# 맥주 등 주류 및 음료
# 2024-01-17
# 12월
# 김강삼
#
# 홈페이지 보기
#
# 강원특별자치도
#
#
#   한빛레이저
# 특수 목적용 기계 제조업
# 산업용 레이저 가공장비
# 2024-01-04
# 12월
# 김정묵
#
# 홈페이지 보기
#
# 대전광역시
#
#
#   포스코DX
# 건축기술, 엔지니어링 및 관련 기술 서비스업
# EIC 자동화 엔지니어링 및 IT서비스
# 2024-01-02
# 12월
# 정덕균
#
# 홈페이지 보기
#
# 경상북도
#
#
#   DS단석
# 기타 화학제품 제조업
# 바이오에너지
# 2023-12-22
# 12월
# 한승욱
#
# 홈페이지 보기
#
# 경기도
#
#
#   IBKS제23호스팩
# 금융 지원 서비스업
# 기업인수 및 합병
# 2023-12-22
# 12월
# 오창수
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   하나30호스팩
# 금융 지원 서비스업
# 기업인수합병
# 2023-12-22
# 12월
# 전신웅
#
#
# 서울특별시
#
#
#   씨싸이트
# 봉제의복 제조업
# 니트류 OEM
# 2023-12-21
# 12월
# 김상기
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   블루엠텍
# 기타 전문 도매업
# 의약품 유통업
# 2023-12-13
# 12월
# 김현수
#
# 홈페이지 보기
#
# 경기도
#
#
#   LS머트리얼즈
# 전자부품 제조업
# 울트라커패시터(셀 및 모듈)
# 2023-12-12
# 12월
# 홍영호
#
#
# 경기도
#
#
#   케이엔에스
# 특수 목적용 기계 제조업
# 이차전지 자동화 설비
# 2023-12-06
# 12월
# 정봉진
#
# 홈페이지 보기
#
# 경기도
#
#
#   교보15호스팩
# 금융 지원 서비스업
# 기업인수합병
# 2023-12-05
# 12월
# 김상도
#
#
# 서울특별시
#
#
#   와이바이오로직스
# 자연과학 및 공학 연구개발업
# 항체의약품 및 항체후보물질 연구개발
# 2023-12-05
# 12월
# 박영우..
#
# 홈페이지 보기
#
# 대전광역시
#
#
#   삼성스팩9호
# 금융 지원 서비스업
# 기업인수합병
# 2023-12-04
# 12월
# 오정헌
#
#
# 서울특별시
#
#
#   에이텀
# 전자부품 제조업
# 평판형 트랜스
# 2023-12-01
# 06월
# 한택수
#
# 홈페이지 보기
#
# 경기도
#
#
#   엔에이치스팩30호
# 금융 지원 서비스업
# 금융지원서비스업
# 2023-12-01
# 12월
# 조선희
#
#
# 서울특별시
#
#
#   에이에스텍
# 기타 화학제품 제조업
# 자외선 차단제 유기 원료
# 2023-11-28
# 12월
# 윤종배..
#
# 홈페이지 보기
#
# 충청남도
#
#
#   그린리소스
# 반도체 제조업
# 반도체 및 디스플레이 장비 보호코팅 및 소재
# 2023-11-24
# 12월
# 이종수..
#
# 홈페이지 보기
#
# 인천광역시
#
#
#   제이엔비
# 특수 목적용 기계 제조업
# 진공 펌프용 유틸리티 장치(Stacker 등), 정밀가공 부품
# 2023-11-24
# 12월
# 이정범
#
# 홈페이지 보기
#
# 경기도
#
#
#   한선엔지니어링
# 기타 금속 가공제품 제조업
# 계장용 피팅 및 밸브, 모듈
# 2023-11-24
# 12월
# 이제훈
#
# 홈페이지 보기
#
# 부산광역시
#
#
#   동인기연
# 가죽, 가방 및 유사제품 제조업
# 스포츠용품(등산용가방,골프백),금속압형제품,유아용품 제조,도소매,통신 판매/부동산 임대
# 2023-11-21
# 12월
# 정인수
#
# 홈페이지 보기
#
# 경기도
#
#
#   에코아이
# 기타 전문 서비스업
# 탄소배출권 및 탄소배출권 관련 컨설팅
# 2023-11-21
# 12월
# 이수복
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   스톰테크
# 플라스틱제품 제조업
# 정수기 피팅, 밸브, 파우셋 등 부품
# 2023-11-20
# 12월
# 강기환..
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   에코프로머티
# 일차전지 및 이차전지 제조업
# 배터리 양극재용 핵심소재 하이니켈 전구체
# 2023-11-17
# 12월
# 김병훈
#
# 홈페이지 보기
#
# 경상북도
#
#
#   캡스톤파트너스
# 기타 금융업
# 벤처투자조합 등 조합 결성 및 운영
# 2023-11-15
# 12월
# 송은강
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   프로젠
# 자연과학 및 공학 연구개발업
# 바이오의약품
# 2023-11-15
# 12월
# 김종균
#
# 홈페이지 보기
#
# 서울특별시
#
#
#   에스와이스틸텍
# 구조용 금속제품, 탱크 및 증기발생기 제조업
# 데크플레이트
# 2023-11-13
# 12월
# 홍성균
#
# 홈페이지 보기
#
# 충청북도
#
#
#   에이직랜드
# 반도체 제조업
# 비메모리 반도체 설계및 제조, 전자회로 연구, 설계, 레이아웃 등
# 2023-11-13
# 12월
# 이종민
#
# 홈페이지 보기
#
# 경기도

# %%
result = []

# 페이지 번호를 증가시키며 데이터 수집
while True:
    r = requests.get(url, params=payload)
    soup = bs(r.text, 'lxml')

    # 모든 'tr' 요소를 찾기 (데이터가 'tr' 태그에 있다고 가정)
    rows = soup.find_all('tr')
    if not rows:  # 더 이상 데이터가 없으면 종료
        break
    
    for row in rows:
        columns = row.find_all('td')
        if columns:
            row_data = [column.get_text(strip=True) for column in columns]
            result.append(row_data)
    
    print(f"Page {payload['pageIndex']} processed")
    
    # 페이지 인덱스 증가
    payload['pageIndex'] += 1

# DataFrame으로 변환
if result:
    columns = ['회사명', '업종', '주요제품', '상장일', '결산월', '대표자명', '홈페이지', '지역']
    final_df = pd.DataFrame(result, columns=columns[:len(result[0])])
# DataFrame 출력
final_df

# %%
result = []

# 모든 'tr' 요소를 찾기 (데이터가 'tr' 태그에 있다고 가정)
for row in soup.find_all('tr'):
    columns = row.find_all('td')
    if columns:
        row_data = [column.get_text(strip=True) for column in columns]
        result.append(row_data)

# DataFrame으로 변환
if result:
    columns = ['회사명', '업종', '주요제품', '상장일', '결산월', '대표자명', '홈페이지', '지역']
    final_df = pd.DataFrame(result, columns=columns[:len(result[0])])

# DataFrame 출력
final_df
#print(final_df)
# Out:
#            회사명                                     업종  \
# 0    엔에이치스팩31호                             금융 지원 서비스업
# 1   SK증권제13호스팩                             금융 지원 서비스업
# 2      엑셀세라퓨틱스                            기초 의약물질 제조업
# 3     이베스트스팩6호                             금융 지원 서비스업
# 4         시프트업                         소프트웨어 개발 및 공급업
# 5           하스                  의료용품 및 기타 의약 관련제품 제조업
# 6       이노스페이스                       항공기,우주선 및 부품 제조업
# 7   신한글로벌액티브리츠                            신탁업 및 집합투자업
# 8       에이치브이엠                            1차 비철금속 제조업
# 9         팡스카이                         소프트웨어 개발 및 공급업
# 10      하이젠알앤엠      전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 11    한국제15호스팩                             금융 지원 서비스업
# 12      에스오에스랩  측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 13  미래에셋비전스팩6호                             금융 지원 서비스업
# 14  에이치엠씨제7호스팩                             금융 지원 서비스업
#
#                                                  주요제품         상장일  결산월   대표자명  \
# 0                                            금융지원서비스업  2024-07-26  12월    이시형
# 1                                         기업인수목적 주식회사  2024-07-25  12월    임율표
# 2                              CellCor SFD/CD(세포배양배지)  2024-07-15  12월    이의일
# 3                                         기업인수목적 주식회사  2024-07-12  12월     박용
# 4                                            게임 소프트웨어  2024-07-11  12월    김형태
# 5   리튬디실리케이트 수복소재(Amber block, Amber Ingot 등), 지르코...  2024-07-03  12월    김용수
# 6                         소형발사체, 로켓추진기관, 과학로켓, 시험평가용역  2024-07-02  12월    김수종
# 7                                           신탁 및 집합투자  2024-07-01  02월    김선영
# 8                    Ni계 합금, Fe계 합금, 스퍼터링타겟, Cu계 합금 등  2024-06-28  12월    문승호
# 9                                       게임 개발 및 리퍼블리싱  2024-06-28  12월  조호현..
# 10                             전동기 및 발전기 (범용모터, 서보모터)  2024-06-27  12월    김재학
# 11                                             기업인수합병  2024-06-26  12월     유한
# 12                               산업용 및 차량용 라이다(LiDAR)  2024-06-25  12월    정지성
# 13                                             기업인수합병  2024-06-24  12월    정명훈
# 14                                               기타금융  2024-06-24  12월    강신명
#
#        홈페이지       지역
# 0              서울특별시
# 1              서울특별시
# 2              서울특별시
# 3              서울특별시
# 4   홈페이지 보기    서울특별시
# 5   홈페이지 보기  강원특별자치도
# 6   홈페이지 보기  세종특별자치시
# 7   홈페이지 보기    서울특별시
# 8   홈페이지 보기      경기도
# 9   홈페이지 보기    서울특별시
# 10  홈페이지 보기     경상남도
# 11             서울특별시
# 12  홈페이지 보기    광주광역시
# 13             서울특별시
# 14             서울특별시

# %%
url = "https://kind.krx.co.kr/corpgeneral/corpList.do"
#payload = dict(method=searchCorpList, pageIndex=1, currentPageSize=100, comAbbrv=, beginIndex=, orderMode=3, orderStat='D', isurCd=, repIsuSrtCd=, searchCodeType=, marketType=, searchType=13, industry=, fiscalYearEnd='all', comAbbrvTmp=, location='all')
payload = {
        'method': 'searchCorpList',
        'pageIndex': page,
        'currentPageSize': 100,
        'comAbbrv': '',
        'beginIndex': '',
        'orderMode': 3,
        'orderStat': 'D',
        'isurCd': '',
        'repIsuSrtCd': '',
        'searchCodeType': '',
        'marketType': '',
        'searchType': 13,
        'industry': '',
        'fiscalYearEnd': 'all',
        'comAbbrvTmp': '',
        'location': 'all'
    }
r = requests.get(url, parmas = payload)

soup = bs(r.text, 'lxml')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[186], line 21
#       2 #payload = dict(method=searchCorpList, pageIndex=1, currentPageSize=100, comAbbrv=, beginIndex=, orderMode=3, orderStat='D', isurCd=, repIsuSrtCd=, searchCodeType=, marketType=, searchType=13, industry=, fiscalYearEnd='all', comAbbrvTmp=, location='all')
#       3 payload = {
#       4         'method': 'searchCorpList',
#       5         'pageIndex': page,
#    (...)
#      19         'location': 'all'
#      20     }
# ---> 21 r = requests.get(url, parmas = payload)
#      23 soup = bs(r.text, 'lxml')
#
# File ~\miniforge3\envs\fintech\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# TypeError: Session.request() got an unexpected keyword argument 'parmas'

# %%
    payload = {
        'method': 'searchCorpList',
        'pageIndex': page,
        'currentPageSize': 100,
        'comAbbrv': '',
        'beginIndex': '',
        'orderMode': 3,
        'orderStat': 'D',
        'isurCd': '',
        'repIsuSrtCd': '',
        'searchCodeType': '',
        'marketType': '',
        'searchType': 13,
        'industry': '',
        'fiscalYearEnd': 'all',
        'comAbbrvTmp': '',
        'location': 'all'
    }

# %%
total_items = int(soup.select_one('.info.type-00 > em').text.replace(',', ''))

# %%
soup.select('tr')[3]
# Out:
# <tr>
# <td class="first" title="(주)유수홀딩스"><img alt="유가증권" class="vmiddle legend" src="/images/common/icn_t_yu.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('00070'); return false;" title="유수홀딩스"> 유수홀딩스</a> </td>
# <td class="textOverflow" title="회사 본부 및 경영 컨설팅 서비스업">회사 본부 및 경영 컨설팅 서비스업</td>
# <td class="textOverflow" title="지주사업">지주사업</td>
# <td class="txc">1956-03-03</td>
# <td class="txc">12월</td>
# <td class="txc" title="송영규">송영규</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.eusu-holdings.com" target="_blank" title="http://www.eusu-holdings.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">서울특별시</td>
# </tr>

# %%
for tr in soup.select('tr')[1:3]:
    for td in tr.select('td')[:1]:
        print(td.text)
# Out:
# 전체
# 농업, 임업 및 어업
# 광업
# 제조업
#  - 식료품 제조업
#  - 음료 제조업
#  - 담배 제조업
#  - 섬유제품 제조업; 의복제외
#  - 의복, 의복액세서리 및 모피제품 제조업
#  - 가죽, 가방 및 신발 제조업
#  - 목재 및 나무제품 제조업;가구제외
#  - 펄프, 종이 및 종이제품 제조업
#  - 인쇄 및 기록매체 복제업
#  - 코크스, 연탄 및 석유정제품 제조업
#  - 화학물질 및 화학제품 제조업;의약품 제외
#  - 의료용 물질 및 의약품 제조업
#  - 고무 및 플라스틱제품 제조업
#  - 비금속 광물제품 제조업
#  - 1차 금속 제조업
#  - 금속가공제품 제조업;기계 및 가구 제외
#  - 전자부품, 컴퓨터, 영상, 음향 및 통신장비 제조업
#  - 의료, 정밀, 광학기기 및 시계 제조업
#  - 전기장비 제조업
#  - 기타 기계 및 장비 제조업
#  - 자동차 및 트레일러 제조업
#  - 기타 운송장비 제조업
#  - 가구 제조업
#  - 기타 제품 제조업
#  - 산업용 기계 및 장비 수리업
# 전기, 가스, 증기 및 공기조절 공급업
# 수도, 하수 및 폐기물 처리, 원료 재생업
# 건설업
# 도매 및 소매업
# 운수 및 창고업
# 숙박 및 음식점업
# 정보통신업
# 금융 및 보험업
# 부동산업
# 전문, 과학 및 기술 서비스업
# 사업시설 관리, 사업지원 및 임대 서비스업
# 공공행정, 국방 및 사회보장 행정
# 교육 서비스업
# 보건업 및 사회복지 서비스업
# 예술, 스포츠 및 여가관련 서비스업
# 협회 및 단체, 수리 및 기타 개인 서비스업
# 가구 내 고용활동 및 달리 분류되지 않은 자가소비 생산활동
# 국제 및 외국기관
#
#
#
#
#
#
#
#
#
#
#
#
#
# 찾기

# %%
soup.select_one('table.list.type-00.tmt30')['summary']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 soup.select_one('table.list.type-00.tmt30')['summary']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
keys = soup.select_one('table.list.type-00.tmt30')['summary'].split(', ')
keys
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 keys = soup.select_one('table.list.type-00.tmt30')['summary'].split(', ')
#       2 keys
#
# TypeError: 'NoneType' object is not subscriptable

# %%
result = {}
for tr in soup.select('tr'):
    for td in tr.select('td'):
        result.setdefault()
        print(td.text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[149], line 4
#       2 for tr in soup.select('tr'):
#       3     for td in tr.select('td'):
# ----> 4         result.setdefault()
#       5         print(td.text)
#
# TypeError: setdefault expected at least 1 argument, got 0

# %%
# td랑 keys 개수가 같음
result = {}
for tr in soup.select('tr'):
    for key, td in zip(keys, tr.select('td')):
        result.setdefault(key, []).append(td.text)
result
# Out:
# {'회사명': ['  엔에이치스팩31호 ',
#   '  SK증권제13호스팩  ',
#   '  엑셀세라퓨틱스 ',
#   '  이베스트스팩6호 ',
#   '  시프트업 ',
#   '  하스 ',
#   '  이노스페이스 ',
#   '  신한글로벌액티브리츠 ',
#   '  에이치브이엠 ',
#   '  팡스카이 ',
#   '  하이젠알앤엠 ',
#   '  한국제15호스팩 ',
#   '  에스오에스랩 ',
#   '  미래에셋비전스팩6호 ',
#   '  에이치엠씨제7호스팩 ',
#   '  파라다이스  ',
#   '  한중엔시에스 ',
#   '  KB제29호스팩 ',
#   '  미래에셋비전스팩5호 ',
#   '  씨어스테크놀로지 ',
#   '  한국제14호스팩 ',
#   '  디비금융스팩12호 ',
#   '  라메디텍 ',
#   '  그리드위즈 ',
#   '  다원넥스뷰 ',
#   '  미래에셋비전스팩4호 ',
#   '  노브랜드 ',
#   '  KB제28호스팩 ',
#   '  아이씨티케이 ',
#   '  HD현대마린솔루션 ',
#   '  SK증권제12호스팩 ',
#   '  코칩 ',
#   '  민테크 ',
#   '  카티스 ',
#   '  디앤디파마텍 ',
#   '  유안타제16호스팩 ',
#   '  제일엠앤에스 ',
#   '  삐아 ',
#   '  하나33호스팩 ',
#   '  신한제13호스팩 ',
#   '  신한제12호스팩 ',
#   '  아이엠비디엑스 ',
#   '  SK이터닉스 ',
#   '  하나32호스팩 ',
#   '  엔젤로보틱스 ',
#   '  제이투케이바이오 ',
#   '  삼현 ',
#   '  오상헬스케어 ',
#   '  케이엔알시스템 ',
#   '  비엔케이제2호스팩 ',
#   '  하나31호스팩 ',
#   '  SK증권제11호스팩 ',
#   '  유안타제15호스팩 ',
#   '  유진스팩10호 ',
#   '  에이피알 ',
#   '  이에이트 ',
#   '  코셈 ',
#   '  케이웨더 ',
#   '  사피엔반도체 ',
#   '  에스피소프트 ',
#   '  스튜디오삼익 ',
#   '  신영스팩10호 ',
#   '  폰드그룹 ',
#   '  IBKS제24호스팩 ',
#   '  레이저옵텍 ',
#   '  이닉스 ',
#   '  엘앤에프   ',
#   '  포스뱅크 ',
#   '  현대힘스 ',
#   '  HB인베스트먼트 ',
#   '  드림인사이트 ',
#   '  대신밸런스제17호스팩 ',
#   '  우진엔텍 ',
#   '  세븐브로이맥주 ',
#   '  한빛레이저 ',
#   '  포스코DX   ',
#   '  DS단석 ',
#   '  IBKS제23호스팩 ',
#   '  하나30호스팩 ',
#   '  씨싸이트 ',
#   '  블루엠텍 ',
#   '  LS머트리얼즈  ',
#   '  케이엔에스 ',
#   '  교보15호스팩 ',
#   '  와이바이오로직스 ',
#   '  삼성스팩9호 ',
#   '  에이텀 ',
#   '  엔에이치스팩30호 ',
#   '  에이에스텍 ',
#   '  그린리소스 ',
#   '  제이엔비 ',
#   '  한선엔지니어링 ',
#   '  동인기연 ',
#   '  에코아이 ',
#   '  스톰테크 ',
#   '  에코프로머티   ',
#   '  캡스톤파트너스 ',
#   '  프로젠 ',
#   '  에스와이스틸텍 ',
#   '  에이직랜드 '],
#  '업종': ['금융 지원 서비스업',
#   '금융 지원 서비스업',
#   '기초 의약물질 제조업',
#   '금융 지원 서비스업',
#   '소프트웨어 개발 및 공급업',
#   '의료용품 및 기타 의약 관련제품 제조업',
#   '항공기,우주선 및 부품 제조업',
#   '신탁업 및 집합투자업',
#   '1차 비철금속 제조업',
#   '소프트웨어 개발 및 공급업',
#   '전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업',
#   '금융 지원 서비스업',
#   '측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외',
#   '금융 지원 서비스업',
#   '금융 지원 서비스업',
#   '유원지 및 기타 오락관련 서비스업',
#   '전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업',
#   '금융 지원 서비스업',
#   '금융 지원 서비스업',
#   '의료용 기기 제조업',
#   '금융 지원 서비스업',
#   '기타 금융업',
#   '의료용 기기 제조업',
#   '그외 기타 전문, 과학 및 기술 서비스업',
#   '사진장비 및 광학기기 제조업',
#   '금융 지원 서비스업',
#   '편조의복 제조업',
#   '금융 지원 서비스업',
#   '반도체 제조업',
#   '건축기술, 엔지니어링 및 관련 기술 서비스업',
#   '금융 지원 서비스업',
#   '전자부품 제조업',
#   '측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외',
#   '컴퓨터 프로그래밍, 시스템 통합 및 관리업',
#   '자연과학 및 공학 연구개발업',
#   '금융 지원 서비스업',
#   '특수 목적용 기계 제조업',
#   '기타 화학제품 제조업',
#   '금융 지원 서비스업',
#   '금융 지원 서비스업',
#   '금융 지원 서비스업',
#   '자연과학 및 공학 연구개발업',
#   '건물 건설업',
#   '금융 지원 서비스업',
#   '특수 목적용 기계 제조업',
#   '기타 화학제품 제조업',
#   '자동차 신품 부품 제조업',
#   '의료용품 및 기타 의약 관련제품 제조업',
#   '측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외',
#   '금융 지원 서비스업',
#   '금융 지원 서비스업',
#   '금융 지원 서비스업',
#   '금융 지원 서비스업',
#   '금융 지원 서비스업',
#   '기타 화학제품 제조업',
#   '소프트웨어 개발 및 공급업',
#   '측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외',
#   '일반 목적용 기계 제조업',
#   '반도체 제조업',
#   '컴퓨터 프로그래밍, 시스템 통합 및 관리업',
#   '기타 생활용품 소매업',
#   '금융 지원 서비스업',
#   '봉제의복 제조업',
#   '금융 지원 서비스업',
#   '의료용 기기 제조업',
#   '자동차 신품 부품 제조업',
#   '일차전지 및 이차전지 제조업',
#   '일반 목적용 기계 제조업',
#   '선박 및 보트 건조업',
#   '기타 금융업',
#   '광고업',
#   '금융 지원 서비스업',
#   '그외 기타 전문, 과학 및 기술 서비스업',
#   '알코올음료 제조업',
#   '특수 목적용 기계 제조업',
#   '건축기술, 엔지니어링 및 관련 기술 서비스업',
#   '기타 화학제품 제조업',
#   '금융 지원 서비스업',
#   '금융 지원 서비스업',
#   '봉제의복 제조업',
#   '기타 전문 도매업',
#   '전자부품 제조업',
#   '특수 목적용 기계 제조업',
#   '금융 지원 서비스업',
#   '자연과학 및 공학 연구개발업',
#   '금융 지원 서비스업',
#   '전자부품 제조업',
#   '금융 지원 서비스업',
#   '기타 화학제품 제조업',
#   '반도체 제조업',
#   '특수 목적용 기계 제조업',
#   '기타 금속 가공제품 제조업',
#   '가죽, 가방 및 유사제품 제조업',
#   '기타 전문 서비스업',
#   '플라스틱제품 제조업',
#   '일차전지 및 이차전지 제조업',
#   '기타 금융업',
#   '자연과학 및 공학 연구개발업',
#   '구조용 금속제품, 탱크 및 증기발생기 제조업',
#   '반도체 제조업'],
#  '주요제품': ['금융지원서비스업',
#   '기업인수목적 주식회사',
#   'CellCor SFD/CD(세포배양배지)',
#   '기업인수목적 주식회사',
#   '게임 소프트웨어',
#   '리튬디실리케이트 수복소재(Amber block, Amber Ingot 등), 지르코니아 유치관',
#   '소형발사체, 로켓추진기관, 과학로켓, 시험평가용역',
#   '신탁 및 집합투자',
#   'Ni계 합금, Fe계 합금, 스퍼터링타겟, Cu계 합금 등',
#   '게임 개발 및 리퍼블리싱',
#   '전동기 및 발전기 (범용모터, 서보모터)',
#   '기업인수합병',
#   '산업용 및 차량용 라이다(LiDAR)',
#   '기업인수합병',
#   '기타금융',
#   '카지노, 호텔, 복합리조트',
#   '수냉식 냉각시스템 ESS Parts, 공랭식 ESS Module Parts, EV Module 및 내연기관 Parts',
#   '기업인수합병',
#   '기업인수합병',
#   '심전도검사솔루션 입원환자모니터링솔루션',
#   '기업인수합병',
#   '기업인수 및 합병',
#   '초소형 레이저 의료기기  및 미용기기',
#   '수요관리 서비스, 전기차 충전기 모뎀 등',
#   'LSMB(Laser Micro Bonding System)',
#   '기업인수목적회사(기타금융서비스)',
#   'Knit, Woven 의류',
#   '기업인수합병',
#   'PUF반도체,보안솔루션(보안반도체,정보통신모듈기기,정보통신용반도체) 제조,개발',
#   'AM(After Market) 솔루션, 친환경 Retrofit, 디지털 제어',
#   '기업인수목적 주식회사',
#   '소형 및 초소형 슈퍼커패시터',
#   '배터리 진단시스템, 배터리 시스템, 충방전 검사장비',
#   '산업인프라 보안플랫폼',
#   '대사성질환 치료제 등',
#   '금융 지원 서비스(기업인수목적회사)',
#   '2차전지 믹싱시스템',
#   '색조화장품',
#   '기업인수합병',
#   '기타금융서비스(기업합병)',
#   '금융서비스(기업인수목적회사)',
#   '알파리퀴드ⓡ 100, 알파리퀴드ⓡ HRR, 알파리퀴드ⓡ 디텍트, 알파리퀴드ⓡ 스크리닝',
#   '부동산 개발',
#   '기업인수합병',
#   '재활 전문 웨어러블 로봇, 근력 보조 무동력 웨어러블 슈트, 일상생활 보조 웨어러블 로봇 등',
#   '화장품 원료(천연소재 바이오소재 등)',
#   '스마트 액추에이터, 스마트 파워유닛',
#   '생화학 측정기 및 센서, 면역진단기기 및 마커, 분자진단기기 및 시약 등',
#   '특수목적 시험장비, 산업용로봇',
#   '금융 지원 서비스업',
#   '기업인수합병',
#   '기업인수목적 주식회사',
#   '금융 지원 서비스',
#   '기업인수합병',
#   '화장품, 피부미용기기 등',
#   'CFD 시뮬레이션 소프트웨어, 디지털트윈 플랫폼',
#   '주사전자현미경(SEM)',
#   '공기개선솔루션, 기상데이터, 공기측정솔루션 등',
#   'Micro/Mini-LED Display Driver IC',
#   'SPLA 라이센스 총판 사업,CLOUD, gDaaS 등',
#   '침실가구, 거실가구,  옷장/수납, 주방가구 등',
#   '기업인수합병',
#   '의류(언더웨어, 의복, 잡화, 코스메틱 등)',
#   '금융 지원 서비스업',
#   '레이저 기반 피부미용기기 및 질환치료기기',
#   '2차전지용 배터리셀 패드 등',
#   '이차전지 양극활물질',
#   'POS 단말기, KIOSK 단말기',
#   '선박기자재 (선박 블록, 보강재, 도장 등)',
#   '벤처투자조합 등 조합 결성 및 운영',
#   '광고대행',
#   '금융 지원 서비스업',
#   '발전소 계측제어설비 정비 서비스',
#   '맥주 등 주류 및 음료',
#   '산업용 레이저 가공장비',
#   'EIC 자동화 엔지니어링 및 IT서비스',
#   '바이오에너지',
#   '기업인수 및 합병',
#   '기업인수합병',
#   '니트류 OEM',
#   '의약품 유통업',
#   '울트라커패시터(셀 및 모듈)',
#   '이차전지 자동화 설비',
#   '기업인수합병',
#   '항체의약품 및 항체후보물질 연구개발',
#   '기업인수합병',
#   '평판형 트랜스',
#   '금융지원서비스업',
#   '자외선 차단제 유기 원료',
#   '반도체 및 디스플레이 장비 보호코팅 및 소재',
#   '진공 펌프용 유틸리티 장치(Stacker 등), 정밀가공 부품',
#   '계장용 피팅 및 밸브, 모듈',
#   '스포츠용품(등산용가방,골프백),금속압형제품,유아용품 제조,도소매,통신 판매/부동산 임대',
#   '탄소배출권 및 탄소배출권 관련 컨설팅',
#   '정수기 피팅, 밸브, 파우셋 등 부품',
#   '배터리 양극재용 핵심소재 하이니켈 전구체',
#   '벤처투자조합 등 조합 결성 및 운영',
#   '바이오의약품',
#   '데크플레이트',
#   '비메모리 반도체 설계및 제조, 전자회로 연구, 설계, 레이아웃 등'],
#  '상장일': ['2024-07-26',
#   '2024-07-25',
#   '2024-07-15',
#   '2024-07-12',
#   '2024-07-11',
#   '2024-07-03',
#   '2024-07-02',
#   '2024-07-01',
#   '2024-06-28',
#   '2024-06-28',
#   '2024-06-27',
#   '2024-06-26',
#   '2024-06-25',
#   '2024-06-24',
#   '2024-06-24',
#   '2024-06-24',
#   '2024-06-24',
#   '2024-06-21',
#   '2024-06-19',
#   '2024-06-19',
#   '2024-06-19',
#   '2024-06-18',
#   '2024-06-17',
#   '2024-06-14',
#   '2024-06-11',
#   '2024-05-29',
#   '2024-05-23',
#   '2024-05-17',
#   '2024-05-17',
#   '2024-05-08',
#   '2024-05-07',
#   '2024-05-07',
#   '2024-05-03',
#   '2024-05-03',
#   '2024-05-02',
#   '2024-05-02',
#   '2024-04-30',
#   '2024-04-25',
#   '2024-04-24',
#   '2024-04-22',
#   '2024-04-15',
#   '2024-04-03',
#   '2024-03-29',
#   '2024-03-27',
#   '2024-03-26',
#   '2024-03-25',
#   '2024-03-21',
#   '2024-03-13',
#   '2024-03-07',
#   '2024-03-05',
#   '2024-03-05',
#   '2024-03-04',
#   '2024-02-29',
#   '2024-02-29',
#   '2024-02-27',
#   '2024-02-23',
#   '2024-02-23',
#   '2024-02-22',
#   '2024-02-19',
#   '2024-02-15',
#   '2024-02-06',
#   '2024-02-06',
#   '2024-02-02',
#   '2024-02-01',
#   '2024-02-01',
#   '2024-02-01',
#   '2024-01-29',
#   '2024-01-29',
#   '2024-01-26',
#   '2024-01-25',
#   '2024-01-25',
#   '2024-01-24',
#   '2024-01-24',
#   '2024-01-17',
#   '2024-01-04',
#   '2024-01-02',
#   '2023-12-22',
#   '2023-12-22',
#   '2023-12-22',
#   '2023-12-21',
#   '2023-12-13',
#   '2023-12-12',
#   '2023-12-06',
#   '2023-12-05',
#   '2023-12-05',
#   '2023-12-04',
#   '2023-12-01',
#   '2023-12-01',
#   '2023-11-28',
#   '2023-11-24',
#   '2023-11-24',
#   '2023-11-24',
#   '2023-11-21',
#   '2023-11-21',
#   '2023-11-20',
#   '2023-11-17',
#   '2023-11-15',
#   '2023-11-15',
#   '2023-11-13',
#   '2023-11-13'],
#  '결산월': ['12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '02월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '06월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월',
#   '12월'],
#  '대표자명': ['이시형',
#   '임율표',
#   '이의일',
#   '박용',
#   '김형태',
#   '김용수',
#   '김수종',
#   '김선영',
#   '문승호',
#   '조호현..',
#   '김재학',
#   '유한',
#   '정지성',
#   '정명훈',
#   '강신명',
#   '최종환..',
#   '김환식',
#   '서영화',
#   '김대호',
#   '이영신',
#   '변성환',
#   '김창희',
#   '최종석',
#   '김구환',
#   '남기중',
#   '김정수',
#   '이상규',
#   '고광범',
#   '이정원',
#   '이기동',
#   '이재혁',
#   '손진형',
#   '홍영진',
#   '김승수',
#   '이슬기',
#   '박병권',
#   '이영진',
#   '박광춘',
#   '박태한',
#   '배성환',
#   '이동호',
#   '김태유',
#   '김해중',
#   '박종찬',
#   '공경철',
#   '이재섭',
#   '황성호',
#   '강철훈',
#   '김명한',
#   '정민중',
#   '한규정',
#   '최상우',
#   '구태훈',
#   '김동진',
#   '김병훈',
#   '김진현',
#   '이준희',
#   '김동식',
#   '이명희',
#   '이은재',
#   '최정석',
#   '여지우',
#   '임종민..',
#   '김강민',
#   '주홍,..',
#   '강동호..',
#   '최수안',
#   '은동욱',
#   '최지용',
#   '황유선',
#   '김기철',
#   '이문수',
#   '신상연',
#   '김강삼',
#   '김정묵',
#   '정덕균',
#   '한승욱',
#   '오창수',
#   '전신웅',
#   '김상기',
#   '김현수',
#   '홍영호',
#   '정봉진',
#   '김상도',
#   '박영우..',
#   '오정헌',
#   '한택수',
#   '조선희',
#   '윤종배..',
#   '이종수..',
#   '이정범',
#   '이제훈',
#   '정인수',
#   '이수복',
#   '강기환..',
#   '김병훈',
#   '송은강',
#   '김종균',
#   '홍성균',
#   '이종민'],
#  '홈페이지': ['\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n',
#   '\n홈페이지 보기\n',
#   '\n',
#   '\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n',
#   '\n',
#   '\n홈페이지 보기\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n',
#   '\n홈페이지 보기\n',
#   '\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n',
#   '\n홈페이지 보기\n',
#   '\n',
#   '\n홈페이지 보기\n',
#   '\n',
#   '\n홈페이지 보기\n',
#   '\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n',
#   '\n홈페이지 보기\n'],
#  '지역': ['서울특별시',
#   '서울특별시',
#   '서울특별시',
#   '서울특별시',
#   '서울특별시',
#   '강원특별자치도',
#   '세종특별자치시',
#   '서울특별시',
#   '경기도',
#   '서울특별시',
#   '경상남도',
#   '서울특별시',
#   '광주광역시',
#   '서울특별시',
#   '서울특별시',
#   '서울특별시',
#   '경상북도',
#   '서울특별시',
#   '서울특별시',
#   '경기도',
#   '서울특별시',
#   '서울특별시',
#   '서울특별시',
#   '경기도',
#   '경기도',
#   '서울특별시',
#   '서울특별시',
#   '서울특별시',
#   '서울특별시',
#   '부산광역시',
#   '서울특별시',
#   '경기도',
#   '대전광역시',
#   '경기도',
#   '경기도',
#   '서울특별시',
#   '경기도',
#   '인천광역시',
#   '서울특별시',
#   '서울특별시',
#   '서울특별시',
#   '서울특별시',
#   '경기도',
#   '서울특별시',
#   '서울특별시',
#   '충청북도',
#   '경상남도',
#   '경기도',
#   '경기도',
#   '서울특별시',
#   '서울특별시',
#   '서울특별시',
#   '서울특별시',
#   '서울특별시',
#   '서울특별시',
#   '서울특별시',
#   '대전광역시',
#   '서울특별시',
#   '경기도',
#   '서울특별시',
#   '서울특별시',
#   '서울특별시',
#   '서울특별시',
#   '서울특별시',
#   '경기도',
#   '부산광역시',
#   '대구광역시',
#   '서울특별시',
#   '울산광역시',
#   '서울특별시',
#   '서울특별시',
#   '서울특별시',
#   '경기도',
#   '강원특별자치도',
#   '대전광역시',
#   '경상북도',
#   '경기도',
#   '서울특별시',
#   '서울특별시',
#   '서울특별시',
#   '경기도',
#   '경기도',
#   '경기도',
#   '서울특별시',
#   '대전광역시',
#   '서울특별시',
#   '경기도',
#   '서울특별시',
#   '충청남도',
#   '인천광역시',
#   '경기도',
#   '부산광역시',
#   '경기도',
#   '서울특별시',
#   '서울특별시',
#   '경상북도',
#   '서울특별시',
#   '서울특별시',
#   '충청북도',
#   '경기도']}

# %%
# td랑 keys 개수가 같음
result = {}
for tr in soup.select('tr'):
    for key, td in zip(keys, tr.select('td')):
        result.setdefault(key, []).append(td.text)

result_df = pd.DataFrame(result)
result_df
# Out:
#                회사명                        업종  \
# 0       엔에이치스팩31호                 금융 지원 서비스업
# 1     SK증권제13호스팩                  금융 지원 서비스업
# 2         엑셀세라퓨틱스                기초 의약물질 제조업
# 3        이베스트스팩6호                 금융 지원 서비스업
# 4            시프트업             소프트웨어 개발 및 공급업
# ..             ...                       ...
# 95       에코프로머티              일차전지 및 이차전지 제조업
# 96        캡스톤파트너스                     기타 금융업
# 97            프로젠            자연과학 및 공학 연구개발업
# 98        에스와이스틸텍   구조용 금속제품, 탱크 및 증기발생기 제조업
# 99          에이직랜드                    반도체 제조업
#
#                                     주요제품         상장일  결산월 대표자명         홈페이지  \
# 0                               금융지원서비스업  2024-07-26  12월  이시형           \n
# 1                            기업인수목적 주식회사  2024-07-25  12월  임율표           \n
# 2                 CellCor SFD/CD(세포배양배지)  2024-07-15  12월  이의일           \n
# 3                            기업인수목적 주식회사  2024-07-12  12월   박용           \n
# 4                               게임 소프트웨어  2024-07-11  12월  김형태  \n홈페이지 보기\n
# ..                                   ...         ...  ...  ...          ...
# 95                배터리 양극재용 핵심소재 하이니켈 전구체  2023-11-17  12월  김병훈  \n홈페이지 보기\n
# 96                   벤처투자조합 등 조합 결성 및 운영  2023-11-15  12월  송은강  \n홈페이지 보기\n
# 97                                바이오의약품  2023-11-15  12월  김종균  \n홈페이지 보기\n
# 98                                데크플레이트  2023-11-13  12월  홍성균  \n홈페이지 보기\n
# 99  비메모리 반도체 설계및 제조, 전자회로 연구, 설계, 레이아웃 등  2023-11-13  12월  이종민  \n홈페이지 보기\n
#
#        지역
# 0   서울특별시
# 1   서울특별시
# 2   서울특별시
# 3   서울특별시
# 4   서울특별시
# ..    ...
# 95   경상북도
# 96  서울특별시
# 97  서울특별시
# 98   충청북도
# 99    경기도
#
# [100 rows x 8 columns]

# %%
result2 = {}
for tr in soup.select('tr'):
    for key, td in zip(keys[6:7], tr.select('td')[6:7]):
        
        #print(td.text)
        print(td.select_one('a')['href'] if td.string == None else "") # 6번째인 링크 찾기
        
        # for img in td.select('img'): # 증권 ㅈ종류, 회사 이름
        #     print(img['alt'])
    # result2.setdefault(key, []).append(td.next)
# Out:
# http://shiftup.co.kr
# http://www.hassbio.com
# http://www.innospc.com/
# http://shglobalreit.com
# http://hvm.co.kr/
# http://www.panggame.com/
# http://higenrnm.com
#
# http://soslab.co
#
#
# http://www.paradise.co.kr/ko/main
# http://www.hjncs.com
#
#
# http://seerstech.com
#
#
#
# http://www.gridwiz.com
# http://www.nexview.co.kr
#
# http://www.nobland.com
#
# http://www.ictk.com
# http://www.hd-marinesolution.com/
#
# http://www.korchip.com
# http://www.g-mintech.co.kr
# http://CATIS.CO.KR
# http://www.ddpharmatech.com
#
# http://www.jeilm.co.kr
# http://www.bbiacosmetic.com/
#
#
#
# http://www.imbdx.com/
# http://www.sketernix.com
#
# http://www.angel-robotics.com/ko/
# http://www.j2kbio.com
# http://www.samhyun.co.kr
# http://www.osanghc.com
# http://www.knrsys.com
# http://bnkspac2.com
#
#
#
#
# http://apr-in.com
# http://e8ight.co.kr/
# http://www.coxem.com
# http://www.kweather.co.kr
# http://www.sapien-semicon.com
# http://www.spsoft.co.kr
# http://www.studiosamick.com
#
# http://www.pond-group.co.kr
# http://www.ibks.com
# http://www.laseroptek.com
# http://www.inics.kr
# http://www.landf.co.kr/
# http://www.posbank.com/
# http://www.hyms.kr
# http://www.hbvc.co.kr
# http://bydream.co.kr/
#
# http://www.woojinntec.com/
# http://sevenbrau.com
# http://www.hblaser.co.kr
# http://www.poscodx.com/kor/
# http://dsdansuk.com
# http://www.ibks.com
#
# http://www.c-site.co.kr
# http://www.bluemtec.com
#
# http://knssystem.com
#
# http://ybiologics.com
#
# http://www.iatum.com/
#
# http://www.asteh.co.kr
# http://www.greenresource.kr
# http://www.jnbeng.com/
# http://www.slok.co.kr
# http://www.dong-in.com/
# http://www.ecoeye.com
# http://www.stormtec.co.kr/
# http://ecopromaterials.com/
# http://cspartners.co.kr
# http://progen.co.kr/
# http://systeeltech.com/
# http://www.asicland.com

# %%
result2 = {}
for tr in soup.select('tr'):
    for idx,(key, td) in enumerate(zip(keys, tr.select('td'))):
        print(idx, key, td.text)
        #print(td.text)
        # print(td.select_one('a')['href'] if td.string == None else "") # 6번째인 링크 찾기
# Out:
# 0 회사명   엔에이치스팩31호
# 1 업종 금융 지원 서비스업
# 2 주요제품 금융지원서비스업
# 3 상장일 2024-07-26
# 4 결산월 12월
# 5 대표자명 이시형
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   SK증권제13호스팩
# 1 업종 금융 지원 서비스업
# 2 주요제품 기업인수목적 주식회사
# 3 상장일 2024-07-25
# 4 결산월 12월
# 5 대표자명 임율표
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   엑셀세라퓨틱스
# 1 업종 기초 의약물질 제조업
# 2 주요제품 CellCor SFD/CD(세포배양배지)
# 3 상장일 2024-07-15
# 4 결산월 12월
# 5 대표자명 이의일
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   이베스트스팩6호
# 1 업종 금융 지원 서비스업
# 2 주요제품 기업인수목적 주식회사
# 3 상장일 2024-07-12
# 4 결산월 12월
# 5 대표자명 박용
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   시프트업
# 1 업종 소프트웨어 개발 및 공급업
# 2 주요제품 게임 소프트웨어
# 3 상장일 2024-07-11
# 4 결산월 12월
# 5 대표자명 김형태
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   하스
# 1 업종 의료용품 및 기타 의약 관련제품 제조업
# 2 주요제품 리튬디실리케이트 수복소재(Amber block, Amber Ingot 등), 지르코니아 유치관
# 3 상장일 2024-07-03
# 4 결산월 12월
# 5 대표자명 김용수
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 강원특별자치도
# 0 회사명   이노스페이스
# 1 업종 항공기,우주선 및 부품 제조업
# 2 주요제품 소형발사체, 로켓추진기관, 과학로켓, 시험평가용역
# 3 상장일 2024-07-02
# 4 결산월 12월
# 5 대표자명 김수종
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 세종특별자치시
# 0 회사명   신한글로벌액티브리츠
# 1 업종 신탁업 및 집합투자업
# 2 주요제품 신탁 및 집합투자
# 3 상장일 2024-07-01
# 4 결산월 02월
# 5 대표자명 김선영
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   에이치브이엠
# 1 업종 1차 비철금속 제조업
# 2 주요제품 Ni계 합금, Fe계 합금, 스퍼터링타겟, Cu계 합금 등
# 3 상장일 2024-06-28
# 4 결산월 12월
# 5 대표자명 문승호
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경기도
# 0 회사명   팡스카이
# 1 업종 소프트웨어 개발 및 공급업
# 2 주요제품 게임 개발 및 리퍼블리싱
# 3 상장일 2024-06-28
# 4 결산월 12월
# 5 대표자명 조호현..
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   하이젠알앤엠
# 1 업종 전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 2 주요제품 전동기 및 발전기 (범용모터, 서보모터)
# 3 상장일 2024-06-27
# 4 결산월 12월
# 5 대표자명 김재학
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경상남도
# 0 회사명   한국제15호스팩
# 1 업종 금융 지원 서비스업
# 2 주요제품 기업인수합병
# 3 상장일 2024-06-26
# 4 결산월 12월
# 5 대표자명 유한
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   에스오에스랩
# 1 업종 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 2 주요제품 산업용 및 차량용 라이다(LiDAR)
# 3 상장일 2024-06-25
# 4 결산월 12월
# 5 대표자명 정지성
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 광주광역시
# 0 회사명   미래에셋비전스팩6호
# 1 업종 금융 지원 서비스업
# 2 주요제품 기업인수합병
# 3 상장일 2024-06-24
# 4 결산월 12월
# 5 대표자명 정명훈
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   에이치엠씨제7호스팩
# 1 업종 금융 지원 서비스업
# 2 주요제품 기타금융
# 3 상장일 2024-06-24
# 4 결산월 12월
# 5 대표자명 강신명
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   파라다이스
# 1 업종 유원지 및 기타 오락관련 서비스업
# 2 주요제품 카지노, 호텔, 복합리조트
# 3 상장일 2024-06-24
# 4 결산월 12월
# 5 대표자명 최종환..
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   한중엔시에스
# 1 업종 전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 2 주요제품 수냉식 냉각시스템 ESS Parts, 공랭식 ESS Module Parts, EV Module 및 내연기관 Parts
# 3 상장일 2024-06-24
# 4 결산월 12월
# 5 대표자명 김환식
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경상북도
# 0 회사명   KB제29호스팩
# 1 업종 금융 지원 서비스업
# 2 주요제품 기업인수합병
# 3 상장일 2024-06-21
# 4 결산월 12월
# 5 대표자명 서영화
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   미래에셋비전스팩5호
# 1 업종 금융 지원 서비스업
# 2 주요제품 기업인수합병
# 3 상장일 2024-06-19
# 4 결산월 12월
# 5 대표자명 김대호
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   씨어스테크놀로지
# 1 업종 의료용 기기 제조업
# 2 주요제품 심전도검사솔루션 입원환자모니터링솔루션
# 3 상장일 2024-06-19
# 4 결산월 12월
# 5 대표자명 이영신
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경기도
# 0 회사명   한국제14호스팩
# 1 업종 금융 지원 서비스업
# 2 주요제품 기업인수합병
# 3 상장일 2024-06-19
# 4 결산월 12월
# 5 대표자명 변성환
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   디비금융스팩12호
# 1 업종 기타 금융업
# 2 주요제품 기업인수 및 합병
# 3 상장일 2024-06-18
# 4 결산월 12월
# 5 대표자명 김창희
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   라메디텍
# 1 업종 의료용 기기 제조업
# 2 주요제품 초소형 레이저 의료기기  및 미용기기
# 3 상장일 2024-06-17
# 4 결산월 12월
# 5 대표자명 최종석
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   그리드위즈
# 1 업종 그외 기타 전문, 과학 및 기술 서비스업
# 2 주요제품 수요관리 서비스, 전기차 충전기 모뎀 등
# 3 상장일 2024-06-14
# 4 결산월 12월
# 5 대표자명 김구환
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경기도
# 0 회사명   다원넥스뷰
# 1 업종 사진장비 및 광학기기 제조업
# 2 주요제품 LSMB(Laser Micro Bonding System)
# 3 상장일 2024-06-11
# 4 결산월 12월
# 5 대표자명 남기중
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경기도
# 0 회사명   미래에셋비전스팩4호
# 1 업종 금융 지원 서비스업
# 2 주요제품 기업인수목적회사(기타금융서비스)
# 3 상장일 2024-05-29
# 4 결산월 12월
# 5 대표자명 김정수
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   노브랜드
# 1 업종 편조의복 제조업
# 2 주요제품 Knit, Woven 의류
# 3 상장일 2024-05-23
# 4 결산월 12월
# 5 대표자명 이상규
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   KB제28호스팩
# 1 업종 금융 지원 서비스업
# 2 주요제품 기업인수합병
# 3 상장일 2024-05-17
# 4 결산월 12월
# 5 대표자명 고광범
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   아이씨티케이
# 1 업종 반도체 제조업
# 2 주요제품 PUF반도체,보안솔루션(보안반도체,정보통신모듈기기,정보통신용반도체) 제조,개발
# 3 상장일 2024-05-17
# 4 결산월 12월
# 5 대표자명 이정원
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   HD현대마린솔루션
# 1 업종 건축기술, 엔지니어링 및 관련 기술 서비스업
# 2 주요제품 AM(After Market) 솔루션, 친환경 Retrofit, 디지털 제어
# 3 상장일 2024-05-08
# 4 결산월 12월
# 5 대표자명 이기동
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 부산광역시
# 0 회사명   SK증권제12호스팩
# 1 업종 금융 지원 서비스업
# 2 주요제품 기업인수목적 주식회사
# 3 상장일 2024-05-07
# 4 결산월 12월
# 5 대표자명 이재혁
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   코칩
# 1 업종 전자부품 제조업
# 2 주요제품 소형 및 초소형 슈퍼커패시터
# 3 상장일 2024-05-07
# 4 결산월 12월
# 5 대표자명 손진형
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경기도
# 0 회사명   민테크
# 1 업종 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 2 주요제품 배터리 진단시스템, 배터리 시스템, 충방전 검사장비
# 3 상장일 2024-05-03
# 4 결산월 12월
# 5 대표자명 홍영진
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 대전광역시
# 0 회사명   카티스
# 1 업종 컴퓨터 프로그래밍, 시스템 통합 및 관리업
# 2 주요제품 산업인프라 보안플랫폼
# 3 상장일 2024-05-03
# 4 결산월 12월
# 5 대표자명 김승수
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경기도
# 0 회사명   디앤디파마텍
# 1 업종 자연과학 및 공학 연구개발업
# 2 주요제품 대사성질환 치료제 등
# 3 상장일 2024-05-02
# 4 결산월 12월
# 5 대표자명 이슬기
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경기도
# 0 회사명   유안타제16호스팩
# 1 업종 금융 지원 서비스업
# 2 주요제품 금융 지원 서비스(기업인수목적회사)
# 3 상장일 2024-05-02
# 4 결산월 12월
# 5 대표자명 박병권
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   제일엠앤에스
# 1 업종 특수 목적용 기계 제조업
# 2 주요제품 2차전지 믹싱시스템
# 3 상장일 2024-04-30
# 4 결산월 12월
# 5 대표자명 이영진
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경기도
# 0 회사명   삐아
# 1 업종 기타 화학제품 제조업
# 2 주요제품 색조화장품
# 3 상장일 2024-04-25
# 4 결산월 12월
# 5 대표자명 박광춘
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 인천광역시
# 0 회사명   하나33호스팩
# 1 업종 금융 지원 서비스업
# 2 주요제품 기업인수합병
# 3 상장일 2024-04-24
# 4 결산월 12월
# 5 대표자명 박태한
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   신한제13호스팩
# 1 업종 금융 지원 서비스업
# 2 주요제품 기타금융서비스(기업합병)
# 3 상장일 2024-04-22
# 4 결산월 12월
# 5 대표자명 배성환
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   신한제12호스팩
# 1 업종 금융 지원 서비스업
# 2 주요제품 금융서비스(기업인수목적회사)
# 3 상장일 2024-04-15
# 4 결산월 12월
# 5 대표자명 이동호
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   아이엠비디엑스
# 1 업종 자연과학 및 공학 연구개발업
# 2 주요제품 알파리퀴드ⓡ 100, 알파리퀴드ⓡ HRR, 알파리퀴드ⓡ 디텍트, 알파리퀴드ⓡ 스크리닝
# 3 상장일 2024-04-03
# 4 결산월 12월
# 5 대표자명 김태유
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   SK이터닉스
# 1 업종 건물 건설업
# 2 주요제품 부동산 개발
# 3 상장일 2024-03-29
# 4 결산월 12월
# 5 대표자명 김해중
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경기도
# 0 회사명   하나32호스팩
# 1 업종 금융 지원 서비스업
# 2 주요제품 기업인수합병
# 3 상장일 2024-03-27
# 4 결산월 12월
# 5 대표자명 박종찬
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   엔젤로보틱스
# 1 업종 특수 목적용 기계 제조업
# 2 주요제품 재활 전문 웨어러블 로봇, 근력 보조 무동력 웨어러블 슈트, 일상생활 보조 웨어러블 로봇 등
# 3 상장일 2024-03-26
# 4 결산월 12월
# 5 대표자명 공경철
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   제이투케이바이오
# 1 업종 기타 화학제품 제조업
# 2 주요제품 화장품 원료(천연소재 바이오소재 등)
# 3 상장일 2024-03-25
# 4 결산월 12월
# 5 대표자명 이재섭
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 충청북도
# 0 회사명   삼현
# 1 업종 자동차 신품 부품 제조업
# 2 주요제품 스마트 액추에이터, 스마트 파워유닛
# 3 상장일 2024-03-21
# 4 결산월 12월
# 5 대표자명 황성호
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경상남도
# 0 회사명   오상헬스케어
# 1 업종 의료용품 및 기타 의약 관련제품 제조업
# 2 주요제품 생화학 측정기 및 센서, 면역진단기기 및 마커, 분자진단기기 및 시약 등
# 3 상장일 2024-03-13
# 4 결산월 12월
# 5 대표자명 강철훈
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경기도
# 0 회사명   케이엔알시스템
# 1 업종 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 2 주요제품 특수목적 시험장비, 산업용로봇
# 3 상장일 2024-03-07
# 4 결산월 12월
# 5 대표자명 김명한
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경기도
# 0 회사명   비엔케이제2호스팩
# 1 업종 금융 지원 서비스업
# 2 주요제품 금융 지원 서비스업
# 3 상장일 2024-03-05
# 4 결산월 12월
# 5 대표자명 정민중
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   하나31호스팩
# 1 업종 금융 지원 서비스업
# 2 주요제품 기업인수합병
# 3 상장일 2024-03-05
# 4 결산월 12월
# 5 대표자명 한규정
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   SK증권제11호스팩
# 1 업종 금융 지원 서비스업
# 2 주요제품 기업인수목적 주식회사
# 3 상장일 2024-03-04
# 4 결산월 12월
# 5 대표자명 최상우
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   유안타제15호스팩
# 1 업종 금융 지원 서비스업
# 2 주요제품 금융 지원 서비스
# 3 상장일 2024-02-29
# 4 결산월 12월
# 5 대표자명 구태훈
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   유진스팩10호
# 1 업종 금융 지원 서비스업
# 2 주요제품 기업인수합병
# 3 상장일 2024-02-29
# 4 결산월 12월
# 5 대표자명 김동진
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   에이피알
# 1 업종 기타 화학제품 제조업
# 2 주요제품 화장품, 피부미용기기 등
# 3 상장일 2024-02-27
# 4 결산월 12월
# 5 대표자명 김병훈
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   이에이트
# 1 업종 소프트웨어 개발 및 공급업
# 2 주요제품 CFD 시뮬레이션 소프트웨어, 디지털트윈 플랫폼
# 3 상장일 2024-02-23
# 4 결산월 12월
# 5 대표자명 김진현
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   코셈
# 1 업종 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 2 주요제품 주사전자현미경(SEM)
# 3 상장일 2024-02-23
# 4 결산월 12월
# 5 대표자명 이준희
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 대전광역시
# 0 회사명   케이웨더
# 1 업종 일반 목적용 기계 제조업
# 2 주요제품 공기개선솔루션, 기상데이터, 공기측정솔루션 등
# 3 상장일 2024-02-22
# 4 결산월 12월
# 5 대표자명 김동식
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   사피엔반도체
# 1 업종 반도체 제조업
# 2 주요제품 Micro/Mini-LED Display Driver IC
# 3 상장일 2024-02-19
# 4 결산월 12월
# 5 대표자명 이명희
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경기도
# 0 회사명   에스피소프트
# 1 업종 컴퓨터 프로그래밍, 시스템 통합 및 관리업
# 2 주요제품 SPLA 라이센스 총판 사업,CLOUD, gDaaS 등
# 3 상장일 2024-02-15
# 4 결산월 12월
# 5 대표자명 이은재
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   스튜디오삼익
# 1 업종 기타 생활용품 소매업
# 2 주요제품 침실가구, 거실가구,  옷장/수납, 주방가구 등
# 3 상장일 2024-02-06
# 4 결산월 12월
# 5 대표자명 최정석
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   신영스팩10호
# 1 업종 금융 지원 서비스업
# 2 주요제품 기업인수합병
# 3 상장일 2024-02-06
# 4 결산월 12월
# 5 대표자명 여지우
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   폰드그룹
# 1 업종 봉제의복 제조업
# 2 주요제품 의류(언더웨어, 의복, 잡화, 코스메틱 등)
# 3 상장일 2024-02-02
# 4 결산월 12월
# 5 대표자명 임종민..
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   IBKS제24호스팩
# 1 업종 금융 지원 서비스업
# 2 주요제품 금융 지원 서비스업
# 3 상장일 2024-02-01
# 4 결산월 12월
# 5 대표자명 김강민
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   레이저옵텍
# 1 업종 의료용 기기 제조업
# 2 주요제품 레이저 기반 피부미용기기 및 질환치료기기
# 3 상장일 2024-02-01
# 4 결산월 12월
# 5 대표자명 주홍,..
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경기도
# 0 회사명   이닉스
# 1 업종 자동차 신품 부품 제조업
# 2 주요제품 2차전지용 배터리셀 패드 등
# 3 상장일 2024-02-01
# 4 결산월 12월
# 5 대표자명 강동호..
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 부산광역시
# 0 회사명   엘앤에프
# 1 업종 일차전지 및 이차전지 제조업
# 2 주요제품 이차전지 양극활물질
# 3 상장일 2024-01-29
# 4 결산월 12월
# 5 대표자명 최수안
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 대구광역시
# 0 회사명   포스뱅크
# 1 업종 일반 목적용 기계 제조업
# 2 주요제품 POS 단말기, KIOSK 단말기
# 3 상장일 2024-01-29
# 4 결산월 12월
# 5 대표자명 은동욱
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   현대힘스
# 1 업종 선박 및 보트 건조업
# 2 주요제품 선박기자재 (선박 블록, 보강재, 도장 등)
# 3 상장일 2024-01-26
# 4 결산월 12월
# 5 대표자명 최지용
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 울산광역시
# 0 회사명   HB인베스트먼트
# 1 업종 기타 금융업
# 2 주요제품 벤처투자조합 등 조합 결성 및 운영
# 3 상장일 2024-01-25
# 4 결산월 12월
# 5 대표자명 황유선
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   드림인사이트
# 1 업종 광고업
# 2 주요제품 광고대행
# 3 상장일 2024-01-25
# 4 결산월 12월
# 5 대표자명 김기철
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   대신밸런스제17호스팩
# 1 업종 금융 지원 서비스업
# 2 주요제품 금융 지원 서비스업
# 3 상장일 2024-01-24
# 4 결산월 12월
# 5 대표자명 이문수
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   우진엔텍
# 1 업종 그외 기타 전문, 과학 및 기술 서비스업
# 2 주요제품 발전소 계측제어설비 정비 서비스
# 3 상장일 2024-01-24
# 4 결산월 12월
# 5 대표자명 신상연
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경기도
# 0 회사명   세븐브로이맥주
# 1 업종 알코올음료 제조업
# 2 주요제품 맥주 등 주류 및 음료
# 3 상장일 2024-01-17
# 4 결산월 12월
# 5 대표자명 김강삼
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 강원특별자치도
# 0 회사명   한빛레이저
# 1 업종 특수 목적용 기계 제조업
# 2 주요제품 산업용 레이저 가공장비
# 3 상장일 2024-01-04
# 4 결산월 12월
# 5 대표자명 김정묵
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 대전광역시
# 0 회사명   포스코DX
# 1 업종 건축기술, 엔지니어링 및 관련 기술 서비스업
# 2 주요제품 EIC 자동화 엔지니어링 및 IT서비스
# 3 상장일 2024-01-02
# 4 결산월 12월
# 5 대표자명 정덕균
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경상북도
# 0 회사명   DS단석
# 1 업종 기타 화학제품 제조업
# 2 주요제품 바이오에너지
# 3 상장일 2023-12-22
# 4 결산월 12월
# 5 대표자명 한승욱
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경기도
# 0 회사명   IBKS제23호스팩
# 1 업종 금융 지원 서비스업
# 2 주요제품 기업인수 및 합병
# 3 상장일 2023-12-22
# 4 결산월 12월
# 5 대표자명 오창수
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   하나30호스팩
# 1 업종 금융 지원 서비스업
# 2 주요제품 기업인수합병
# 3 상장일 2023-12-22
# 4 결산월 12월
# 5 대표자명 전신웅
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   씨싸이트
# 1 업종 봉제의복 제조업
# 2 주요제품 니트류 OEM
# 3 상장일 2023-12-21
# 4 결산월 12월
# 5 대표자명 김상기
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   블루엠텍
# 1 업종 기타 전문 도매업
# 2 주요제품 의약품 유통업
# 3 상장일 2023-12-13
# 4 결산월 12월
# 5 대표자명 김현수
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경기도
# 0 회사명   LS머트리얼즈
# 1 업종 전자부품 제조업
# 2 주요제품 울트라커패시터(셀 및 모듈)
# 3 상장일 2023-12-12
# 4 결산월 12월
# 5 대표자명 홍영호
# 6 홈페이지
#
# 7 지역 경기도
# 0 회사명   케이엔에스
# 1 업종 특수 목적용 기계 제조업
# 2 주요제품 이차전지 자동화 설비
# 3 상장일 2023-12-06
# 4 결산월 12월
# 5 대표자명 정봉진
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경기도
# 0 회사명   교보15호스팩
# 1 업종 금융 지원 서비스업
# 2 주요제품 기업인수합병
# 3 상장일 2023-12-05
# 4 결산월 12월
# 5 대표자명 김상도
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   와이바이오로직스
# 1 업종 자연과학 및 공학 연구개발업
# 2 주요제품 항체의약품 및 항체후보물질 연구개발
# 3 상장일 2023-12-05
# 4 결산월 12월
# 5 대표자명 박영우..
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 대전광역시
# 0 회사명   삼성스팩9호
# 1 업종 금융 지원 서비스업
# 2 주요제품 기업인수합병
# 3 상장일 2023-12-04
# 4 결산월 12월
# 5 대표자명 오정헌
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   에이텀
# 1 업종 전자부품 제조업
# 2 주요제품 평판형 트랜스
# 3 상장일 2023-12-01
# 4 결산월 06월
# 5 대표자명 한택수
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경기도
# 0 회사명   엔에이치스팩30호
# 1 업종 금융 지원 서비스업
# 2 주요제품 금융지원서비스업
# 3 상장일 2023-12-01
# 4 결산월 12월
# 5 대표자명 조선희
# 6 홈페이지
#
# 7 지역 서울특별시
# 0 회사명   에이에스텍
# 1 업종 기타 화학제품 제조업
# 2 주요제품 자외선 차단제 유기 원료
# 3 상장일 2023-11-28
# 4 결산월 12월
# 5 대표자명 윤종배..
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 충청남도
# 0 회사명   그린리소스
# 1 업종 반도체 제조업
# 2 주요제품 반도체 및 디스플레이 장비 보호코팅 및 소재
# 3 상장일 2023-11-24
# 4 결산월 12월
# 5 대표자명 이종수..
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 인천광역시
# 0 회사명   제이엔비
# 1 업종 특수 목적용 기계 제조업
# 2 주요제품 진공 펌프용 유틸리티 장치(Stacker 등), 정밀가공 부품
# 3 상장일 2023-11-24
# 4 결산월 12월
# 5 대표자명 이정범
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경기도
# 0 회사명   한선엔지니어링
# 1 업종 기타 금속 가공제품 제조업
# 2 주요제품 계장용 피팅 및 밸브, 모듈
# 3 상장일 2023-11-24
# 4 결산월 12월
# 5 대표자명 이제훈
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 부산광역시
# 0 회사명   동인기연
# 1 업종 가죽, 가방 및 유사제품 제조업
# 2 주요제품 스포츠용품(등산용가방,골프백),금속압형제품,유아용품 제조,도소매,통신 판매/부동산 임대
# 3 상장일 2023-11-21
# 4 결산월 12월
# 5 대표자명 정인수
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경기도
# 0 회사명   에코아이
# 1 업종 기타 전문 서비스업
# 2 주요제품 탄소배출권 및 탄소배출권 관련 컨설팅
# 3 상장일 2023-11-21
# 4 결산월 12월
# 5 대표자명 이수복
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   스톰테크
# 1 업종 플라스틱제품 제조업
# 2 주요제품 정수기 피팅, 밸브, 파우셋 등 부품
# 3 상장일 2023-11-20
# 4 결산월 12월
# 5 대표자명 강기환..
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   에코프로머티
# 1 업종 일차전지 및 이차전지 제조업
# 2 주요제품 배터리 양극재용 핵심소재 하이니켈 전구체
# 3 상장일 2023-11-17
# 4 결산월 12월
# 5 대표자명 김병훈
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경상북도
# 0 회사명   캡스톤파트너스
# 1 업종 기타 금융업
# 2 주요제품 벤처투자조합 등 조합 결성 및 운영
# 3 상장일 2023-11-15
# 4 결산월 12월
# 5 대표자명 송은강
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   프로젠
# 1 업종 자연과학 및 공학 연구개발업
# 2 주요제품 바이오의약품
# 3 상장일 2023-11-15
# 4 결산월 12월
# 5 대표자명 김종균
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 서울특별시
# 0 회사명   에스와이스틸텍
# 1 업종 구조용 금속제품, 탱크 및 증기발생기 제조업
# 2 주요제품 데크플레이트
# 3 상장일 2023-11-13
# 4 결산월 12월
# 5 대표자명 홍성균
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 충청북도
# 0 회사명   에이직랜드
# 1 업종 반도체 제조업
# 2 주요제품 비메모리 반도체 설계및 제조, 전자회로 연구, 설계, 레이아웃 등
# 3 상장일 2023-11-13
# 4 결산월 12월
# 5 대표자명 이종민
# 6 홈페이지
# 홈페이지 보기
#
# 7 지역 경기도

# %%
result2 = {}
for tr in soup.select('tr'):
    for idx,(key, td) in enumerate(zip(keys, tr.select('td'))):
        if idx == 0:
            kinds = [(img['alt']) for img in td.select('img')]
            kind = ", ".join(kinds)
            result2.setdefault('증권종류',[]).append(kind)
            result2.setdefault(key,[]).append(td.text)

        elif idx == 6:
            home_link = (td.select_one('a')['href'] if td.string == None else "") # 6번째인 링크 찾기
            result2.setdefault(key, []).append(home_link)
        else:

            result2.setdefault(key, []).append(td.text)
result_df2 = pd.DataFrame(result2)
result_df2
# Out:
#                              증권종류          회사명                   업종  \
# 0  유가증권, KTOP30, KOSPI200, KRX300     유한양행                  의약품 제조업
# 1          유가증권, KOSPI200, KRX300    CJ대한통운               도로 화물 운송업
# 2                            유가증권          경방                종합 소매업
# 3                            유가증권       유수홀딩스   회사 본부 및 경영 컨설팅 서비스업
# 4                            유가증권    한진중공업홀딩스     연료용 가스 제조 및 배관공급업
#
#                                                 주요제품         상장일  결산월   대표자명  \
# 0  의약품(삐콤씨, 안티푸라민, 렉라자, 로수바미브, 코푸시럽 등), 생활용품(유한락스...  1962-11-01  12월  대표이..
# 1  Contract Logistics, 포워딩, 항만하역, 해운, 택배국제특송, SCM...  1956-07-02  12월  신영수..
# 2          섬유류(면사,면혼방사,면직물,면혼방직물,화섬사,화섬직물) 제조,도매,수출입  1956-03-03  12월  김준,..
# 3                                               지주사업  1956-03-03  12월    송영규
# 4                                               지주회사  1956-03-03  12월  조남호..
#
#                            홈페이지     지역
# 0        http://www.yuhan.co.kr  서울특별시
# 1    http://www.cjlogistics.com  서울특별시
# 2    http://www.kyungbang.co.kr  서울특별시
# 3  http://www.eusu-holdings.com  서울특별시
# 4  http://www.hhic-holdings.com    경기도

# %%
result = {}
for tr in soup.select('tr'):
    for idx, (key, td) in enumerate(zip(keys, tr.select('td'))):
        if idx == 0:
            kinds = [img['alt'] for img in td.select('img')]   # 1번째 증권 종류, 회사이름
            kind = ", ".join(kinds)
            result.setdefault('증권종류', []).append(kind)
            result.setdefault(key, []).append(td.text)
            print(td.select_one('a')['onclick'].split('')[1])
        elif idx == 6:
            home_link = td.select_one('a')['href'] if td.string == None else ""  # 6번째 링크 찾기
            result.setdefault(key, []).append(home_link)
        else:
            result.setdefault(key, []).append(td.text)

        
result
result_df = pd.DataFrame(result)
result_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 9
#       7     result.setdefault('증권종류', []).append(kind)
#       8     result.setdefault(key, []).append(td.text)
# ----> 9     print(td.select_one('a')['onclick'].split('')[1])
#      10 elif idx == 6:
#      11     home_link = td.select_one('a')['href'] if td.string == None else ""  # 6번째 링크 찾기
#
# ValueError: empty separator

# %%
result2 = {}
for tr in soup.select('tr'):
    for idx,(key, td) in enumerate(zip(keys, tr.select('td'))):
        print(idx, key, td.text, soup.select_one('a')['onclick'].split("1")[0])
# Out:
# 0 회사명   에이플러스에셋  companysummary_open('24492'); return false;
# 1 업종 보험 및 연금관련 서비스업 companysummary_open('24492'); return false;
# 2 주요제품 보험대리 및 중개업 companysummary_open('24492'); return false;
# 3 상장일 2020-11-20 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 곽근호.. companysummary_open('24492'); return false;
# 6 홈페이지
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   티앤엘  companysummary_open('24492'); return false;
# 1 업종 의료용품 및 기타 의약 관련제품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 창상치료재, 정형외과용 고정재 companysummary_open('24492'); return false;
# 3 상장일 2020-11-20 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 최윤소 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   고바이오랩  companysummary_open('24492'); return false;
# 1 업종 자연과학 및 공학 연구개발업 companysummary_open('24492'); return false;
# 2 주요제품 마이크로바이옴 치료제 및 건강기능식품 companysummary_open('24492'); return false;
# 3 상장일 2020-11-18 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 고광표 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   네패스아크  companysummary_open('24492'); return false;
# 1 업종 그외 기타 전문, 과학 및 기술 서비스업 companysummary_open('24492'); return false;
# 2 주요제품 반도체 테스트 서비스 companysummary_open('24492'); return false;
# 3 상장일 2020-11-17 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 이창우.. companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 충청북도 companysummary_open('24492'); return false;
# 0 회사명   교촌에프앤비  companysummary_open('24492'); return false;
# 1 업종 음·식료품 및 담배 도매업 companysummary_open('24492'); return false;
# 2 주요제품 치킨 프랜차이즈 companysummary_open('24492'); return false;
# 3 상장일 2020-11-12 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 송종화 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경상북도 companysummary_open('24492'); return false;
# 0 회사명   소룩스  companysummary_open('24492'); return false;
# 1 업종 전구 및 조명장치 제조업 companysummary_open('24492'); return false;
# 2 주요제품 실내등(형광등, LED등), 실외등, 특수등 companysummary_open('24492'); return false;
# 3 상장일 2020-11-06 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 정재준 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 충청남도 companysummary_open('24492'); return false;
# 0 회사명   위드텍  companysummary_open('24492'); return false;
# 1 업종 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외 companysummary_open('24492'); return false;
# 2 주요제품 AMCs 모니터링 시스템, 공정 프로세스 모니터링 시스템, TMS companysummary_open('24492'); return false;
# 3 상장일 2020-10-30 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 유승교.. companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 대전광역시 companysummary_open('24492'); return false;
# 0 회사명   센코  companysummary_open('24492'); return false;
# 1 업종 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외 companysummary_open('24492'); return false;
# 2 주요제품 가스센서 및 모듈, 휴대용 및 고정형 가스검지기, 악취 & 미세먼지 모니터링 시스템 companysummary_open('24492'); return false;
# 3 상장일 2020-10-29 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 하승철 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   바이브컴퍼니  companysummary_open('24492'); return false;
# 1 업종 소프트웨어 개발 및 공급업 companysummary_open('24492'); return false;
# 2 주요제품 소셜 빅데이터 기반 인공지능 서비스 (소셜메트릭스), 문제 해결 솔루션 (AI Solver) companysummary_open('24492'); return false;
# 3 상장일 2020-10-28 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 김성언 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   원포유  companysummary_open('24492'); return false;
# 1 업종 소프트웨어 개발 및 공급업 companysummary_open('24492'); return false;
# 2 주요제품 비대면서비스플랫폼, 인공지능 companysummary_open('24492'); return false;
# 3 상장일 2020-10-23 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 전동호 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   미코바이오메드  companysummary_open('24492'); return false;
# 1 업종 의료용 기기 제조업 companysummary_open('24492'); return false;
# 2 주요제품 체외진단용 의료기기 companysummary_open('24492'); return false;
# 3 상장일 2020-10-22 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 홍영석 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   피플바이오  companysummary_open('24492'); return false;
# 1 업종 의료용품 및 기타 의약 관련제품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 올리고머화 베타-아밀로이드 검사제품(알츠하이머병 진단) companysummary_open('24492'); return false;
# 3 상장일 2020-10-19 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 강성민 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   하이브    companysummary_open('24492'); return false;
# 1 업종 오디오물 출판 및 원판 녹음업 companysummary_open('24492'); return false;
# 2 주요제품 음악 기획/제작, 퍼블리싱, 아티스트 매니지먼트 companysummary_open('24492'); return false;
# 3 상장일 2020-10-15 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 박지원 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   넥스틴    companysummary_open('24492'); return false;
# 1 업종 특수 목적용 기계 제조업 companysummary_open('24492'); return false;
# 2 주요제품 반도체 전공정용 패턴결함 검사장비(AEGIS 등) companysummary_open('24492'); return false;
# 3 상장일 2020-10-08 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 박태훈 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   케이엔솔  companysummary_open('24492'); return false;
# 1 업종 일반 목적용 기계 제조업 companysummary_open('24492'); return false;
# 2 주요제품 클린룸 설비 companysummary_open('24492'); return false;
# 3 상장일 2020-09-24 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 구자겸.. companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 충청북도 companysummary_open('24492'); return false;
# 0 회사명   비나텍  companysummary_open('24492'); return false;
# 1 업종 일차전지 및 이차전지 제조업 companysummary_open('24492'); return false;
# 2 주요제품 초고용량 커패시터(슈퍼커패시터) companysummary_open('24492'); return false;
# 3 상장일 2020-09-23 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 성도경 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 전북특별자치도 companysummary_open('24492'); return false;
# 0 회사명   씨엔알리서치  companysummary_open('24492'); return false;
# 1 업종 그외 기타 전문, 과학 및 기술 서비스업 companysummary_open('24492'); return false;
# 2 주요제품 금융 지원 서비스 companysummary_open('24492'); return false;
# 3 상장일 2020-09-23 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 윤문태 companysummary_open('24492'); return false;
# 6 홈페이지
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   박셀바이오   companysummary_open('24492'); return false;
# 1 업종 자연과학 및 공학 연구개발업 companysummary_open('24492'); return false;
# 2 주요제품 항암면역세포치료제(자연살해세포, 수지상세포, CAR-T 및 인터루킨 기반 항암제) companysummary_open('24492'); return false;
# 3 상장일 2020-09-22 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 이제중.. companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 전라남도 companysummary_open('24492'); return false;
# 0 회사명   티와이홀딩스   companysummary_open('24492'); return false;
# 1 업종 기타 금융업 companysummary_open('24492'); return false;
# 2 주요제품 지주사업 companysummary_open('24492'); return false;
# 3 상장일 2020-09-22 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 유종연 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   비비씨  companysummary_open('24492'); return false;
# 1 업종 기타 화학제품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 덴탈 케어용 소재(테이퍼모 등) companysummary_open('24492'); return false;
# 3 상장일 2020-09-21 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 강기태 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 대전광역시 companysummary_open('24492'); return false;
# 0 회사명   코스텍시스  companysummary_open('24492'); return false;
# 1 업종 반도체 제조업 companysummary_open('24492'); return false;
# 2 주요제품 RF PKG. Spacer companysummary_open('24492'); return false;
# 3 상장일 2020-09-18 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 한규진 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 인천광역시 companysummary_open('24492'); return false;
# 0 회사명   핌스  companysummary_open('24492'); return false;
# 1 업종 전자부품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 OLED Metal Mask companysummary_open('24492'); return false;
# 3 상장일 2020-09-18 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 김민용 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 인천광역시 companysummary_open('24492'); return false;
# 0 회사명   압타머사이언스  companysummary_open('24492'); return false;
# 1 업종 자연과학 및 공학 연구개발업 companysummary_open('24492'); return false;
# 2 주요제품 압타머기반 신약개발 및 진단제품 개발 companysummary_open('24492'); return false;
# 3 상장일 2020-09-16 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 한동일 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   이오플로우  companysummary_open('24492'); return false;
# 1 업종 의료용 기기 제조업 companysummary_open('24492'); return false;
# 2 주요제품 웨어러블 인슐린펌프 companysummary_open('24492'); return false;
# 3 상장일 2020-09-14 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 김재진 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   카카오게임즈    companysummary_open('24492'); return false;
# 1 업종 소프트웨어 개발 및 공급업 companysummary_open('24492'); return false;
# 2 주요제품 모바일, PC게임 퍼블리싱 companysummary_open('24492'); return false;
# 3 상장일 2020-09-10 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 San.. companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   피엔케이피부임상연구센타  companysummary_open('24492'); return false;
# 1 업종 그외 기타 전문, 과학 및 기술 서비스업 companysummary_open('24492'); return false;
# 2 주요제품 피부인체적용시험 companysummary_open('24492'); return false;
# 3 상장일 2020-09-09 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 박진오.. companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   코람코라이프인프라리츠  companysummary_open('24492'); return false;
# 1 업종 부동산 임대 및 공급업 companysummary_open('24492'); return false;
# 2 주요제품 부동산 투자 및 관리 companysummary_open('24492'); return false;
# 3 상장일 2020-08-31 companysummary_open('24492'); return false;
# 4 결산월 11월 companysummary_open('24492'); return false;
# 5 대표자명 이성균 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   아이디피  companysummary_open('24492'); return false;
# 1 업종 컴퓨터 및 주변장치 제조업 companysummary_open('24492'); return false;
# 2 주요제품 카드인쇄용 프린터, 카드인쇄용 리본 companysummary_open('24492'); return false;
# 3 상장일 2020-08-24 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 노현철 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   셀레믹스  companysummary_open('24492'); return false;
# 1 업종 기초 의약물질 제조업 companysummary_open('24492'); return false;
# 2 주요제품 타겟캡처키트 companysummary_open('24492'); return false;
# 3 상장일 2020-08-21 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 김효기.. companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   고스트스튜디오  companysummary_open('24492'); return false;
# 1 업종 소프트웨어 개발 및 공급업 companysummary_open('24492'); return false;
# 2 주요제품 캐주얼게임, 소셜카지노게임 companysummary_open('24492'); return false;
# 3 상장일 2020-08-18 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 손창욱.. companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 홍콩 companysummary_open('24492'); return false;
# 0 회사명   브랜드엑스코퍼레이션  companysummary_open('24492'); return false;
# 1 업종 기타 정보 서비스업 companysummary_open('24492'); return false;
# 2 주요제품 애슬레저의류, 생활/청결 용품 companysummary_open('24492'); return false;
# 3 상장일 2020-08-13 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 강민준.. companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   영림원소프트랩  companysummary_open('24492'); return false;
# 1 업종 소프트웨어 개발 및 공급업 companysummary_open('24492'); return false;
# 2 주요제품 ERP Package, 유지 관리 등 companysummary_open('24492'); return false;
# 3 상장일 2020-08-12 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 권영범 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   한국파마  companysummary_open('24492'); return false;
# 1 업종 의약품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 완제의약품(정신신경계, 소화기계, 순환기계, 항생항균, 기타) companysummary_open('24492'); return false;
# 3 상장일 2020-08-10 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 박은희 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   제이알글로벌리츠  companysummary_open('24492'); return false;
# 1 업종 부동산 임대 및 공급업 companysummary_open('24492'); return false;
# 2 주요제품 벨기에 파이낸스 타워 companysummary_open('24492'); return false;
# 3 상장일 2020-08-07 companysummary_open('24492'); return false;
# 4 결산월 06월 companysummary_open('24492'); return false;
# 5 대표자명 오남수 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   솔브레인    companysummary_open('24492'); return false;
# 1 업종 기타 화학제품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 반도체 및 디스플레이 관련 화학재료 제조ㆍ판매 등 companysummary_open('24492'); return false;
# 3 상장일 2020-08-06 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 노환철 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   이루다  companysummary_open('24492'); return false;
# 1 업종 의료용 기기 제조업 companysummary_open('24492'); return false;
# 2 주요제품 레이저 및 고주파 의료기기 companysummary_open('24492'); return false;
# 3 상장일 2020-08-06 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 김용한 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   미래에셋맵스리츠  companysummary_open('24492'); return false;
# 1 업종 부동산 임대 및 공급업 companysummary_open('24492'); return false;
# 2 주요제품 부동산 임대업 companysummary_open('24492'); return false;
# 3 상장일 2020-08-05 companysummary_open('24492'); return false;
# 4 결산월 11월 companysummary_open('24492'); return false;
# 5 대표자명 정상구 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   이지스레지던스리츠  companysummary_open('24492'); return false;
# 1 업종 부동산 임대 및 공급업 companysummary_open('24492'); return false;
# 2 주요제품 부동산투자, 취득, 매매, 임대 companysummary_open('24492'); return false;
# 3 상장일 2020-08-05 companysummary_open('24492'); return false;
# 4 결산월 06월 companysummary_open('24492'); return false;
# 5 대표자명 이승환 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   와이팜  companysummary_open('24492'); return false;
# 1 업종 전자부품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 전력증폭기 모듈(PAM) companysummary_open('24492'); return false;
# 3 상장일 2020-07-31 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 유대규 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   에코앤드림   companysummary_open('24492'); return false;
# 1 업종 기타 화학제품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 배출가스 저감용 촉매 및 이차전지 양극활물질 전구체 companysummary_open('24492'); return false;
# 3 상장일 2020-07-30 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 김민용 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 충청북도 companysummary_open('24492'); return false;
# 0 회사명   엠투아이  companysummary_open('24492'); return false;
# 1 업종 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외 companysummary_open('24492'); return false;
# 2 주요제품 스마트HMI, 스마트SCADA, 스마트팩토리솔루션 companysummary_open('24492'); return false;
# 3 상장일 2020-07-29 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 강원희 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   더네이쳐홀딩스  companysummary_open('24492'); return false;
# 1 업종 의복 액세서리 제조업 companysummary_open('24492'); return false;
# 2 주요제품 의류, 여행용 가방 및 잡화류 companysummary_open('24492'); return false;
# 3 상장일 2020-07-27 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 박영준 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   제놀루션  companysummary_open('24492'); return false;
# 1 업종 기초 의약물질 제조업 companysummary_open('24492'); return false;
# 2 주요제품 핵산추출기기 및 시약, RNAi 사업 등 companysummary_open('24492'); return false;
# 3 상장일 2020-07-24 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 김기옥 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   솔트룩스  companysummary_open('24492'); return false;
# 1 업종 소프트웨어 개발 및 공급업 companysummary_open('24492'); return false;
# 2 주요제품 인공지능 및 빅데이터 소프트웨어 companysummary_open('24492'); return false;
# 3 상장일 2020-07-23 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 이경일 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   바이오인프라생명과학  companysummary_open('24492'); return false;
# 1 업종 자연과학 및 공학 연구개발업 companysummary_open('24492'); return false;
# 2 주요제품 I-FINDER(바이오마커 진단) companysummary_open('24492'); return false;
# 3 상장일 2020-07-22 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 이덕윤 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   티에스아이  companysummary_open('24492'); return false;
# 1 업종 특수 목적용 기계 제조업 companysummary_open('24492'); return false;
# 2 주요제품 2차전지 장비(믹싱시스템, 믹싱제작품, 믹싱 공사, 코터건조시스템) companysummary_open('24492'); return false;
# 3 상장일 2020-07-22 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 표인식 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   에이프로  companysummary_open('24492'); return false;
# 1 업종 기타 전기장비 제조업 companysummary_open('24492'); return false;
# 2 주요제품 2차전지 장비 등(일반충방전기, 고온가압 충방전기 등) companysummary_open('24492'); return false;
# 3 상장일 2020-07-16 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 임종현 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   이지스밸류플러스리츠  companysummary_open('24492'); return false;
# 1 업종 부동산 임대 및 공급업 companysummary_open('24492'); return false;
# 2 주요제품 부동산투자, 취득, 매매, 임대 companysummary_open('24492'); return false;
# 3 상장일 2020-07-16 companysummary_open('24492'); return false;
# 4 결산월 08월 companysummary_open('24492'); return false;
# 5 대표자명 도병운 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   소마젠  companysummary_open('24492'); return false;
# 1 업종 그외 기타 전문, 과학 및 기술 서비스업 companysummary_open('24492'); return false;
# 2 주요제품 유전체 분석 서비스 (NGS, CES 등) companysummary_open('24492'); return false;
# 3 상장일 2020-07-13 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 홍수 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 미국 companysummary_open('24492'); return false;
# 0 회사명   신도기연  companysummary_open('24492'); return false;
# 1 업종 특수 목적용 기계 제조업 companysummary_open('24492'); return false;
# 2 주요제품 OLED용 후공정장비(라미네이터, 오토클레이브 등) companysummary_open('24492'); return false;
# 3 상장일 2020-07-06 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 박웅기 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   위더스제약  companysummary_open('24492'); return false;
# 1 업종 의약품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 의약품 제조 및 도소매(순환기용제 등) companysummary_open('24492'); return false;
# 3 상장일 2020-07-03 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 성대영 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   에스케이바이오팜    companysummary_open('24492'); return false;
# 1 업종 자연과학 및 공학 연구개발업 companysummary_open('24492'); return false;
# 2 주요제품 신경질환 및 정신질환을 포함한 중추신경 관련 신약 개발 companysummary_open('24492'); return false;
# 3 상장일 2020-07-02 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 이동훈 companysummary_open('24492'); return false;
# 6 홈페이지
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   엠브레인  companysummary_open('24492'); return false;
# 1 업종 시장조사 및 여론조사업 companysummary_open('24492'); return false;
# 2 주요제품 온라인 및 오프라인 리서치 companysummary_open('24492'); return false;
# 3 상장일 2020-07-01 companysummary_open('24492'); return false;
# 4 결산월 06월 companysummary_open('24492'); return false;
# 5 대표자명 최인수 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   젠큐릭스  companysummary_open('24492'); return false;
# 1 업종 의료용품 및 기타 의약 관련제품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 유방암 예후진단 및 폐암/대장암 동반진단 제품/검사서비스 companysummary_open('24492'); return false;
# 3 상장일 2020-06-25 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 조상래 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   무진메디  companysummary_open('24492'); return false;
# 1 업종 자연과학 및 공학 연구개발업 companysummary_open('24492'); return false;
# 2 주요제품 NANO-MEDICINE 전문회사,LNP(지질나노입자)를 이용한 원료 소재 및 개량/신약 개발 companysummary_open('24492'); return false;
# 3 상장일 2020-06-24 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 윤태종 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   HB솔루션  companysummary_open('24492'); return false;
# 1 업종 특수 목적용 기계 제조업 companysummary_open('24492'); return false;
# 2 주요제품 디스플레이 제조용 장비(도포기, 조립기, 검사기) companysummary_open('24492'); return false;
# 3 상장일 2020-06-22 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 이재원 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 충청남도 companysummary_open('24492'); return false;
# 0 회사명   에스에이티이엔지  companysummary_open('24492'); return false;
# 1 업종 특수 목적용 기계 제조업 companysummary_open('24492'); return false;
# 2 주요제품 기업인수목적회사 companysummary_open('24492'); return false;
# 3 상장일 2020-06-22 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 소진석.. companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   에스씨엠생명과학  companysummary_open('24492'); return false;
# 1 업종 의약품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 세포치료제 companysummary_open('24492'); return false;
# 3 상장일 2020-06-17 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 - companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 인천광역시 companysummary_open('24492'); return false;
# 0 회사명   휴럼  companysummary_open('24492'); return false;
# 1 업종 기타 식품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 금융지원 서비스 companysummary_open('24492'); return false;
# 3 상장일 2020-06-17 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 김진석 companysummary_open('24492'); return false;
# 6 홈페이지
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   이지바이오  companysummary_open('24492'); return false;
# 1 업종 동물용 사료 및 조제식품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 자돈사료, 사료첨가제 companysummary_open('24492'); return false;
# 3 상장일 2020-06-05 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 황일환.. companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   드림씨아이에스  companysummary_open('24492'); return false;
# 1 업종 자연과학 및 공학 연구개발업 companysummary_open('24492'); return false;
# 2 주요제품 시판후조사대행(rPMS) companysummary_open('24492'); return false;
# 3 상장일 2020-05-22 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 유정희 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   대덕전자   companysummary_open('24492'); return false;
# 1 업종 전자부품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 PCB(Printed Circuit Board, 인쇄회로기판)의 제조 및 판매 companysummary_open('24492'); return false;
# 3 상장일 2020-05-21 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 신영환 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   HLB사이언스  companysummary_open('24492'); return false;
# 1 업종 의료용품 및 기타 의약 관련제품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 패혈증 치료제, 면역항암제 전달기술 등 companysummary_open('24492'); return false;
# 3 상장일 2020-04-24 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 윤종선 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   엔피디  companysummary_open('24492'); return false;
# 1 업종 전자부품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 스마트폰 OLED용 FPCA companysummary_open('24492'); return false;
# 3 상장일 2020-03-16 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 강명구 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   플레이디  companysummary_open('24492'); return false;
# 1 업종 광고업 companysummary_open('24492'); return false;
# 2 주요제품 온라인 광고 대행 companysummary_open('24492'); return false;
# 3 상장일 2020-03-12 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 이준용 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   서울바이오시스  companysummary_open('24492'); return false;
# 1 업종 반도체 제조업 companysummary_open('24492'); return false;
# 2 주요제품 Visible LED, UV LED companysummary_open('24492'); return false;
# 3 상장일 2020-03-06 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 이정훈.. companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   제이앤티씨    companysummary_open('24492'); return false;
# 1 업종 전자부품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 강화유리, 커넥터 companysummary_open('24492'); return false;
# 3 상장일 2020-03-04 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 조남혁.. companysummary_open('24492'); return false;
# 6 홈페이지
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   켄코아에어로스페이스  companysummary_open('24492'); return false;
# 1 업종 항공기,우주선 및 부품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 항공가공품 및 조립품 companysummary_open('24492'); return false;
# 3 상장일 2020-03-03 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 케네스.. companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경상남도 companysummary_open('24492'); return false;
# 0 회사명   레몬  companysummary_open('24492'); return false;
# 1 업종 화학섬유 제조업 companysummary_open('24492'); return false;
# 2 주요제품 EMI Shield Can, 나노멤브레인 등 companysummary_open('24492'); return false;
# 3 상장일 2020-02-28 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 김광진 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경상북도 companysummary_open('24492'); return false;
# 0 회사명   서남  companysummary_open('24492'); return false;
# 1 업종 기타 전기장비 제조업 companysummary_open('24492'); return false;
# 2 주요제품 고온초전도선재 companysummary_open('24492'); return false;
# 3 상장일 2020-02-20 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 문승현 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   위세아이텍  companysummary_open('24492'); return false;
# 1 업종 소프트웨어 개발 및 공급업 companysummary_open('24492'); return false;
# 2 주요제품 빅데이터분석, 인공지능, 데이터품질관리 솔루션 companysummary_open('24492'); return false;
# 3 상장일 2020-02-10 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 김다산.. companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   케이씨씨글라스  companysummary_open('24492'); return false;
# 1 업종 유리 및 유리제품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 판유리 등 companysummary_open('24492'); return false;
# 3 상장일 2020-01-21 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 정몽익.. companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   세림B&G  companysummary_open('24492'); return false;
# 1 업종 플라스틱제품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 기업인수 companysummary_open('24492'); return false;
# 3 상장일 2019-12-27 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 나상수 companysummary_open('24492'); return false;
# 6 홈페이지
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   이앤에치  companysummary_open('24492'); return false;
# 1 업종 기타 섬유제품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 미세먼지용 HEPA 소재, 차량용 캐빈필터소재, 마스크용 소재 companysummary_open('24492'); return false;
# 3 상장일 2019-12-27 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 김정운.. companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   CJ 바이오사이언스  companysummary_open('24492'); return false;
# 1 업종 자연과학 및 공학 연구개발업 companysummary_open('24492'); return false;
# 2 주요제품 생명정보 플랫폼, 마이크로바이옴 분석 서비스 companysummary_open('24492'); return false;
# 3 상장일 2019-12-26 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 천종식 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   엔에스엠  companysummary_open('24492'); return false;
# 1 업종 합성고무 및 플라스틱 물질 제조업 companysummary_open('24492'); return false;
# 2 주요제품 전도성 고분자 코팅 대전방지 필름 companysummary_open('24492'); return false;
# 3 상장일 2019-12-26 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 여건수 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   피피아이  companysummary_open('24492'); return false;
# 1 업종 통신 및 방송 장비 제조업 companysummary_open('24492'); return false;
# 2 주요제품 데이터센터용 AWG, 통신용 AWG, 스플리터, 계측기 등 companysummary_open('24492'); return false;
# 3 상장일 2019-12-26 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 김진봉 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 광주광역시 companysummary_open('24492'); return false;
# 0 회사명   RF머트리얼즈  companysummary_open('24492'); return false;
# 1 업종 전자부품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 광통신, RF통신용 패키지 companysummary_open('24492'); return false;
# 3 상장일 2019-12-24 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 남동우 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   아이비김영  companysummary_open('24492'); return false;
# 1 업종 일반 교습 학원 companysummary_open('24492'); return false;
# 2 주요제품 오프라인 학원, 온라인강의 companysummary_open('24492'); return false;
# 3 상장일 2019-12-24 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 김석철 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   브릿지바이오  companysummary_open('24492'); return false;
# 1 업종 기초 의약물질 제조업 companysummary_open('24492'); return false;
# 2 주요제품 펠리노-1 단백질 저해제, 오토택신 저해제 companysummary_open('24492'); return false;
# 3 상장일 2019-12-20 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 이정규 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   다보링크  companysummary_open('24492'); return false;
# 1 업종 통신 및 방송 장비 제조업 companysummary_open('24492'); return false;
# 2 주요제품 AP, APController 외 companysummary_open('24492'); return false;
# 3 상장일 2019-12-19 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 임상현 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   메드팩토  companysummary_open('24492'); return false;
# 1 업종 자연과학 및 공학 연구개발업 companysummary_open('24492'); return false;
# 2 주요제품 항암제 신약개발 companysummary_open('24492'); return false;
# 3 상장일 2019-12-19 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 김성진 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   원텍    companysummary_open('24492'); return false;
# 1 업종 의료용 기기 제조업 companysummary_open('24492'); return false;
# 2 주요제품 기업 인수 및 합병 companysummary_open('24492'); return false;
# 3 상장일 2019-12-19 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 김종원.. companysummary_open('24492'); return false;
# 6 홈페이지
#  companysummary_open('24492'); return false;
# 7 지역 대전광역시 companysummary_open('24492'); return false;
# 0 회사명   신테카바이오  companysummary_open('24492'); return false;
# 1 업종 소프트웨어 개발 및 공급업 companysummary_open('24492'); return false;
# 2 주요제품 유전체 빅데이터 기반의 AI신약개발 및 정밀의료서비스 companysummary_open('24492'); return false;
# 3 상장일 2019-12-17 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 정종선 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 대전광역시 companysummary_open('24492'); return false;
# 0 회사명   제이엘케이  companysummary_open('24492'); return false;
# 1 업종 소프트웨어 개발 및 공급업 companysummary_open('24492'); return false;
# 2 주요제품 인공지능 기반 의료영상 진단 플랫폼, 인공지능 기반 산업용 X-ray 판독시스템 companysummary_open('24492'); return false;
# 3 상장일 2019-12-11 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 김동민 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 충청북도 companysummary_open('24492'); return false;
# 0 회사명   태웅로직스  companysummary_open('24492'); return false;
# 1 업종 기타 운송관련 서비스업 companysummary_open('24492'); return false;
# 2 주요제품 3자물류주선 (복합운송, 프로젝트운송, CIS운송 등) companysummary_open('24492'); return false;
# 3 상장일 2019-12-10 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 한재동 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   윙스풋  companysummary_open('24492'); return false;
# 1 업종 섬유, 의복, 신발 및 가죽제품 소매업 companysummary_open('24492'); return false;
# 2 주요제품 신발 매입 및 공급 companysummary_open('24492'); return false;
# 3 상장일 2019-12-09 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 황성웅 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   노드메이슨  companysummary_open('24492'); return false;
# 1 업종 기타 화학제품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 헉슬리/Huxley 화장품(스킨케어 스페셜/스킨케어베이직) companysummary_open('24492'); return false;
# 3 상장일 2019-12-06 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 구자풍 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   리메드  companysummary_open('24492'); return false;
# 1 업종 의료용 기기 제조업 companysummary_open('24492'); return false;
# 2 주요제품 자기장 치료기기 companysummary_open('24492'); return false;
# 3 상장일 2019-12-06 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 이근용 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 대전광역시 companysummary_open('24492'); return false;
# 0 회사명   NH프라임리츠  companysummary_open('24492'); return false;
# 1 업종 부동산 임대 및 공급업 companysummary_open('24492'); return false;
# 2 주요제품 부동산 투자 companysummary_open('24492'); return false;
# 3 상장일 2019-12-05 companysummary_open('24492'); return false;
# 4 결산월 11월 companysummary_open('24492'); return false;
# 5 대표자명 소선호 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   비올  companysummary_open('24492'); return false;
# 1 업종 의료용 기기 제조업 companysummary_open('24492'); return false;
# 2 주요제품 의료기기 companysummary_open('24492'); return false;
# 3 상장일 2019-12-03 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 이상진 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   타스컴  companysummary_open('24492'); return false;
# 1 업종 의료용 기기 제조업 companysummary_open('24492'); return false;
# 2 주요제품 당뇨질환 세포치료제 / 당뇨관리 의료기기 companysummary_open('24492'); return false;
# 3 상장일 2019-12-02 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 이인근 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   진코스텍  companysummary_open('24492'); return false;
# 1 업종 기타 화학제품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 마스크팩 ODM/OEM, 하이드로겔 마스크팩 companysummary_open('24492'); return false;
# 3 상장일 2019-11-29 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 김임준 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   웨이버스  companysummary_open('24492'); return false;
# 1 업종 소프트웨어 개발 및 공급업 companysummary_open('24492'); return false;
# 2 주요제품 금융 지원 서비스 companysummary_open('24492'); return false;
# 3 상장일 2019-11-28 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 김학성 companysummary_open('24492'); return false;
# 6 홈페이지
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   유엑스엔  companysummary_open('24492'); return false;
# 1 업종 의료용 기기 제조업 companysummary_open('24492'); return false;
# 2 주요제품 혈당센서, 혈당측정기 companysummary_open('24492'); return false;
# 3 상장일 2019-11-28 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 박세진 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   HLB바이오스텝  companysummary_open('24492'); return false;
# 1 업종 자연과학 및 공학 연구개발업 companysummary_open('24492'); return false;
# 2 주요제품 비임상실험 유효성(약리)평가 companysummary_open('24492'); return false;
# 3 상장일 2019-11-27 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 문정환 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 인천광역시 companysummary_open('24492'); return false;
# 0 회사명   씨티알모빌리티  companysummary_open('24492'); return false;
# 1 업종 자동차 신품 부품 제조업 companysummary_open('24492'); return false;
# 2 주요제품 이너레이스, 오디 클러치보스, 로터샤프트, 슬리브기어, 컨트롤 암, 엑슬 companysummary_open('24492'); return false;
# 3 상장일 2019-11-25 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 이동옥.. companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 울산광역시 companysummary_open('24492'); return false;
# 0 회사명   티움바이오  companysummary_open('24492'); return false;
# 1 업종 자연과학 및 공학 연구개발업 companysummary_open('24492'); return false;
# 2 주요제품 특발성폐섬유증 치료제, 면역항암제, 자궁내막증치료제, 혈우병치료제 companysummary_open('24492'); return false;
# 3 상장일 2019-11-22 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 김훈택 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 경기도 companysummary_open('24492'); return false;
# 0 회사명   씨에스베어링  companysummary_open('24492'); return false;
# 1 업종 일반 목적용 기계 제조업 companysummary_open('24492'); return false;
# 2 주요제품 풍력용 선회베어링, 산업용 선회베어링 companysummary_open('24492'); return false;
# 3 상장일 2019-11-21 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 방성훈 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 서울특별시 companysummary_open('24492'); return false;
# 0 회사명   우양  companysummary_open('24492'); return false;
# 1 업종 과실, 채소 가공 및 저장 처리업 companysummary_open('24492'); return false;
# 2 주요제품 HMR, 음료 베이스, 퓨레 등 companysummary_open('24492'); return false;
# 3 상장일 2019-11-20 companysummary_open('24492'); return false;
# 4 결산월 12월 companysummary_open('24492'); return false;
# 5 대표자명 이구열 companysummary_open('24492'); return false;
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;
# 7 지역 충청남도 companysummary_open('24492'); return false;

# %%
soup.select('tr')[1].select_one('a')['onclick'].split("'")[1]
# Out:
# '24492'

# %%
for tr in soup.select('tr')[1:2]:
    for td in soup.select('td')[:1]:
        print(td.select_one('a')['onclick'].split("'")[1] + '0')
        #print(td)
# Out:
# 244920

# %%
result2 = {}
for tr in soup.select('tr'):
    for idx,(key, td) in enumerate(zip(keys, tr.select('td'))):
        code = soup.select_one('a')['onclick'].split("1")[0] + '0'
        print(idx, key, td.text, code)
        #print(result2.setdefault('종목코드', []).append(code + '0'))
# Out:
# 0 회사명   에이플러스에셋  companysummary_open('24492'); return false;0
# 1 업종 보험 및 연금관련 서비스업 companysummary_open('24492'); return false;0
# 2 주요제품 보험대리 및 중개업 companysummary_open('24492'); return false;0
# 3 상장일 2020-11-20 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 곽근호.. companysummary_open('24492'); return false;0
# 6 홈페이지
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   티앤엘  companysummary_open('24492'); return false;0
# 1 업종 의료용품 및 기타 의약 관련제품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 창상치료재, 정형외과용 고정재 companysummary_open('24492'); return false;0
# 3 상장일 2020-11-20 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 최윤소 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   고바이오랩  companysummary_open('24492'); return false;0
# 1 업종 자연과학 및 공학 연구개발업 companysummary_open('24492'); return false;0
# 2 주요제품 마이크로바이옴 치료제 및 건강기능식품 companysummary_open('24492'); return false;0
# 3 상장일 2020-11-18 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 고광표 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   네패스아크  companysummary_open('24492'); return false;0
# 1 업종 그외 기타 전문, 과학 및 기술 서비스업 companysummary_open('24492'); return false;0
# 2 주요제품 반도체 테스트 서비스 companysummary_open('24492'); return false;0
# 3 상장일 2020-11-17 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 이창우.. companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 충청북도 companysummary_open('24492'); return false;0
# 0 회사명   교촌에프앤비  companysummary_open('24492'); return false;0
# 1 업종 음·식료품 및 담배 도매업 companysummary_open('24492'); return false;0
# 2 주요제품 치킨 프랜차이즈 companysummary_open('24492'); return false;0
# 3 상장일 2020-11-12 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 송종화 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경상북도 companysummary_open('24492'); return false;0
# 0 회사명   소룩스  companysummary_open('24492'); return false;0
# 1 업종 전구 및 조명장치 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 실내등(형광등, LED등), 실외등, 특수등 companysummary_open('24492'); return false;0
# 3 상장일 2020-11-06 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 정재준 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 충청남도 companysummary_open('24492'); return false;0
# 0 회사명   위드텍  companysummary_open('24492'); return false;0
# 1 업종 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외 companysummary_open('24492'); return false;0
# 2 주요제품 AMCs 모니터링 시스템, 공정 프로세스 모니터링 시스템, TMS companysummary_open('24492'); return false;0
# 3 상장일 2020-10-30 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 유승교.. companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 대전광역시 companysummary_open('24492'); return false;0
# 0 회사명   센코  companysummary_open('24492'); return false;0
# 1 업종 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외 companysummary_open('24492'); return false;0
# 2 주요제품 가스센서 및 모듈, 휴대용 및 고정형 가스검지기, 악취 & 미세먼지 모니터링 시스템 companysummary_open('24492'); return false;0
# 3 상장일 2020-10-29 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 하승철 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   바이브컴퍼니  companysummary_open('24492'); return false;0
# 1 업종 소프트웨어 개발 및 공급업 companysummary_open('24492'); return false;0
# 2 주요제품 소셜 빅데이터 기반 인공지능 서비스 (소셜메트릭스), 문제 해결 솔루션 (AI Solver) companysummary_open('24492'); return false;0
# 3 상장일 2020-10-28 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 김성언 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   원포유  companysummary_open('24492'); return false;0
# 1 업종 소프트웨어 개발 및 공급업 companysummary_open('24492'); return false;0
# 2 주요제품 비대면서비스플랫폼, 인공지능 companysummary_open('24492'); return false;0
# 3 상장일 2020-10-23 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 전동호 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   미코바이오메드  companysummary_open('24492'); return false;0
# 1 업종 의료용 기기 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 체외진단용 의료기기 companysummary_open('24492'); return false;0
# 3 상장일 2020-10-22 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 홍영석 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   피플바이오  companysummary_open('24492'); return false;0
# 1 업종 의료용품 및 기타 의약 관련제품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 올리고머화 베타-아밀로이드 검사제품(알츠하이머병 진단) companysummary_open('24492'); return false;0
# 3 상장일 2020-10-19 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 강성민 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   하이브    companysummary_open('24492'); return false;0
# 1 업종 오디오물 출판 및 원판 녹음업 companysummary_open('24492'); return false;0
# 2 주요제품 음악 기획/제작, 퍼블리싱, 아티스트 매니지먼트 companysummary_open('24492'); return false;0
# 3 상장일 2020-10-15 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 박지원 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   넥스틴    companysummary_open('24492'); return false;0
# 1 업종 특수 목적용 기계 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 반도체 전공정용 패턴결함 검사장비(AEGIS 등) companysummary_open('24492'); return false;0
# 3 상장일 2020-10-08 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 박태훈 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   케이엔솔  companysummary_open('24492'); return false;0
# 1 업종 일반 목적용 기계 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 클린룸 설비 companysummary_open('24492'); return false;0
# 3 상장일 2020-09-24 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 구자겸.. companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 충청북도 companysummary_open('24492'); return false;0
# 0 회사명   비나텍  companysummary_open('24492'); return false;0
# 1 업종 일차전지 및 이차전지 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 초고용량 커패시터(슈퍼커패시터) companysummary_open('24492'); return false;0
# 3 상장일 2020-09-23 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 성도경 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 전북특별자치도 companysummary_open('24492'); return false;0
# 0 회사명   씨엔알리서치  companysummary_open('24492'); return false;0
# 1 업종 그외 기타 전문, 과학 및 기술 서비스업 companysummary_open('24492'); return false;0
# 2 주요제품 금융 지원 서비스 companysummary_open('24492'); return false;0
# 3 상장일 2020-09-23 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 윤문태 companysummary_open('24492'); return false;0
# 6 홈페이지
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   박셀바이오   companysummary_open('24492'); return false;0
# 1 업종 자연과학 및 공학 연구개발업 companysummary_open('24492'); return false;0
# 2 주요제품 항암면역세포치료제(자연살해세포, 수지상세포, CAR-T 및 인터루킨 기반 항암제) companysummary_open('24492'); return false;0
# 3 상장일 2020-09-22 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 이제중.. companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 전라남도 companysummary_open('24492'); return false;0
# 0 회사명   티와이홀딩스   companysummary_open('24492'); return false;0
# 1 업종 기타 금융업 companysummary_open('24492'); return false;0
# 2 주요제품 지주사업 companysummary_open('24492'); return false;0
# 3 상장일 2020-09-22 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 유종연 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   비비씨  companysummary_open('24492'); return false;0
# 1 업종 기타 화학제품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 덴탈 케어용 소재(테이퍼모 등) companysummary_open('24492'); return false;0
# 3 상장일 2020-09-21 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 강기태 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 대전광역시 companysummary_open('24492'); return false;0
# 0 회사명   코스텍시스  companysummary_open('24492'); return false;0
# 1 업종 반도체 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 RF PKG. Spacer companysummary_open('24492'); return false;0
# 3 상장일 2020-09-18 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 한규진 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 인천광역시 companysummary_open('24492'); return false;0
# 0 회사명   핌스  companysummary_open('24492'); return false;0
# 1 업종 전자부품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 OLED Metal Mask companysummary_open('24492'); return false;0
# 3 상장일 2020-09-18 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 김민용 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 인천광역시 companysummary_open('24492'); return false;0
# 0 회사명   압타머사이언스  companysummary_open('24492'); return false;0
# 1 업종 자연과학 및 공학 연구개발업 companysummary_open('24492'); return false;0
# 2 주요제품 압타머기반 신약개발 및 진단제품 개발 companysummary_open('24492'); return false;0
# 3 상장일 2020-09-16 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 한동일 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   이오플로우  companysummary_open('24492'); return false;0
# 1 업종 의료용 기기 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 웨어러블 인슐린펌프 companysummary_open('24492'); return false;0
# 3 상장일 2020-09-14 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 김재진 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   카카오게임즈    companysummary_open('24492'); return false;0
# 1 업종 소프트웨어 개발 및 공급업 companysummary_open('24492'); return false;0
# 2 주요제품 모바일, PC게임 퍼블리싱 companysummary_open('24492'); return false;0
# 3 상장일 2020-09-10 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 San.. companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   피엔케이피부임상연구센타  companysummary_open('24492'); return false;0
# 1 업종 그외 기타 전문, 과학 및 기술 서비스업 companysummary_open('24492'); return false;0
# 2 주요제품 피부인체적용시험 companysummary_open('24492'); return false;0
# 3 상장일 2020-09-09 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 박진오.. companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   코람코라이프인프라리츠  companysummary_open('24492'); return false;0
# 1 업종 부동산 임대 및 공급업 companysummary_open('24492'); return false;0
# 2 주요제품 부동산 투자 및 관리 companysummary_open('24492'); return false;0
# 3 상장일 2020-08-31 companysummary_open('24492'); return false;0
# 4 결산월 11월 companysummary_open('24492'); return false;0
# 5 대표자명 이성균 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   아이디피  companysummary_open('24492'); return false;0
# 1 업종 컴퓨터 및 주변장치 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 카드인쇄용 프린터, 카드인쇄용 리본 companysummary_open('24492'); return false;0
# 3 상장일 2020-08-24 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 노현철 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   셀레믹스  companysummary_open('24492'); return false;0
# 1 업종 기초 의약물질 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 타겟캡처키트 companysummary_open('24492'); return false;0
# 3 상장일 2020-08-21 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 김효기.. companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   고스트스튜디오  companysummary_open('24492'); return false;0
# 1 업종 소프트웨어 개발 및 공급업 companysummary_open('24492'); return false;0
# 2 주요제품 캐주얼게임, 소셜카지노게임 companysummary_open('24492'); return false;0
# 3 상장일 2020-08-18 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 손창욱.. companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 홍콩 companysummary_open('24492'); return false;0
# 0 회사명   브랜드엑스코퍼레이션  companysummary_open('24492'); return false;0
# 1 업종 기타 정보 서비스업 companysummary_open('24492'); return false;0
# 2 주요제품 애슬레저의류, 생활/청결 용품 companysummary_open('24492'); return false;0
# 3 상장일 2020-08-13 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 강민준.. companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   영림원소프트랩  companysummary_open('24492'); return false;0
# 1 업종 소프트웨어 개발 및 공급업 companysummary_open('24492'); return false;0
# 2 주요제품 ERP Package, 유지 관리 등 companysummary_open('24492'); return false;0
# 3 상장일 2020-08-12 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 권영범 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   한국파마  companysummary_open('24492'); return false;0
# 1 업종 의약품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 완제의약품(정신신경계, 소화기계, 순환기계, 항생항균, 기타) companysummary_open('24492'); return false;0
# 3 상장일 2020-08-10 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 박은희 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   제이알글로벌리츠  companysummary_open('24492'); return false;0
# 1 업종 부동산 임대 및 공급업 companysummary_open('24492'); return false;0
# 2 주요제품 벨기에 파이낸스 타워 companysummary_open('24492'); return false;0
# 3 상장일 2020-08-07 companysummary_open('24492'); return false;0
# 4 결산월 06월 companysummary_open('24492'); return false;0
# 5 대표자명 오남수 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   솔브레인    companysummary_open('24492'); return false;0
# 1 업종 기타 화학제품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 반도체 및 디스플레이 관련 화학재료 제조ㆍ판매 등 companysummary_open('24492'); return false;0
# 3 상장일 2020-08-06 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 노환철 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   이루다  companysummary_open('24492'); return false;0
# 1 업종 의료용 기기 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 레이저 및 고주파 의료기기 companysummary_open('24492'); return false;0
# 3 상장일 2020-08-06 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 김용한 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   미래에셋맵스리츠  companysummary_open('24492'); return false;0
# 1 업종 부동산 임대 및 공급업 companysummary_open('24492'); return false;0
# 2 주요제품 부동산 임대업 companysummary_open('24492'); return false;0
# 3 상장일 2020-08-05 companysummary_open('24492'); return false;0
# 4 결산월 11월 companysummary_open('24492'); return false;0
# 5 대표자명 정상구 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   이지스레지던스리츠  companysummary_open('24492'); return false;0
# 1 업종 부동산 임대 및 공급업 companysummary_open('24492'); return false;0
# 2 주요제품 부동산투자, 취득, 매매, 임대 companysummary_open('24492'); return false;0
# 3 상장일 2020-08-05 companysummary_open('24492'); return false;0
# 4 결산월 06월 companysummary_open('24492'); return false;0
# 5 대표자명 이승환 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   와이팜  companysummary_open('24492'); return false;0
# 1 업종 전자부품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 전력증폭기 모듈(PAM) companysummary_open('24492'); return false;0
# 3 상장일 2020-07-31 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 유대규 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   에코앤드림   companysummary_open('24492'); return false;0
# 1 업종 기타 화학제품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 배출가스 저감용 촉매 및 이차전지 양극활물질 전구체 companysummary_open('24492'); return false;0
# 3 상장일 2020-07-30 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 김민용 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 충청북도 companysummary_open('24492'); return false;0
# 0 회사명   엠투아이  companysummary_open('24492'); return false;0
# 1 업종 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외 companysummary_open('24492'); return false;0
# 2 주요제품 스마트HMI, 스마트SCADA, 스마트팩토리솔루션 companysummary_open('24492'); return false;0
# 3 상장일 2020-07-29 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 강원희 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   더네이쳐홀딩스  companysummary_open('24492'); return false;0
# 1 업종 의복 액세서리 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 의류, 여행용 가방 및 잡화류 companysummary_open('24492'); return false;0
# 3 상장일 2020-07-27 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 박영준 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   제놀루션  companysummary_open('24492'); return false;0
# 1 업종 기초 의약물질 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 핵산추출기기 및 시약, RNAi 사업 등 companysummary_open('24492'); return false;0
# 3 상장일 2020-07-24 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 김기옥 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   솔트룩스  companysummary_open('24492'); return false;0
# 1 업종 소프트웨어 개발 및 공급업 companysummary_open('24492'); return false;0
# 2 주요제품 인공지능 및 빅데이터 소프트웨어 companysummary_open('24492'); return false;0
# 3 상장일 2020-07-23 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 이경일 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   바이오인프라생명과학  companysummary_open('24492'); return false;0
# 1 업종 자연과학 및 공학 연구개발업 companysummary_open('24492'); return false;0
# 2 주요제품 I-FINDER(바이오마커 진단) companysummary_open('24492'); return false;0
# 3 상장일 2020-07-22 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 이덕윤 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   티에스아이  companysummary_open('24492'); return false;0
# 1 업종 특수 목적용 기계 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 2차전지 장비(믹싱시스템, 믹싱제작품, 믹싱 공사, 코터건조시스템) companysummary_open('24492'); return false;0
# 3 상장일 2020-07-22 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 표인식 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   에이프로  companysummary_open('24492'); return false;0
# 1 업종 기타 전기장비 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 2차전지 장비 등(일반충방전기, 고온가압 충방전기 등) companysummary_open('24492'); return false;0
# 3 상장일 2020-07-16 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 임종현 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   이지스밸류플러스리츠  companysummary_open('24492'); return false;0
# 1 업종 부동산 임대 및 공급업 companysummary_open('24492'); return false;0
# 2 주요제품 부동산투자, 취득, 매매, 임대 companysummary_open('24492'); return false;0
# 3 상장일 2020-07-16 companysummary_open('24492'); return false;0
# 4 결산월 08월 companysummary_open('24492'); return false;0
# 5 대표자명 도병운 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   소마젠  companysummary_open('24492'); return false;0
# 1 업종 그외 기타 전문, 과학 및 기술 서비스업 companysummary_open('24492'); return false;0
# 2 주요제품 유전체 분석 서비스 (NGS, CES 등) companysummary_open('24492'); return false;0
# 3 상장일 2020-07-13 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 홍수 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 미국 companysummary_open('24492'); return false;0
# 0 회사명   신도기연  companysummary_open('24492'); return false;0
# 1 업종 특수 목적용 기계 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 OLED용 후공정장비(라미네이터, 오토클레이브 등) companysummary_open('24492'); return false;0
# 3 상장일 2020-07-06 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 박웅기 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   위더스제약  companysummary_open('24492'); return false;0
# 1 업종 의약품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 의약품 제조 및 도소매(순환기용제 등) companysummary_open('24492'); return false;0
# 3 상장일 2020-07-03 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 성대영 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   에스케이바이오팜    companysummary_open('24492'); return false;0
# 1 업종 자연과학 및 공학 연구개발업 companysummary_open('24492'); return false;0
# 2 주요제품 신경질환 및 정신질환을 포함한 중추신경 관련 신약 개발 companysummary_open('24492'); return false;0
# 3 상장일 2020-07-02 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 이동훈 companysummary_open('24492'); return false;0
# 6 홈페이지
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   엠브레인  companysummary_open('24492'); return false;0
# 1 업종 시장조사 및 여론조사업 companysummary_open('24492'); return false;0
# 2 주요제품 온라인 및 오프라인 리서치 companysummary_open('24492'); return false;0
# 3 상장일 2020-07-01 companysummary_open('24492'); return false;0
# 4 결산월 06월 companysummary_open('24492'); return false;0
# 5 대표자명 최인수 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   젠큐릭스  companysummary_open('24492'); return false;0
# 1 업종 의료용품 및 기타 의약 관련제품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 유방암 예후진단 및 폐암/대장암 동반진단 제품/검사서비스 companysummary_open('24492'); return false;0
# 3 상장일 2020-06-25 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 조상래 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   무진메디  companysummary_open('24492'); return false;0
# 1 업종 자연과학 및 공학 연구개발업 companysummary_open('24492'); return false;0
# 2 주요제품 NANO-MEDICINE 전문회사,LNP(지질나노입자)를 이용한 원료 소재 및 개량/신약 개발 companysummary_open('24492'); return false;0
# 3 상장일 2020-06-24 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 윤태종 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   HB솔루션  companysummary_open('24492'); return false;0
# 1 업종 특수 목적용 기계 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 디스플레이 제조용 장비(도포기, 조립기, 검사기) companysummary_open('24492'); return false;0
# 3 상장일 2020-06-22 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 이재원 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 충청남도 companysummary_open('24492'); return false;0
# 0 회사명   에스에이티이엔지  companysummary_open('24492'); return false;0
# 1 업종 특수 목적용 기계 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 기업인수목적회사 companysummary_open('24492'); return false;0
# 3 상장일 2020-06-22 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 소진석.. companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   에스씨엠생명과학  companysummary_open('24492'); return false;0
# 1 업종 의약품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 세포치료제 companysummary_open('24492'); return false;0
# 3 상장일 2020-06-17 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 - companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 인천광역시 companysummary_open('24492'); return false;0
# 0 회사명   휴럼  companysummary_open('24492'); return false;0
# 1 업종 기타 식품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 금융지원 서비스 companysummary_open('24492'); return false;0
# 3 상장일 2020-06-17 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 김진석 companysummary_open('24492'); return false;0
# 6 홈페이지
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   이지바이오  companysummary_open('24492'); return false;0
# 1 업종 동물용 사료 및 조제식품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 자돈사료, 사료첨가제 companysummary_open('24492'); return false;0
# 3 상장일 2020-06-05 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 황일환.. companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   드림씨아이에스  companysummary_open('24492'); return false;0
# 1 업종 자연과학 및 공학 연구개발업 companysummary_open('24492'); return false;0
# 2 주요제품 시판후조사대행(rPMS) companysummary_open('24492'); return false;0
# 3 상장일 2020-05-22 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 유정희 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   대덕전자   companysummary_open('24492'); return false;0
# 1 업종 전자부품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 PCB(Printed Circuit Board, 인쇄회로기판)의 제조 및 판매 companysummary_open('24492'); return false;0
# 3 상장일 2020-05-21 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 신영환 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   HLB사이언스  companysummary_open('24492'); return false;0
# 1 업종 의료용품 및 기타 의약 관련제품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 패혈증 치료제, 면역항암제 전달기술 등 companysummary_open('24492'); return false;0
# 3 상장일 2020-04-24 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 윤종선 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   엔피디  companysummary_open('24492'); return false;0
# 1 업종 전자부품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 스마트폰 OLED용 FPCA companysummary_open('24492'); return false;0
# 3 상장일 2020-03-16 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 강명구 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   플레이디  companysummary_open('24492'); return false;0
# 1 업종 광고업 companysummary_open('24492'); return false;0
# 2 주요제품 온라인 광고 대행 companysummary_open('24492'); return false;0
# 3 상장일 2020-03-12 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 이준용 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   서울바이오시스  companysummary_open('24492'); return false;0
# 1 업종 반도체 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 Visible LED, UV LED companysummary_open('24492'); return false;0
# 3 상장일 2020-03-06 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 이정훈.. companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   제이앤티씨    companysummary_open('24492'); return false;0
# 1 업종 전자부품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 강화유리, 커넥터 companysummary_open('24492'); return false;0
# 3 상장일 2020-03-04 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 조남혁.. companysummary_open('24492'); return false;0
# 6 홈페이지
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   켄코아에어로스페이스  companysummary_open('24492'); return false;0
# 1 업종 항공기,우주선 및 부품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 항공가공품 및 조립품 companysummary_open('24492'); return false;0
# 3 상장일 2020-03-03 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 케네스.. companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경상남도 companysummary_open('24492'); return false;0
# 0 회사명   레몬  companysummary_open('24492'); return false;0
# 1 업종 화학섬유 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 EMI Shield Can, 나노멤브레인 등 companysummary_open('24492'); return false;0
# 3 상장일 2020-02-28 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 김광진 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경상북도 companysummary_open('24492'); return false;0
# 0 회사명   서남  companysummary_open('24492'); return false;0
# 1 업종 기타 전기장비 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 고온초전도선재 companysummary_open('24492'); return false;0
# 3 상장일 2020-02-20 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 문승현 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   위세아이텍  companysummary_open('24492'); return false;0
# 1 업종 소프트웨어 개발 및 공급업 companysummary_open('24492'); return false;0
# 2 주요제품 빅데이터분석, 인공지능, 데이터품질관리 솔루션 companysummary_open('24492'); return false;0
# 3 상장일 2020-02-10 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 김다산.. companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   케이씨씨글라스  companysummary_open('24492'); return false;0
# 1 업종 유리 및 유리제품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 판유리 등 companysummary_open('24492'); return false;0
# 3 상장일 2020-01-21 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 정몽익.. companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   세림B&G  companysummary_open('24492'); return false;0
# 1 업종 플라스틱제품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 기업인수 companysummary_open('24492'); return false;0
# 3 상장일 2019-12-27 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 나상수 companysummary_open('24492'); return false;0
# 6 홈페이지
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   이앤에치  companysummary_open('24492'); return false;0
# 1 업종 기타 섬유제품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 미세먼지용 HEPA 소재, 차량용 캐빈필터소재, 마스크용 소재 companysummary_open('24492'); return false;0
# 3 상장일 2019-12-27 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 김정운.. companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   CJ 바이오사이언스  companysummary_open('24492'); return false;0
# 1 업종 자연과학 및 공학 연구개발업 companysummary_open('24492'); return false;0
# 2 주요제품 생명정보 플랫폼, 마이크로바이옴 분석 서비스 companysummary_open('24492'); return false;0
# 3 상장일 2019-12-26 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 천종식 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   엔에스엠  companysummary_open('24492'); return false;0
# 1 업종 합성고무 및 플라스틱 물질 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 전도성 고분자 코팅 대전방지 필름 companysummary_open('24492'); return false;0
# 3 상장일 2019-12-26 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 여건수 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   피피아이  companysummary_open('24492'); return false;0
# 1 업종 통신 및 방송 장비 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 데이터센터용 AWG, 통신용 AWG, 스플리터, 계측기 등 companysummary_open('24492'); return false;0
# 3 상장일 2019-12-26 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 김진봉 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 광주광역시 companysummary_open('24492'); return false;0
# 0 회사명   RF머트리얼즈  companysummary_open('24492'); return false;0
# 1 업종 전자부품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 광통신, RF통신용 패키지 companysummary_open('24492'); return false;0
# 3 상장일 2019-12-24 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 남동우 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   아이비김영  companysummary_open('24492'); return false;0
# 1 업종 일반 교습 학원 companysummary_open('24492'); return false;0
# 2 주요제품 오프라인 학원, 온라인강의 companysummary_open('24492'); return false;0
# 3 상장일 2019-12-24 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 김석철 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   브릿지바이오  companysummary_open('24492'); return false;0
# 1 업종 기초 의약물질 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 펠리노-1 단백질 저해제, 오토택신 저해제 companysummary_open('24492'); return false;0
# 3 상장일 2019-12-20 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 이정규 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   다보링크  companysummary_open('24492'); return false;0
# 1 업종 통신 및 방송 장비 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 AP, APController 외 companysummary_open('24492'); return false;0
# 3 상장일 2019-12-19 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 임상현 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   메드팩토  companysummary_open('24492'); return false;0
# 1 업종 자연과학 및 공학 연구개발업 companysummary_open('24492'); return false;0
# 2 주요제품 항암제 신약개발 companysummary_open('24492'); return false;0
# 3 상장일 2019-12-19 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 김성진 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   원텍    companysummary_open('24492'); return false;0
# 1 업종 의료용 기기 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 기업 인수 및 합병 companysummary_open('24492'); return false;0
# 3 상장일 2019-12-19 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 김종원.. companysummary_open('24492'); return false;0
# 6 홈페이지
#  companysummary_open('24492'); return false;0
# 7 지역 대전광역시 companysummary_open('24492'); return false;0
# 0 회사명   신테카바이오  companysummary_open('24492'); return false;0
# 1 업종 소프트웨어 개발 및 공급업 companysummary_open('24492'); return false;0
# 2 주요제품 유전체 빅데이터 기반의 AI신약개발 및 정밀의료서비스 companysummary_open('24492'); return false;0
# 3 상장일 2019-12-17 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 정종선 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 대전광역시 companysummary_open('24492'); return false;0
# 0 회사명   제이엘케이  companysummary_open('24492'); return false;0
# 1 업종 소프트웨어 개발 및 공급업 companysummary_open('24492'); return false;0
# 2 주요제품 인공지능 기반 의료영상 진단 플랫폼, 인공지능 기반 산업용 X-ray 판독시스템 companysummary_open('24492'); return false;0
# 3 상장일 2019-12-11 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 김동민 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 충청북도 companysummary_open('24492'); return false;0
# 0 회사명   태웅로직스  companysummary_open('24492'); return false;0
# 1 업종 기타 운송관련 서비스업 companysummary_open('24492'); return false;0
# 2 주요제품 3자물류주선 (복합운송, 프로젝트운송, CIS운송 등) companysummary_open('24492'); return false;0
# 3 상장일 2019-12-10 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 한재동 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   윙스풋  companysummary_open('24492'); return false;0
# 1 업종 섬유, 의복, 신발 및 가죽제품 소매업 companysummary_open('24492'); return false;0
# 2 주요제품 신발 매입 및 공급 companysummary_open('24492'); return false;0
# 3 상장일 2019-12-09 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 황성웅 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   노드메이슨  companysummary_open('24492'); return false;0
# 1 업종 기타 화학제품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 헉슬리/Huxley 화장품(스킨케어 스페셜/스킨케어베이직) companysummary_open('24492'); return false;0
# 3 상장일 2019-12-06 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 구자풍 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   리메드  companysummary_open('24492'); return false;0
# 1 업종 의료용 기기 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 자기장 치료기기 companysummary_open('24492'); return false;0
# 3 상장일 2019-12-06 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 이근용 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 대전광역시 companysummary_open('24492'); return false;0
# 0 회사명   NH프라임리츠  companysummary_open('24492'); return false;0
# 1 업종 부동산 임대 및 공급업 companysummary_open('24492'); return false;0
# 2 주요제품 부동산 투자 companysummary_open('24492'); return false;0
# 3 상장일 2019-12-05 companysummary_open('24492'); return false;0
# 4 결산월 11월 companysummary_open('24492'); return false;0
# 5 대표자명 소선호 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   비올  companysummary_open('24492'); return false;0
# 1 업종 의료용 기기 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 의료기기 companysummary_open('24492'); return false;0
# 3 상장일 2019-12-03 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 이상진 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   타스컴  companysummary_open('24492'); return false;0
# 1 업종 의료용 기기 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 당뇨질환 세포치료제 / 당뇨관리 의료기기 companysummary_open('24492'); return false;0
# 3 상장일 2019-12-02 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 이인근 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   진코스텍  companysummary_open('24492'); return false;0
# 1 업종 기타 화학제품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 마스크팩 ODM/OEM, 하이드로겔 마스크팩 companysummary_open('24492'); return false;0
# 3 상장일 2019-11-29 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 김임준 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   웨이버스  companysummary_open('24492'); return false;0
# 1 업종 소프트웨어 개발 및 공급업 companysummary_open('24492'); return false;0
# 2 주요제품 금융 지원 서비스 companysummary_open('24492'); return false;0
# 3 상장일 2019-11-28 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 김학성 companysummary_open('24492'); return false;0
# 6 홈페이지
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   유엑스엔  companysummary_open('24492'); return false;0
# 1 업종 의료용 기기 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 혈당센서, 혈당측정기 companysummary_open('24492'); return false;0
# 3 상장일 2019-11-28 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 박세진 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   HLB바이오스텝  companysummary_open('24492'); return false;0
# 1 업종 자연과학 및 공학 연구개발업 companysummary_open('24492'); return false;0
# 2 주요제품 비임상실험 유효성(약리)평가 companysummary_open('24492'); return false;0
# 3 상장일 2019-11-27 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 문정환 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 인천광역시 companysummary_open('24492'); return false;0
# 0 회사명   씨티알모빌리티  companysummary_open('24492'); return false;0
# 1 업종 자동차 신품 부품 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 이너레이스, 오디 클러치보스, 로터샤프트, 슬리브기어, 컨트롤 암, 엑슬 companysummary_open('24492'); return false;0
# 3 상장일 2019-11-25 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 이동옥.. companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 울산광역시 companysummary_open('24492'); return false;0
# 0 회사명   티움바이오  companysummary_open('24492'); return false;0
# 1 업종 자연과학 및 공학 연구개발업 companysummary_open('24492'); return false;0
# 2 주요제품 특발성폐섬유증 치료제, 면역항암제, 자궁내막증치료제, 혈우병치료제 companysummary_open('24492'); return false;0
# 3 상장일 2019-11-22 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 김훈택 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 경기도 companysummary_open('24492'); return false;0
# 0 회사명   씨에스베어링  companysummary_open('24492'); return false;0
# 1 업종 일반 목적용 기계 제조업 companysummary_open('24492'); return false;0
# 2 주요제품 풍력용 선회베어링, 산업용 선회베어링 companysummary_open('24492'); return false;0
# 3 상장일 2019-11-21 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 방성훈 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 서울특별시 companysummary_open('24492'); return false;0
# 0 회사명   우양  companysummary_open('24492'); return false;0
# 1 업종 과실, 채소 가공 및 저장 처리업 companysummary_open('24492'); return false;0
# 2 주요제품 HMR, 음료 베이스, 퓨레 등 companysummary_open('24492'); return false;0
# 3 상장일 2019-11-20 companysummary_open('24492'); return false;0
# 4 결산월 12월 companysummary_open('24492'); return false;0
# 5 대표자명 이구열 companysummary_open('24492'); return false;0
# 6 홈페이지
# 홈페이지 보기
#  companysummary_open('24492'); return false;0
# 7 지역 충청남도 companysummary_open('24492'); return false;0

# %%
page = 1
page_size = 100
final_result_df = pd.DataFrame()
while True:
    url = "https://kind.krx.co.kr/corpgeneral/corpList.do"
    payload = dict(method='searchCorpList',pageIndex=page, currentPageSize=page_size,orderMode=3,orderStat='D',searchType=13, fiscalYearEnd='all', location='all')
    r = requests.get(url, params=payload)
    print(r.status_code, end="\r")
    soup = bs(r.text, 'lxml')
    
    total_items = int(soup.select_one(".info.type-00 > em").text.replace(",", ""))
    total_pages = total_items // page_size + 1
    
    print(f"{page}/{total_pages} 수집중", end="\r")
    keys = soup.select_one("table.list.type-00.tmt30")['summary'].split(", ") 
    
    result = {}
    for tr in soup.select('tr'):
        for idx, (key, td) in enumerate(zip(keys, tr.select('td'))):
            if idx == 0:
                kinds = [img['alt'].strip() for img in td.select('img')]   # 1번째 증권 종류, 회사이름
                kind = ", ".join(kinds)
                code = td.select_one("a")['onclick'].split("'")[1] # 종목코드 추출
                result.setdefault('증권종류', []).append(kind)
                result.setdefault(key, []).append(td.text)
                result.setdefault('종목코드', []).append(code+"0") # 종목코드 추가
            elif idx == 6:
                home_link = td.select_one('a')['href'] if td.string == None else ""  # 6번째 링크 찾기
                result.setdefault(key, []).append(home_link)
            else:
                result.setdefault(key, []).append(td.text)
    result_df = pd.DataFrame(result)
    final_result_df = pd.concat([final_result_df, result_df])
        
    if page < total_pages:
        page += 1
        time.sleep(5)
    else:
        break

display(final_result_df)
final_result_df.to_csv(f"상장기업정보_{today}기준.csv", encoding='utf-8', index=False)  # 수집일 기준으로 csv 파일로 저장
# Out:
# 28/28 수집중
#                               증권종류            회사명    종목코드  \
# 0                             유가증권          산일전기   062040
# 1                             유가증권       에이치에스효성   487570
# 2                      코스닥, 투자주의종목    엔에이치스팩31호    481890
# 3                              코스닥    SK증권제13호스팩   473950
# 4                              코스닥       엑셀세라퓨틱스   373110
# ..                             ...            ...     ...
# 0   유가증권, KTOP30, KOSPI200, KRX300       유한양행      000100
# 1           유가증권, KOSPI200, KRX300      CJ대한통운     000120
# 2                             유가증권            경방   000050
# 3                             유가증권         유수홀딩스   000700
# 4                             유가증권      한진중공업홀딩스   003480
#
#                                    업종  \
# 0   전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 1                              기타 금융업
# 2                          금융 지원 서비스업
# 3                          금융 지원 서비스업
# 4                         기초 의약물질 제조업
# ..                                ...
# 0                             의약품 제조업
# 1                           도로 화물 운송업
# 2                              종합 소매업
# 3                 회사 본부 및 경영 컨설팅 서비스업
# 4                   연료용 가스 제조 및 배관공급업
#
#                                                  주요제품         상장일  결산월   대표자명  \
# 0                                유입, 몰드, 주상, 건식 변압기 등  2024-07-29  12월    박동석
# 1                                                지주사업  2024-07-29  12월  조현상..
# 2                                            금융지원서비스업  2024-07-26  12월    이시형
# 3                                         기업인수목적 주식회사  2024-07-25  12월    임율표
# 4                              CellCor SFD/CD(세포배양배지)  2024-07-15  12월    이의일
# ..                                                ...         ...  ...    ...
# 0   의약품(삐콤씨, 안티푸라민, 렉라자, 로수바미브, 코푸시럽 등), 생활용품(유한락스...  1962-11-01  12월  대표이..
# 1   Contract Logistics, 포워딩, 항만하역, 해운, 택배국제특송, SCM...  1956-07-02  12월  신영수..
# 2           섬유류(면사,면혼방사,면직물,면혼방직물,화섬사,화섬직물) 제조,도매,수출입  1956-03-03  12월  김준,..
# 3                                                지주사업  1956-03-03  12월    송영규
# 4                                                지주회사  1956-03-03  12월  조남호..
#
#                             홈페이지     지역
# 0         http://www.sanil.co.kr    경기도
# 1       http://www.hshyosung.com  서울특별시
# 2                                 서울특별시
# 3                                 서울특별시
# 4                                 서울특별시
# ..                           ...    ...
# 0         http://www.yuhan.co.kr  서울특별시
# 1     http://www.cjlogistics.com  서울특별시
# 2     http://www.kyungbang.co.kr  서울특별시
# 3   http://www.eusu-holdings.com  서울특별시
# 4   http://www.hhic-holdings.com    경기도
#
# [2705 rows x 10 columns]

# %% [markdown]
# ## DB에 상장기업정보 저장하기

# %%
import os
from datetime import date

# %% [markdown]
# ## Pandas read_html로 표 데이터 가져오기

# %%
page = 1
page_size = 100
all_data =[]
final_result_df = pd.DataFrame()

url = "https://kind.krx.co.kr/corpgeneral/corpList.do"
payload = {
    'method': 'searchCorpList',
    'pageIndex': page,
    'currentPageSize': page_size,
    'comAbbrv': '',
    'beginIndex': '',
    'orderMode': 3,
    'orderStat': 'D',
    'isurCd': '',
    'repIsuSrtCd': '',
    'searchCodeType': '',
    'marketType': '',
    'searchType': 13,
    'industry': '',
    'fiscalYearEnd': 'all',
    'comAbbrvTmp': '',
    'location': 'all'
}
    
r = requests.get(url, params = payload)
print(r.url)

soup = bs(r.text, 'lxml')
# Out:
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=1&currentPageSize=100&comAbbrv=&beginIndex=&orderMode=3&orderStat=D&isurCd=&repIsuSrtCd=&searchCodeType=&marketType=&searchType=13&industry=&fiscalYearEnd=all&comAbbrvTmp=&location=all

# %%
df = pd.read_html(r.url)
df
# Out:
# [                 Unnamed: 0  \
#  0   ììì´ì¹ì¤í©31í¸
#  1    SKì¦ê¶ì 13í¸ì¤í©
#  2     ìì
#  ì¸ë¼í¨í±ì¤
#  3    ì´ë² ì¤í¸ì¤í©6í¸
#  4               ìíí¸ì
#  ..                      ...
#  95       ìì½íë¡ë¨¸í°
#  96    ìº¡ì¤í¤íí¸ëì¤
#  97                  íë¡ì
#  98    ìì¤ìì´ì¤í¸í
#  
#  99          ìì´ì§ëë
#
#                                             Unnamed: 1  \
#  0                           ê¸ìµ ì§ì ìë¹ì¤ì
#  1                           ê¸ìµ ì§ì ìë¹ì¤ì
#  2                        ê¸°ì´ ìì½ë¬¼ì§ ì ì¡°ì
#  3                           ê¸ìµ ì§ì ìë¹ì¤ì
#  4                 ìíí¸ì¨ì´ ê°ë° ë° ê³µê¸ì
#  ..                                                ...
#  95             ì¼ì°¨ì ì§ ë° ì´ì°¨ì ì§ ì ì¡°ì
#  96                                    ê¸°í ê¸ìµì
#  97             ìì°ê³¼í ë° ê³µí ì°êµ¬ê°ë°ì
#  98  êµ¬ì¡°ì© ê¸ìì í, í±í¬ ë° ì¦ê¸°ë°ì...
#  99                                 ë°ëì²´ ì ì¡°ì
#
#                                             Unnamed: 2  Unnamed: 3 Unnamed: 4  \
#  0                             ê¸ìµì§ììë¹ì¤ì  2024-07-26      12ì
#  1                     ê¸°ì
#  ì¸ìëª©ì  ì£¼ìíì¬  2024-07-25      12ì
#  2                  CellCor SFD/CD(ì¸í¬ë°°ìë°°ì§)  2024-07-15      12ì
#  3                     ê¸°ì
#  ì¸ìëª©ì  ì£¼ìíì¬  2024-07-12      12ì
#  4                              ê²ì ìíí¸ì¨ì´  2024-07-11      12ì
#  ..                                                ...         ...        ...
#  95  ë°°í°ë¦¬ ìê·¹ì¬ì© íµì¬ìì¬ íì´ëì...  2023-11-17      12ì
#  96    ë²¤ì²í¬ìì¡°í© ë± ì¡°í© ê²°ì± ë° ì´ì  2023-11-15      12ì
#  97                                 ë°ì´ì¤ìì½í  2023-11-15      12ì
#  98                                 ë°í¬íë ì´í¸  2023-11-13      12ì
#  99  ë¹ë©ëª¨ë¦¬ ë°ëì²´ ì¤ê³ë° ì ì¡°, ì ì...  2023-11-13      12ì
#
#     Unnamed: 5           Unnamed: 6       Unnamed: 7
#  0   ì´ìí                  NaN  ìì¸í¹ë³ì
#  1   ìì¨í                  NaN  ìì¸í¹ë³ì
#  2   ì´ìì¼                  NaN  ìì¸í¹ë³ì
#  3      ë°ì©                  NaN  ìì¸í¹ë³ì
#  4   ê¹íí  ííì´ì§ ë³´ê¸°  ìì¸í¹ë³ì
#  ..        ...                  ...              ...
#  95  ê¹ë³í  ííì´ì§ ë³´ê¸°     ê²½ìë¶ë
#  96  ì¡ìê°  ííì´ì§ ë³´ê¸°  ìì¸í¹ë³ì
#  97   ê¹ì¢
#  ê·  ííì´ì§ ë³´ê¸°  ìì¸í¹ë³ì
#  98   íì±ê·  ííì´ì§ ë³´ê¸°     ì¶©ì²­ë¶ë
#  99  ì´ì¢
#  ë¯¼  ííì´ì§ ë³´ê¸°        ê²½ê¸°ë
#
#  [100 rows x 8 columns]]

# %%
df = pd.read_html(r.text)
df
# Out:
# C:\Users\5-04\AppData\Local\Temp\ipykernel_17008\3940714850.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)
# [    Unnamed: 0                Unnamed: 1  \
#  0    엔에이치스팩31호                금융 지원 서비스업
#  1   SK증권제13호스팩                금융 지원 서비스업
#  2      엑셀세라퓨틱스               기초 의약물질 제조업
#  3     이베스트스팩6호                금융 지원 서비스업
#  4         시프트업            소프트웨어 개발 및 공급업
#  ..         ...                       ...
#  95      에코프로머티           일차전지 및 이차전지 제조업
#  96     캡스톤파트너스                    기타 금융업
#  97         프로젠           자연과학 및 공학 연구개발업
#  98     에스와이스틸텍  구조용 금속제품, 탱크 및 증기발생기 제조업
#  99       에이직랜드                   반도체 제조업
#
#                                Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
#  0                               금융지원서비스업  2024-07-26        12월        이시형
#  1                            기업인수목적 주식회사  2024-07-25        12월        임율표
#  2                 CellCor SFD/CD(세포배양배지)  2024-07-15        12월        이의일
#  3                            기업인수목적 주식회사  2024-07-12        12월         박용
#  4                               게임 소프트웨어  2024-07-11        12월        김형태
#  ..                                   ...         ...        ...        ...
#  95                배터리 양극재용 핵심소재 하이니켈 전구체  2023-11-17        12월        김병훈
#  96                   벤처투자조합 등 조합 결성 및 운영  2023-11-15        12월        송은강
#  97                                바이오의약품  2023-11-15        12월        김종균
#  98                                데크플레이트  2023-11-13        12월        홍성균
#  99  비메모리 반도체 설계및 제조, 전자회로 연구, 설계, 레이아웃 등  2023-11-13        12월        이종민
#
#     Unnamed: 6 Unnamed: 7
#  0         NaN      서울특별시
#  1         NaN      서울특별시
#  2         NaN      서울특별시
#  3         NaN      서울특별시
#  4     홈페이지 보기      서울특별시
#  ..        ...        ...
#  95    홈페이지 보기       경상북도
#  96    홈페이지 보기      서울특별시
#  97    홈페이지 보기      서울특별시
#  98    홈페이지 보기       충청북도
#  99    홈페이지 보기        경기도
#
#  [100 rows x 8 columns]]

# %%
# 오로지 표 형태로만 되어 있을 때만 사용이 가능하다

df = pd.read_html(r.text)[0]
df
# Out:
# C:\Users\5-04\AppData\Local\Temp\ipykernel_17008\241153109.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
#     Unnamed: 0                Unnamed: 1  \
# 0    엔에이치스팩31호                금융 지원 서비스업
# 1   SK증권제13호스팩                금융 지원 서비스업
# 2      엑셀세라퓨틱스               기초 의약물질 제조업
# 3     이베스트스팩6호                금융 지원 서비스업
# 4         시프트업            소프트웨어 개발 및 공급업
# ..         ...                       ...
# 95      에코프로머티           일차전지 및 이차전지 제조업
# 96     캡스톤파트너스                    기타 금융업
# 97         프로젠           자연과학 및 공학 연구개발업
# 98     에스와이스틸텍  구조용 금속제품, 탱크 및 증기발생기 제조업
# 99       에이직랜드                   반도체 제조업
#
#                               Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                               금융지원서비스업  2024-07-26        12월        이시형
# 1                            기업인수목적 주식회사  2024-07-25        12월        임율표
# 2                 CellCor SFD/CD(세포배양배지)  2024-07-15        12월        이의일
# 3                            기업인수목적 주식회사  2024-07-12        12월         박용
# 4                               게임 소프트웨어  2024-07-11        12월        김형태
# ..                                   ...         ...        ...        ...
# 95                배터리 양극재용 핵심소재 하이니켈 전구체  2023-11-17        12월        김병훈
# 96                   벤처투자조합 등 조합 결성 및 운영  2023-11-15        12월        송은강
# 97                                바이오의약품  2023-11-15        12월        김종균
# 98                                데크플레이트  2023-11-13        12월        홍성균
# 99  비메모리 반도체 설계및 제조, 전자회로 연구, 설계, 레이아웃 등  2023-11-13        12월        이종민
#
#    Unnamed: 6 Unnamed: 7
# 0         NaN      서울특별시
# 1         NaN      서울특별시
# 2         NaN      서울특별시
# 3         NaN      서울특별시
# 4     홈페이지 보기      서울특별시
# ..        ...        ...
# 95    홈페이지 보기       경상북도
# 96    홈페이지 보기      서울특별시
# 97    홈페이지 보기      서울특별시
# 98    홈페이지 보기       충청북도
# 99    홈페이지 보기        경기도
#
# [100 rows x 8 columns]

# %%
final_result_df
# Out:
#                               증권종류            회사명    종목코드  \
# 0                             유가증권          산일전기   062040
# 1                             유가증권       에이치에스효성   487570
# 2                      코스닥, 투자주의종목    엔에이치스팩31호    481890
# 3                              코스닥    SK증권제13호스팩   473950
# 4                              코스닥       엑셀세라퓨틱스   373110
# ..                             ...            ...     ...
# 0   유가증권, KTOP30, KOSPI200, KRX300       유한양행      000100
# 1           유가증권, KOSPI200, KRX300      CJ대한통운     000120
# 2                             유가증권            경방   000050
# 3                             유가증권         유수홀딩스   000700
# 4                             유가증권      한진중공업홀딩스   003480
#
#                                    업종  \
# 0   전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 1                              기타 금융업
# 2                          금융 지원 서비스업
# 3                          금융 지원 서비스업
# 4                         기초 의약물질 제조업
# ..                                ...
# 0                             의약품 제조업
# 1                           도로 화물 운송업
# 2                              종합 소매업
# 3                 회사 본부 및 경영 컨설팅 서비스업
# 4                   연료용 가스 제조 및 배관공급업
#
#                                                  주요제품         상장일  결산월   대표자명  \
# 0                                유입, 몰드, 주상, 건식 변압기 등  2024-07-29  12월    박동석
# 1                                                지주사업  2024-07-29  12월  조현상..
# 2                                            금융지원서비스업  2024-07-26  12월    이시형
# 3                                         기업인수목적 주식회사  2024-07-25  12월    임율표
# 4                              CellCor SFD/CD(세포배양배지)  2024-07-15  12월    이의일
# ..                                                ...         ...  ...    ...
# 0   의약품(삐콤씨, 안티푸라민, 렉라자, 로수바미브, 코푸시럽 등), 생활용품(유한락스...  1962-11-01  12월  대표이..
# 1   Contract Logistics, 포워딩, 항만하역, 해운, 택배국제특송, SCM...  1956-07-02  12월  신영수..
# 2           섬유류(면사,면혼방사,면직물,면혼방직물,화섬사,화섬직물) 제조,도매,수출입  1956-03-03  12월  김준,..
# 3                                                지주사업  1956-03-03  12월    송영규
# 4                                                지주회사  1956-03-03  12월  조남호..
#
#                             홈페이지     지역
# 0         http://www.sanil.co.kr    경기도
# 1       http://www.hshyosung.com  서울특별시
# 2                                 서울특별시
# 3                                 서울특별시
# 4                                 서울특별시
# ..                           ...    ...
# 0         http://www.yuhan.co.kr  서울특별시
# 1     http://www.cjlogistics.com  서울특별시
# 2     http://www.kyungbang.co.kr  서울특별시
# 3   http://www.eusu-holdings.com  서울특별시
# 4   http://www.hhic-holdings.com    경기도
#
# [2705 rows x 10 columns]

# %% [markdown]
# ## 기업정보 DB에 저장하기

# %%
# 2개 install
# !conda install PyMySQL      # mysql에 접속하게 해주는 라이브러리
# !conda install sqlalchemy   # sql을 쉬게 사용하게 해주는 라이브러리

# %%
from sqlalchemy import create_engine, text
import pymysql
pymysql.install_as_MySQLdb()
from dotenv import load_dotenv
load_dotenv(dotenv_path = ".env_db")
import os

# %%
engine = create_engine(f"{os.getenv('db')}+{os.getenv('dbtype')}://{os.getenv('id')}:{os.getenv('pw')}@{os.getenv('host')}")
conn = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# NoSuchModuleError                         Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 engine = create_engine(f"{os.getenv('db')}+{os.getenv('dbtype')}://{os.getenv('id')}:{os.getenv('pw')}@{os.getenv('host')}")
#       2 conn = engine.connect()
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\util\deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\create.py:550, in create_engine(url, **kwargs)
#     546 u = _url.make_url(url)
#     548 u, plugins, kwargs = u._instantiate_plugins(kwargs)
# --> 550 entrypoint = u._get_entrypoint()
#     551 _is_async = kwargs.pop("_is_async", False)
#     552 if _is_async:
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\url.py:758, in URL._get_entrypoint(self)
#     756 else:
#     757     name = self.drivername.replace("+", ".")
# --> 758 cls = registry.load(name)
#     759 # check for legacy dialects that
#     760 # would return a module with 'dialect' as the
#     761 # actual class
#     762 if (
#     763     hasattr(cls, "dialect")
#     764     and isinstance(cls.dialect, type)
#     765     and issubclass(cls.dialect, Dialect)
#     766 ):
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\util\langhelpers.py:375, in PluginLoader.load(self, name)
#     372         self.impls[name] = impl.load
#     373         return impl.load()
# --> 375 raise exc.NoSuchModuleError(
#     376     "Can't load plugin: %s:%s" % (self.group, name)
#     377 )
#
# NoSuchModuleError: Can't load plugin: sqlalchemy.dialects:mysql.pymyslq

# %%
# 데이터베이스에 접속 후 데이터베이스 생성
conn.execute(text('CREATE DATABASE IF NOT EXISTS korea_stock_info'))
conn.close()
# Out:
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In[90], line 2
#       1 # 데이터베이스에 접속 후 데이터베이스 생성
# ----> 2 conn.execute(text('CREATE DATABASE IF NOT EXISTS korea_stock_info'))
#       3 conn.close()
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\base.py:1418, in Connection.execute(self, statement, parameters, execution_options)
#    1416     raise exc.ObjectNotExecutableError(statement) from err
#    1417 else:
# -> 1418     return meth(
#    1419         self,
#    1420         distilled_parameters,
#    1421         execution_options or NO_OPTIONS,
#    1422     )
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\sql\elements.py:515, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     513     if TYPE_CHECKING:
#     514         assert isinstance(self, Executable)
# --> 515     return connection._execute_clauseelement(
#     516         self, distilled_params, execution_options
#     517     )
#     518 else:
#     519     raise exc.ObjectNotExecutableError(self)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\base.py:1640, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1628 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1629     "compiled_cache", self.engine._compiled_cache
#    1630 )
#    1632 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1633     dialect=dialect,
#    1634     compiled_cache=compiled_cache,
#    (...)
#    1638     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1639 )
# -> 1640 ret = self._execute_context(
#    1641     dialect,
#    1642     dialect.execution_ctx_cls._init_compiled,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     execution_options,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     elem,
#    1649     extracted_params,
#    1650     cache_hit=cache_hit,
#    1651 )
#    1652 if has_events:
#    1653     self.dispatch.after_execute(
#    1654         self,
#    1655         elem,
#    (...)
#    1659         ret,
#    1660     )
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\base.py:1813, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1811     conn = self._dbapi_connection
#    1812     if conn is None:
# -> 1813         conn = self._revalidate_connection()
#    1815     context = constructor(
#    1816         dialect, self, conn, execution_options, *args, **kw
#    1817     )
#    1818 except (exc.PendingRollbackError, exc.ResourceClosedError):
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\base.py:680, in Connection._revalidate_connection(self)
#     678     self._dbapi_connection = self.engine.raw_connection()
#     679     return self._dbapi_connection
# --> 680 raise exc.ResourceClosedError("This Connection is closed")
#
# ResourceClosedError: This Connection is closed

# %%
today = date.today()
today = str(today)

# %%
today = today.replace('-', '_')
today
# Out:
# '2024_07_29'

# %%
#DataFrame을 MySQL 테이블로 저장
engine = create_engine(f'{os.getenv('db')}+{os.getenv('dbtype')}://{os.getenv('id')}:{os.getenv('pw')}@{os.getenv('host')}/{os.getenv('database')}')
conn = engine.connect()
final_result_df.to_sql(f'{today}_stock_company_info2', con=conn, if_exists = 'append', index = False)
conn.close()
# Out:
#   Cell In[100], line 2
#     engine = create_engine(f'{os.getenv('db')}+{os.getenv('dbtype')}://{os.getenv('id')}:{os.getenv('pw')}@{os.getenv('host')}/{os.getenv('database')}')
#                                          ^
# SyntaxError: f-string: unmatched '('
