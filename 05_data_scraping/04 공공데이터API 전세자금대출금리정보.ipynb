# %%
import os
import sys
import urllib.request
from dotenv import load_dotenv
load_dotenv()
import pandas as pd
import requests

# %%
info = []
load_dotenv()
url = 'http://apis.data.go.kr/B551408/rent-loan-rate-info/rate-list'
serviceKey = os.getenv('serviceKey')
payload = dict(serviceKey = serviceKey, numOfRows = 10, pageNo = 1, dataType = 'JSON')
#params ={'serviceKey' : '5o4Mnwi/7yNflVHo7r2AdBMYfFd+oOw16UxQvEoR2Lo5a2kmVuhG9m3LzxutPZ3ygVscdUhG2aU3oixr+58BFw==', 'pageNo' : '1', 'numOfRows' : '10', 'dataType' : 'JSON' }
r = requests.get(url, params=payload)
print(r.url)
print(r.status_code)
data = r.json()
data
# Out:
# http://apis.data.go.kr/B551408/rent-loan-rate-info/rate-list?serviceKey=5o4Mnwi%2F7yNflVHo7r2AdBMYfFd%2BoOw16UxQvEoR2Lo5a2kmVuhG9m3LzxutPZ3ygVscdUhG2aU3oixr%2B58BFw%3D%3D&numOfRows=10&pageNo=1&dataType=JSON
# 200
# {'header': {'resultCode': '00', 'resultMsg': '정상'},
#  'body': {'pageNo': 1,
#   'totalCount': 18,
#   'numOfRows': 10,
#   'items': [{'bssYmdStart': '20240715',
#     'interest4_1': '0',
#     'interest3_2': '0',
#     'interest4_2': '0',
#     'interest2_1': '0',
#     'interest1_2': '0',
#     'interest3_1': '0',
#     'interest2_2': '0',
#     'interest1_1': '0',
#     'bssYmdEnd': '20240721',
#     'organId': '산업은행',
#     'callCenter': '1588-1500'},
#    {'bssYmdStart': '20240715',
#     'interest4_1': '0',
#     'interest3_2': '0',
#     'interest4_2': '0',
#     'interest2_1': '0',
#     'interest1_2': '0',
#     'interest3_1': '0',
#     'interest2_2': '0',
#     'interest1_1': '0',
#     'bssYmdEnd': '20240721',
#     'organId': '제주은행',
# ...

# %%
info = []
load_dotenv()
url = 'http://apis.data.go.kr/B551408/rent-loan-rate-info/rate-list'
serviceKey = os.getenv('serviceKey')
payload = dict(serviceKey = serviceKey, numOfRows = 10, pageNo = 1, dataType = 'JSON')
#params ={'serviceKey' : '5o4Mnwi/7yNflVHo7r2AdBMYfFd+oOw16UxQvEoR2Lo5a2kmVuhG9m3LzxutPZ3ygVscdUhG2aU3oixr+58BFw==', 'pageNo' : '1', 'numOfRows' : '10', 'dataType' : 'JSON' }
r = requests.get(url, params=payload)
print(r.url)
print(r.status_code)
data = r.json()
result = pd.json_normalize(data["body"]["items"])
#data
result
# Out:
# http://apis.data.go.kr/B551408/rent-loan-rate-info/rate-list?serviceKey=5o4Mnwi%2F7yNflVHo7r2AdBMYfFd%2BoOw16UxQvEoR2Lo5a2kmVuhG9m3LzxutPZ3ygVscdUhG2aU3oixr%2B58BFw%3D%3D&numOfRows=10&pageNo=1&dataType=JSON
# 200
#   bssYmdStart interest4_1 interest3_2 interest4_2 interest2_1 interest1_2  \
# 0    20240715           0           0           0           0           0
# 1    20240715           0           0           0           0           0
# 2    20240715           0           0           0           0           0
# 3    20240715           0           0           0           0           0
# 4    20240715           0           0           0           0           0
# 5    20240715        4.28           0           0           0           0
# 6    20240715        5.04           0           0           0           0
# 7    20240715        3.46           0           0           0           0
# 8    20240715        2.76           0           0           0           0
# ...

# %%
info = []
load_dotenv()
url = 'http://apis.data.go.kr/B551408/rent-loan-rate-info/rate-list'
serviceKey = os.getenv('serviceKey')
payload = dict(serviceKey = serviceKey, numOfRows = 10, pageNo = 1, dataType = 'JSON')
#params ={'serviceKey' : '5o4Mnwi/7yNflVHo7r2AdBMYfFd+oOw16UxQvEoR2Lo5a2kmVuhG9m3LzxutPZ3ygVscdUhG2aU3oixr+58BFw==', 'pageNo' : '1', 'numOfRows' : '10', 'dataType' : 'JSON' }
r = requests.get(url, params=payload)
print(r.url)

print(r.status_code)
if(r.status_code == 200):
    data = r.json()
    print(type(data))

result = pd.json_normalize(data["body"]["items"])

#result.to_csv("guarantee_data_result.csv", encoding="utf-8") 한글이 깨져서 보임
result.to_csv("guarantee_data_result.csv", encoding="euc-kr")
# Out:
# http://apis.data.go.kr/B551408/rent-loan-rate-info/rate-list?serviceKey=5o4Mnwi%2F7yNflVHo7r2AdBMYfFd%2BoOw16UxQvEoR2Lo5a2kmVuhG9m3LzxutPZ3ygVscdUhG2aU3oixr%2B58BFw%3D%3D&numOfRows=10&pageNo=1&dataType=JSON
# 200
# <class 'dict'>

# %%
import os
for key, value in os.environ.items():
    print(f'{key} : {value}')
# Out:
# ALLUSERSPROFILE : C:\ProgramData
# APPDATA : C:\Users\5-04\AppData\Roaming
# COMMONPROGRAMFILES : C:\Program Files\Common Files
# COMMONPROGRAMFILES(X86) : C:\Program Files (x86)\Common Files
# COMMONPROGRAMW6432 : C:\Program Files\Common Files
# COMPUTERNAME : 5-04
# COMSPEC : C:\WINDOWS\system32\cmd.exe
# CONDA_DEFAULT_ENV : fintech
# CONDA_EXE : C:\Users\5-04\miniforge3\Scripts\conda.exe
# CONDA_PREFIX : C:\Users\5-04\miniforge3\envs\fintech
# CONDA_PREFIX_1 : C:\Users\5-04\miniforge3
# CONDA_PROMPT_MODIFIER : (fintech)
# CONDA_PYTHON_EXE : C:\Users\5-04\miniforge3\python.exe
# CONDA_SHLVL : 2
# DRIVERDATA : C:\Windows\System32\Drivers\DriverData
# FPS_BROWSER_APP_PROFILE_STRING : Internet Explorer
# FPS_BROWSER_USER_PROFILE_STRING : Default
# HOMEDRIVE : C:
# HOMEPATH : \Users\5-04
# LOCALAPPDATA : C:\Users\5-04\AppData\Local
# LOGONSERVER : \\5-04
# NUMBER_OF_PROCESSORS : 12
# ONEDRIVE : C:\Users\5-04\OneDrive
# OS : Windows_NT
# ...
